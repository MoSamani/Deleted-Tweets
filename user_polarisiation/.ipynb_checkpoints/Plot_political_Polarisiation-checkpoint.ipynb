# %%
#CSV Bibliothek importieren 
import csv
#Pandas importieren und als pd bezeichnen
import pandas as pd
#Numpy importieren und als np bezeichnen 
import numpy as np
#Json Biliothek importieren
import json
#Obere Schranke für die Größe der Daten auf 100,000,000 setzen  
csv.field_size_limit(100000000)
#Maximale Anzahl von Zeilen und Spalten Zeigen 
pd.options.display.max_columns = None
pd.options.display.max_rows = None
#Um die Zeiträume bearbeiten zu können
from datetime import datetime
#Seaborn für die Plot importieren
import seaborn as sns
#matplotlib Importieren und als plt bezeichnen
import matplotlib.pyplot as plt
#Macht die Plots inline
# %matplotlib inline 
#dates importieren, um Zeitstempel bearbeiten zu können
import matplotlib.dates as mdates
#tick importieren
import matplotlib.ticker as tick
#Die Nachkommastellen auf 4 Zashlen einschränken
pd.options.display.float_format = '{:.4f}'.format

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import ScalarFormatter
from matplotlib import ticker

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***

# %% [markdown]
# # TweetsCov19
# ## KDE-Plot

# %% [markdown]
# ***

# %%
path = '../data/tweetsCov19_polarized_users_deletionratio_reputation.tsv'

df_tweetscov19 = pd.read_csv(path, sep='\t', error_bad_lines=False, names=[ "Username", 'politic', 'science', 'moderacy', 'Deletion_ratio', 'Reputation', 'is_deleted'])

print('Shape :', df_tweetscov19.shape)
df_tweetscov19.head()
# Out:
# Shape : (2216076, 7)
#                            Username  politic  science  moderacy  \
# 0  00008ca06f863b962f72cc9167d7978a  -1.0000   0.0000   -1.0000
# 1  00008de3f61d5f04329ee6867d5475b9  -1.0000   0.0000    1.0000
# 2  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 3  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 4  00016e20a3865cb74581803c27d27b89  -1.0000   0.0000   -1.0000
#
#    Deletion_ratio  Reputation  is_deleted
# 0          0.0000      0.1828       False
# 1          1.0000      0.6003        True
# 2          1.0000      0.3327        True
# 3          1.0000      0.3327        True
# 4          0.0000      0.5896       False

# %%
print('Alle Users:', df_tweetscov19.Username.unique().size)
# Out:
# Alle Users: 203725

# %%
df_tweetscov19 = df_tweetscov19[df_tweetscov19['politic'] != 0]

print('Shape: ', df_tweetscov19.shape)
df_tweetscov19.head()
# Out:
# Shape:  (1973156, 7)
#                            Username  politic  science  moderacy  \
# 0  00008ca06f863b962f72cc9167d7978a  -1.0000   0.0000   -1.0000
# 1  00008de3f61d5f04329ee6867d5475b9  -1.0000   0.0000    1.0000
# 2  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 3  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 4  00016e20a3865cb74581803c27d27b89  -1.0000   0.0000   -1.0000
#
#    Deletion_ratio  Reputation  is_deleted
# 0          0.0000      0.1828       False
# 1          1.0000      0.6003        True
# 2          1.0000      0.3327        True
# 3          1.0000      0.3327        True
# 4          0.0000      0.5896       False

# %%
df_tweetscov19_del = df_tweetscov19[df_tweetscov19['is_deleted']==True]
df_tweetscov19_undel = df_tweetscov19[df_tweetscov19['is_deleted']==False]

# %%
print('Deleted Tweets:', df_tweetscov19_del.shape)
print('Non-deleted Tweets:', df_tweetscov19_undel.shape)
# Out:
# Deleted Tweets: (350401, 7)
# Non-deleted Tweets: (1622755, 7)

# %%
print('Alle Users:', df_tweetscov19.Username.unique().size)

df = df_tweetscov19[df_tweetscov19['politic']>0]
print('Alle kon. Users in gesammten Tweets:', df.Username.unique().size)

df = df_tweetscov19[df_tweetscov19['politic']<0]
print('Alle lib. Users in gesammten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 171353
# Alle kon. Users in gesammten Tweets: 36179
# Alle lib. Users in gesammten Tweets: 135174

# %%
print('Alle Users:', df_tweetscov19_del.Username.unique().size)

df = df_tweetscov19_del[df_tweetscov19_del['politic']>0]
print('Alle kon. Users in gelöschten Tweets:', df.Username.unique().size)

df = df_tweetscov19_del[df_tweetscov19_del['politic']<0]
print('Alle lib. Users in gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 38986
# Alle kon. Users in gelöschten Tweets: 10989
# Alle lib. Users in gelöschten Tweets: 27997

# %%
print('Alle Users:', df_tweetscov19_undel.Username.unique().size)

df = df_tweetscov19_undel[df_tweetscov19_undel['politic']>0]
print('Alle kon. Users in nicht gelöschten Tweets:', df.Username.unique().size)

df = df_tweetscov19_undel[df_tweetscov19_undel['politic']<0]
print('Alle lib. Users in nicht gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 147054
# Alle kon. Users in nicht gelöschten Tweets: 28368
# Alle lib. Users in nicht gelöschten Tweets: 118686

# %%
def plot_kdeplot_v1(df, hue, x, x_label, titel, name): 
    ax = sns.kdeplot(data=df, x=x, hue=hue, fill=True, legend= False)
    #ax = sns.kdeplot(data=df, x=x, hue=hue, multiple="fill")
    
    
    ax.set_ylabel(ylabel='Density', fontsize=15)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=15)

    plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(0.2, 1.13), ncol=2, loc=2, borderaxespad=0, fontsize=12)
    #g.set_title(titel, fontweight="bold")
    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(1.02, 1.), loc=2, borderaxespad=0)
    plt.tight_layout()
    plt.savefig('../plots/'+name+'.pdf')

# %%
df = df_tweetscov19[['is_deleted', 'politic']]
plot_kdeplot_v1(df, 'is_deleted','politic' ,'Political' ,'TweetsCov19', 'kdeplot_tweetscov19_politic_all_tweets_conditionaldistribution')

# %%
def plot_kdeplot_v2(df, hue, x, x_label, titel, name):
    #sns.color_palette("RdPu", 10)
    ax = sns.kdeplot(data=df, x=x, hue=hue, multiple="fill")
    
    
    ax.set_ylabel(ylabel='Density', fontsize=15)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=15)

    plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(0.2, 1.13), ncol=2, loc=2, borderaxespad=0, fontsize=12)
    #g.set_title(titel, fontweight="bold")
    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(1.02, 1.), loc=2, borderaxespad=0)
    plt.tight_layout()
    plt.savefig('../plots/'+name+'.pdf')

# %%
df = df_tweetscov19[['is_deleted', 'politic']]
plot_kdeplot_v2(df, 'is_deleted','politic' ,'Political' ,'TweetsCov19', 'kdeplot_tweetscov19_politic_all_tweets_Normalizethestackeddistribution')

# %%
def plot_kdeplot_v3(df, hue, x, x_label, titel, name): 
    #ax = sns.kdeplot(data=df, x=x, hue=hue, multiple="fill")
    ax = sns.kdeplot(
    data=df, x=x, hue=hue,
    cumulative=True, common_norm=False, common_grid=True,
    )
    
    ax.set_ylabel(ylabel='Density', fontsize=15)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=15)

    plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(0.2, 1.13), ncol=2, loc=2, borderaxespad=0, fontsize=12)
    #g.set_title(titel, fontweight="bold")
    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(1.02, 1.), loc=2, borderaxespad=0)
    plt.tight_layout()
    plt.savefig('../plots/'+name+'.pdf')

# %%
df = df_tweetscov19[['is_deleted', 'politic']]
plot_kdeplot_v3(df, 'is_deleted','politic' ,'Political' ,'TweetsCov19', 'kdeplot_tweetscov19_politic_all_tweets_cumulativedistributionfunction')

# %% [markdown]
# ***

# %% [markdown]
# # Histogram

# %% [markdown]
# ***

# %%
def plot_histogram(df, titel):
    
    #figure(figsize=(8, 6), dpi=80)
    
    fig, ax = plt.subplots()
    colors = ['b', 'r']
    labels = ['Liberale', 'konservativ']
    
    N, bins, patches = ax.hist(df, bins=10, color = 'gray')
    for i in range(0,5):
        patches[i].set_facecolor('b')
    patches[1].set_label('Liberal')
    for i in range(5,len(patches)):
        patches[i].set_facecolor('r')
    patches[9].set_label('Conservative')
        
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    figsize=(8, 6)
    plt.ylabel('Number of users', fontsize=16)
    ax.set_xlabel(xlabel='Politic', fontsize=17)

    #plt.title('Political polarization', fontsize=18)
    plt.legend( fontsize=12)
    plt.tight_layout()

    plt.savefig('../plots/'+titel+'.pdf')

# %%
df = df_tweetscov19.drop_duplicates(subset=['Username'])
plot_histogram(df['politic'],'hist_tweetsCov19_political_polarized_users(alltweets)')

# %%
df = df_tweetscov19_del.drop_duplicates(subset=['Username'])
plot_histogram(df['politic'],'hist_tweetsCov19_political_polarized_users(deletedtweets)')

# %%
df = df_tweetscov19_undel.drop_duplicates(subset=['Username'])
plot_histogram(df['politic'],'hist_tweetsCov19_political_polarized_users(nondeletedtweets)')

# %% [markdown]
# ----

# %%
#Labels und Pfad 
TweetsCov19_labels = ['Tweet_Id', "Benutzername", 'Zeitstempel', 'Abonnenten', 'Abonnierten', 'Retweets', 'Likes', 'Entities', 'Stimmung', 'Erwähnungen', 'Hashtags', 'URLs', 'Text', 'Ist_gelöscht', 'Anzahl der Erwähnungen', 'Anzahl der Hashtags', 'Anzahl der URLs', 'Domäne', 'Textlänge', 'Lesbarkeit','Vader_neg', 'Vader_neu', 'Vader_pos', 'Vader_Mittelwert', 'Emojis', 'Anzahl der Emojis',  'Emoji_neg', 'Emoji_neu', 'Emoji_pos', 'Emoji_Mittelwert', 'Emoji_bearbeiteten']
TweetsCov19_Pfad =  'C:/Mo//tweetDB/data_sample/tweetscov19_sample/TweetsCov19_stichprobe_final.tsv'

# %%
#Stichprobe von Tweetscov19-Stichprobe lesen

df_tweetscov19 = pd.read_csv(TweetsCov19_Pfad, sep='\t', error_bad_lines=False, names=TweetsCov19_labels)
print('Form:', df_tweetscov19.shape)
df_tweetscov19.head()
# Out:
# Form: (9409841, 31)
#               Tweet_Id                      Benutzername  \
# 0  1178791637348212736  c57d4fb895c5f4a33d2a2b24709f93b5
# 1  1178791641601232896  627f7d4ef584ba33a676a4ebcb861cdb
# 2  1178791643509612547  7966d5716c1c4f33591b17755184e3d6
# 3  1178791644214235137  f17996c036ed4cd981f5448fe00d9ed2
# 4  1178791645371875329  32a54e5f6d8a67de1bffd2e689594dc8
#
#                  Zeitstempel  Abonnenten  Abonnierten  Retweets  Likes  \
# 0  2019-09-30 22:00:01+00:00      764191          132        19    180
# 1  2019-09-30 22:00:02+00:00      321189        26833        32     43
# 2  2019-09-30 22:00:03+00:00       14209        10623        90    182
# 3  2019-09-30 22:00:03+00:00     2264986          655        60    528
# 4  2019-09-30 22:00:03+00:00         171          138        33    117
#
#                                             Entities Stimmung    Erwähnungen  \
# 0                  foodie:Foodie:-2.096663959988218;     1 -1          null;
# 1  mainland china:Mainland_China:-1.6252666161640...     1 -1          null;
# 2  brexit:Brexit:-1.582809637810362;hear hear:Hea...     1 -2          null;
# 3                                              null;     3 -1  amstandardca.
# 4  my family:My_Family:-2.6353832182503094;roll t...     4 -1          null;
#
#          Hashtags                                               URLs  \
# 0  HalloweenTime?                                              null;
# 1        HongKong  https://www.catholicnewsagency.com/news/amid-h...
# 2          Brexit                                              null;
# 3        BlueJays                                              null;
# 4           null;                                              null;
#
#                                                 Text  Ist_gelöscht  \
# 0  Has your appetite materialized just as fast as...          True
# 1  The persecution of Catholics in mainland China...         False
# 2  Hear, hear..\nEmily: You were an outspoken cri...         False
# 3  We wrapped up the season with a WINNING week! ...         False
# 4  Super excited to announce that I will be spend...         False
#
#    Anzahl der Erwähnungen  Anzahl der Hashtags  Anzahl der URLs  \
# 0                       0                    1                0
# 1                       0                    1                1
# 2                       0                    1                0
# 3                       1                    1                0
# 4                       0                    0                0
#
#                    Domäne  Textlänge  Lesbarkeit  Vader_neg  Vader_neu  \
# 0                       0        155     76.5530    -0.0000     1.0000
# 1  catholicnewsagency.com        204     29.4680    -0.0000     0.9190
# 2                       0        163     79.5340    -0.2020     0.7980
# 3                       0        132     85.8890    -0.0000     0.6240
# 4                       0        257     61.2030    -0.0000     0.7650
#
#    Vader_pos  Vader_Mittelwert      Emojis  Anzahl der Emojis  Emoji_neg  \
# 0     0.0000            0.0000          []                  0    -0.0000
# 1     0.0810            0.3182          []                  0    -0.0000
# 2     0.0000           -0.6486          []                  0    -0.0000
# 3     0.3760            0.8633          []                  0    -0.0000
# 4     0.2350            0.9117  ['🐘', '🔴']                  2    -0.0150
#
#    Emoji_neu  Emoji_pos  Emoji_Mittelwert  Emoji_bearbeiteten
# 0     0.0000     0.0000            0.0000              0.0000
# 1     0.0000     0.0000            0.0000              0.0000
# 2     0.0000     0.0000            0.0000              0.0000
# 3     0.0000     0.0000            0.0000              0.0000
# 4     0.2650     0.2200            0.2235              2.0000

# %% [markdown]
# ***

# %% [markdown]
# # Hexabin
# ### Reputation-Polarisierung

# %%
from pylab import *

def plot_hexbin_reputaion(df, hue,x ,x_label, color, titel):
    
    ax = df.plot.hexbin(x=x, y="Reputation",cmap=color, gridsize=20, sharex=False)
    ax.set_ylabel(ylabel='Reputaion', fontsize=17)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=16)
    
    
  
    
    f = plt.gcf()
    cax = f.get_axes()[1]
    #cax.set_ylabel('test')
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    #formatter.set_useOffset(1000)
    
    cax.tick_params(labelsize=16)
    #cax.ticklabel_format(style='scientific', useMathText=True)
    
    cax.xaxis.set_major_formatter(formatter)
    cax.yaxis.set_major_formatter(formatter)
    
    fig = ax.get_figure()
    fig.tight_layout()

    fig.savefig('../plots/'+titel+'.pdf')
    plt.show()

# %%
df = df_tweetscov19[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

plot_hexbin_reputaion(df, 'is_deleted','politic', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(alltweets)')

# %%
plot_hexbin_reputaion(df_del, 'is_deleted','politic', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(deletedtweets)')

# %%
plot_hexbin_reputaion(df_undel, 'is_deleted','politic', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(nondeletedtweets)')

# %% [markdown]
# ***

# %%
def plot_heatmap(df, x, y,x_label, color, titel):
    
    df = df[[x, y]]
    df = df.round(2)
    zeros = (df == 0).sum()
    print('Number of zeros: \n', zeros)
    #df.replace(0, np.nan, inplace=True)
    df = df.groupby([x, y]).size().reset_index(name='count')

    
    heatmap_data = df.pivot(y, x, "count")
    heatmap_data = heatmap_data.sort_values(by=y,ascending=False)

    color = plt.get_cmap(color)   # default color
    color.set_bad('white')    # if the value is bad the color would be lightblue instead of white

    sns.set(font_scale=2)
    f, ax = plt.subplots(figsize=(7, 5))
    sns.heatmap(heatmap_data, square=False, norm= matplotlib.colors.LogNorm(), cbar_kws={"shrink": 1}, cmap=color)
    ax.tick_params(labelsize=15)
    ax.set_ylabel(ylabel='Reputaion', fontsize=17)
    ax.set_xlabel(xlabel=x_label, fontsize=17)
    #ax.figure.axes[-1].set_ylabel('Number of tweets', size=20)
    #ax.figure.axes[-1].set_ylabel( size=20)

    fig = ax.get_figure()
    fig.tight_layout()

    fig.savefig('../plots/heatmaps/'+titel+'.pdf')
    plt.show()

# %%
df = df_tweetscov19[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

# %%
plot_heatmap(df,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetscov19_political_reputation(alltweets)')
# Out:
# Number of zeros:
#  politic          0
# Reputation    5547
# dtype: int64

# %%
plot_heatmap(df_del,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetscov19_political_reputation(deletedtweets)')
# Out:
# Number of zeros:
#  politic          0
# Reputation    2817
# dtype: int64

# %%
plot_heatmap(df_undel,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetscov19_political_reputation(nondeletedtweets)')
# Out:
# Number of zeros:
#  politic          0
# Reputation    2730
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # TweetKB
# ## KDE-Plot

# %% [markdown]
# ***

# %%
path = '../data/tweetsKB_polarized_users_deletionratio_reputation.tsv'

df_tweetskb = pd.read_csv(path, sep='\t', error_bad_lines=False, names=["Username", 'politic', 'science', 'moderacy', 'Deletion_ratio', 'Reputation', 'is_deleted'])

print('Shape :', df_tweetskb.shape)
df_tweetskb.head()
# Out:
# Shape : (552665, 7)
#           Username  politic  science  moderacy  Deletion_ratio  Reputation  \
# 0       0000Condor  -1.0000   0.0000    1.0000          1.0000      0.2556
# 1  007newsandviews  -1.0000   0.0000   -1.0000          0.0000      0.4828
# 2       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 3       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 4       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
#
#    is_deleted
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False

# %%
print('Alle Users:', df_tweetskb.Username.unique().size)
# Out:
# Alle Users: 78638

# %%
df_tweetskb = df_tweetskb[df_tweetskb['politic'] != 0]

print('Shape: ', df_tweetskb.shape)
df_tweetskb.head()
# Out:
# Shape:  (478718, 7)
#           Username  politic  science  moderacy  Deletion_ratio  Reputation  \
# 0       0000Condor  -1.0000   0.0000    1.0000          1.0000      0.2556
# 1  007newsandviews  -1.0000   0.0000   -1.0000          0.0000      0.4828
# 2       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 3       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 4       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
#
#    is_deleted
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False

# %%
df_tweetskb_del = df_tweetskb[df_tweetskb['is_deleted']==True]
df_tweetskb_undel = df_tweetskb[df_tweetskb['is_deleted']==False]

# %%
print('Deleted Tweets:', df_tweetskb_del.shape)
print('Non-deleted Tweets:', df_tweetskb_undel.shape)
# Out:
# Deleted Tweets: (100976, 7)
# Non-deleted Tweets: (377742, 7)

# %%
print('Alle Users:', df_tweetskb.Username.unique().size)

df = df_tweetskb[df_tweetskb['politic']>0]
print('Alle kon. Users in gesammten Tweets:', df.Username.unique().size)

df = df_tweetskb[df_tweetskb['politic']<0]
print('Alle lib. Users in gesammten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 66027
# Alle kon. Users in gesammten Tweets: 14967
# Alle lib. Users in gesammten Tweets: 51060

# %%
print('Alle Users:', df_tweetskb_del.Username.unique().size)

df = df_tweetskb_del[df_tweetskb_del['politic']>0]
print('Alle kon. Users in gelöschten Tweets:', df.Username.unique().size)

df = df_tweetskb_del[df_tweetskb_del['politic']<0]
print('Alle lib. Users in gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 14796
# Alle kon. Users in gelöschten Tweets: 4405
# Alle lib. Users in gelöschten Tweets: 10391

# %%
print('Alle Users:', df_tweetskb_undel.Username.unique().size)

df = df_tweetskb_undel[df_tweetskb_undel['politic']>0]
print('Alle kon. Users in nicht gelöschten Tweets:', df.Username.unique().size)

df = df_tweetskb_undel[df_tweetskb_undel['politic']<0]
print('Alle lib. Users in nicht gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 55227
# Alle kon. Users in nicht gelöschten Tweets: 11426
# Alle lib. Users in nicht gelöschten Tweets: 43801

# %%
df = df_tweetskb[['is_deleted', 'politic']]
plot_kdeplot_v1(df, 'is_deleted','politic' ,'Politic' ,'TweetsCov19', 'kdeplot_tweetskb_politic_alltweets_conditionaldistribution')

# %%
df = df_tweetskb[['is_deleted', 'politic']]
plot_kdeplot_v2(df, 'is_deleted','politic' ,'Politic' ,'TweetsCov19', 'kdeplot_tweetskb_politic_alltweets_Normalizethestackeddistribution')

# %%
df = df_tweetskb[['is_deleted', 'politic']]
plot_kdeplot_v3(df, 'is_deleted','politic' ,'Politic' ,'TweetsCov19', 'kdeplot_tweetskb_politic_alltweets_cumulativedistributionfunction')

# %% [markdown]
# # Histogram

# %% [markdown]
# ***

# %%
def plot_histogram_kb(df, titel):
    #figure(figsize=(8, 6), dpi=80)
    
    fig, ax = plt.subplots()
    colors = ['b', 'r']
    #labels = ['Liberale', 'konservativ']
    
    N, bins, patches = ax.hist(df, bins=10, color = 'gray')
    for i in range(0,5):
        patches[i].set_facecolor('royalblue')
    patches[1].set_label('Liberal')
    for i in range(5,len(patches)):
        patches[i].set_facecolor('crimson')
    patches[9].set_label('Conservative')
    
          
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    figsize=(8, 6)
    plt.ylabel('Number of users', fontsize=16)
    ax.set_xlabel(xlabel='Politic', fontsize=17)

    #plt.title('Political polarization', fontsize=18)
    plt.legend( fontsize=12)
    plt.tight_layout()
    plt.savefig('../plots/'+titel+'.pdf')

# %%
#All Tweets
df = df_tweetskb.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['politic'],'hist_tweetsKB_political_polarized_users(alltweets)')

# %%
df = df_tweetskb_del.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['politic'],'hist_tweetsKB_political_polarized_users(deletedtweets)')

# %%
df = df_tweetskb_undel.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['politic'],'hist_tweetsKB_political_polarized_users(nondeletedtweets)')

# %% [markdown]
# ***

# %% [markdown]
# # Hexabin
# ### Reputation-Polarisierung

# %% [markdown]
# ***

# %%
df = df_tweetskb[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

plot_hexbin_reputaion(df, 'is_deleted', 'politic', 'Politic', 'Blues', 'Hexabinplot_tweetskb_political_reputation(alltweets)')

# %%
plot_hexbin_reputaion(df_del, 'is_deleted', 'politic', 'Politic', 'Blues','Hexabinplot_tweetskb_political_reputation(deletedtweets)')

# %%
plot_hexbin_reputaion(df_undel, 'is_deleted', 'politic', 'Politische', 'Blues', 'Hexabinplot_tweetskb_political_reputation(nondeletedtweets)')

# %%
pfad_tsv = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/TweetsFormodel_final/tweetskb_tweet_features_for_model.tsv'

df_tweetskb = pd.read_csv(pfad_tsv, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment_negative', 'Sentiment_neutral', 'Sentiment_positive', 'Sentiment_compound', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_political_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_posted_tweets', 'user_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'is_deleted', 'user_sentiment_average', 'tweet_sentiment_deviation', 'tweet_political_polarisation_deviation', 'tweet_science_polarisation_deviation', 'tweet_moderacy_polarisation_deviation'])

print('Shape :', df_tweetskb.shape)
df_tweetskb.head()
# Out:
# Shape : (9409841, 95)
#               Tweet_Id         Username  Retweets  Favorites  \
# 0  1178791636039589889         DCComics         2         13
# 1  1178791641265639424       seanberdyz         4         20
# 2  1178791640573579264  AnArtistAtBirth         0          0
# 3  1178791644797255680     lagosboygang         0          0
# 4  1178791648056217600     Phenom_Hoops         1          1
#
#    Sentiment_negative  Sentiment_neutral  Sentiment_positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.0000             1.0000              0.0000
# 2             -0.0000             1.0000              0.0000
# 3             -0.0000             1.0000              0.0000
# 4             -0.0000             0.9420              0.0580
#
#    Sentiment_compound  Hashtags_num  Mentions_num  Text_len  URLs_num  \
# 0              0.0000             1             1       192         1
# 1              0.0000             0             0        73         1
# 2              0.0000             1             0       128         0
# 3              0.0000             0             2        77         0
# 4              0.2263             1             0       227         1
#
#    readability  Emoji_num  Emoji_sent  tweet_political_polarisation  \
# 0      70.3500          0      0.0000                        0.0000
# 1      82.3900          0      0.0000                        0.0000
# 2     123.7550          0      0.0000                        0.0000
# 3     105.9210          0      0.0000                        0.0000
# 4      65.9430          0      0.0000                        0.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000  2.8600  0.0000
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000  0.0000  0.0000
# 3                      0.0000                       0.0000  0.0000  0.0000
# 4                      0.0000                       0.0000 12.8200  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  2.8600  0.0000 0.0000 2.8600   0.0000 0.0000 0.0000    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 4  0.0000  0.0000 7.6900 0.0000   2.5600 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    7.6900 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 1  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 2  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 3  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   7.6900
# 4  0.0000  2.5600  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   2.5600
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000       2.8600  0.0000 0.0000  2.8600 0.0000
# 1  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 2  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 3  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  5.1300       0.0000  0.0000 5.1300  0.0000 0.0000
#
#    focuspast  focuspresent  focusfuture      i     we    you  shehe   they  \
# 0     5.7100        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 1     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 2     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 3     7.6900        7.6900       7.6900 0.0000 0.0000 0.0000 0.0000 0.0000
# 4     2.5600        2.5600       0.0000 0.0000 0.0000 7.6900 0.0000 2.5600
#
#     ipron  article   prep  auxverb  adverb   conj  negate   verb    adj  \
# 0 11.4300  11.4300 0.0000   2.8600  2.8600 0.0000  5.7100 8.5700 5.7100
# 1  0.0000   0.0000 0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 2  0.0000   0.0000 0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 3  7.6900   0.0000 7.6900   0.0000  0.0000 0.0000  7.6900 0.0000 0.0000
# 4  0.0000   2.5600 5.1300   0.0000  5.1300 0.0000 10.2600 2.5600 0.0000
#
#    compare  interrog  number  quant    see   hear   feel  motion  space  \
# 0   0.0000    0.0000  2.8600 2.8600 0.0000 0.0000 0.0000 11.4300 2.8600
# 1   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 2   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 3   0.0000    7.6900  0.0000 7.6900 0.0000 0.0000 0.0000  0.0000 0.0000
# 4   2.5600    0.0000  0.0000 0.0000 0.0000 0.0000 2.5600  7.6900 5.1300
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                      -1.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_posted_tweets  user_deleted_tweets  \
# 0                     -1.0000                  42                    0
# 1                      0.0000                   3                    1
# 2                      0.0000                   1                    1
# 3                      0.0000                   5                    5
# 4                      0.0000                   7                    0
#
#    user_Deletion_ratio  user_Reputation  is_deleted  user_sentiment_average  \
# 0               0.0000           0.9998       False                  0.1736
# 1               0.3333           0.7068        True                  0.1273
# 2               1.0000           0.3364        True                  0.0000
# 3               1.0000           0.2896        True                  0.0529
# 4               0.0000           0.9387       False                  0.1517
#
#    tweet_sentiment_deviation  tweet_political_polarisation_deviation  \
# 0                     0.0000                                  1.0000
# 1                     0.0000                                  0.0000
# 2                     0.0000                                  0.0000
# 3                     0.0000                                  0.0000
# 4                     0.0746                                  0.0000
#
#    tweet_science_polarisation_deviation  tweet_moderacy_polarisation_deviation
# 0                                0.0000                                 1.0000
# 1                                0.0000                                 0.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
df_tweetskb = df_tweetskb[df_tweetskb['user_political_polarisation'] != 0]

print('Shape: ', df_tweetskb.shape)
df_tweetskb.head()
# Out:
# Shape:  (478718, 95)
#                Tweet_Id        Username  Retweets  Favorites  \
# 0   1178791636039589889        DCComics         2         13
# 9   1178791665735208960  dailytelegraph         0          0
# 58  1178792055822311426     Londonscot3         0          0
# 60  1178792079155179520       Mauerback        39         60
# 88  1178792395573383168     dailyherald         0          0
#
#     Sentiment_negative  Sentiment_neutral  Sentiment_positive  \
# 0              -0.0000             1.0000              0.0000
# 9              -0.1000             0.8150              0.0850
# 58             -0.1360             0.7860              0.0790
# 60             -0.0000             0.7580              0.2420
# 88             -0.1960             0.8040              0.0000
#
#     Sentiment_compound  Hashtags_num  Mentions_num  Text_len  URLs_num  \
# 0               0.0000             1             1       192         1
# 9              -0.1280             0             0       201         1
# 58             -0.4019             0             4       268         0
# 60              0.8625             0             1       209         1
# 88             -0.5994             0             1       124         1
#
#     readability  Emoji_num  Emoji_sent  tweet_political_polarisation  \
# 0       70.3500          0      0.0000                        0.0000
# 9       46.2550          0      0.0000                        1.0000
# 58      17.5730          1      0.5220                        0.0000
# 60      36.5100          0      0.0000                        0.0000
# 88      75.5000          0      0.0000                        1.0000
#
#     tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                       0.0000                       0.0000  2.8600  0.0000
# 9                       0.0000                       1.0000  0.0000  0.0000
# 58                      0.0000                       0.0000  7.8900  0.0000
# 60                      0.0000                       0.0000  2.9400  0.0000
# 88                      0.0000                      -1.0000 14.2900  0.0000
#
#     friend  female   male   work  leisure   home  money  relegion  death  \
# 0   2.8600  0.0000 0.0000 2.8600   0.0000 0.0000 0.0000    0.0000 0.0000
# 9   0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 3.0300    0.0000 0.0000
# 58  0.0000  0.0000 0.0000 5.2600   0.0000 0.0000 0.0000    0.0000 0.0000
# 60  0.0000  0.0000 0.0000 5.8800   0.0000 0.0000 5.8800    0.0000 0.0000
# 88  4.7600  0.0000 4.7600 0.0000   0.0000 0.0000 0.0000    0.0000 4.7600
#
#     informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0     0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 9     0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 3.0300  0.0000  0.0000
# 58    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 60    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 88    4.7600 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
#
#     ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0   0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 9   0.0000  3.0300  3.0300 0.0000 3.0300 0.0000   0.0000 0.0000   0.0000
# 58  0.0000  0.0000  5.2600 2.6300 0.0000 2.6300   0.0000 0.0000   2.6300
# 60  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   2.9400 0.0000   2.9400
# 88  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
#
#     tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0   0.0000   0.0000  0.0000       2.8600  0.0000 0.0000  2.8600 0.0000
# 9   0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 58  0.0000   2.6300  2.6300       2.6300  0.0000 0.0000  0.0000 5.2600
# 60  2.9400   2.9400  2.9400       0.0000  0.0000 0.0000  0.0000 0.0000
# 88  0.0000   0.0000  0.0000       4.7600  0.0000 0.0000  4.7600 0.0000
#
#     focuspast  focuspresent  focusfuture      i     we    you  shehe   they  \
# 0      5.7100        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 9      6.0600        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 3.0300
# 58     2.6300        0.0000       0.0000 2.6300 0.0000 0.0000 5.2600 5.2600
# 60     5.8800        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 5.8800
# 88     4.7600        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
#
#      ipron  article   prep  auxverb  adverb   conj  negate   verb    adj  \
# 0  11.4300  11.4300 0.0000   2.8600  2.8600 0.0000  5.7100 8.5700 5.7100
# 9   9.0900   6.0600 3.0300   0.0000  3.0300 0.0000  3.0300 3.0300 0.0000
# 58  2.6300  13.1600 5.2600   2.6300 10.5300 0.0000 10.5300 2.6300 2.6300
# 60  5.8800  11.7600 5.8800   2.9400  2.9400 0.0000  8.8200 2.9400 2.9400
# 88  0.0000  19.0500 0.0000   0.0000  0.0000 0.0000  4.7600 0.0000 0.0000
#
#     compare  interrog  number  quant    see   hear   feel  motion  space  \
# 0    0.0000    0.0000  2.8600 2.8600 0.0000 0.0000 0.0000 11.4300 2.8600
# 9    0.0000    3.0300  0.0000 0.0000 0.0000 3.0300 3.0300  0.0000 0.0000
# 58   2.6300    0.0000  2.6300 2.6300 0.0000 0.0000 0.0000  2.6300 5.2600
# 60   0.0000    0.0000  0.0000 0.0000 0.0000 2.9400 2.9400  8.8200 5.8800
# 88   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  9.5200 4.7600
#
#      time  user_political_polarisation  user_science_polarisation  \
# 0  0.0000                      -1.0000                     0.0000
# 9  0.0000                       1.0000                     0.0000
# 58 0.0000                      -1.0000                     0.0000
# 60 0.0000                      -1.0000                     0.0000
# 88 0.0000                       1.0000                     0.0000
#
#     user_moderacy_polarisation  user_posted_tweets  user_deleted_tweets  \
# 0                      -1.0000                  42                    0
# 9                       1.0000                   9                    0
# 58                     -1.0000                   3                    0
# 60                     -1.0000                  11                    0
# 88                     -1.0000                  10                    0
#
#     user_Deletion_ratio  user_Reputation  is_deleted  user_sentiment_average  \
# 0                0.0000           0.9998       False                  0.1736
# 9                0.0000           0.9291       False                 -0.2187
# 58               0.0000           0.3675       False                 -0.0369
# 60               0.0000           0.9466       False                  0.2801
# 88               0.0000           0.9856       False                 -0.0978
#
#     tweet_sentiment_deviation  tweet_political_polarisation_deviation  \
# 0                      0.0000                                  1.0000
# 9                      0.0907                                  0.0000
# 58                    -0.3650                                  1.0000
# 60                     0.5824                                  1.0000
# 88                    -0.5016                                  0.0000
#
#     tweet_science_polarisation_deviation  \
# 0                                 0.0000
# 9                                 0.0000
# 58                                0.0000
# 60                                0.0000
# 88                                0.0000
#
#     tweet_moderacy_polarisation_deviation
# 0                                  1.0000
# 9                                  0.0000
# 58                                 1.0000
# 60                                 1.0000
# 88                                 0.0000

# %%
df = df_tweetskb[['is_deleted', 'user_political_polarisation', 'tweet_political_polarisation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

plot_hexbin_reputaion(df, 'is_deleted','user_political_polarisation', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(alltweets)')

# %%
plot_hexbin_reputaion(df_del, 'is_deleted','user_political_polarisation', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(alltweets)')

# %%
plot_hexbin_reputaion(df_undel, 'is_deleted','user_political_polarisation', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(alltweets)')

# %% [markdown]
# ***

# %%
df = df_tweetskb[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

# %%
plot_heatmap(df,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetskb_political_reputation(alltweets)')
# Out:
# Number of zeros:
#  politic         0
# Reputation    890
# dtype: int64

# %%
plot_heatmap(df_del,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetskb_political_reputation(deletedtweets)')
# Out:
# Number of zeros:
#  politic         0
# Reputation    398
# dtype: int64

# %%
plot_heatmap(df_undel,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetskb_political_reputation(nondeletedtweets)')
# Out:
# Number of zeros:
#  politic         0
# Reputation    492
# dtype: int64
