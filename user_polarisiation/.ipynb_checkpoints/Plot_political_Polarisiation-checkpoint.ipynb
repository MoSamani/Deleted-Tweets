# %%
#CSV Bibliothek importieren 
import csv
#Pandas importieren und als pd bezeichnen
import pandas as pd
#Numpy importieren und als np bezeichnen 
import numpy as np
#Json Biliothek importieren
import json
#Obere Schranke für die Größe der Daten auf 100,000,000 setzen  
csv.field_size_limit(100000000)
#Maximale Anzahl von Zeilen und Spalten Zeigen 
pd.options.display.max_columns = None
pd.options.display.max_rows = None
#Um die Zeiträume bearbeiten zu können
from datetime import datetime
#Seaborn für die Plot importieren
import seaborn as sns
#matplotlib Importieren und als plt bezeichnen
import matplotlib.pyplot as plt
#Macht die Plots inline
# %matplotlib inline 
#dates importieren, um Zeitstempel bearbeiten zu können
import matplotlib.dates as mdates
#tick importieren
import matplotlib.ticker as tick
#Die Nachkommastellen auf 4 Zashlen einschränken
pd.options.display.float_format = '{:.4f}'.format

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import ScalarFormatter
from matplotlib import ticker

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***

# %% [markdown]
# # TweetsCov19
# ## KDE-Plot

# %% [markdown]
# ***

# %%
path = '../data/tweetsCov19_polarized_and_neutral_users_deletionratio_reputation.tsv'

df_tweetscov19 = pd.read_csv(path, sep='\t', error_bad_lines=False, names=[ "Username", 'politic', 'science', 'moderacy', 'Deletion_ratio', 'Reputation', 'is_deleted'])

print('Shape :', df_tweetscov19.shape)
df_tweetscov19.head()
# Out:
# Shape : (2231354, 7)
#                            Username  politic  science  moderacy  \
# 0  00008ca06f863b962f72cc9167d7978a  -1.0000   0.0000   -1.0000
# 1  00008de3f61d5f04329ee6867d5475b9  -1.0000   0.0000    1.0000
# 2  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 3  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 4  00016e20a3865cb74581803c27d27b89  -1.0000   0.0000   -1.0000
#
#    Deletion_ratio  Reputation  is_deleted
# 0          0.0000      0.1828       False
# 1          1.0000      0.6003        True
# 2          1.0000      0.3327        True
# 3          1.0000      0.3327        True
# 4          0.0000      0.5896       False

# %%
print('Alle Users:', df_tweetscov19.Username.unique().size)
# Out:
# Alle Users: 205084

# %%
df_tweetscov19 = df_tweetscov19[df_tweetscov19['politic'] != 0]

print('Shape: ', df_tweetscov19.shape)
df_tweetscov19.head()
# Out:
# Shape:  (1973156, 7)
#                            Username  politic  science  moderacy  \
# 0  00008ca06f863b962f72cc9167d7978a  -1.0000   0.0000   -1.0000
# 1  00008de3f61d5f04329ee6867d5475b9  -1.0000   0.0000    1.0000
# 2  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 3  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 4  00016e20a3865cb74581803c27d27b89  -1.0000   0.0000   -1.0000
#
#    Deletion_ratio  Reputation  is_deleted
# 0          0.0000      0.1828       False
# 1          1.0000      0.6003        True
# 2          1.0000      0.3327        True
# 3          1.0000      0.3327        True
# 4          0.0000      0.5896       False

# %%
df_tweetscov19_del = df_tweetscov19[df_tweetscov19['is_deleted']==True]
df_tweetscov19_undel = df_tweetscov19[df_tweetscov19['is_deleted']==False]

# %%
print('Deleted Tweets:', df_tweetscov19_del.shape)
print('Non-deleted Tweets:', df_tweetscov19_undel.shape)
# Out:
# Deleted Tweets: (350401, 7)
# Non-deleted Tweets: (1622755, 7)

# %%
print('Alle Users:', df_tweetscov19.Username.unique().size)

df = df_tweetscov19[df_tweetscov19['politic']>0]
print('Alle kon. Users in gesammten Tweets:', df.Username.unique().size)

df = df_tweetscov19[df_tweetscov19['politic']<0]
print('Alle lib. Users in gesammten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 171353
# Alle kon. Users in gesammten Tweets: 36179
# Alle lib. Users in gesammten Tweets: 135174

# %%
print('Alle Users:', df_tweetscov19_del.Username.unique().size)

df = df_tweetscov19_del[df_tweetscov19_del['politic']>0]
print('Alle kon. Users in gelöschten Tweets:', df.Username.unique().size)

df = df_tweetscov19_del[df_tweetscov19_del['politic']<0]
print('Alle lib. Users in gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 38986
# Alle kon. Users in gelöschten Tweets: 10989
# Alle lib. Users in gelöschten Tweets: 27997

# %%
print('Alle Users:', df_tweetscov19_undel.Username.unique().size)

df = df_tweetscov19_undel[df_tweetscov19_undel['politic']>0]
print('Alle kon. Users in nicht gelöschten Tweets:', df.Username.unique().size)

df = df_tweetscov19_undel[df_tweetscov19_undel['politic']<0]
print('Alle lib. Users in nicht gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 147054
# Alle kon. Users in nicht gelöschten Tweets: 28368
# Alle lib. Users in nicht gelöschten Tweets: 118686

# %%
def plot_kdeplot_v1(df, hue, x, x_label, titel, name): 
    ax = sns.kdeplot(data=df, x=x, hue=hue, fill=True, legend= False)
    #ax = sns.kdeplot(data=df, x=x, hue=hue, multiple="fill")
    
    
    ax.set_ylabel(ylabel='Density', fontsize=15)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=15)

    plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(0.2, 1.13), ncol=2, loc=2, borderaxespad=0, fontsize=12)
    #g.set_title(titel, fontweight="bold")
    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(1.02, 1.), loc=2, borderaxespad=0)
    plt.tight_layout()
    #plt.savefig('../plots/'+name+'.pdf')

# %%
df = df_tweetscov19[['is_deleted', 'politic']]
plot_kdeplot_v1(df, 'is_deleted','politic' ,'Political' ,'TweetsCov19', 'kdeplot_tweetscov19_politic_all_tweets_conditionaldistribution')

# %%
def plot_kdeplot_v2(df, hue, x, x_label, titel, name):
    #sns.color_palette("RdPu", 10)
    ax = sns.kdeplot(data=df, x=x, hue=hue, multiple="fill")
    
    ax.set_title('Political', fontsize=17)
    ax.set_ylabel(ylabel='Density', fontsize=17)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=15)

    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(0.2, 1.13), ncol=2, loc=2, borderaxespad=0, fontsize=12)
    #g.set_title(titel, fontweight="bold")
    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(1.02, 1.), loc=2, borderaxespad=0)
    plt.legend([],[], frameon=False)
    plt.tight_layout()
    #plt.savefig('../plots/'+name+'.pdf')

# %%
df = df_tweetscov19[['is_deleted', 'politic']]
plot_kdeplot_v2(df, 'is_deleted','politic' ,'           libera <-> conservatice' ,'TweetsCov19', 'kdeplot_tweetscov19_politic_all_tweets_Normalizethestackeddistribution')

# %%
def plot_kdeplot_v3(df, hue, x, x_label, titel, name): 
    #ax = sns.kdeplot(data=df, x=x, hue=hue, multiple="fill")
    ax = sns.kdeplot(
    data=df, x=x, hue=hue,
    cumulative=True, common_norm=False, common_grid=True,
    )
    
    ax.set_ylabel(ylabel='Density', fontsize=15)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=15)

    plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(0.2, 1.13), ncol=2, loc=2, borderaxespad=0, fontsize=12)
    #g.set_title(titel, fontweight="bold")
    #plt.legend(labels = ['Deleted','Non-deleted'], bbox_to_anchor=(1.02, 1.), loc=2, borderaxespad=0)
    plt.tight_layout()
    #plt.savefig('../plots/'+name+'.pdf')

# %%
df = df_tweetscov19[['is_deleted', 'politic']]
plot_kdeplot_v3(df, 'is_deleted','politic' ,'Political' ,'TweetsCov19', 'kdeplot_tweetscov19_politic_all_tweets_cumulativedistributionfunction')

# %% [markdown]
# ***

# %% [markdown]
# # Histogram

# %% [markdown]
# ***

# %%
def plot_histogram(df, titel):
    
    #figure(figsize=(8, 6), dpi=80)
    
    fig, ax = plt.subplots()
    colors = ['b', 'r']
    labels = ['Liberale', 'konservativ']
    
    N, bins, patches = ax.hist(df, bins=10, color = 'gray')
    for i in range(0,5):
        patches[i].set_facecolor('b')
    patches[1].set_label('Liberal')
    for i in range(5,len(patches)):
        patches[i].set_facecolor('r')
    patches[9].set_label('Conservative')
        
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    figsize=(8, 6)
    plt.ylabel('Number of users', fontsize=16)
    ax.set_xlabel(xlabel='Politic', fontsize=17)

    #plt.title('Political polarization', fontsize=18)
    plt.legend( fontsize=12)
    plt.tight_layout()

    #plt.savefig('../plots/'+titel+'.pdf')

# %%
df = df_tweetscov19.drop_duplicates(subset=['Username'])
plot_histogram(df['politic'],'hist_tweetsCov19_political_polarized_users(alltweets)')

# %%
df = df_tweetscov19_del.drop_duplicates(subset=['Username'])
plot_histogram(df['politic'],'hist_tweetsCov19_political_polarized_users(deletedtweets)')

# %%
df = df_tweetscov19_undel.drop_duplicates(subset=['Username'])
plot_histogram(df['politic'],'hist_tweetsCov19_political_polarized_users(nondeletedtweets)')

# %% [markdown]
# ***

# %%
path = '../data/tweetscov19_political_polarized_users_with_atleast_one_polarized_domain.tsv'

df_tweetscov19_political_polarized_and_neutralized = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Username', 'Number_of_liberals', 'Number_of_conservatives', 'Sum_polarised_domains', 'political_polarisation'])

print('Shape :', df_tweetscov19_political_polarized_and_neutralized.shape)
df_tweetscov19_political_polarized_and_neutralized.head()
# Out:
# Shape : (176301, 5)
#                            Username  Number_of_liberals  \
# 0  00008ca06f863b962f72cc9167d7978a                  -1
# 1  00008de3f61d5f04329ee6867d5475b9                  -1
# 2  00012a177385cd6e7590e2acb3f206e3                  -1
# 3  00016e20a3865cb74581803c27d27b89                  -1
# 4  000186b796b0eb667801aad27ca978eb                  -2
#
#    Number_of_conservatives  Sum_polarised_domains  political_polarisation
# 0                        0                      1                 -1.0000
# 1                        0                      1                 -1.0000
# 2                        0                      1                 -1.0000
# 3                        0                      1                 -1.0000
# 4                        0                      2                 -1.0000

# %%
pfad_tsv = '../data/TweetsCov19_alltweets_reputation_deletionratio.tsv'

df_tweetscov19_alltweets_reputation_deletionratio = pd.read_csv(pfad_tsv, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Followers', 'Friends', 'is_deleted', 'Reputation', 'num_posted', 'num_deleted', 'Deletionratio'])

print('Form :', df_tweetscov19_alltweets_reputation_deletionratio.shape)
df_tweetscov19_alltweets_reputation_deletionratio.head()
# Out:
# Form : (9409841, 9)
#               Tweet_Id                          Username  Followers  Friends  \
# 0  1178791637348212736  c57d4fb895c5f4a33d2a2b24709f93b5     764191      132
# 1  1181705842275573766  c57d4fb895c5f4a33d2a2b24709f93b5     765034      132
# 2  1187828746503540738  c57d4fb895c5f4a33d2a2b24709f93b5     766578      132
# 3  1192622772658290688  c57d4fb895c5f4a33d2a2b24709f93b5     767939      133
# 4  1193272068621717504  c57d4fb895c5f4a33d2a2b24709f93b5     768180      133
#
#    is_deleted  Reputation  num_posted  num_deleted  Deletionratio
# 0        True      0.9998          21           21         1.0000
# 1        True      0.9998          21           21         1.0000
# 2        True      0.9998          21           21         1.0000
# 3        True      0.9998          21           21         1.0000
# 4        True      0.9998          21           21         1.0000

# %%
df_tweetscov19_alltweets_reputation_deletionratio = df_tweetscov19_alltweets_reputation_deletionratio[['Username', 'is_deleted']]

df_tweetscov19_political_polarized_and_neutralized = df_tweetscov19_political_polarized_and_neutralized[['Username', 'political_polarisation']]

df_tweetscov19_polarized_user = pd.merge(df_tweetscov19_alltweets_reputation_deletionratio, df_tweetscov19_political_polarized_and_neutralized, on='Username', how='inner')
print('Form :', df_tweetscov19_polarized_user.shape)
df_tweetscov19_polarized_user.head()
# Out:
# Form : (2057978, 3)
#                            Username  is_deleted  political_polarisation
# 0  7966d5716c1c4f33591b17755184e3d6       False                 -0.5000
# 1  7966d5716c1c4f33591b17755184e3d6        True                 -0.5000
# 2  7966d5716c1c4f33591b17755184e3d6       False                 -0.5000
# 3  7966d5716c1c4f33591b17755184e3d6       False                 -0.5000
# 4  7966d5716c1c4f33591b17755184e3d6        True                 -0.5000

# %%
df_tweetscov19_polarized_user_del = df_tweetscov19_polarized_user[df_tweetscov19_polarized_user['is_deleted']==True]
df_tweetscov19_polarized_user_undel = df_tweetscov19_polarized_user[df_tweetscov19_polarized_user['is_deleted']==False]

# %%
def plot_histogram(df, titel):
    
    #figure(figsize=(8, 6), dpi=80)
    
    fig, ax = plt.subplots()
    colors = ['b', 'r']
    labels = ['Liberale', 'konservativ']
    
    N, bins, patches = ax.hist(df, bins=11, color = 'gray')
    
    patches[5].set_label('Neutral')
    patches[5].set_facecolor('gray')
    for i in range(0,5):
        patches[i].set_facecolor('b')
    patches[2].set_label('Liberal')
    
    
    for i in range(6,len(patches)):
        patches[i].set_facecolor('r')
    patches[9].set_label('Conservative')
        
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    figsize=(8, 6)
    plt.ylabel('Number of users', fontsize=16)
    ax.set_xlabel(xlabel='Politic', fontsize=17)

    #plt.title('Political polarization', fontsize=18)
    plt.legend( fontsize=12)
    plt.tight_layout()

    plt.savefig('../plots/'+titel+'.pdf')

# %%
df = df_tweetscov19_polarized_user.drop_duplicates(subset=['Username'])
plot_histogram(df['political_polarisation'],'hist_tweetsCov19_political_polarized_users(alltweets)')

# %%
df = df_tweetscov19_polarized_user_del.drop_duplicates(subset=['Username'])
plot_histogram(df['political_polarisation'],'hist_tweetsCov19_political_polarized_users(deletedtweets)')

# %%
df = df_tweetscov19_polarized_user_undel.drop_duplicates(subset=['Username'])
plot_histogram(df['political_polarisation'],'hist_tweetsCov19_political_polarized_users(nondeletedtweets)')

# %% [markdown]
# ----

# %% [markdown]
# ***

# %% [markdown]
# # Hexabin
# ### Reputation-Polarisierung

# %%
df_tweetscov19 = df_tweetscov19[df_tweetscov19['politic'] != 0]

print('Shape: ', df_tweetscov19.shape)
df_tweetscov19.head()
# Out:
# Shape:  (1973156, 7)
#                            Username  politic  science  moderacy  \
# 0  00008ca06f863b962f72cc9167d7978a  -1.0000   0.0000   -1.0000
# 1  00008de3f61d5f04329ee6867d5475b9  -1.0000   0.0000    1.0000
# 2  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 3  00012a177385cd6e7590e2acb3f206e3  -1.0000   0.0000    1.0000
# 4  00016e20a3865cb74581803c27d27b89  -1.0000   0.0000   -1.0000
#
#    Deletion_ratio  Reputation  is_deleted
# 0          0.0000      0.1828       False
# 1          1.0000      0.6003        True
# 2          1.0000      0.3327        True
# 3          1.0000      0.3327        True
# 4          0.0000      0.5896       False

# %%
from pylab import *

def plot_hexbin_reputaion(df, hue,x ,x_label, color, titel):
    
    ax = df.plot.hexbin(x=x, y="Reputation",cmap=color, gridsize=20, sharex=False)
    ax.set_ylabel(ylabel='Reputaion', fontsize=17)
    ax.set_xlabel(xlabel=x_label, fontsize=17)

    ax.tick_params(axis='x', which='major', labelsize=16)
    ax.tick_params(axis='y', which='major', labelsize=16)
    
    
  
    
    f = plt.gcf()
    cax = f.get_axes()[1]
    #cax.set_ylabel('test')
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    #formatter.set_useOffset(1000)
    
    cax.tick_params(labelsize=16)
    #cax.ticklabel_format(style='scientific', useMathText=True)
    
    cax.xaxis.set_major_formatter(formatter)
    cax.yaxis.set_major_formatter(formatter)
    
    fig = ax.get_figure()
    fig.tight_layout()

    #fig.savefig('../plots/'+titel+'.pdf')
    plt.show()

# %%
df = df_tweetscov19[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

plot_hexbin_reputaion(df, 'is_deleted','politic', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(alltweets)')

# %%
plot_hexbin_reputaion(df_del, 'is_deleted','politic', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(deletedtweets)')

# %%
plot_hexbin_reputaion(df_undel, 'is_deleted','politic', 'Politic', 'Blues', 'Hexabinplot_tweetscov19_political_reputation(nondeletedtweets)')

# %% [markdown]
# ***

# %%
def plot_heatmap(df, polarisation, reputation,x_label, color, titel):
    
    df = df[[polarisation, reputation]]
    df = df.round(1)
    zeros = (df == 0).sum()
    print('Number of zeros: \n', zeros)
    #df.replace(0, np.nan, inplace=True)
    df = df.groupby([polarisation, reputation]).size().reset_index(name='count')

    
    heatmap_data = df.pivot(reputation, polarisation, "count")
    heatmap_data = heatmap_data.sort_values(by=reputation,ascending=False)

    color = plt.get_cmap(color)   # default color
    color.set_bad('white')    # if the value is bad the color would be lightblue instead of white

    sns.set(font_scale=2)
    f, ax = plt.subplots(figsize=(7, 5))
    sns.heatmap(heatmap_data, square=False, norm= matplotlib.colors.LogNorm(), cbar_kws={"shrink": 1}, cmap=color)
    ax.tick_params(labelsize=15)
    ax.set_ylabel(ylabel='Reputaion', fontsize=17)
    ax.set_xlabel(xlabel=x_label, fontsize=17)
    #ax.figure.axes[-1].set_ylabel('Number of tweets', size=20)
    #ax.figure.axes[-1].set_ylabel( size=20)

    fig = ax.get_figure()
    fig.tight_layout()

    #fig.savefig('../plots/heatmaps/'+titel+'.pdf')
    plt.show()

# %%
df = df_tweetscov19[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

# %%
plot_heatmap(df,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetscov19_political_reputation(alltweets)_1')
# Out:
# Number of zeros:
#  politic        8050
# Reputation    13504
# dtype: int64

# %%
plot_heatmap(df_del,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetscov19_political_reputation(deletedtweets)_1')
# Out:
# Number of zeros:
#  politic       3325
# Reputation    5521
# dtype: int64

# %%
plot_heatmap(df_undel,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetscov19_political_reputation(nondeletedtweets)_1')
# Out:
# Number of zeros:
#  politic       4725
# Reputation    7983
# dtype: int64

# %% [markdown]
# ***

# %%
import numpy as np
import numpy.random
import matplotlib.pyplot as plt

# Generate some test data
x = df[ 'politic']
y = df[ 'Reputation']

heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.grid(False)
plt.imshow(heatmap.T, extent=extent, origin='lower')
plt.show()

# %%
def myplot(x, y, s, bins=1000):
    heatmap, xedges, yedges = np.histogram2d(x, y, bins=bins)
    heatmap = gaussian_filter(heatmap, sigma=s)

    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    return heatmap.T, extent

# %%
from scipy.ndimage.filters import gaussian_filter
import matplotlib.cm as cm

x = df[ 'politic']
y = df [ 'Reputation']

sigmas = [0, 16, 32, 64]

fig, ax = plt.subplots()

#ax.plot(x, y, 'k.', markersize=5)
#ax.set_title("Scatter plot")

img, extent = myplot(x, y, 64)
ax.imshow(img, extent=extent, origin='lower', cmap=cm.jet)
#ax.set_title("Smoothing with  $\sigma$ = %d" % s)
plt.grid(False)
plt.show()

# %%
x = df_del[ 'politic']
y = df_del[ 'Reputation']

sigmas = [0, 16, 32, 64]

fig, ax = plt.subplots()

#ax.plot(x, y, 'k.', markersize=5)
#ax.set_title("Scatter plot")

img, extent = myplot(x, y, 64)
ax.imshow(img, extent=extent, origin='lower', cmap=cm.jet)
#ax.set_title("Smoothing with  $\sigma$ = %d" % s)
plt.grid(False)
plt.show()

# %%
x = df_undel[ 'politic']
y = df_undel[ 'Reputation']

sigmas = [0, 16, 32, 64]

fig, ax = plt.subplots()

#ax.plot(x, y, 'k.', markersize=5)
#ax.set_title("Scatter plot")

img, extent = myplot(x, y, 64)
ax.imshow(img, extent=extent, origin='lower', cmap=cm.jet)
#ax.set_title("Smoothing with  $\sigma$ = %d" % s)
plt.grid(False)
plt.show()

# %%
df = df_tweetscov19[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

# %%
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as pyo

fig = px.density_heatmap(df, x="politic", y="Reputation", nbinsx=20, nbinsy=20, color_continuous_scale="Blues")
fig.layout.height = 500
fig.layout.width = 600
fig.update_layout(
    xaxis = dict(
        tickmode = 'linear',
        dtick = 0.5,
        tickfont = dict(
        #family = 'Old Standard TT, serif',
        size = 20,
        color = 'black'
          ),
        titlefont = dict(
         #family = 'Arial, sans-serif',
         size = 20,
         color = 'Black'
          ),
        ),
    yaxis = dict(
        tickmode = 'linear',
        dtick = 0.5,
        tickfont = dict(
        #family = 'Old Standard TT, serif',
        size = 20,
        color = 'black'
          ),
    titlefont = dict(
         #family = 'Arial, sans-serif',
         size = 20,
         color = 'Black'
          ),
        ),
    coloraxis_colorbar=dict(
        title="Number of Tweets",
        thicknessmode="pixels",
        titlefont = dict(
         #family = 'Arial, sans-serif',
         size = 15,
         color = 'Black'
          ),
        tickfont = dict(
        #family = 'Old Standard TT, serif',
        size = 15,
        color = 'black'
          ),
        ),
    
    
    )

#fig.show()
pyo.plot(fig, filename="example.html")
#fig.write_image("./fig1.pdf")
# Out:
# 'example.html'

# %%
fig = px.density_heatmap(df_del, x="politic", y="Reputation", nbinsx=20, nbinsy=20, color_continuous_scale="Blues")
fig.layout.height = 500
fig.layout.width = 600
#fig.show()
pyo.plot(fig, filename="example.html")
# Out:
# 'example.html'

# %%
fig = px.density_heatmap(df_undel, x="politic", y="Reputation", nbinsx=20, nbinsy=20, color_continuous_scale="Blues")
fig.layout.height = 500
fig.layout.width = 600
#fig.show()
pyo.plot(fig, filename="example.html")
# Out:
# 'example.html'

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # TweetKB
# ## KDE-Plot

# %% [markdown]
# ***

# %%
path = '../data/tweetsKB_polarized_users_deletionratio_reputation.tsv'

df_tweetskb = pd.read_csv(path, sep='\t', error_bad_lines=False, names=["Username", 'politic', 'science', 'moderacy', 'Deletion_ratio', 'Reputation', 'is_deleted'])

print('Shape :', df_tweetskb.shape)
df_tweetskb.head()
# Out:
# Shape : (552665, 7)
#           Username  politic  science  moderacy  Deletion_ratio  Reputation  \
# 0       0000Condor  -1.0000   0.0000    1.0000          1.0000      0.2556
# 1  007newsandviews  -1.0000   0.0000   -1.0000          0.0000      0.4828
# 2       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 3       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 4       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
#
#    is_deleted
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False

# %%
print('Alle Users:', df_tweetskb.Username.unique().size)
# Out:
# Alle Users: 78638

# %%
df_tweetskb = df_tweetskb[df_tweetskb['politic'] != 0]

print('Shape: ', df_tweetskb.shape)
df_tweetskb.head()
# Out:
# Shape:  (478718, 7)
#           Username  politic  science  moderacy  Deletion_ratio  Reputation  \
# 0       0000Condor  -1.0000   0.0000    1.0000          1.0000      0.2556
# 1  007newsandviews  -1.0000   0.0000   -1.0000          0.0000      0.4828
# 2       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 3       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
# 4       007plus100  -1.0000   0.0000   -1.0000          0.0000      0.3980
#
#    is_deleted
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False

# %%
df_tweetskb_del = df_tweetskb[df_tweetskb['is_deleted']==True]
df_tweetskb_undel = df_tweetskb[df_tweetskb['is_deleted']==False]

# %%
print('Deleted Tweets:', df_tweetskb_del.shape)
print('Non-deleted Tweets:', df_tweetskb_undel.shape)
# Out:
# Deleted Tweets: (100976, 7)
# Non-deleted Tweets: (377742, 7)

# %%
print('Alle Users:', df_tweetskb.Username.unique().size)

df = df_tweetskb[df_tweetskb['politic']>0]
print('Alle kon. Users in gesammten Tweets:', df.Username.unique().size)

df = df_tweetskb[df_tweetskb['politic']<0]
print('Alle lib. Users in gesammten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 66027
# Alle kon. Users in gesammten Tweets: 14967
# Alle lib. Users in gesammten Tweets: 51060

# %%
print('Alle Users:', df_tweetskb_del.Username.unique().size)

df = df_tweetskb_del[df_tweetskb_del['politic']>0]
print('Alle kon. Users in gelöschten Tweets:', df.Username.unique().size)

df = df_tweetskb_del[df_tweetskb_del['politic']<0]
print('Alle lib. Users in gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 14796
# Alle kon. Users in gelöschten Tweets: 4405
# Alle lib. Users in gelöschten Tweets: 10391

# %%
print('Alle Users:', df_tweetskb_undel.Username.unique().size)

df = df_tweetskb_undel[df_tweetskb_undel['politic']>0]
print('Alle kon. Users in nicht gelöschten Tweets:', df.Username.unique().size)

df = df_tweetskb_undel[df_tweetskb_undel['politic']<0]
print('Alle lib. Users in nicht gelöschten Tweets:', df.Username.unique().size)
# Out:
# Alle Users: 55227
# Alle kon. Users in nicht gelöschten Tweets: 11426
# Alle lib. Users in nicht gelöschten Tweets: 43801

# %%
df = df_tweetskb[['is_deleted', 'politic']]
plot_kdeplot_v1(df, 'is_deleted','politic' ,'Politic' ,'TweetsCov19', 'kdeplot_tweetskb_politic_alltweets_conditionaldistribution')

# %%
df = df_tweetskb[['is_deleted', 'politic']]
plot_kdeplot_v2(df, 'is_deleted','politic' ,'Politic' ,'TweetsCov19', 'kdeplot_tweetskb_politic_alltweets_Normalizethestackeddistribution')

# %%
df = df_tweetskb[['is_deleted', 'politic']]
plot_kdeplot_v3(df, 'is_deleted','politic' ,'Politic' ,'TweetsCov19', 'kdeplot_tweetskb_politic_alltweets_cumulativedistributionfunction')

# %% [markdown]
# # Histogram

# %% [markdown]
# ***

# %%
def plot_histogram_kb(df, titel):
    #figure(figsize=(8, 6), dpi=80)
    
    fig, ax = plt.subplots()
    colors = ['b', 'r']
    #labels = ['Liberale', 'konservativ']
    
    N, bins, patches = ax.hist(df, bins=10, color = 'gray')
    for i in range(0,5):
        patches[i].set_facecolor('royalblue')
    patches[1].set_label('Liberal')
    for i in range(5,len(patches)):
        patches[i].set_facecolor('crimson')
    patches[9].set_label('Conservative')
    
          
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    figsize=(8, 6)
    plt.ylabel('Number of users', fontsize=16)
    ax.set_xlabel(xlabel='Politic', fontsize=17)

    #plt.title('Political polarization', fontsize=18)
    plt.legend( fontsize=12)
    plt.tight_layout()
    #plt.savefig('../plots/'+titel+'.pdf')

# %%
#All Tweets
df = df_tweetskb.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['politic'],'hist_tweetsKB_political_polarized_users(alltweets)')

# %%
df = df_tweetskb_del.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['politic'],'hist_tweetsKB_political_polarized_users(deletedtweets)')

# %%
df = df_tweetskb_undel.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['politic'],'hist_tweetsKB_political_polarized_users(nondeletedtweets)')

# %% [markdown]
# ***

# %%
path = '../data/tweetskb_political_polarized_users_with_atleast_one_polarized_domain.tsv'

df_tweetskb_political_polarized_and_neutralized = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Username', 'Number_of_liberals', 'Number_of_conservatives', 'Sum_polarised_domains', 'political_polarisation'])

print('Shape :', df_tweetskb_political_polarized_and_neutralized.shape)
df_tweetskb_political_polarized_and_neutralized.head()
# Out:
# Shape : (67511, 5)
#           Username  Number_of_liberals  Number_of_conservatives  \
# 0       0000Condor                  -1                        0
# 1     007AliSohrab                  -1                        1
# 2  007newsandviews                  -1                        0
# 3       007plus100                  -1                        0
# 4    00CelebNewz00                  -1                        0
#
#    Sum_polarised_domains  political_polarisation
# 0                      1                 -1.0000
# 1                      2                  0.0000
# 2                      1                 -1.0000
# 3                      1                 -1.0000
# 4                      1                 -1.0000

# %%
path = '../data/TweetsKB_alltweets_reputation_deletionratio.tsv'

df_tweetskb_alltweets_reputation_deletionratio = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Followers', 'Friends', 'is_deleted', 'num_posted', 'num_del', 'Deletionratio',  'Reputation'])

print('Form :', df_tweetskb_alltweets_reputation_deletionratio.shape)
df_tweetskb_alltweets_reputation_deletionratio.head()
# Out:
# Form : (9409841, 9)
#               Tweet_Id  Username  Followers  Friends  is_deleted  num_posted  \
# 0  1178791636039589889  DCComics    3349606      563       False          42
# 1  1179833467644850176  DCComics    3351904      563       False          42
# 2  1180490470125965313  DCComics    3354879      563       False          42
# 3  1187059882534400000  DCComics    3369484      562       False          42
# 4  1190311668141580288  DCComics    3376154      564       False          42
#
#    num_del  Deletionratio  Reputation
# 0        0         0.0000      0.9998
# 1        0         0.0000      0.9998
# 2        0         0.0000      0.9998
# 3        0         0.0000      0.9998
# 4        0         0.0000      0.9998

# %%
df_tweetskb_alltweets_reputation_deletionratio = df_tweetskb_alltweets_reputation_deletionratio[['Username', 'is_deleted']]
df_tweetskb_political_polarized_and_neutralized = df_tweetskb_political_polarized_and_neutralized[['Username', 'political_polarisation']]

df_tweetskb_polarized_users = pd.merge(df_tweetskb_alltweets_reputation_deletionratio, df_tweetskb_political_polarized_and_neutralized, on='Username', how='inner')
print('Form :', df_tweetskb_polarized_users.shape)
df_tweetskb_polarized_users.head()
# Out:
# Form : (501063, 3)
#    Username  is_deleted  political_polarisation
# 0  DCComics       False                 -1.0000
# 1  DCComics       False                 -1.0000
# 2  DCComics       False                 -1.0000
# 3  DCComics       False                 -1.0000
# 4  DCComics       False                 -1.0000

# %%
df_tweetskb_polarized_users_del = df_tweetskb_polarized_users[df_tweetscov19_polarized_user['is_deleted']==True]
df_tweetskb_polarized_users_undel = df_tweetskb_polarized_users[df_tweetscov19_polarized_user['is_deleted']==False]

# %%
def plot_histogram_kb(df, titel):
    #figure(figsize=(8, 6), dpi=80)
    
    fig, ax = plt.subplots()
    colors = ['b', 'r']
    #labels = ['Liberale', 'konservativ']
    
    N, bins, patches = ax.hist(df, bins=11, color = 'gray')
    patches[5].set_label('Neutral')
    patches[5].set_facecolor('gray')
    for i in range(0,5):
        patches[i].set_facecolor('royalblue')
    patches[1].set_label('Liberal')
    for i in range(6,len(patches)):
        patches[i].set_facecolor('crimson')
    patches[9].set_label('Conservative')
    
          
    ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    figsize=(8, 6)
    plt.ylabel('Number of users', fontsize=16)
    ax.set_xlabel(xlabel='Politic', fontsize=17)

    #plt.title('Political polarization', fontsize=18)
    plt.legend( fontsize=12)
    plt.tight_layout()
    plt.savefig('../plots/'+titel+'.pdf')

# %%
#All Tweets
df = df_tweetskb_polarized_users.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['political_polarisation'],'hist_tweetsKB_political_polarized_users(alltweets)')

# %%
df = df_tweetskb_polarized_users_del.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['political_polarisation'],'hist_tweetsKB_political_polarized_users(deletedtweets)')

# %%
df = df_tweetskb_polarized_users_undel.drop_duplicates(subset=['Username'])
plot_histogram_kb(df['political_polarisation'],'hist_tweetsKB_political_polarized_users(nondeletedtweets)')

# %% [markdown]
# ***

# %% [markdown]
# # Hexabin
# ### Reputation-Polarisierung

# %% [markdown]
# ***

# %%
df = df_tweetskb[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

plot_hexbin_reputaion(df, 'is_deleted', 'politic', 'Politic', 'Blues', 'Hexabinplot_tweetskb_political_reputation(alltweets)')

# %%
plot_hexbin_reputaion(df_del, 'is_deleted', 'politic', 'Politic', 'Blues','Hexabinplot_tweetskb_political_reputation(deletedtweets)')

# %%
plot_hexbin_reputaion(df_undel, 'is_deleted', 'politic', 'Politische', 'Blues', 'Hexabinplot_tweetskb_political_reputation(nondeletedtweets)')

# %% [markdown]
# ***

# %%
df = df_tweetskb[['is_deleted', 'politic', 'Reputation']]

df_del =  df[df['is_deleted']==True]
df_undel = df[df['is_deleted']==False]

# %%
plot_heatmap(df,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetskb_political_reputation(alltweets)_1')
# Out:
# Number of zeros:
#  politic        130
# Reputation    2264
# dtype: int64

# %%
plot_heatmap(df_del,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetskb_political_reputation(deletedtweets)')
# Out:
# Number of zeros:
#  politic         0
# Reputation    398
# dtype: int64

# %%
plot_heatmap(df_undel,'politic', 'Reputation', 'Politic', 'Blues', 'Heatmap_tweetskb_political_reputation(nondeletedtweets)')
# Out:
# Number of zeros:
#  politic         0
# Reputation    492
# dtype: int64
