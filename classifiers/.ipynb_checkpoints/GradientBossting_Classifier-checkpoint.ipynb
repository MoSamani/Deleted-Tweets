# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
from termcolor import colored
csv.field_size_limit(100000000)
import pickle

from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingClassifier

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# # RandomForestClassifier
# ## TweetsCov19
# ### (Tweet content + user features)

# %%
path = '../data/df_tweetscov19_sample_20000.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference' ])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (20000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1236495952258707456  d98b72ff8b36385f50e1bd44bf3d09b9         0          0
# 1  1265887546409713664  c751771e7a305d4679d628f7c1a330e3         7          8
# 2  1265363442501853184  09f7798af45e96fba119819297777bfa         0          0
# 3  1251336179951128577  d979f1b0ca230cfb22300313318e3dc7         0          0
# 4  1209276556448800772  1210c19b21e622ce71e65c6a6cced1be        26        512
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     1.0000     0.0000     0.0000             0             0
# 1    -0.1020     0.8980     0.0000    -0.3818             3             0
# 2    -0.0000     0.7860     0.2140     0.4588             0             1
# 3    -0.0570     0.9430     0.0000    -0.4215             0             0
# 4    -0.2360     0.7070     0.0570    -0.8779             0             2
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0       278         1      79.7930          0      0.0000
# 1       205         0      14.7960          0      0.0000
# 2        73         0      53.6550          0      0.0000
# 3       272         0      43.2380          0      0.0000
# 4       258         0      83.5760          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  2.0400  0.0000  0.0000  0.0000 0.0000 4.0800
# 1                       0.0000  3.7000  0.0000  0.0000  0.0000 0.0000 7.4100
# 2                       0.0000  8.3300  0.0000  0.0000  0.0000 8.3300 0.0000
# 3                       0.0000  4.2600  0.0000  0.0000  0.0000 0.0000 0.0000
# 4                       0.0000  4.5500  0.0000  0.0000  0.0000 2.2700 2.2700
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    2.0400 0.0000    0.0000  0.0000
# 1   0.0000 3.7000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   8.3300 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 2.1300    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 2.2700    0.0000 0.0000    2.2700 0.0000    0.0000  2.2700
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  2.0400  0.0000 0.0000  0.0000  0.0000  0.0000  2.0400  0.0000 0.0000
# 1  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  8.3300  8.3300  0.0000 0.0000
# 3  0.0000  0.0000 0.0000  2.1300  0.0000  0.0000  0.0000  2.1300 0.0000
# 4  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  2.2700  4.5500 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   2.0400  0.0000   4.0800  4.0800
# 1 0.0000 0.0000   0.0000 3.7000   3.7000  3.7000   3.7000  0.0000
# 2 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 2.1300 0.0000   0.0000 2.1300   0.0000  0.0000   4.2600 10.6400
# 4 0.0000 0.0000   9.0900 2.2700   2.2700  2.2700   0.0000  4.5500
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 2.0400  0.0000 0.0000     2.0400        0.0000
# 1       3.7000  3.7000 3.7000  0.0000 0.0000     0.0000        3.7000
# 2       0.0000  0.0000 0.0000  8.3300 0.0000     0.0000        0.0000
# 3       0.0000  2.1300 0.0000  0.0000 0.0000     2.1300        6.3800
# 4       0.0000  0.0000 2.2700  2.2700 2.2700     9.0900        6.8200
#
#    focusfuture      i     we    you  shehe   they   ipron  article    prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  4.0800   4.0800  8.1600
# 1       0.0000 0.0000 3.7000 0.0000 0.0000 0.0000  0.0000   3.7000  7.4100
# 2       0.0000 0.0000 0.0000 0.0000 8.3300 0.0000  0.0000  16.6700  8.3300
# 3       0.0000 0.0000 0.0000 0.0000 0.0000 2.1300  8.5100   2.1300 10.6400
# 4       0.0000 0.0000 0.0000 0.0000 2.2700 0.0000 11.3600   2.2700  6.8200
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   4.0800  4.0800 2.0400  2.0400  4.0800 6.1200   0.0000    0.0000  0.0000
# 1   3.7000  7.4100 3.7000  0.0000  3.7000 0.0000   0.0000    3.7000  0.0000
# 2   0.0000  8.3300 0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 3   4.2600  6.3800 4.2600  2.1300  6.3800 4.2600   4.2600    2.1300  2.1300
# 4   9.0900  6.8200 9.0900  2.2700 22.7300 4.5500   2.2700    2.2700  2.2700
#
#    quant    see   hear   feel  motion   space   time  \
# 0 2.0400 0.0000 0.0000 0.0000  0.0000  6.1200 0.0000
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 11.1100 3.7000
# 2 0.0000 0.0000 8.3300 0.0000  0.0000  0.0000 0.0000
# 3 6.3800 0.0000 0.0000 0.0000  0.0000  4.2600 6.3800
# 4 0.0000 0.0000 0.0000 0.0000  0.0000  2.2700 2.2700
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                      -1.0000                     1.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       2
# 1                      0.0000                      10
# 2                      0.0000                       1
# 3                      0.0000                       3
# 4                     -1.0000                     106
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               0.5000           0.6171        True
# 1                        1               0.1000           0.8864        True
# 2                        1               1.0000           0.2731        True
# 3                        3               1.0000           0.8745        True
# 4                      104               0.9811           0.9888        True
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                     -0.2009                          0.0000
# 1                      0.1799                         -0.5617
# 2                      0.4588                          0.0000
# 3                     -0.1517                         -0.2698
# 4                     -0.0995                         -0.7784
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   1.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                -1.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  1.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (20000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1250457305373696004  1def7bdb6e6dd52206c4cb21f7c85a1e         6          8
# 1  1253008335734845441  e9eb3502df1e3d6de1c79ccb00e6c0f3         0          0
# 2  1244586626287796224  463843f75b0c83eaade84d146cc34164         0          0
# 3  1183628503566241792  6f9b35f6f2b613c7413a31cb778c95aa         0          0
# 4  1239179232112230400  a4845128dd5d5df264059436a35594d6        38         66
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.1110     0.8390     0.0500    -0.4019             1             0
# 1    -0.2160     0.7840     0.0000    -0.3570             0             1
# 2    -0.1810     0.6720     0.1480    -0.1260             0             1
# 3    -0.0000     1.0000     0.0000     0.0000             0             6
# 4    -0.3400     0.5560     0.1050    -0.8020             4             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0       261         0      47.5960          0      0.0000
# 1        62         0      52.8650          0      0.0000
# 2        80         0      75.1980          0      0.0000
# 3        80         0     -17.8130          0      0.0000
# 4       193         1      22.4730          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  7.3200  0.0000  0.0000  0.0000 0.0000 4.8800
# 1                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 2                       0.0000  7.1400  0.0000  0.0000  0.0000 0.0000 0.0000
# 3                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 4                       0.0000  3.5700  0.0000  0.0000  0.0000 0.0000 7.1400
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 7.3200 7.3200    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 3.5700    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  2.4400  4.8800 0.0000
# 1  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000 10.0000  0.0000 0.0000
# 2  0.0000  0.0000 0.0000  7.1400  0.0000  0.0000  0.0000  7.1400 0.0000
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4  0.0000  0.0000 0.0000  7.1400  0.0000  0.0000  3.5700  0.0000 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 2.4400   0.0000 2.4400   0.0000  2.4400   0.0000  0.0000
# 1 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 7.1400   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000   0.0000 3.5700   0.0000  0.0000   0.0000  3.5700
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       4.8800  0.0000 4.8800  0.0000 0.0000     2.4400        7.3200
# 1       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000       20.0000
# 2       0.0000  0.0000 0.0000  7.1400 0.0000     7.1400        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 4       0.0000  3.5700 0.0000  0.0000 0.0000     7.1400        0.0000
#
#    focusfuture       i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000  0.0000 2.4400 0.0000 0.0000 0.0000 2.4400   4.8800 14.6300
# 1       0.0000 10.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000 10.0000
# 2       0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  7.1400
# 3       0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  0.0000
# 4       0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 7.1400   0.0000 17.8600
#
#    auxverb  adverb   conj  negate    verb     adj  compare  interrog  number  \
# 0   7.3200  7.3200 2.4400  0.0000  7.3200  7.3200   2.4400    4.8800  0.0000
# 1  10.0000 10.0000 0.0000  0.0000 10.0000 20.0000  10.0000    0.0000 10.0000
# 2   0.0000  0.0000 7.1400  0.0000  7.1400  7.1400   7.1400    0.0000  0.0000
# 3   0.0000  0.0000 0.0000  0.0000  0.0000  0.0000   0.0000    0.0000  0.0000
# 4   0.0000  0.0000 0.0000  0.0000  7.1400  0.0000   0.0000    0.0000  0.0000
#
#     quant    see   hear   feel  motion  space    time  \
# 0  2.4400 0.0000 0.0000 0.0000  0.0000 9.7600  2.4400
# 1 10.0000 0.0000 0.0000 0.0000  0.0000 0.0000 10.0000
# 2  0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  7.1400
# 3  0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 4  0.0000 0.0000 0.0000 0.0000  0.0000 3.5700  0.0000
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                       0.3333                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       2
# 1                      0.0000                       1
# 2                      0.0000                       1
# 3                      0.0000                       1
# 4                     -1.0000                      16
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        0               0.0000           0.6030       False
# 1                        1               1.0000           0.4000        True
# 2                        1               1.0000           0.4703        True
# 3                        0               0.0000           0.6187       False
# 4                        0               0.0000           0.9040       False
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                     -0.6018                          0.1998
# 1                     -0.3570                          0.0000
# 2                     -0.1260                          0.0000
# 3                      0.0000                          0.0000
# 4                      0.0876                         -0.8896
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                  -0.3333
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  1.0000

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_difference',
#        'tweet_political_polarisation_difference',
#        'tweet_science_polarisation_difference',
#        'tweet_moderacy_polarisation_difference'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)
df_tweetscov19_user.tail()
# Out:
#                   Tweet_Id                          Username  Retweets  \
# 19995  1257837846070726657  5587f06a443319852054e1934db6c45e         0
# 19996  1241407339598680072  80d49897048cd5d63031e78f7578ece6         1
# 19997  1264604972349448192  5e0b5735267e681a6aedbdc451859fa1       140
# 19998  1263503302219763712  206c0118873c3c8e0bc6b1cb6321f9c2         0
# 19999  1223314022365265920  7c4313f09a8be683301c231d5efcde95         0
#
#        Favorites  Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  \
# 19995          0    -0.2200     0.7800     0.0000    -0.6229             0
# 19996          1    -0.0000     0.7620     0.2380     0.3612             0
# 19997        172    -0.1280     0.8720     0.0000    -0.2960             0
# 19998          0    -0.0000     1.0000     0.0000     0.0000             0
# 19999          0    -0.0000     0.7520     0.2480     0.5093             0
#
#        Mentions_num  Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 19995             1       116         0      80.7850          0      0.0000
# 19996             2        53         0      84.9000          0      0.0000
# 19997             0       126         1      58.4070          0      0.0000
# 19998             0        56         0      96.0250          1      0.0000
# 19999             1        43         0      66.7870          1      0.4500
#
#        tweet_politic_polarisation  tweet_science_polarisation  \
# 19995                      0.0000                      0.0000
# 19996                      0.0000                      0.0000
# 19997                      0.0000                      0.0000
# 19998                      0.0000                      0.0000
# 19999                      0.0000                      0.0000
#
#        tweet_moderacy_polarisation  social  family  friend  female    male  \
# 19995                       0.0000 14.2900  0.0000  0.0000  4.7600  0.0000
# 19996                       0.0000 22.2200  0.0000  0.0000  0.0000 11.1100
# 19997                       0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 19998                       0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 19999                       0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#         work  leisure   home  money  relegion  death  informal  swear  \
# 19995 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    4.7600 0.0000
# 19996 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19997 4.3500   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19998 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19999 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#        netspeak  assent  nonflu  filler   body  health  sexual  ingest  \
# 19995    4.7600  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  4.7600
# 19996    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19997    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#        posemo  negemo    anx  anger    sad  insight  cause  discrep  tentat  \
# 19995  0.0000  4.7600 0.0000 0.0000 4.7600   4.7600 4.7600   4.7600  0.0000
# 19996  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19997  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19998  0.0000  0.0000 0.0000 0.0000 0.0000   7.6900 0.0000  15.3800 15.3800
# 19999  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000 16.6700
#
#        certain  differ  affiliation  achiev   power  reward   risk  focuspast  \
# 19995   4.7600  4.7600       0.0000  4.7600  0.0000  0.0000 0.0000     9.5200
# 19996   0.0000  0.0000       0.0000  0.0000 22.2200  0.0000 0.0000     0.0000
# 19997   0.0000  4.3500       0.0000  4.3500  0.0000  0.0000 0.0000     0.0000
# 19998   0.0000  7.6900       0.0000  0.0000  0.0000  0.0000 0.0000     7.6900
# 19999   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000     0.0000
#
#        focuspresent  focusfuture      i     we    you   shehe   they   ipron  \
# 19995        9.5200       0.0000 0.0000 0.0000 0.0000  0.0000 9.5200 14.2900
# 19996       11.1100       0.0000 0.0000 0.0000 0.0000 11.1100 0.0000  0.0000
# 19997        0.0000       0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 19998       15.3800       0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 15.3800
# 19999       16.6700       0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
#
#        article    prep  auxverb  adverb   conj  negate    verb     adj  \
# 19995   0.0000  4.7600  14.2900  0.0000 4.7600  4.7600 23.8100  4.7600
# 19996   0.0000 22.2200   0.0000  0.0000 0.0000  0.0000 11.1100  0.0000
# 19997   0.0000 13.0400   0.0000  0.0000 0.0000  0.0000  0.0000 13.0400
# 19998   0.0000  7.6900  15.3800  0.0000 7.6900  0.0000 30.7700  0.0000
# 19999   0.0000 16.6700   0.0000  0.0000 0.0000  0.0000 16.6700  0.0000
#
#        compare  interrog  number   quant    see   hear   feel  motion   space  \
# 19995   4.7600    0.0000  0.0000  0.0000 0.0000 0.0000 0.0000  4.7600  4.7600
# 19996   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000 0.0000 11.1100 22.2200
# 19997   8.7000    0.0000  4.3500  4.3500 0.0000 0.0000 0.0000  0.0000  8.7000
# 19998   0.0000    7.6900  0.0000  0.0000 0.0000 0.0000 0.0000  7.6900  0.0000
# 19999   0.0000    0.0000  0.0000 16.6700 0.0000 0.0000 0.0000  0.0000  0.0000
#
#          time  user_political_polarisation  user_science_polarisation  \
# 19995  0.0000                       0.0000                     0.0000
# 19996  0.0000                       0.0000                     0.0000
# 19997 17.3900                       0.0000                     0.0000
# 19998  0.0000                       0.0000                     0.0000
# 19999 16.6700                      -1.0000                     0.0000
#
#        user_moderacy_polarisation  user_num_posted_tweets  \
# 19995                      0.0000                       5
# 19996                      0.0000                       1
# 19997                      0.0000                     964
# 19998                      0.0000                       1
# 19999                     -1.0000                      28
#
#        user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  \
# 19995                        3               0.6000           0.6637
# 19996                        1               1.0000           0.4733
# 19997                        3               0.0031           0.9998
# 19998                        1               1.0000           0.2346
# 19999                        0               0.0000           0.8227
#
#        Is_deleted  user_vadercompound_average  tweet_vadercompound_difference  \
# 19995           1                     -0.0346                         -0.5883
# 19996           1                      0.3612                          0.0000
# 19997           0                     -0.0429                         -0.2531
# 19998           1                      0.0000                          0.0000
# 19999           0                      0.0684                          0.4409
#
#        tweet_political_polarisation_difference  \
# 19995                                   0.0000
# 19996                                   0.0000
# 19997                                   0.0000
# 19998                                   0.0000
# 19999                                   1.0000
#
#        tweet_science_polarisation_difference  \
# 19995                                 0.0000
# 19996                                 0.0000
# 19997                                 0.0000
# 19998                                 0.0000
# 19999                                 0.0000
#
#        tweet_moderacy_polarisation_difference
# 19995                                  0.0000
# 19996                                  0.0000
# 19997                                  0.0000
# 19998                                  0.0000
# 19999                                  1.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (20000, 89)
# (20000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
 X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 89)
# (4000, 89)
# (16000,)
# (4000,)

# %%
def test_gradientboosting_clf(model, X_test, y_test):
    
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
gb_model = fit_gradientboosting_clf(X_train, y_train)

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_GB_Benutzer_Inhalt_alle_ohne_moderacy_2.sav'
#pickle.dump(gb_model, open(pfad_modell, 'wb'))

# %%
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# Accuracy : 0.61325

# %%
y_pred = gb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.53      0.58      1994
#            1       0.60      0.69      0.64      2006
#
#     accuracy                           0.61      4000
#    macro avg       0.62      0.61      0.61      4000
# weighted avg       0.62      0.61      0.61      4000

# %%
def plot_confusion_matrix(y_test, y_pred, classes, titel):
    
    confusion_mx = confusion_matrix(y_test, y_pred)
    confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
    
    sns.heatmap(confusion_mx, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_test, y_pred, gb_model.classes_, 'Confusion Matrix')

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.009
#  f1        : 0.65 +/- 0.010
#  recall    : 0.71 +/- 0.016

# %%
def features_classifier_(df, model):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = model.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)

    df_column_feature = df_column_feature.reset_index()
    df_column_feature
    return df_column_feature

# %%
f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.2752
# 1      80              user_political_polarisation      0.1060
# 2      81                user_science_polarisation      0.0766
# 3       9                                 URLs_num      0.0728
# 4       8                                 Text_len      0.0411
# 5       6                             Hashtags_num      0.0403
# 6      10                              readability      0.0288
# 7      27                                 informal      0.0198
# 8      58                                      you      0.0198
# 9      63                                     prep      0.0189
# 10     56                                        i      0.0180
# 11     84               user_vadercompound_average      0.0177
# 12     68                                     verb      0.0141
# 13      5                                vader_com      0.0141
# 14     82               user_moderacy_polarisation      0.0140
# 15     85           tweet_vadercompound_difference      0.0111
# 16      0                                 Retweets      0.0101
# 17     28                                    swear      0.0098
# 18     77                                   motion      0.0092
# 19     59                                    shehe      0.0087
# 20     38                                   negemo      0.0083
# 21     21                                     work      0.0083
# 22     65                                   adverb      0.0069
# 23      3                                Vader_neu      0.0064
# 24     19                                   female      0.0061
# 25     11                                Emoji_num      0.0059
# 26     16                                   social      0.0057
# 27     79                                     time      0.0052
# 28     66                                     conj      0.0051
# 29      7                             Mentions_num      0.0050
# 30     35                                   sexual      0.0050
# 31     78                                    space      0.0048
# 32     12                               Emoji_sent      0.0045
# 33     87    tweet_science_polarisation_difference      0.0043
# 34     37                                   posemo      0.0042
# 35     61                                    ipron      0.0041
# 36     45                                   tentat      0.0041
# 37     29                                 netspeak      0.0038
# 38     55                              focusfuture      0.0036
# 39     69                                      adj      0.0035
# 40     60                                     they      0.0034
# 41      4                                Vader_pos      0.0033
# 42     64                                  auxverb      0.0031
# 43     33                                     body      0.0030
# 44     42                                  insight      0.0028
# 45     74                                      see      0.0025
# 46     48                              affiliation      0.0025
# 47     49                                   achiev      0.0024
# 48     70                                  compare      0.0024
# 49     51                                   reward      0.0023
# 50     73                                    quant      0.0022
# 51     43                                    cause      0.0022
# 52     47                                   differ      0.0022
# 53     86  tweet_political_polarisation_difference      0.0021
# 54     67                                   negate      0.0021
# 55     40                                    anger      0.0020
# 56     88   tweet_moderacy_polarisation_difference      0.0018
# 57     53                                focuspast      0.0018
# 58     17                                   family      0.0017
# 59     44                                  discrep      0.0016
# 60      1                                Favorites      0.0015
# 61     18                                   friend      0.0014
# 62     24                                    money      0.0014
# 63     22                                  leisure      0.0013
# 64     50                                    power      0.0013
# 65     32                                   filler      0.0012
# 66     20                                     male      0.0012
# 67     23                                     home      0.0011
# 68     13               tweet_politic_polarisation      0.0011
# 69     46                                  certain      0.0011
# 70     34                                   health      0.0010
# 71     54                             focuspresent      0.0010
# 72     31                                   nonflu      0.0010
# 73     76                                     feel      0.0009
# 74     26                                    death      0.0008
# 75     36                                   ingest      0.0007
# 76      2                                Vader_neg      0.0007
# 77     30                                   assent      0.0006
# 78     75                                     hear      0.0006
# 79     15              tweet_moderacy_polarisation      0.0005
# 80     71                                 interrog      0.0005
# 81     62                                  article      0.0004
# 82     52                                     risk      0.0004
# 83     25                                 relegion      0.0000
# 84     72                                   number      0.0000
# 85     39                                      anx      0.0000
# 86     41                                      sad      0.0000
# 87     14               tweet_science_polarisation      0.0000
# 88     57                                       we      0.0000

# %%
f_importances = f_importances[f_importances['importance'] >= 0.001]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'user_political_polarisation'
#  'user_science_polarisation' 'URLs_num' 'Text_len' 'Hashtags_num'
#  'readability' 'informal' 'you' 'prep' 'i' 'user_vadercompound_average'
#  'verb' 'vader_com' 'user_moderacy_polarisation'
#  'tweet_vadercompound_difference' 'Retweets' 'swear' 'motion' 'shehe'
#  'negemo' 'work' 'adverb' 'Vader_neu' 'female' 'Emoji_num' 'social' 'time'
#  'conj' 'Mentions_num' 'sexual' 'space' 'Emoji_sent'
#  'tweet_science_polarisation_difference' 'posemo' 'ipron' 'tentat'
#  'netspeak' 'focusfuture' 'adj' 'they' 'Vader_pos' 'auxverb' 'body'
#  'insight' 'see' 'affiliation' 'achiev' 'compare' 'reward' 'quant' 'cause'
#  'differ' 'tweet_political_polarisation_difference' 'negate' 'anger'
#  'tweet_moderacy_polarisation_difference' 'focuspast' 'family' 'discrep'
#  'Favorites' 'friend' 'money' 'leisure' 'power' 'filler' 'male' 'home'
#  'tweet_politic_polarisation' 'certain' 'health' 'focuspresent']

# %%
len(f_importances)
# Out:
# 72

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (20000, 72)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 72)
# (4000, 72)
# (16000,)
# (4000,)

# %%
rf_model = fit_gradientboosting_clf(X_train, y_train)

# %%
test_gradientboosting_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.61325

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.54      0.58      1994
#            1       0.60      0.69      0.64      2006
#
#     accuracy                           0.61      4000
#    macro avg       0.62      0.61      0.61      4000
# weighted avg       0.62      0.61      0.61      4000

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.009
#  f1        : 0.65 +/- 0.009
#  recall    : 0.71 +/- 0.014

# %% [markdown]
# ***

# %% [markdown]
# ## SelectFromModel
# ### Tweetscov19(content + user)

# %%
# %%time
selector = SelectFromModel(GradientBoostingClassifier(n_estimators=100), threshold = 0.001)
selector.fit(X_train, y_train)
# Out:
# Wall time: 6.59 s
# SelectFromModel(estimator=GradientBoostingClassifier(random_state=0),
#                 threshold=0.001)

# %%
def features_classifier_selectfrommodell(df, selector):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = selector.estimator_.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)
    
    df_column_feature = df_column_feature.reset_index()
    features = df.columns[selector.get_support()]
    df_column_feature = df_column_feature[0: len(features)]
    
    return df_column_feature

# %%
# %%time
f_importances_sfm = features_classifier_selectfrommodell(X, selector)
f_importances_sfm
# Out:
# Wall time: 38.9 ms
#     index                                  Feature  importance
# 0       0                          user_Reputation      0.2798
# 1       1              user_political_polarisation      0.1049
# 2       2                user_science_polarisation      0.0774
# 3       3                                 URLs_num      0.0729
# 4       4                                 Text_len      0.0407
# 5       5                             Hashtags_num      0.0389
# 6       6                              readability      0.0266
# 7       7                                 informal      0.0214
# 8      11               user_vadercompound_average      0.0206
# 9       8                                      you      0.0201
# 10     10                                        i      0.0172
# 11      9                                     prep      0.0159
# 12     12                                     verb      0.0144
# 13     14               user_moderacy_polarisation      0.0142
# 14     15           tweet_vadercompound_difference      0.0134
# 15     16                                 Retweets      0.0123
# 16     13                                vader_com      0.0110
# 17     21                                     work      0.0102
# 18     27                                     time      0.0101
# 19     17                                    swear      0.0099
# 20     18                                   motion      0.0094
# 21     20                                   negemo      0.0074
# 22     22                                   adverb      0.0068
# 23     30                                   sexual      0.0066
# 24     19                                    shehe      0.0063
# 25     29                             Mentions_num      0.0059
# 26     24                                   female      0.0058
# 27     31                                    space      0.0055
# 28     25                                Emoji_num      0.0052
# 29     33    tweet_science_polarisation_difference      0.0049
# 30     37                                 netspeak      0.0047
# 31     23                                Vader_neu      0.0047
# 32     26                                   social      0.0045
# 33     34                                   posemo      0.0043
# 34     36                                   tentat      0.0042
# 35     41                                Vader_pos      0.0042
# 36     38                              focusfuture      0.0038
# 37     32                               Emoji_sent      0.0037
# 38     45                                      see      0.0036
# 39     62                                    money      0.0034
# 40     46                              affiliation      0.0033
# 41     35                                    ipron      0.0033
# 42     52                                   differ      0.0033
# 43     47                                   achiev      0.0033
# 44     40                                     they      0.0032
# 45     39                                      adj      0.0031
# 46     60                                Favorites      0.0030
# 47     50                                    quant      0.0029
# 48     49                                   reward      0.0029
# 49     71                             focuspresent      0.0028
# 50     53  tweet_political_polarisation_difference      0.0027
# 51     44                                  insight      0.0026
# 52     43                                     body      0.0024
# 53     28                                     conj      0.0023
# 54     51                                    cause      0.0023
# 55     63                                  leisure      0.0022
# 56     68               tweet_politic_polarisation      0.0021
# 57     48                                  compare      0.0021
# 58     55                                    anger      0.0019
# 59     58                                   family      0.0017
# 60     64                                    power      0.0013
# 61     61                                   friend      0.0011
# 62     66                                     male      0.0010

# %%
def transform_data(selector, df):
    
    features = df.columns[selector.get_support()]
    print('Number of selected features:', len(features))
    print('')
    print('Selected features: \n', features.tolist())

    X_new = selector.transform(X)
    
    print('Shape of new X:', X_new.shape)

    return X_new

# %%
 X_new = transform_data(selector, X)
# Out:
# Number of selected features: 63
#
# Selected features:
#  ['user_Reputation', 'user_political_polarisation', 'user_science_polarisation', 'URLs_num', 'Text_len', 'Hashtags_num', 'readability', 'informal', 'you', 'prep', 'i', 'user_vadercompound_average', 'verb', 'vader_com', 'user_moderacy_polarisation', 'tweet_vadercompound_difference', 'Retweets', 'swear', 'motion', 'shehe', 'negemo', 'work', 'adverb', 'Vader_neu', 'female', 'Emoji_num', 'social', 'time', 'conj', 'Mentions_num', 'sexual', 'space', 'Emoji_sent', 'tweet_science_polarisation_difference', 'posemo', 'ipron', 'tentat', 'netspeak', 'focusfuture', 'adj', 'they', 'Vader_pos', 'body', 'insight', 'see', 'affiliation', 'achiev', 'compare', 'reward', 'quant', 'cause', 'differ', 'tweet_political_polarisation_difference', 'anger', 'family', 'Favorites', 'friend', 'money', 'leisure', 'power', 'male', 'tweet_politic_polarisation', 'focuspresent']

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200,  learning_rate = 0.01 )  
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.014

# %% [markdown]
# ***

# %% [markdown]
# ## Rekursive Feature Elimination(RFE)
# ### tweetscov19(content + user)

# %%
# %%time
selector = RFE(GradientBoostingClassifier(n_estimators=100))
selector.fit(X_train, y_train)
# Out:
# Wall time: 3min 23s
# RFE(estimator=GradientBoostingClassifier(random_state=0))

# %%
def features_classifier_rfe(df, selector):

    column_feature = {}

    for i, c in enumerate(df):
        column_feature[c] = selector.estimator_.feature_importances_[i]
        #print(c)

    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)
    
    return df_column_feature.reset_index()

# %%
# %%time
df_rfe_selected = X[X.columns[selector.get_support()]]
f_importances_rfe = features_classifier_rfe(df_rfe_selected, selector)
f_importances_rfe
# Out:
# Wall time: 24.9 ms
#     index                                Feature  importance
# 0       0                        user_Reputation      0.2853
# 1       1            user_political_polarisation      0.1093
# 2       2              user_science_polarisation      0.0779
# 3       3                               URLs_num      0.0753
# 4       5                           Hashtags_num      0.0423
# 5       4                               Text_len      0.0411
# 6       6                            readability      0.0357
# 7       8                                    you      0.0226
# 8      16                               Retweets      0.0213
# 9       7                               informal      0.0207
# 10     11             user_vadercompound_average      0.0191
# 11     10                                      i      0.0187
# 12     15         tweet_vadercompound_difference      0.0183
# 13     12                                   verb      0.0179
# 14     14             user_moderacy_polarisation      0.0177
# 15      9                                   prep      0.0167
# 16     13                              vader_com      0.0155
# 17     21                                   work      0.0131
# 18     23                              Vader_neu      0.0108
# 19     22                                 adverb      0.0103
# 20     17                                  swear      0.0100
# 21     19                                  shehe      0.0093
# 22     18                                 motion      0.0089
# 23     26                                   time      0.0087
# 24     33                                  ipron      0.0085
# 25     25                                 social      0.0082
# 26     29                                 sexual      0.0079
# 27     24                              Emoji_num      0.0077
# 28     20                                 negemo      0.0071
# 29     35                                    adj      0.0063
# 30     31  tweet_science_polarisation_difference      0.0056
# 31     28                           Mentions_num      0.0053
# 32     34                            focusfuture      0.0051
# 33     30                                  space      0.0043
# 34     27                                   conj      0.0042
# 35     32                                 posemo      0.0032

# %%
 X_new = transform_data(selector, X)
# Out:
# Number of selected features: 36
#
# Selected features:
#  ['user_Reputation', 'user_political_polarisation', 'user_science_polarisation', 'URLs_num', 'Text_len', 'Hashtags_num', 'readability', 'informal', 'you', 'prep', 'i', 'user_vadercompound_average', 'verb', 'vader_com', 'user_moderacy_polarisation', 'tweet_vadercompound_difference', 'Retweets', 'swear', 'motion', 'shehe', 'negemo', 'work', 'adverb', 'Vader_neu', 'Emoji_num', 'social', 'time', 'conj', 'Mentions_num', 'sexual', 'space', 'tweet_science_polarisation_difference', 'posemo', 'ipron', 'focusfuture', 'adj']
# Shape of new X: (20000, 36)

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01 )  
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.58 +/- 0.006
#  f1        : 0.67 +/- 0.008
#  recall    : 0.79 +/- 0.016

# %% [markdown]
# ***

# %%
learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]

for i in range(len(learning_rate)):

    clf_cv = GradientBoostingClassifier(n_estimators=100, learning_rate = learning_rate[i] )  
    
    print('learning_rate = ', learning_rate[i])
    print_cross_val_score(clf_cv, X_new, y)
    print('---------------------------')
# Out:
# learning_rate =  0.0001
#  percision : 0.57 +/- 0.009
#  f1        : 0.65 +/- 0.011
#  recall    : 0.77 +/- 0.037
# ---------------------------
# learning_rate =  0.001
#  percision : 0.57 +/- 0.012
#  f1        : 0.65 +/- 0.007
#  recall    : 0.76 +/- 0.030
# ---------------------------
# learning_rate =  0.01
#  percision : 0.58 +/- 0.006
#  f1        : 0.67 +/- 0.008
#  recall    : 0.79 +/- 0.016
# ---------------------------
# learning_rate =  0.1
#  percision : 0.60 +/- 0.010
#  f1        : 0.65 +/- 0.010
#  recall    : 0.71 +/- 0.014
# ---------------------------
# learning_rate =  0.2
#  percision : 0.61 +/- 0.009
#  f1        : 0.64 +/- 0.010
#  recall    : 0.69 +/- 0.014
# ---------------------------
# learning_rate =  0.3
#  percision : 0.61 +/- 0.011
#  f1        : 0.63 +/- 0.010
#  recall    : 0.66 +/- 0.013
# ---------------------------

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]

for i in range(len(n_estimators)):

    clf_cv = GradientBoostingClassifier(n_estimators = n_estimators[i], learning_rate= 0.01)
    
    print('n_estimators = ', n_estimators[i])
    print_cross_val_score(clf_cv, X_new, y)
    print('---------------------------')
# Out:
# n_estimators =  100
#  percision : 0.58 +/- 0.006
#  f1        : 0.67 +/- 0.008
#  recall    : 0.79 +/- 0.016
# ---------------------------
# n_estimators =  200
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.014
# ---------------------------
# n_estimators =  300
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.007
#  recall    : 0.74 +/- 0.011
# ---------------------------
# n_estimators =  400
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.007
#  recall    : 0.73 +/- 0.012
# ---------------------------
# n_estimators =  500
#  percision : 0.60 +/- 0.006
#  f1        : 0.65 +/- 0.007
#  recall    : 0.73 +/- 0.013
# ---------------------------
# n_estimators =  1000
#  percision : 0.60 +/- 0.010
#  f1        : 0.65 +/- 0.009
#  recall    : 0.71 +/- 0.012
# ---------------------------

# %% [markdown]
# ***

# %%
m_leafnode = [2,4,8,16,32,64,128]

for i in range(len(m_leafnode)):

    clf_cv = GradientBoostingClassifier(n_estimators = 200,  learning_rate= 0.01, max_leaf_nodes = m_leafnode[i])
    print('max_leaf_nodes = ', m_leafnode[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# max_leaf_nodes =  2
#  percision : 0.57 +/- 0.007
#  f1        : 0.66 +/- 0.007
#  recall    : 0.79 +/- 0.015
# ---------------------------
# max_leaf_nodes =  4
#  percision : 0.59 +/- 0.008
#  f1        : 0.66 +/- 0.008
#  recall    : 0.74 +/- 0.015
# ---------------------------
# max_leaf_nodes =  8
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  16
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  32
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  64
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  128
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200, learning_rate=0.01, max_leaf_nodes=8, loss='deviance' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200, learning_rate=0.01, max_leaf_nodes=8, loss='exponential' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200, learning_rate=0.01, max_leaf_nodes=8, criterion='mse' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01,max_leaf_nodes=8,criterion='squared_error')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=200, learning_rate= 0.01, max_leaf_nodes=8 )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.010
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.010
# Wall time: 8min 19s

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100, learning_rate= 0.01, max_leaf_nodes=8 )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.008
#  f1        : 0.66 +/- 0.010
#  recall    : 0.78 +/- 0.019
# Wall time: 4min 11s

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ****

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.1 )  
print_cross_val_score(clf_cv, X, y)

# %% [markdown]
# ## Plot feature Imortances
# ### TweetCov19 (Content + User)

# %%
def plot_hist_Features(l_features_importances, l_features, titel):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue', 'indigo', 'brown', 'green', 'black']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
         
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout() #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Political p.u.', 'Retweets', 'Likes', 'Reputation', 'Science p.u.']

# %%
plot_hist_Features(l_features_importances, l_features, 'Gb_TweetsCov19_content_User(reputation)_2_o_moderacy_all_del')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ## TweetsCov19
# ### (Content only)

# %%
features = df_tweetscov19_user.columns
features

#features = features[2:83]
df_tweetscov19_user = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (20000, 80)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 80)
# (4000, 80)
# (16000,)
# (4000,)

# %%
# %%time
gb_model = fit_gradientboosting_clf(X_train, y_train)
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# Accuracy : 0.59375
# Wall time: 6.11 s

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_GB_Inhalt_all_ohne_moderacy.sav'
#pickle.dump(gb_model, open(pfad_modell, 'wb'))

# %%
f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                      Feature  importance
# 0       9                     URLs_num      0.1057
# 1       0                     Retweets      0.0707
# 2       8                     Text_len      0.0562
# 3       1                    Favorites      0.0538
# 4      14   tweet_science_polarisation      0.0509
# 5      10                  readability      0.0465
# 6       6                 Hashtags_num      0.0427
# 7      13   tweet_politic_polarisation      0.0338
# 8      68                         verb      0.0333
# 9      63                         prep      0.0298
# 10     27                     informal      0.0285
# 11     21                         work      0.0230
# 12     56                            i      0.0225
# 13     77                       motion      0.0213
# 14      5                    vader_com      0.0203
# 15     35                       sexual      0.0175
# 16     11                    Emoji_num      0.0172
# 17     60                         they      0.0169
# 18     58                          you      0.0166
# 19     78                        space      0.0117
# 20     59                        shehe      0.0116
# 21     79                         time      0.0106
# 22     52                         risk      0.0105
# 23     16                       social      0.0095
# 24     69                          adj      0.0093
# 25     15  tweet_moderacy_polarisation      0.0092
# 26      7                 Mentions_num      0.0091
# 27     33                         body      0.0081
# 28     74                          see      0.0081
# 29     53                    focuspast      0.0080
# 30      2                    Vader_neg      0.0079
# 31     55                  focusfuture      0.0074
# 32     49                       achiev      0.0070
# 33     34                       health      0.0069
# 34     22                      leisure      0.0069
# 35     50                        power      0.0068
# 36      3                    Vader_neu      0.0067
# 37     28                        swear      0.0066
# 38      4                    Vader_pos      0.0066
# 39     45                       tentat      0.0064
# 40     47                       differ      0.0062
# 41     61                        ipron      0.0062
# 42     48                  affiliation      0.0060
# 43     19                       female      0.0060
# 44     12                   Emoji_sent      0.0059
# 45     62                      article      0.0059
# 46     20                         male      0.0057
# 47     65                       adverb      0.0057
# 48     43                        cause      0.0054
# 49     37                       posemo      0.0053
# 50     64                      auxverb      0.0051
# 51     42                      insight      0.0045
# 52     54                 focuspresent      0.0042
# 53     38                       negemo      0.0042
# 54     70                      compare      0.0040
# 55     51                       reward      0.0038
# 56     75                         hear      0.0036
# 57     29                     netspeak      0.0036
# 58     24                        money      0.0034
# 59     67                       negate      0.0029
# 60     66                         conj      0.0026
# 61     36                       ingest      0.0025
# 62     23                         home      0.0024
# 63     57                           we      0.0024
# 64     44                      discrep      0.0018
# 65     73                        quant      0.0017
# 66     46                      certain      0.0013
# 67     76                         feel      0.0011
# 68     39                          anx      0.0009
# 69     30                       assent      0.0009
# 70     26                        death      0.0007
# 71     31                       nonflu      0.0007
# 72     71                     interrog      0.0006
# 73     40                        anger      0.0004
# 74     72                       number      0.0000
# 75     32                       filler      0.0000
# 76     18                       friend      0.0000
# 77     25                     relegion      0.0000
# 78     41                          sad      0.0000
# 79     17                       family      0.0000

# %%
y_pred = gb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58      2002
#            1       0.59      0.62      0.60      1998
#
#     accuracy                           0.59      4000
#    macro avg       0.59      0.59      0.59      4000
# weighted avg       0.59      0.59      0.59      4000

# %%
plot_confusion_matrix(y_test, y_pred, gb_model.classes_, 'Confusion Matrix')

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.1 )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.008
#  f1        : 0.61 +/- 0.008
#  recall    : 0.63 +/- 0.008
# Wall time: 3min 27s

# %% [markdown]
# ********************************************************
# ********************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### TweetsCov19 (Content Only)

# %%
def plot_hist_Features_content_only(l_features_importances, l_features, titel):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['brown', 'peru', 'black','tan', 'mediumslateblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
         
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    
    fig.tight_layout()  
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Retweets', 'Likes', 'Science p.T.', 'Political p.T.', 'Text l.']

# %%
plot_hist_Features_content_only(l_features_importances, l_features, 'Gb_TweetsCov19_content_only_o_moderacy_all_del')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# # Tweetskb
# ### (Content + User Features)

# %%
path = '../data/df_tweetskb_sample_20000.tsv'

df_tweetskb_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference'])

print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (20000, 95)
#               Tweet_Id       Username  Retweets  Favorites  Vader_neg  \
# 0  1225591042872954881  MarylandTwang         0          0    -0.0000
# 1  1228234997900824578  yv04_official         0          0    -0.0000
# 2  1219729452713644032   TupacAlbania         0          0    -0.0000
# 3  1211057745979461632       BigZuri_         0          0    -0.6020
# 4  1247337657698525184  trinamoriarty         0          0    -0.0690
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     0.6490     0.3510     0.9448             0             0       182
# 1     0.9310     0.0690     0.4137             1             0       253
# 2     1.0000     0.0000     0.0000             0             0        80
# 3     0.3980     0.0000    -0.7930             0             0        27
# 4     0.5900     0.3410     0.8625             0             1       137
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0      95.8030          0      0.0000                      0.0000
# 1         0      55.8270          0      0.0000                      0.0000
# 2         0      65.1680          0      0.0000                      0.0000
# 3         0      83.3200          0      0.0000                      0.0000
# 4         0      56.7990          2      0.4840                      0.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000  6.0600  3.0300
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000  5.8800  0.0000
# 3                      0.0000                       0.0000 16.6700  0.0000
# 4                      0.0000                       0.0000 11.5400  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  0.0000  3.0300 3.0300 0.0000   3.0300 0.0000 3.0300    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    3.0300 0.0000    0.0000  3.0300  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4   15.3800 3.8500    3.8500  7.6900  3.8500  0.0000 0.0000  3.8500  3.8500
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  6.0600  0.0000 0.0000 0.0000 0.0000   0.0000 6.0600   0.0000
# 1  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   2.4400 2.4400   2.4400
# 2  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000  11.7600 0.0000   0.0000
# 3  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  3.8500  3.8500  3.8500 0.0000 3.8500 0.0000   0.0000 0.0000   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000       6.0600  0.0000 0.0000  3.0300 0.0000
# 1  4.8800   0.0000  4.8800       0.0000  0.0000 0.0000  0.0000 2.4400
# 2  0.0000   0.0000  0.0000       0.0000  0.0000 5.8800  0.0000 0.0000
# 3  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  3.8500 0.0000
#
#    focuspast  focuspresent  focusfuture      i     we    you  shehe    they  \
# 0    21.2100        0.0000       0.0000 0.0000 0.0000 3.0300 0.0000  6.0600
# 1     9.7600        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000  4.8800
# 2    17.6500        0.0000      23.5300 0.0000 0.0000 0.0000 0.0000  5.8800
# 3    16.6700        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 16.6700
# 4     3.8500        3.8500       7.6900 0.0000 3.8500 0.0000 0.0000  0.0000
#
#    ipron  article    prep  auxverb  adverb   conj  negate   verb    adj  \
# 0 3.0300   6.0600  6.0600   6.0600  9.0900 0.0000 21.2100 6.0600 0.0000
# 1 9.7600  12.2000  9.7600   4.8800  2.4400 4.8800 14.6300 2.4400 2.4400
# 2 5.8800   5.8800  5.8800   5.8800 11.7600 0.0000 17.6500 5.8800 0.0000
# 3 0.0000  16.6700  0.0000   0.0000  0.0000 0.0000 16.6700 0.0000 0.0000
# 4 0.0000  15.3800 11.5400   7.6900  7.6900 0.0000 19.2300 3.8500 7.6900
#
#    compare  interrog  number  quant     see   hear   feel  motion   space  \
# 0   0.0000    0.0000  3.0300 0.0000  0.0000 0.0000 3.0300  3.0300  6.0600
# 1   2.4400    2.4400  2.4400 0.0000  0.0000 0.0000 2.4400 12.2000  0.0000
# 2   5.8800    5.8800  0.0000 0.0000  5.8800 0.0000 0.0000 11.7600  5.8800
# 3   0.0000    0.0000  0.0000 0.0000 16.6700 0.0000 0.0000  0.0000  0.0000
# 4   3.8500    0.0000  0.0000 0.0000  3.8500 0.0000 0.0000  0.0000 11.5400
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       1
# 2                      0.0000                       1
# 3                      0.0000                       8
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.8684        True
# 1                        1               1.0000           0.0187        True
# 2                        1               1.0000           0.2329        True
# 3                        8               1.0000           0.6473        True
# 4                        1               1.0000           0.1885        True
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                      0.9448                          0.0000
# 1                      0.4137                          0.0000
# 2                      0.0000                          0.0000
# 3                     -0.0037                         -0.7893
# 4                      0.8625                          0.0000
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
features = df_tweetskb_user.columns
#features

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 0, 1)
df_tweetskb_user.tail()
# Out:
#                   Tweet_Id         Username  Retweets  Favorites  Vader_neg  \
# 19995  1202377071797899266    derekhalfdead         0          0    -0.0000
# 19996  1182914318452441088   littledolanhoe         0          0    -0.0000
# 19997  1240556004686864384         Here4Kat         2          8    -0.0000
# 19998  1250120446533447681  ramonsalinasart         7         20    -0.0000
# 19999  1220777813881393152      Swordsfall1        79        250    -0.1560
#
#        Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 19995     0.5220     0.4780     0.6705             1             0        67
# 19996     1.0000     0.0000     0.0000             0             1        49
# 19997     0.7770     0.2230     0.9118             0             1       288
# 19998     0.8640     0.1360     0.7482             1             0       298
# 19999     0.6070     0.2360     0.6908             0             1       199
#
#        URLs_num  readability  Emoji_num  Emoji_sent  \
# 19995         0      18.4440          1      0.7670
# 19996         0      61.2400          0      0.0000
# 19997         1      55.9310          0      0.0000
# 19998         5      57.1190          6      0.3690
# 19999         0      90.0320          0      0.0000
#
#        tweet_politic_polarisation  tweet_science_polarisation  \
# 19995                      0.0000                      0.0000
# 19996                      0.0000                      0.0000
# 19997                      0.0000                      0.0000
# 19998                      0.0000                      0.0000
# 19999                      0.0000                      0.0000
#
#        tweet_moderacy_polarisation  social  family  friend  female   male  \
# 19995                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 19996                       0.0000 37.5000  0.0000  0.0000  0.0000 0.0000
# 19997                       0.0000 11.1100  0.0000  0.0000  3.7000 0.0000
# 19998                       0.0000  6.3800  0.0000  0.0000  0.0000 0.0000
# 19999                       0.0000  8.5700  0.0000  2.8600  0.0000 0.0000
#
#         work  leisure   home  money  relegion  death  informal  swear  \
# 19995 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19996 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000   12.5000 0.0000
# 19997 0.0000   3.7000 0.0000 1.8500    0.0000 0.0000    0.0000 0.0000
# 19998 2.1300   4.2600 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19999 2.8600   2.8600 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#        netspeak  assent  nonflu  filler   body  health  sexual  ingest  \
# 19995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19996   12.5000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19997    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  1.8500
# 19998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#        posemo  negemo    anx  anger    sad  insight  cause  discrep  tentat  \
# 19995  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19996 12.5000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19997  5.5600  0.0000 0.0000 0.0000 0.0000   0.0000 1.8500   3.7000  0.0000
# 19998  2.1300  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19999  5.7100  5.7100 0.0000 5.7100 0.0000   2.8600 2.8600   0.0000  0.0000
#
#        certain  differ  affiliation  achiev  power  reward   risk  focuspast  \
# 19995   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000
# 19996   0.0000  0.0000      12.5000  0.0000 0.0000  0.0000 0.0000    12.5000
# 19997   5.5600  0.0000       0.0000  1.8500 7.4100  3.7000 0.0000    11.1100
# 19998   0.0000  0.0000       2.1300  2.1300 0.0000  0.0000 0.0000     4.2600
# 19999   2.8600  0.0000       5.7100  0.0000 0.0000  8.5700 0.0000     8.5700
#
#        focuspresent  focusfuture      i      we    you  shehe   they  ipron  \
# 19995        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 19996        0.0000      12.5000 0.0000 12.5000 0.0000 0.0000 0.0000 0.0000
# 19997        0.0000       0.0000 0.0000  5.5600 3.7000 0.0000 0.0000 5.5600
# 19998        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 2.1300
# 19999        0.0000       0.0000 0.0000  0.0000 0.0000 2.8600 5.7100 5.7100
#
#        article    prep  auxverb  adverb   conj  negate   verb    adj  compare  \
# 19995   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000   0.0000
# 19996  12.5000 12.5000  12.5000  0.0000 0.0000 12.5000 0.0000 0.0000   0.0000
# 19997  11.1100  9.2600   9.2600  3.7000 0.0000 14.8100 7.4100 1.8500   1.8500
# 19998   4.2600  0.0000   0.0000  2.1300 0.0000  2.1300 0.0000 0.0000   0.0000
# 19999  17.1400  5.7100   2.8600  0.0000 0.0000 11.4300 5.7100 0.0000   0.0000
#
#        interrog  number  quant    see   hear   feel  motion   space   time  \
# 19995    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 19996    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 12.5000 12.5000 0.0000
# 19997    0.0000  1.8500 5.5600 0.0000 0.0000 1.8500  7.4100  1.8500 0.0000
# 19998    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 19999    0.0000  0.0000 0.0000 0.0000 0.0000 2.8600  5.7100  0.0000 0.0000
#
#        user_political_polarisation  user_science_polarisation  \
# 19995                       0.0000                     0.0000
# 19996                       0.0000                     0.0000
# 19997                       0.0000                     0.0000
# 19998                       0.0000                     0.0000
# 19999                       0.0000                     0.0000
#
#        user_moderacy_polarisation  user_num_posted_tweets  \
# 19995                      0.0000                       1
# 19996                      0.0000                       4
# 19997                      0.0000                       1
# 19998                      0.0000                       4
# 19999                      0.0000                      24
#
#        user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  \
# 19995                        0               0.0000           0.8610
# 19996                        0               0.0000           0.8656
# 19997                        0               0.0000           0.9865
# 19998                        0               0.0000           0.3747
# 19999                        0               0.0000           0.9064
#
#        Is_deleted  user_vadercompound_average  tweet_vadercompound_difference  \
# 19995           1                      0.6705                          0.0000
# 19996           1                     -0.1415                          0.0000
# 19997           1                      0.9118                          0.0000
# 19998           1                      0.7764                         -0.0282
# 19999           1                      0.0961                          0.5947
#
#        tweet_political_polarisation_difference  \
# 19995                                   0.0000
# 19996                                   0.0000
# 19997                                   0.0000
# 19998                                   0.0000
# 19999                                   0.0000
#
#        tweet_science_polarisation_difference  \
# 19995                                 0.0000
# 19996                                 0.0000
# 19997                                 0.0000
# 19998                                 0.0000
# 19999                                 0.0000
#
#        tweet_moderacy_polarisation_difference
# 19995                                  0.0000
# 19996                                  0.0000
# 19997                                  0.0000
# 19998                                  0.0000
# 19999                                  0.0000

# %%
print(len(features))
features
# Out:
# 95
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_difference',
#        'tweet_political_polarisation_difference',
#        'tweet_science_polarisation_difference',
#        'tweet_moderacy_polarisation_difference'],
#       dtype='object')

# %%
#df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (20000, 89)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 89)
# (4000, 89)
# (16000,)
# (4000,)

# %%
gb_model = fit_gradientboosting_clf(X_train, y_train)
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# Accuracy : 0.5675

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_GB_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#pickle.dump(gb_model, open(pfad_modell, 'wb'))

# %%
f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.1450
# 1      62                                  article      0.0470
# 2      84               user_vadercompound_average      0.0450
# 3      55                              focusfuture      0.0441
# 4      27                                 informal      0.0385
# 5       8                                 Text_len      0.0367
# 6      82               user_moderacy_polarisation      0.0353
# 7       9                                 URLs_num      0.0348
# 8       7                             Mentions_num      0.0325
# 9      10                              readability      0.0293
# 10     21                                     work      0.0249
# 11      6                             Hashtags_num      0.0235
# 12     80              user_political_polarisation      0.0226
# 13     81                user_science_polarisation      0.0199
# 14     38                                   negemo      0.0199
# 15     61                                    ipron      0.0197
# 16      2                                Vader_neg      0.0178
# 17      0                                 Retweets      0.0164
# 18     85           tweet_vadercompound_difference      0.0164
# 19      5                                vader_com      0.0142
# 20     22                                  leisure      0.0135
# 21     72                                   number      0.0133
# 22     57                                       we      0.0129
# 23     78                                    space      0.0128
# 24     67                                   negate      0.0126
# 25     35                                   sexual      0.0124
# 26     64                                  auxverb      0.0114
# 27     18                                   friend      0.0103
# 28      1                                Favorites      0.0098
# 29      3                                Vader_neu      0.0098
# 30     11                                Emoji_num      0.0097
# 31     63                                     prep      0.0092
# 32     77                                   motion      0.0090
# 33     49                                   achiev      0.0090
# 34     60                                     they      0.0081
# 35     16                                   social      0.0078
# 36      4                                Vader_pos      0.0072
# 37     54                             focuspresent      0.0061
# 38     25                                 relegion      0.0059
# 39     19                                   female      0.0059
# 40     45                                   tentat      0.0058
# 41     50                                    power      0.0057
# 42     37                                   posemo      0.0055
# 43     87    tweet_science_polarisation_difference      0.0053
# 44     73                                    quant      0.0050
# 45     17                                   family      0.0047
# 46     69                                      adj      0.0047
# 47     51                                   reward      0.0043
# 48     29                                 netspeak      0.0042
# 49     86  tweet_political_polarisation_difference      0.0042
# 50     76                                     feel      0.0041
# 51     58                                      you      0.0039
# 52     70                                  compare      0.0038
# 53     23                                     home      0.0037
# 54     46                                  certain      0.0037
# 55     40                                    anger      0.0035
# 56     47                                   differ      0.0034
# 57     31                                   nonflu      0.0033
# 58     53                                focuspast      0.0032
# 59     12                               Emoji_sent      0.0031
# 60     28                                    swear      0.0030
# 61     59                                    shehe      0.0029
# 62     26                                    death      0.0026
# 63     13               tweet_politic_polarisation      0.0023
# 64     75                                     hear      0.0022
# 65     48                              affiliation      0.0020
# 66     44                                  discrep      0.0019
# 67     68                                     verb      0.0019
# 68     43                                    cause      0.0018
# 69     36                                   ingest      0.0018
# 70     33                                     body      0.0017
# 71     66                                     conj      0.0017
# 72     42                                  insight      0.0016
# 73     34                                   health      0.0016
# 74     30                                   assent      0.0015
# 75     56                                        i      0.0013
# 76     39                                      anx      0.0013
# 77     24                                    money      0.0012
# 78     41                                      sad      0.0005
# 79     14               tweet_science_polarisation      0.0000
# 80     15              tweet_moderacy_polarisation      0.0000
# 81     20                                     male      0.0000
# 82     52                                     risk      0.0000
# 83     32                                   filler      0.0000
# 84     65                                   adverb      0.0000
# 85     71                                 interrog      0.0000
# 86     79                                     time      0.0000
# 87     74                                      see      0.0000
# 88     88   tweet_moderacy_polarisation_difference      0.0000

# %%
X_train.shape
# Out:
# (16000, 89)

# %%
y_pred = gb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58      2003
#            1       0.57      0.54      0.55      1997
#
#     accuracy                           0.57      4000
#    macro avg       0.57      0.57      0.57      4000
# weighted avg       0.57      0.57      0.57      4000

# %%
plot_confusion_matrix(y_test, y_pred, gb_model.classes_, 'Confusion Matrix')

# %%
pfad_model = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_GB_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#gb_modell = pickle.load(open(pfad_modell, 'rb'))

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.1 )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.010
#  f1        : 0.55 +/- 0.009
#  recall    : 0.53 +/- 0.013
# Wall time: 3min 21s

# %% [markdown]
# *****************************************************
# *****************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content + User)

# %%
def plot_hist_Features_kb(l_features_importances, l_features, titel):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue', 'brown', 'green', 'Indigo', 'lightblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

   
    fig.tight_layout()
    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Political p.u.', 'Reputation', 'Retweets', 'Science p.u.']

# %%
plot_hist_Features_kb(l_features_importances, l_features, 'Gb_Tweetskb_content_User(reputation)_2_o_moderacy_all_del')

# %% [markdown]
# ***********************************************************************
# ***********************************************************************

# %% [markdown]
# ## Tweetskb
# ### Content only

# %%
features = df_tweetskb_user.columns
features

#features = features[2:83]
df_tweetskb_user = df_tweetskb_user[features.tolist()]
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (20000, 80)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 80)
# (4000, 80)
# (16000,)
# (4000,)

# %%
# %%time
gb_model = fit_gradientboosting_clf(X_train, y_train)
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# Accuracy : 0.56925
# Wall time: 4.88 s

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_GB_Inhalt_alle_ohne_moderacy.sav'
#pickle.dump(gb_model, open(pfad_modell, 'wb'))

# %%
f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                      Feature  importance
# 0       8                     Text_len      0.0673
# 1      55                  focusfuture      0.0526
# 2      27                     informal      0.0463
# 3      62                      article      0.0458
# 4       9                     URLs_num      0.0450
# 5      21                         work      0.0396
# 6       2                    Vader_neg      0.0369
# 7       7                 Mentions_num      0.0331
# 8      10                  readability      0.0315
# 9       1                    Favorites      0.0307
# 10      4                    Vader_pos      0.0265
# 11      6                 Hashtags_num      0.0263
# 12     61                        ipron      0.0248
# 13     38                       negemo      0.0244
# 14      5                    vader_com      0.0234
# 15      0                     Retweets      0.0225
# 16     22                      leisure      0.0216
# 17     60                         they      0.0215
# 18     35                       sexual      0.0200
# 19     57                           we      0.0194
# 20     72                       number      0.0177
# 21     13   tweet_politic_polarisation      0.0150
# 22     78                        space      0.0145
# 23      3                    Vader_neu      0.0126
# 24     77                       motion      0.0123
# 25     64                      auxverb      0.0123
# 26     49                       achiev      0.0122
# 27     63                         prep      0.0122
# 28     45                       tentat      0.0118
# 29     11                    Emoji_num      0.0116
# 30     18                       friend      0.0104
# 31     19                       female      0.0095
# 32     17                       family      0.0095
# 33     67                       negate      0.0093
# 34     29                     netspeak      0.0088
# 35     14   tweet_science_polarisation      0.0084
# 36     37                       posemo      0.0079
# 37     12                   Emoji_sent      0.0077
# 38     51                       reward      0.0071
# 39     54                 focuspresent      0.0069
# 40     68                         verb      0.0068
# 41     47                       differ      0.0064
# 42     53                    focuspast      0.0062
# 43     16                       social      0.0062
# 44     58                          you      0.0062
# 45     42                      insight      0.0061
# 46     43                        cause      0.0055
# 47     69                          adj      0.0052
# 48     73                        quant      0.0048
# 49     59                        shehe      0.0046
# 50     46                      certain      0.0042
# 51     65                       adverb      0.0040
# 52     31                       nonflu      0.0039
# 53     56                            i      0.0039
# 54     15  tweet_moderacy_polarisation      0.0037
# 55     39                          anx      0.0035
# 56     70                      compare      0.0035
# 57     28                        swear      0.0034
# 58     50                        power      0.0033
# 59     34                       health      0.0031
# 60     48                  affiliation      0.0030
# 61     25                     relegion      0.0030
# 62     40                        anger      0.0029
# 63     66                         conj      0.0024
# 64     36                       ingest      0.0024
# 65     44                      discrep      0.0023
# 66     71                     interrog      0.0022
# 67     33                         body      0.0020
# 68     26                        death      0.0018
# 69     30                       assent      0.0013
# 70     24                        money      0.0012
# 71     23                         home      0.0011
# 72     52                         risk      0.0008
# 73     32                       filler      0.0006
# 74     76                         feel      0.0006
# 75     75                         hear      0.0005
# 76     20                         male      0.0004
# 77     74                          see      0.0000
# 78     41                          sad      0.0000
# 79     79                         time      0.0000

# %%
y_pred = gb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.60      0.58      2003
#            1       0.57      0.54      0.55      1997
#
#     accuracy                           0.57      4000
#    macro avg       0.57      0.57      0.57      4000
# weighted avg       0.57      0.57      0.57      4000

# %%
plot_confusion_matrix(y_test, y_pred, gb_model.classes_, 'Confusion Matrix')

# %%
y_prob_test = gb_model.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.6782533090536069

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_GB_Inhalt_alle_ohne_moderacy.sav'
#gb_regression = pickle.load(open(pfad_modell, 'rb'))

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.1 )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.012
#  f1        : 0.55 +/- 0.014
#  recall    : 0.53 +/- 0.019
# Wall time: 2min 41s

# %% [markdown]
# ***************************************************
# ***************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetskb (Content Only)

# %%
def plot_hist_Features_content_only_kb(l_features_importances, l_features, titel):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['brown','khaki', 'lightsalmon', 'lightskyblue', 'maroon']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
    
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    #fig.tight_layout()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Political p.T.', 'Retweets', 'Science p.T.', 'Readability']

# %%
plot_hist_Features_content_only_kb(l_features_importances, l_features, 'Gb_Tweetskb_content_only_o_moderacy_all_del')
