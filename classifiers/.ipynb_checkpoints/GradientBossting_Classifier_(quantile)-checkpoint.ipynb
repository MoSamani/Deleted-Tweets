# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
from termcolor import colored
csv.field_size_limit(100000000)
import pickle

from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# # RandomForestClassifier
# ## TweetsCov19
# ### (Tweet content + user features)

# %%
path = '../data/df_tweetscov19_sample_200000_23.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative', 'Sentiment neutral', 'Sentiment positive', 'Sentiment compound', 'Number of hashtags', 'Number od mentions', 'Text length', 'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent', 'Political polarisation (tweet based)', 'Science polarisation (tweet based)', 'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx', 'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain', 'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk', 'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj', 'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)', 'Reputation (user)', 'Is_deleted', 'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation' ])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1254069159098322947  4e8e74c47b8950e4b3954c86732007f6         0          0
# 1  1249258619562070019  bd41ec450084d9a16582b6fccbddcc9f         0          0
# 2  1244312339756834817  4de0b1281cf756ea9707014c816679a1         0          0
# 3  1182296312932384768  a28f24f00de6b0aebb557d27f9c51500         0          0
# 4  1240046019548721156  a52194236f9679e4183863c3583c6178         0          0
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.2710             0.7290              0.0000
# 2             -0.2100             0.4330              0.3570
# 3             -0.0000             1.0000              0.0000
# 4             -0.1310             0.8690              0.0000
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   0                   0           17
# 1             -0.3818                   0                   0           72
# 2              0.3336                   1                   0           66
# 3              0.0000                   0                   0           93
# 4             -0.2755                   0                   1          111
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      35.6050                 0      0.0000
# 1               1      40.0900                 0      0.0000
# 2               0      75.5000                 1      0.0000
# 3               0      80.0980                 2     -0.1710
# 4               1      61.2400                 0      0.0000
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1                               0.0000  9.0900  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000  9.0900  0.0000  0.0000  0.0000 0.0000
# 3                               0.0000 10.0000  0.0000  0.0000  0.0000 0.0000
# 4                               0.0000 11.1100  0.0000  0.0000  0.0000 0.0000
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 9.0900   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 5.5600   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  9.0900
# 2  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  9.0900
# 3  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 4  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  5.5600  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 9.0900 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  9.0900
# 2 0.0000 0.0000 0.0000   0.0000 0.0000   9.0900  0.0000   0.0000  0.0000
# 3 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  5.5600
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  9.0900 9.0900  0.0000 0.0000     0.0000        0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        9.0900
# 3       0.0000  0.0000 0.0000  0.0000 0.0000    10.0000       20.0000
# 4       0.0000  0.0000 5.5600  0.0000 0.0000     0.0000        5.5600
#
#    Focusfuture      I     We    You  SheHe   They   Ipron  Article    Prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000  0.0000
# 1       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000  9.0900
# 2       0.0000 0.0000 0.0000 9.0900 0.0000 0.0000  0.0000   0.0000  0.0000
# 3       5.0000 0.0000 0.0000 5.0000 0.0000 0.0000 15.0000   0.0000 10.0000
# 4       0.0000 0.0000 0.0000 5.5600 0.0000 0.0000  0.0000   0.0000  0.0000
#
#    Auxverb  Adverb   Conj  Negate    Verb     Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000 0.0000  0.0000 33.3300  0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000 0.0000  9.0900  0.0000  0.0000   0.0000    0.0000  0.0000
# 2   0.0000  9.0900 9.0900  0.0000  9.0900  0.0000   0.0000    0.0000  0.0000
# 3  10.0000  0.0000 5.0000  0.0000 30.0000  5.0000   5.0000    5.0000  0.0000
# 4   0.0000  5.5600 5.5600  5.5600  5.5600 11.1100   0.0000    5.5600  0.0000
#
#    Quant    See   Hear   Feel  Motion  Space    Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 33.3300
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 2 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 3 0.0000 0.0000 5.0000 0.0000 10.0000 5.0000 10.0000
# 4 0.0000 0.0000 5.5600 0.0000  0.0000 5.5600 11.1100
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                               1.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                              -1.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         1
# 1                             -1.0000                        10
# 2                              0.0000                         1
# 3                              0.0000                         1
# 4                             -1.0000                         5
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          1                 1.0000             0.6264
# 1                         10                 1.0000             1.0000
# 2                          1                 1.0000             0.4861
# 3                          1                 1.0000             0.5193
# 4                          5                 1.0000             0.2887
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0        True                  0.0000                     0.0000
# 1        True                  0.4501                    -0.8319
# 2        True                  0.3336                     0.0000
# 3        True                  0.0000                     0.0000
# 4        True                 -0.4939                     0.2184
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                 -1.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  1.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                0.0000                                 1.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 1.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1249287514159906816  091fa447adc01c6b32465d03e6cdb248         3          6
# 1  1227193153767329792  1238a8afe6354e06c19f70efe70026b0         0          0
# 2  1262093017847984128  992623c17d7871eaed9b555302cf45f7         0          0
# 3  1216323434617196545  12c9471ffbe204372650bb848564976a         0          0
# 4  1237527675570249728  afc14566840f8af31b2ea5b5ad42eda3         0          0
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             0.8710              0.1290
# 1             -0.0000             0.6330              0.3670
# 2             -0.0000             1.0000              0.0000
# 3             -0.2120             0.5080              0.2800
# 4             -0.0770             0.8060              0.1170
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.6705                   7                   1          298
# 1              0.7783                   0                   2           76
# 2              0.0000                   0                   4          186
# 3              0.3523                   0                   0           71
# 4              0.2732                   0                   6          177
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      55.7070                 0      0.0000
# 1               0      26.4700                 0      0.0000
# 2               0      60.6740                 5      1.6600
# 3               0      73.8450                 1      0.2210
# 4               0      65.5560                 0      0.0000
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000  6.9800  0.0000  0.0000  0.0000 0.0000
# 1                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 3                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4                               0.0000  7.4100  0.0000  3.7000  0.0000 0.0000
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 2.3300   0.0000 2.3300 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 9.0900   0.0000 0.0000 9.0900    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 3.4500   0.0000 0.0000 3.4500    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 0.0000   3.7000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  2.3300  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  9.0900  0.0000
# 2  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 3  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000 18.1800
# 4  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  3.7000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000   2.3300  0.0000   0.0000  0.0000
# 1 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   9.0900  9.0900
# 2 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 0.0000 0.0000 0.0000   0.0000 0.0000  18.1800  0.0000   0.0000  0.0000
# 4 3.7000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
#
#    Affiliation  Achiev  Power  Reward    Risk  Focuspast  Focuspresent  \
# 0       4.6500  2.3300 0.0000  2.3300  0.0000     0.0000        9.3000
# 1       0.0000  9.0900 9.0900  9.0900  0.0000     9.0900        0.0000
# 2       0.0000  0.0000 0.0000  0.0000  0.0000     0.0000        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 18.1800     0.0000        9.0900
# 4       3.7000  0.0000 0.0000  0.0000  3.7000     3.7000        0.0000
#
#    Focusfuture      I     We    You  SheHe   They  Ipron  Article    Prep  \
# 0       0.0000 0.0000 4.6500 0.0000 0.0000 0.0000 2.3300   2.3300  6.9800
# 1       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 9.0900   9.0900  9.0900
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  3.4500
# 3       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  18.1800  0.0000
# 4       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 3.7000   7.4100 14.8100
#
#    Auxverb  Adverb   Conj  Negate    Verb    Adj  compare  Interrog  Number  \
# 0  11.6300  0.0000 2.3300  0.0000 11.6300 2.3300   2.3300    0.0000  0.0000
# 1   0.0000  9.0900 9.0900  0.0000  9.0900 9.0900   9.0900    9.0900  0.0000
# 2   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 3   9.0900  9.0900 0.0000  0.0000 18.1800 0.0000   0.0000    0.0000  0.0000
# 4   0.0000  0.0000 0.0000  0.0000  3.7000 3.7000   3.7000    0.0000  0.0000
#
#    Quant    See   Hear   Feel  Motion  Space   Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 2.3300 2.3300
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 9.0900
# 2 0.0000 0.0000 0.0000 0.0000  0.0000 3.4500 3.4500
# 3 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 9.0900
# 4 0.0000 0.0000 0.0000 0.0000  7.4100 7.4100 3.7000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             1.0000
# 1                               0.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         4
# 1                              0.0000                         1
# 2                              0.0000                         8
# 3                              0.0000                         1
# 4                              0.0000                         1
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          0                 0.0000             0.2105
# 1                          1                 1.0000             0.2126
# 2                          8                 1.0000             0.1111
# 3                          0                 0.0000             0.6961
# 4                          0                 0.0000             0.1722
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0       False                  0.2144                     0.4561
# 1        True                  0.7783                     0.0000
# 2        True                  0.0000                     0.0000
# 3       False                  0.3523                     0.0000
# 4       False                  0.2732                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                               -1.0000                                 0.0000
# 1                                0.0000                                 0.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative',
#        'Sentiment neutral', 'Sentiment positive', 'Sentiment compound',
#        'Number of hashtags', 'Number od mentions', 'Text length',
#        'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent',
#        'Political polarisation (tweet based)',
#        'Science polarisation (tweet based)',
#        'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend',
#        'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money', 'Relegion',
#        'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler',
#        'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx',
#        'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain',
#        'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk',
#        'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe',
#        'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj',
#        'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant',
#        'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Political polarisation (user based)',
#        'Science polarisation (user based)',
#        'Moderacy polarisation (user based)', 'Posted_tweets (per user)',
#        'Deleted_tweets (per user)', 'Deletion_ratio (user)',
#        'Reputation (user)', 'Is_deleted', 'User sentiment average',
#        'Tweet sentiment deviation', 'Tweet political polarisation deviation',
#        'Tweet science polarisation deviation',
#        'Tweet moderacy polarisation deviation'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)
df_tweetscov19_user.tail()
# Out:
#                    Tweet_Id                          Username  Retweets  \
# 199995  1238646799734202368  3c7e6ad895b2cff2fe85a401fb66de5b         0
# 199996  1265103731198005248  365d996702e6e748c641ace5573138ba         0
# 199997  1266923237025472512  e15cc003e9d197bed29e42ca19b825ff         0
# 199998  1214751254288719872  ad72c4516df2b041335ee1ef64829843         0
# 199999  1189535572571893762  ad3d1e8f427459978f4c56c3d167234d         0
#
#         Favorites  Sentiment negative  Sentiment neutral  Sentiment positive  \
# 199995          0             -0.0000             1.0000              0.0000
# 199996          0             -0.0280             0.9150              0.0570
# 199997          0             -0.2590             0.7410              0.0000
# 199998          0             -0.2430             0.7570              0.0000
# 199999          0             -0.0000             0.6940              0.3060
#
#         Sentiment compound  Number of hashtags  Number od mentions  \
# 199995              0.0000                   1                   0
# 199996              0.4404                   0                   3
# 199997             -0.7906                   0                   2
# 199998             -0.8519                   0                   3
# 199999              0.9042                   1                   1
#
#         Text length  Number of URLs  Readability  Number of Emojis  \
# 199995          198               0      86.7580                 0
# 199996          319               0      59.3550                 1
# 199997          131               0      61.4500                 0
# 199998          196               0      61.9060                 0
# 199999          234               0      64.7080                 0
#
#         Emoji_sent  Political polarisation (tweet based)  \
# 199995      0.0000                                0.0000
# 199996      0.2210                                0.0000
# 199997      0.0000                                0.0000
# 199998      0.0000                                0.0000
# 199999      0.0000                                0.0000
#
#         Science polarisation (tweet based)  \
# 199995                              0.0000
# 199996                              0.0000
# 199997                              0.0000
# 199998                              0.0000
# 199999                              0.0000
#
#         Moderacy polarisation (tweet based)  Social  Family  Friend  Female  \
# 199995                               0.0000  5.5600  0.0000  0.0000  0.0000
# 199996                               0.0000 16.9500  0.0000  0.0000  1.6900
# 199997                               0.0000  0.0000  0.0000  0.0000  0.0000
# 199998                               0.0000 17.6500  0.0000  0.0000  0.0000
# 199999                               0.0000 14.7100  2.9400  0.0000  2.9400
#
#          Male   Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  \
# 199995 2.7800 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199996 0.0000 1.6900   0.0000 0.0000 0.0000    0.0000 1.6900    0.0000 0.0000
# 199997 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199998 0.0000 0.0000   2.9400 0.0000 0.0000    0.0000 0.0000    2.9400 2.9400
# 199999 0.0000 2.9400   0.0000 0.0000 0.0000    2.9400 0.0000    0.0000 0.0000
#
#         Netspeak  Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  \
# 199995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199996    0.0000  0.0000  0.0000  0.0000 5.0800  1.6900  0.0000  0.0000
# 199997    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199998    0.0000  0.0000  0.0000  0.0000 2.9400  0.0000  0.0000  0.0000
# 199999    0.0000  0.0000  0.0000  0.0000 2.9400  5.8800  0.0000  0.0000
#
#         Posemo  Negemo    Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  \
# 199995  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 199996  0.0000  0.0000 0.0000 0.0000 0.0000   3.3900 1.6900   3.3900  3.3900
# 199997  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 4.3500   0.0000  0.0000
# 199998  0.0000  5.8800 0.0000 2.9400 0.0000   2.9400 2.9400   0.0000  2.9400
# 199999  0.0000  0.0000 0.0000 0.0000 0.0000   2.9400 0.0000   0.0000  2.9400
#
#         Certain  Differ  Affiliation  Achiev  Power  Reward   Risk  Focuspast  \
# 199995   0.0000  5.5600       0.0000  0.0000 0.0000  0.0000 0.0000     5.5600
# 199996   1.6900  3.3900       0.0000  0.0000 3.3900  0.0000 0.0000     1.6900
# 199997   0.0000  0.0000       0.0000  0.0000 4.3500  0.0000 0.0000     0.0000
# 199998   5.8800  0.0000       2.9400  0.0000 2.9400  5.8800 2.9400     8.8200
# 199999   0.0000  2.9400       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000
#
#         Focuspresent  Focusfuture      I     We    You  SheHe   They  Ipron  \
# 199995        0.0000       0.0000 0.0000 0.0000 0.0000 2.7800 0.0000 2.7800
# 199996       13.5600       1.6900 0.0000 0.0000 0.0000 1.6900 6.7800 5.0800
# 199997       13.0400       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 199998        5.8800       0.0000 0.0000 0.0000 5.8800 0.0000 0.0000 8.8200
# 199999        0.0000       0.0000 0.0000 0.0000 8.8200 0.0000 0.0000 0.0000
#
#         Article    Prep  Auxverb  Adverb    Conj  Negate    Verb    Adj  \
# 199995   5.5600  8.3300   0.0000  5.5600  5.5600  2.7800  5.5600 0.0000
# 199996   5.0800 13.5600  13.5600  6.7800  6.7800  1.6900 20.3400 1.6900
# 199997  13.0400  4.3500   4.3500  8.7000  4.3500  0.0000  4.3500 0.0000
# 199998   2.9400 14.7100   5.8800  8.8200  5.8800  0.0000 17.6500 2.9400
# 199999   0.0000  8.8200   0.0000  0.0000 11.7600  0.0000  0.0000 2.9400
#
#         compare  Interrog  Number  Quant    See   Hear   Feel  Motion  Space  \
# 199995   0.0000    0.0000  2.7800 0.0000 2.7800 0.0000 0.0000  5.5600 8.3300
# 199996   1.6900    5.0800  0.0000 1.6900 0.0000 1.6900 0.0000  0.0000 6.7800
# 199997   0.0000    4.3500  0.0000 0.0000 4.3500 0.0000 0.0000  8.7000 4.3500
# 199998   2.9400    5.8800  0.0000 2.9400 0.0000 2.9400 0.0000  0.0000 2.9400
# 199999   5.8800    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
#
#          Time  Political polarisation (user based)  \
# 199995 8.3300                               0.0000
# 199996 6.7800                               0.0000
# 199997 4.3500                               0.0000
# 199998 5.8800                               0.0000
# 199999 0.0000                               0.0000
#
#         Science polarisation (user based)  Moderacy polarisation (user based)  \
# 199995                             0.0000                              0.0000
# 199996                             0.0000                              0.0000
# 199997                             0.0000                              0.0000
# 199998                             0.0000                              0.0000
# 199999                             0.0000                              0.0000
#
#         Posted_tweets (per user)  Deleted_tweets (per user)  \
# 199995                         1                          1
# 199996                         1                          1
# 199997                         9                          9
# 199998                        23                         23
# 199999                         3                          3
#
#         Deletion_ratio (user)  Reputation (user)  Is_deleted  \
# 199995                 1.0000             0.1250           1
# 199996                 1.0000             0.2962           1
# 199997                 1.0000             0.1212           1
# 199998                 1.0000             0.2167           1
# 199999                 1.0000             0.5048           1
#
#         User sentiment average  Tweet sentiment deviation  \
# 199995                  0.0000                     0.0000
# 199996                  0.4404                     0.0000
# 199997                 -0.5536                    -0.2370
# 199998                 -0.1119                    -0.7400
# 199999                  0.5309                     0.3733
#
#         Tweet political polarisation deviation  \
# 199995                                  0.0000
# 199996                                  0.0000
# 199997                                  0.0000
# 199998                                  0.0000
# 199999                                  0.0000
#
#         Tweet science polarisation deviation  \
# 199995                                0.0000
# 199996                                0.0000
# 199997                                0.0000
# 199998                                0.0000
# 199999                                0.0000
#
#         Tweet moderacy polarisation deviation
# 199995                                 0.0000
# 199996                                 0.0000
# 199997                                 0.0000
# 199998                                 0.0000
# 199999                                 0.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
 X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
def fit_gradientboosting_clf(X,y):
    
    clf = GradientBoostingClassifier()
    clf.fit(X,y)
    return clf

# %%
def test_gradientboosting_clf(model, X_test, y_test):
    
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
gb_model = fit_gradientboosting_clf(X_train, y_train)

# %%
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# Accuracy : 0.64725

# %%
y_pred = gb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.52      0.59     19789
#            1       0.62      0.77      0.69     20211
#
#     accuracy                           0.65     40000
#    macro avg       0.66      0.65      0.64     40000
# weighted avg       0.66      0.65      0.64     40000

# %%
def plot_confusion_matrix(y_test, y_pred, classes, titel):
    
    confusion_mx = confusion_matrix(y_test, y_pred)
    confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
    
    sns.heatmap(confusion_mx, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_test, y_pred, gb_model.classes_, 'Confusion Matrix')

# %%
def features_classifier_(df, model):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = model.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)

    df_column_feature = df_column_feature.reset_index()
    df_column_feature
    return df_column_feature

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01, loss='exponential')
clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                                 Feature  importance
# 0      83                       Reputation (user)      0.4137
# 1      80     Political polarisation (user based)      0.1453
# 2      82      Moderacy polarisation (user based)      0.1382
# 3       0                                Retweets      0.1335
# 4       9                          Number of URLs      0.0863
# 5       6                      Number of hashtags      0.0309
# 6      56                                       I      0.0259
# 7       8                             Text length      0.0180
# 8      27                                Informal      0.0046
# 9      21                                    Work      0.0021
# 10     88   Tweet moderacy polarisation deviation      0.0007
# 11      1                               Favorites      0.0005
# 12     84                  User sentiment average      0.0002
# 13     12                              Emoji_sent      0.0001
# 14     59                                   SheHe      0.0000
# 15     66                                    Conj      0.0000
# 16     65                                  Adverb      0.0000
# 17     64                                 Auxverb      0.0000
# 18     63                                    Prep      0.0000
# 19     62                                 Article      0.0000
# 20     61                                   Ipron      0.0000
# 21     60                                    They      0.0000
# 22     58                                     You      0.0000
# 23     68                                    Verb      0.0000
# 24     57                                      We      0.0000
# 25      5                      Sentiment compound      0.0000
# 26     55                             Focusfuture      0.0000
# 27     54                            Focuspresent      0.0000
# 28     53                               Focuspast      0.0000
# 29     52                                    Risk      0.0000
# 30     67                                  Negate      0.0000
# 31     11                        Number of Emojis      0.0000
# 32     51                                  Reward      0.0000
# 33     79                                    Time      0.0000
# 34     87    Tweet science polarisation deviation      0.0000
# 35     86  Tweet political polarisation deviation      0.0000
# 36     85               Tweet sentiment deviation      0.0000
# 37      2                      Sentiment negative      0.0000
# 38      3                       Sentiment neutral      0.0000
# 39     81       Science polarisation (user based)      0.0000
# 40      4                      Sentiment positive      0.0000
# 41     78                                   Space      0.0000
# 42     70                                 compare      0.0000
# 43     77                                  Motion      0.0000
# 44     76                                    Feel      0.0000
# 45     75                                    Hear      0.0000
# 46     74                                     See      0.0000
# 47     73                                   Quant      0.0000
# 48     72                                  Number      0.0000
# 49     71                                Interrog      0.0000
# 50     69                                     Adj      0.0000
# 51     50                                   Power      0.0000
# 52     49                                  Achiev      0.0000
# 53     29                                Netspeak      0.0000
# 54      7                      Number od mentions      0.0000
# 55     26                                   Death      0.0000
# 56     25                                Relegion      0.0000
# 57     24                                   Money      0.0000
# 58     23                                    Home      0.0000
# 59     22                                 Leisure      0.0000
# 60     10                             Readability      0.0000
# 61     20                                    Male      0.0000
# 62     19                                  Female      0.0000
# 63     18                                  Friend      0.0000
# 64     17                                  Family      0.0000
# 65     16                                  Social      0.0000
# 66     15     Moderacy polarisation (tweet based)      0.0000
# 67     14      Science polarisation (tweet based)      0.0000
# 68     13    Political polarisation (tweet based)      0.0000
# 69     28                                   Swear      0.0000
# 70     30                                  Assent      0.0000
# 71     48                             Affiliation      0.0000
# 72     31                                  Nonflu      0.0000
# 73     47                                  Differ      0.0000
# 74     46                                 Certain      0.0000
# 75     45                                  Tentat      0.0000
# 76     43                                   Cause      0.0000
# 77     42                                 Insight      0.0000
# 78     41                                     Sad      0.0000
# 79     40                                   Anger      0.0000
# 80     39                                     Anx      0.0000
# 81     38                                  Negemo      0.0000
# 82     37                                  Posemo      0.0000
# 83     36                                  Ingest      0.0000
# 84     35                                  Sexual      0.0000
# 85     34                                  Health      0.0000
# 86     33                                    Body      0.0000
# 87     32                                  Filler      0.0000
# 88     44                                 Discrep      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'user_political_polarisation' 'Retweets'
#  'user_moderacy_polarisation' 'URLs_num' 'Hashtags_num' 'i' 'Text_len'
#  'informal' 'work' 'tweet_moderacy_polarisation_difference' 'Emoji_sent']

# %%
len(f_importances)
# Out:
# 12

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 12)
# (200000,)

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01 , loss='exponential')
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.007
#  f1        : 0.69 +/- 0.008
#  recall    : 0.81 +/- 0.019

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01 , loss='exponential')
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.007
#  f1        : 0.69 +/- 0.007
#  recall    : 0.81 +/- 0.017

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]

for i in range(len(learning_rate)):

    clf_cv = GradientBoostingClassifier(learning_rate = learning_rate[i] )  
    
    print('learning_rate = ', learning_rate[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# learning_rate =  0.0001
#  percision : 0.57 +/- 0.008
#  f1        : 0.65 +/- 0.007
#  recall    : 0.76 +/- 0.026
# ---------------------------
# learning_rate =  0.001
#  percision : 0.57 +/- 0.011
#  f1        : 0.65 +/- 0.007
#  recall    : 0.76 +/- 0.034
# ---------------------------
# learning_rate =  0.01
#  percision : 0.57 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.016
# ---------------------------
# learning_rate =  0.1
#  percision : 0.60 +/- 0.010
#  f1        : 0.65 +/- 0.012
#  recall    : 0.70 +/- 0.018
# ---------------------------
# learning_rate =  0.2
#  percision : 0.60 +/- 0.011
#  f1        : 0.64 +/- 0.010
#  recall    : 0.67 +/- 0.012
# ---------------------------
# learning_rate =  0.3
#  percision : 0.60 +/- 0.010
#  f1        : 0.63 +/- 0.010
#  recall    : 0.65 +/- 0.012
# ---------------------------

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]

for i in range(len(n_estimators)):

    clf_cv = GradientBoostingClassifier(n_estimators = n_estimators[i], learning_rate= 0.01)
    
    print('n_estimators = ', n_estimators[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# n_estimators =  100
#  percision : 0.57 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.016
# ---------------------------
# n_estimators =  200
#  percision : 0.59 +/- 0.008
#  f1        : 0.66 +/- 0.011
#  recall    : 0.75 +/- 0.017
# ---------------------------
# n_estimators =  300
#  percision : 0.59 +/- 0.009
#  f1        : 0.66 +/- 0.011
#  recall    : 0.74 +/- 0.016
# ---------------------------
# n_estimators =  400
#  percision : 0.59 +/- 0.009
#  f1        : 0.66 +/- 0.012
#  recall    : 0.73 +/- 0.017
# ---------------------------
# n_estimators =  500
#  percision : 0.60 +/- 0.009
#  f1        : 0.65 +/- 0.011
#  recall    : 0.73 +/- 0.016
# ---------------------------
# n_estimators =  1000
#  percision : 0.60 +/- 0.008
#  f1        : 0.65 +/- 0.010
#  recall    : 0.71 +/- 0.016
# ---------------------------

# %% [markdown]
# ***

# %%
m_leafnode = [2,4,8,16,32,64]

for i in range(len(m_leafnode)):

    clf_cv = GradientBoostingClassifier(n_estimators = 100,  learning_rate= 0.01, max_leaf_nodes = m_leafnode[i])
    print('max_leaf_nodes = ', m_leafnode[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# max_leaf_nodes =  2
#  percision : 0.57 +/- 0.007
#  f1        : 0.66 +/- 0.007
#  recall    : 0.79 +/- 0.015
# ---------------------------
# max_leaf_nodes =  4
#  percision : 0.59 +/- 0.008
#  f1        : 0.66 +/- 0.008
#  recall    : 0.74 +/- 0.015
# ---------------------------
# max_leaf_nodes =  8
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  16
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  32
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  64
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------
# max_leaf_nodes =  128
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.008
#  recall    : 0.75 +/- 0.013
# ---------------------------

# %%
max_depth = [2,4,6,8,10]

for i in range(len(max_depth)):

    clf_cv = GradientBoostingClassifier(n_estimators = 100,  learning_rate= 0.01, max_depth = max_depth[i])
    print('max_depth = ', max_depth[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# max_depth =  2
#  percision : 0.57 +/- 0.006
#  f1        : 0.66 +/- 0.008
#  recall    : 0.79 +/- 0.013
# ---------------------------
# max_depth =  4
#  percision : 0.58 +/- 0.008
#  f1        : 0.66 +/- 0.011
#  recall    : 0.76 +/- 0.019
# ---------------------------
# max_depth =  6
#  percision : 0.59 +/- 0.007
#  f1        : 0.66 +/- 0.010
#  recall    : 0.75 +/- 0.019
# ---------------------------
# max_depth =  8
#  percision : 0.59 +/- 0.007
#  f1        : 0.65 +/- 0.009
#  recall    : 0.74 +/- 0.016
# ---------------------------
# max_depth =  10
#  percision : 0.59 +/- 0.010
#  f1        : 0.65 +/- 0.012
#  recall    : 0.73 +/- 0.017
# ---------------------------

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100, learning_rate=0.01, loss='deviance' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.016

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100, learning_rate=0.01, loss='exponential' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.015

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100, learning_rate=0.01, criterion='mse' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.016

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,learning_rate= 0.01,criterion='squared_error')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.016

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,learning_rate= 0.01, max_features = 'auto')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.66 +/- 0.010
#  recall    : 0.79 +/- 0.016

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,learning_rate= 0.01, max_features= 'sqrt')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.008
#  f1        : 0.65 +/- 0.011
#  recall    : 0.73 +/- 0.018

# %%
clf_cv = GradientBoostingClassifier(n_estimators=100,learning_rate= 0.01, max_features= 'log2')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.010
#  f1        : 0.64 +/- 0.012
#  recall    : 0.71 +/- 0.021

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100, learning_rate= 0.01, loss='exponential')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.008
#  f1        : 0.66 +/- 0.006
#  recall    : 0.78 +/- 0.020
# Wall time: 4min 6s

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ****

# %%
# %%time
#200 000 tweets
#Feature importance != 0.0
#(12 Features)

clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01 , loss='exponential')
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.002
#  f1        : 0.68 +/- 0.003
#  recall    : 0.80 +/- 0.005
# Wall time: 8min 28s

# %%
# %%time
#200 000tweets

clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01, loss='exponential')
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.002
#  f1        : 0.68 +/- 0.003
#  recall    : 0.80 +/- 0.005
# Wall time: 45min 33s

# %% [markdown]
# ## Plot feature Imortances
# ### TweetCov19 (Content + User)

# %%
def plot_hist_Features(l_features_importances, l_features, title):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    #colors = ['steelblue', 'indigo', 'brown', 'green', 'black']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [14,14]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    #ax.bar(x, l_features_importances, color = colors)
    ax.bar(x, l_features_importances, width=0.5)
    
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
         
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout() #plt.legend()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Reputation (user)',
#  'Political polarisation (user based)',
#  'Retweets',
#  'Moderacy polarisation (user based)',
#  'Number of URLs',
#  'Number of hashtags',
#  'I',
#  'Text length',
#  'Informal',
#  'Work']

# %%
plot_hist_Features(l_features_importances, l_features, 'Gb_tweetscov19_content_user')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ## TweetsCov19
# ### (Content only)

# %%
features = df_tweetscov19_user.columns
features

#features = features[2:83]
df_tweetscov19_user = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[  'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation' ])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Reputation (user)'])

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
# %%time
gb_model = fit_gradientboosting_clf(X_train, y_train)
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'fit_gradientboosting_clf' is not defined

# %%
gb_model = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01, loss='exponential')
gb_model.fit(X_train, y_train)

f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                               Feature  importance
# 0       0                              Retweets      0.3937
# 1       9                        Number of URLs      0.2966
# 2       1                             Favorites      0.1031
# 3       8                           Text length      0.0543
# 4      56                                     I      0.0437
# 5      21                                  Work      0.0315
# 6      27                              Informal      0.0255
# 7       6                    Number of hashtags      0.0209
# 8      14    Science polarisation (tweet based)      0.0082
# 9      11                      Number of Emojis      0.0079
# 10     13  Political polarisation (tweet based)      0.0071
# 11      7                    Number od mentions      0.0041
# 12     63                                  Prep      0.0023
# 13     28                                 Swear      0.0012
# 14     51                                Reward      0.0000
# 15     52                                  Risk      0.0000
# 16     50                                 Power      0.0000
# 17     53                             Focuspast      0.0000
# 18     54                          Focuspresent      0.0000
# 19     55                           Focusfuture      0.0000
# 20     49                                Achiev      0.0000
# 21     57                                    We      0.0000
# 22     58                                   You      0.0000
# 23     48                           Affiliation      0.0000
# 24     59                                 SheHe      0.0000
# 25     60                                  They      0.0000
# 26     61                                 Ipron      0.0000
# 27     66                                  Conj      0.0000
# 28     62                               Article      0.0000
# 29     72                                Number      0.0000
# 30     78                                 Space      0.0000
# 31     77                                Motion      0.0000
# 32     76                                  Feel      0.0000
# 33     75                                  Hear      0.0000
# 34     74                                   See      0.0000
# 35     73                                 Quant      0.0000
# 36     71                              Interrog      0.0000
# 37     64                               Auxverb      0.0000
# 38     70                               compare      0.0000
# 39     69                                   Adj      0.0000
# 40     68                                  Verb      0.0000
# 41     67                                Negate      0.0000
# 42     46                               Certain      0.0000
# 43     65                                Adverb      0.0000
# 44     47                                Differ      0.0000
# 45     40                                 Anger      0.0000
# 46     45                                Tentat      0.0000
# 47     16                                Social      0.0000
# 48     23                                  Home      0.0000
# 49     22                               Leisure      0.0000
# 50     20                                  Male      0.0000
# 51     19                                Female      0.0000
# 52     18                                Friend      0.0000
# 53     17                                Family      0.0000
# 54     15   Moderacy polarisation (tweet based)      0.0000
# 55     44                               Discrep      0.0000
# 56     12                            Emoji_sent      0.0000
# 57     10                           Readability      0.0000
# 58      5                    Sentiment compound      0.0000
# 59      4                    Sentiment positive      0.0000
# 60      3                     Sentiment neutral      0.0000
# 61      2                    Sentiment negative      0.0000
# 62     24                                 Money      0.0000
# 63     25                              Relegion      0.0000
# 64     26                                 Death      0.0000
# 65     29                              Netspeak      0.0000
# 66     30                                Assent      0.0000
# 67     31                                Nonflu      0.0000
# 68     32                                Filler      0.0000
# 69     33                                  Body      0.0000
# 70     34                                Health      0.0000
# 71     35                                Sexual      0.0000
# 72     36                                Ingest      0.0000
# 73     37                                Posemo      0.0000
# 74     38                                Negemo      0.0000
# 75     39                                   Anx      0.0000
# 76     41                                   Sad      0.0000
# 77     42                               Insight      0.0000
# 78     43                                 Cause      0.0000
# 79     79                                  Time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['Retweets' 'URLs_num' 'Favorites' 'Text_len' 'i' 'work' 'informal'
#  'Hashtags_num' 'tweet_politic_polarisation' 'tweet_science_polarisation'
#  'Emoji_num' 'Mentions_num' 'prep' 'Emoji_sent' 'sexual']

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 15)
# (200000,)

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.1 )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.008
#  f1        : 0.61 +/- 0.008
#  recall    : 0.63 +/- 0.008
# Wall time: 3min 27s

# %%
# %%time
#200 000 tweets
#Feature importance != 0.0
#(15 Features)

clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01 , loss='exponential')
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.64 +/- 0.001
#  recall    : 0.69 +/- 0.006
# Wall time: 7min 56s

# %%
# %%time
#200 000 tweets
#Feature importance != 0.0
#(12 Features)

clf_cv = GradientBoostingClassifier(n_estimators=100,  learning_rate = 0.01 , loss='exponential')
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.64 +/- 0.001
#  recall    : 0.69 +/- 0.006
# Wall time: 7min 55s

# %% [markdown]
# ********************************************************
# ********************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### TweetsCov19 (Content Only)

# %%
def plot_hist_Features_content_only(l_features_importances, l_features, title):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['brown', 'peru', 'black','tan', 'mediumslateblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [14,14]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    #ax.bar(x, l_features_importances, color = colors)
    ax.bar(x, l_features_importances, width=0.5)
    
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=24,  rotation='vertical')
         
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    
    fig.tight_layout()  
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Retweets',
#  'Number of URLs',
#  'Favorites',
#  'Text length',
#  'I',
#  'Work',
#  'Informal',
#  'Number of hashtags',
#  'Science polarisation (tweet based)',
#  'Number of Emojis']

# %%
plot_hist_Features_content_only(l_features_importances, l_features, 'Gb_tweetscov19_content_only')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# # Tweetskb
# ### (Content + User Features)

# %%
path = '../data/df_tweetskb_sample_200000_9.tsv'

df_tweetskb_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative', 'Sentiment neutral', 'Sentiment positive', 'Sentiment compound', 'Number of hashtags', 'Number od mentions', 'Text length', 'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent', 'Political polarisation (tweet based)', 'Science polarisation (tweet based)', 'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx', 'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain', 'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk', 'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj', 'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)', 'Reputation (user)', 'Is_deleted', 'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation'])

print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id        Username  Retweets  Favorites  \
# 0  1234468305332654080        cacamshx         1          1
# 1  1232807636535394304  GrammieJustice         0          0
# 2  1241798055826874368        gguksera         0          0
# 3  1185748472579780608         WTFMeqs         0          0
# 4  1247192242084884488         wavikee         1          4
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.3550             0.6450              0.0000
# 2             -0.0000             1.0000              0.0000
# 3             -0.0000             1.0000              0.0000
# 4             -0.0000             0.8330              0.1670
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   0                   0           34
# 1             -0.5106                   0                   1           71
# 2              0.0000                   0                   0           35
# 3              0.0000                   0                   0           22
# 4              0.4588                   0                   1           68
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0     103.5400                 1      0.0000
# 1               1       6.3590                 0      0.0000
# 2               0      62.7900                 0      0.0000
# 3               0     100.2400                 0      0.0000
# 4               0      66.1000                 4      0.3565
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000 42.8600  0.0000  0.0000 14.2900 0.0000
# 1                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 3                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4                               0.0000  9.0900  0.0000  0.0000  0.0000 0.0000
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 2  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 3  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 4  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000  14.2900  0.0000   0.0000  0.0000
# 1 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0      14.2900  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000    16.6700        0.0000
# 4       0.0000  0.0000 0.0000  0.0000 0.0000    18.1800        0.0000
#
#    Focusfuture       I     We     You  SheHe   They   Ipron  Article    Prep  \
# 0       0.0000 14.2900 0.0000 14.2900 0.0000 0.0000  0.0000   0.0000 14.2900
# 1       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000  0.0000  10.0000  0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000 16.6700   0.0000  0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000  0.0000   0.0000 16.6700
# 4       9.0900  0.0000 0.0000  0.0000 0.0000 9.0900  0.0000   9.0900  0.0000
#
#    Auxverb  Adverb   Conj  Negate   Verb    Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000 0.0000 14.2900 0.0000 0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000   0.0000    0.0000  0.0000
# 2   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000   0.0000    0.0000  0.0000
# 3   0.0000  0.0000 0.0000 16.6700 0.0000 0.0000   0.0000    0.0000  0.0000
# 4   0.0000  0.0000 0.0000 18.1800 0.0000 0.0000   0.0000    0.0000  0.0000
#
#    Quant    See   Hear   Feel  Motion  Space   Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# 1 0.0000 0.0000 0.0000 0.0000 10.0000 0.0000 0.0000
# 2 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# 4 0.0000 0.0000 0.0000 9.0900  0.0000 0.0000 0.0000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                               0.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         2
# 1                              0.0000                         3
# 2                              0.0000                         3
# 3                              0.0000                         1
# 4                              0.0000                         1
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          2                 1.0000             0.5363
# 1                          3                 1.0000             0.3613
# 2                          3                 1.0000             0.5345
# 3                          1                 1.0000             0.1919
# 4                          1                 1.0000             0.1336
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0        True                  0.2107                     0.0000
# 1        True                 -0.0605                    -0.4501
# 2        True                  0.1027                     0.0000
# 3        True                  0.0000                     0.0000
# 4        True                  0.4588                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                0.0000                                 0.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
features = df_tweetskb_user.columns
#features

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 1, 0)
df_tweetskb_user.tail()
# Out:
#                    Tweet_Id       Username  Retweets  Favorites  \
# 199995  1247284461307400200  virtualscones         0          0
# 199996  1204137626728452096       maxi_why         0          0
# 199997  1257710175651323916  _AdeAugustine         0          0
# 199998  1215872861476397056      jodystans         0          0
# 199999  1242155490236403714     DerekRRose         0          0
#
#         Sentiment negative  Sentiment neutral  Sentiment positive  \
# 199995             -0.0000             0.5520              0.4480
# 199996             -0.2050             0.7950              0.0000
# 199997             -0.4420             0.5580              0.0000
# 199998             -0.2710             0.7290              0.0000
# 199999             -0.0000             0.4880              0.5120
#
#         Sentiment compound  Number of hashtags  Number od mentions  \
# 199995              0.7430                   0                   0
# 199996             -0.2023                   0                   0
# 199997             -0.5789                   0                   0
# 199998             -0.3818                   0                   1
# 199999              0.6369                   0                   1
#
#         Text length  Number of URLs  Readability  Number of Emojis  \
# 199995           60               0      95.9550                 0
# 199996           41               0      82.3900                 0
# 199997           38               0      82.3900                 0
# 199998           77               0      29.5150                 0
# 199999           28               0      66.4000                 0
#
#         Emoji_sent  Political polarisation (tweet based)  \
# 199995      0.0000                                0.0000
# 199996      0.0000                                0.0000
# 199997      0.0000                                0.0000
# 199998      0.0000                                0.0000
# 199999      0.0000                                0.0000
#
#         Science polarisation (tweet based)  \
# 199995                              0.0000
# 199996                              0.0000
# 199997                              0.0000
# 199998                              0.0000
# 199999                              0.0000
#
#         Moderacy polarisation (tweet based)  Social  Family  Friend  Female  \
# 199995                               0.0000  0.0000  0.0000  0.0000  0.0000
# 199996                               0.0000 12.5000  0.0000  0.0000  0.0000
# 199997                               0.0000 12.5000  0.0000  0.0000 12.5000
# 199998                               0.0000  9.0900  0.0000  0.0000  0.0000
# 199999                               0.0000 20.0000  0.0000  0.0000  0.0000
#
#          Male   Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  \
# 199995 0.0000 8.3300   8.3300 0.0000 0.0000    8.3300 0.0000    0.0000 0.0000
# 199996 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199997 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199998 9.0900 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199999 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#         Netspeak  Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  \
# 199995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199996    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199997    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  9.0900
# 199999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#         Posemo  Negemo    Anx   Anger    Sad  Insight  Cause  Discrep  Tentat  \
# 199995  0.0000  0.0000 0.0000  0.0000 0.0000   0.0000 0.0000   8.3300  0.0000
# 199996  0.0000 12.5000 0.0000 12.5000 0.0000   0.0000 0.0000   0.0000 12.5000
# 199997  0.0000 12.5000 0.0000  0.0000 0.0000  12.5000 0.0000  12.5000  0.0000
# 199998  0.0000  9.0900 9.0900  9.0900 0.0000   0.0000 0.0000   0.0000  0.0000
# 199999 20.0000  0.0000 0.0000  0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
#
#         Certain  Differ  Affiliation  Achiev  Power  Reward    Risk  \
# 199995   0.0000  0.0000       0.0000  0.0000 8.3300  0.0000  0.0000
# 199996   0.0000 12.5000      12.5000  0.0000 0.0000  0.0000  0.0000
# 199997   0.0000 12.5000       0.0000  0.0000 0.0000  0.0000 12.5000
# 199998   0.0000  0.0000       0.0000  0.0000 9.0900  0.0000  9.0900
# 199999   0.0000  0.0000      20.0000  0.0000 0.0000  0.0000  0.0000
#
#         Focuspast  Focuspresent  Focusfuture      I     We    You  SheHe  \
# 199995     0.0000        8.3300       8.3300 0.0000 0.0000 0.0000 0.0000
# 199996    12.5000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199997    25.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199998     0.0000        0.0000       0.0000 0.0000 0.0000 9.0900 0.0000
# 199999     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
#
#           They   Ipron  Article    Prep  Auxverb  Adverb   Conj  Negate  \
# 199995  8.3300  0.0000   8.3300 16.6700   0.0000  0.0000 0.0000 25.0000
# 199996 12.5000  0.0000  12.5000 12.5000   0.0000 12.5000 0.0000 12.5000
# 199997  0.0000 12.5000   0.0000 12.5000   0.0000 12.5000 0.0000 25.0000
# 199998  0.0000  0.0000   9.0900  0.0000   0.0000  0.0000 0.0000  0.0000
# 199999  0.0000  0.0000   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000
#
#           Verb    Adj  compare  Interrog  Number  Quant    See   Hear   Feel  \
# 199995  0.0000 8.3300   0.0000    0.0000  0.0000 0.0000 8.3300 0.0000 0.0000
# 199996 12.5000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199997  0.0000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199998  0.0000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199999  0.0000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
#
#         Motion  Space   Time  Political polarisation (user based)  \
# 199995  0.0000 0.0000 0.0000                               0.0000
# 199996  0.0000 0.0000 0.0000                               0.0000
# 199997  0.0000 0.0000 0.0000                               0.0000
# 199998  0.0000 0.0000 0.0000                               0.0000
# 199999  0.0000 0.0000 0.0000                               0.0000
#
#         Science polarisation (user based)  Moderacy polarisation (user based)  \
# 199995                             0.0000                              0.0000
# 199996                             0.0000                              0.0000
# 199997                             0.0000                              0.0000
# 199998                             0.0000                              0.0000
# 199999                             0.0000                              0.0000
#
#         Posted_tweets (per user)  Deleted_tweets (per user)  \
# 199995                         1                          0
# 199996                         1                          0
# 199997                         4                          0
# 199998                         5                          0
# 199999                         3                          0
#
#         Deletion_ratio (user)  Reputation (user)  Is_deleted  \
# 199995                 0.0000             0.3476           0
# 199996                 0.0000             0.3703           0
# 199997                 0.0000             0.3828           0
# 199998                 0.0000             0.5587           0
# 199999                 0.0000             0.5087           0
#
#         User sentiment average  Tweet sentiment deviation  \
# 199995                  0.7430                     0.0000
# 199996                 -0.2023                     0.0000
# 199997                  0.2487                    -0.8276
# 199998                 -0.2929                    -0.0889
# 199999                  0.0569                     0.5800
#
#         Tweet political polarisation deviation  \
# 199995                                  0.0000
# 199996                                  0.0000
# 199997                                  0.0000
# 199998                                  0.0000
# 199999                                  0.0000
#
#         Tweet science polarisation deviation  \
# 199995                                0.0000
# 199996                                0.0000
# 199997                                0.0000
# 199998                                0.0000
# 199999                                0.0000
#
#         Tweet moderacy polarisation deviation
# 199995                                 0.0000
# 199996                                 0.0000
# 199997                                 0.0000
# 199998                                 0.0000
# 199999                                 0.0000

# %%
df_tweetskb_user = df_tweetskb_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id         Username  Retweets  Favorites  \
# 0  1229420911427760129  mdcya_dptspokes         1          1
# 1  1254334679504879616          EugeC93         0          0
# 2  1213622629988323328       santybacuh         0          0
# 3  1180105929934692352  JonathanLHoward         0          0
# 4  1218189727343562753       peachysun2        25         99
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.1040             0.5490              0.3460
# 2             -0.0000             0.4710              0.5290
# 3             -0.0540             0.9460              0.0000
# 4             -0.0000             1.0000              0.0000
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   0                   0           46
# 1              0.6597                   1                   0           44
# 2              0.6696                   0                   0           31
# 3             -0.2755                   0                   1          208
# 4              0.0000                   1                   0           67
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      33.5750                 0      0.0000
# 1               0      92.9650                 1      0.2210
# 2               0      83.3200                 0      0.0000
# 3               0      72.0730                 0      0.0000
# 4               0     -52.0400                 0      0.0000
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1                               0.0000 12.5000  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 3                               0.0000  2.5600  0.0000  0.0000  0.0000 2.5600
# 4                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 7.6900   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000   10.0000 0.0000   10.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 2  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 3  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 4  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 4       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
#
#    Focusfuture      I     We    You  SheHe    They   Ipron  Article   Prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000   0.0000 0.0000
# 1       0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 12.5000  12.5000 0.0000
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 20.0000  0.0000  20.0000 0.0000
# 3       5.1300 0.0000 0.0000 2.5600 0.0000  7.6900  7.6900   7.6900 2.5600
# 4       0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 10.0000   0.0000 0.0000
#
#    Auxverb  Adverb   Conj  Negate   Verb     Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000 0.0000  0.0000 0.0000  0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000 0.0000 12.5000 0.0000 12.5000   0.0000    0.0000 12.5000
# 2   0.0000  0.0000 0.0000  0.0000 0.0000  0.0000   0.0000    0.0000  0.0000
# 3   0.0000 10.2600 0.0000  7.6900 5.1300  2.5600   2.5600    0.0000  0.0000
# 4   0.0000  0.0000 0.0000  0.0000 0.0000  0.0000   0.0000    0.0000  0.0000
#
#    Quant     See   Hear   Feel  Motion   Space   Time  \
# 0 0.0000  0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 1 0.0000 12.5000 0.0000 0.0000  0.0000  0.0000 0.0000
# 2 0.0000  0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 3 0.0000  0.0000 0.0000 2.5600  7.6900  7.6900 0.0000
# 4 0.0000  0.0000 0.0000 0.0000  0.0000 10.0000 0.0000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                               0.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         2
# 1                              0.0000                         1
# 2                              0.0000                         2
# 3                              0.0000                        12
# 4                              0.0000                         2
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          0                 0.0000             0.9422
# 1                          0                 0.0000             0.4695
# 2                          0                 0.0000             0.3000
# 3                          0                 0.0000             0.8792
# 4                          0                 0.0000             0.3698
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0           0                  0.3859                     0.0000
# 1           0                  0.6597                     0.0000
# 2           0                  0.3348                     0.3348
# 3           0                  0.0874                    -0.3629
# 4           0                  0.2929                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                0.0000                                 0.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
print(len(features))
features
# Out:
# 95
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative',
#        'Sentiment neutral', 'Sentiment positive', 'Sentiment compound',
#        'Number of hashtags', 'Number od mentions', 'Text length',
#        'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent',
#        'Political polarisation (tweet based)',
#        'Science polarisation (tweet based)',
#        'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend',
#        'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money', 'Relegion',
#        'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler',
#        'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx',
#        'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain',
#        'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk',
#        'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe',
#        'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj',
#        'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant',
#        'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Political polarisation (user based)',
#        'Science polarisation (user based)',
#        'Moderacy polarisation (user based)', 'Posted_tweets (per user)',
#        'Deleted_tweets (per user)', 'Deletion_ratio (user)',
#        'Reputation (user)', 'Is_deleted', 'User sentiment average',
#        'Tweet sentiment deviation', 'Tweet political polarisation deviation',
#        'Tweet science polarisation deviation',
#        'Tweet moderacy polarisation deviation'],
#       dtype='object')

# %%
#df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Tweet_Id', 'Username', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
gb_model = fit_gradientboosting_clf(X_train, y_train)
test_gradientboosting_clf(gb_model, X_test, y_test)
# Out:
# Accuracy : 0.592175

# %%
y_pred = gb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.55     19907
#            1       0.58      0.69      0.63     20093
#
#     accuracy                           0.59     40000
#    macro avg       0.60      0.59      0.59     40000
# weighted avg       0.60      0.59      0.59     40000

# %%
plot_confusion_matrix(y_test, y_pred, gb_model.classes_, 'Confusion Matrix')

# %%
gb_model = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  

gb_model.fit(X_train, y_train)

f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                                 Feature  importance
# 0      83                       Reputation (user)      0.3396
# 1       0                                Retweets      0.1097
# 2      80     Political polarisation (user based)      0.0891
# 3      55                             Focusfuture      0.0786
# 4      82      Moderacy polarisation (user based)      0.0647
# 5       8                             Text length      0.0554
# 6       9                          Number of URLs      0.0435
# 7      35                                  Sexual      0.0424
# 8      27                                Informal      0.0364
# 9      84                  User sentiment average      0.0328
# 10      6                      Number of hashtags      0.0276
# 11     62                                 Article      0.0244
# 12      1                               Favorites      0.0190
# 13     21                                    Work      0.0139
# 14      7                      Number od mentions      0.0099
# 15     88   Tweet moderacy polarisation deviation      0.0059
# 16     86  Tweet political polarisation deviation      0.0023
# 17     11                        Number of Emojis      0.0017
# 18     77                                  Motion      0.0013
# 19     12                              Emoji_sent      0.0006
# 20     57                                      We      0.0006
# 21     85               Tweet sentiment deviation      0.0003
# 22     56                                       I      0.0002
# 23     40                                   Anger      0.0001
# 24     33                                    Body      0.0001
# 25     10                             Readability      0.0001
# 26     19                                  Female      0.0000
# 27      5                      Sentiment compound      0.0000
# 28     28                                   Swear      0.0000
# 29      3                       Sentiment neutral      0.0000
# 30     78                                   Space      0.0000
# 31     58                                     You      0.0000
# 32     67                                  Negate      0.0000
# 33     66                                    Conj      0.0000
# 34     65                                  Adverb      0.0000
# 35     59                                   SheHe      0.0000
# 36     64                                 Auxverb      0.0000
# 37     60                                    They      0.0000
# 38     68                                    Verb      0.0000
# 39     61                                   Ipron      0.0000
# 40     63                                    Prep      0.0000
# 41     16                                  Social      0.0000
# 42     69                                     Adj      0.0000
# 43     70                                 compare      0.0000
# 44     71                                Interrog      0.0000
# 45     72                                  Number      0.0000
# 46     74                                     See      0.0000
# 47     75                                    Hear      0.0000
# 48     76                                    Feel      0.0000
# 49     79                                    Time      0.0000
# 50     81       Science polarisation (user based)      0.0000
# 51      4                      Sentiment positive      0.0000
# 52      2                      Sentiment negative      0.0000
# 53     87    Tweet science polarisation deviation      0.0000
# 54     73                                   Quant      0.0000
# 55     52                                    Risk      0.0000
# 56     54                            Focuspresent      0.0000
# 57     13    Political polarisation (tweet based)      0.0000
# 58     18                                  Friend      0.0000
# 59     20                                    Male      0.0000
# 60     15     Moderacy polarisation (tweet based)      0.0000
# 61     22                                 Leisure      0.0000
# 62     23                                    Home      0.0000
# 63     24                                   Money      0.0000
# 64     25                                Relegion      0.0000
# 65     26                                   Death      0.0000
# 66     14      Science polarisation (tweet based)      0.0000
# 67     29                                Netspeak      0.0000
# 68     30                                  Assent      0.0000
# 69     31                                  Nonflu      0.0000
# 70     32                                  Filler      0.0000
# 71     34                                  Health      0.0000
# 72     36                                  Ingest      0.0000
# 73     53                               Focuspast      0.0000
# 74     37                                  Posemo      0.0000
# 75     38                                  Negemo      0.0000
# 76     39                                     Anx      0.0000
# 77     41                                     Sad      0.0000
# 78     42                                 Insight      0.0000
# 79     43                                   Cause      0.0000
# 80     45                                  Tentat      0.0000
# 81     46                                 Certain      0.0000
# 82     47                                  Differ      0.0000
# 83     48                             Affiliation      0.0000
# 84     49                                  Achiev      0.0000
# 85     50                                   Power      0.0000
# 86     51                                  Reward      0.0000
# 87     17                                  Family      0.0000
# 88     44                                 Discrep      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'Retweets' 'user_political_polarisation' 'focusfuture'
#  'user_moderacy_polarisation' 'Text_len' 'URLs_num' 'sexual' 'informal'
#  'user_vadercompound_average' 'Hashtags_num' 'article' 'work' 'Favorites'
#  'Mentions_num' 'tweet_moderacy_polarisation_difference' 'Emoji_num'
#  'Emoji_sent' 'we' 'tweet_vadercompound_difference'
#  'tweet_political_polarisation_difference' 'friend' 'netspeak' 'discrep'
#  'vader_com' 'i' 'Vader_neu' 'Vader_neg']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 28)
# (200000,)

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.57 +/- 0.003
#  f1        : 0.63 +/- 0.004
#  recall    : 0.69 +/- 0.006
# Wall time: 14min 23s

# %%
# %%time
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.003
#  f1        : 0.63 +/- 0.003
#  recall    : 0.69 +/- 0.004
# Wall time: 38min 11s

# %% [markdown]
# *****************************************************
# *****************************************************

# %%
learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]

for i in range(len(learning_rate)):

    clf_cv = GradientBoostingClassifier(learning_rate = learning_rate[i] )  
    
    print('learning_rate = ', learning_rate[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# learning_rate =  0.0001
#  percision : 0.54 +/- 0.017
#  f1        : 0.62 +/- 0.061
#  recall    : 0.77 +/- 0.175
# ---------------------------
# learning_rate =  0.001
#  percision : 0.55 +/- 0.023
#  f1        : 0.60 +/- 0.063
#  recall    : 0.69 +/- 0.186
# ---------------------------
# learning_rate =  0.01
#  percision : 0.56 +/- 0.010
#  f1        : 0.63 +/- 0.011
#  recall    : 0.72 +/- 0.038
# ---------------------------
# learning_rate =  0.1
#  percision : 0.57 +/- 0.008
#  f1        : 0.62 +/- 0.009
#  recall    : 0.66 +/- 0.012
# ---------------------------
# learning_rate =  0.2
#  percision : 0.57 +/- 0.007
#  f1        : 0.61 +/- 0.006
#  recall    : 0.65 +/- 0.009
# ---------------------------
# learning_rate =  0.3
#  percision : 0.57 +/- 0.008
#  f1        : 0.60 +/- 0.009
#  recall    : 0.63 +/- 0.012
# ---------------------------

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]

for i in range(len(n_estimators)):

    clf_cv = GradientBoostingClassifier(n_estimators = n_estimators[i], learning_rate= 0.01)
    
    print('n_estimators = ', n_estimators[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# n_estimators =  100
#  percision : 0.56 +/- 0.010
#  f1        : 0.63 +/- 0.011
#  recall    : 0.72 +/- 0.038
# ---------------------------
# n_estimators =  200
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014
# ---------------------------
# n_estimators =  300
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.70 +/- 0.012
# ---------------------------
# n_estimators =  400
#  percision : 0.57 +/- 0.009
#  f1        : 0.62 +/- 0.006
#  recall    : 0.69 +/- 0.010
# ---------------------------
# n_estimators =  500
#  percision : 0.57 +/- 0.008
#  f1        : 0.62 +/- 0.006
#  recall    : 0.69 +/- 0.010
# ---------------------------
# n_estimators =  1000
#  percision : 0.57 +/- 0.008
#  f1        : 0.62 +/- 0.007
#  recall    : 0.67 +/- 0.010
# ---------------------------

# %%
m_leafnode = [2,4,8,16,32]

for i in range(len(m_leafnode)):

    clf_cv = GradientBoostingClassifier(n_estimators = 200,  learning_rate= 0.01, max_leaf_nodes = m_leafnode[i])
    print('max_leaf_nodes = ', m_leafnode[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# max_leaf_nodes =  2
#  percision : 0.55 +/- 0.006
#  f1        : 0.63 +/- 0.006
#  recall    : 0.75 +/- 0.014
# ---------------------------
# max_leaf_nodes =  4
#  percision : 0.56 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.018
# ---------------------------
# max_leaf_nodes =  8
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014
# ---------------------------
# max_leaf_nodes =  16
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014
# ---------------------------
# max_leaf_nodes =  32
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014
# ---------------------------

# %%
max_depth = [2,4,6,8,10]

for i in range(len(max_depth)):

    clf_cv = GradientBoostingClassifier(n_estimators=200,  learning_rate=0.01, max_leaf_nodes=8, max_depth=max_depth[i])
    print('max_depth = ', max_depth[i])
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# max_depth =  2
#  percision : 0.56 +/- 0.008
#  f1        : 0.63 +/- 0.006
#  recall    : 0.73 +/- 0.021
# ---------------------------
# max_depth =  4
#  percision : 0.57 +/- 0.010
#  f1        : 0.63 +/- 0.007
#  recall    : 0.70 +/- 0.013
# ---------------------------
# max_depth =  6
#  percision : 0.57 +/- 0.008
#  f1        : 0.63 +/- 0.006
#  recall    : 0.70 +/- 0.011
# ---------------------------
# max_depth =  8
#  percision : 0.57 +/- 0.008
#  f1        : 0.63 +/- 0.006
#  recall    : 0.70 +/- 0.010
# ---------------------------
# max_depth =  10
#  percision : 0.57 +/- 0.008
#  f1        : 0.63 +/- 0.006
#  recall    : 0.70 +/- 0.010
# ---------------------------

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200, learning_rate=0.01, max_leaf_nodes=8, loss='deviance' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200, learning_rate=0.01, max_leaf_nodes=8, loss='exponential' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.008
#  f1        : 0.63 +/- 0.005
#  recall    : 0.71 +/- 0.013

# %%
clf_cv = GradientBoostingClassifier(n_estimators=20, learning_rate=0.01, max_leaf_nodes=8, criterion='mse' )  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.54 +/- 0.018
#  f1        : 0.62 +/- 0.059
#  recall    : 0.76 +/- 0.171

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8,criterion='squared_error')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8, max_features = 'auto')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.009
#  f1        : 0.63 +/- 0.006
#  recall    : 0.71 +/- 0.014

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8, max_features= 'sqrt')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.008
#  f1        : 0.62 +/- 0.005
#  recall    : 0.69 +/- 0.009

# %%
clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8, max_features= 'log2')  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.57 +/- 0.007
#  f1        : 0.62 +/- 0.004
#  recall    : 0.68 +/- 0.009

# %% [markdown]
# ***

# %%
# %%time
#200 000 tweets


clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.56 +/- 0.003
#  f1        : 0.64 +/- 0.003
#  recall    : 0.73 +/- 0.006
# Wall time: 34min 44s

# %%
# %%time
#200 000 tweets


clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.56 +/- 0.003
#  f1        : 0.64 +/- 0.003
#  recall    : 0.74 +/- 0.005
# Wall time: 1h 15min 55s

# %% [markdown]
# ****

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content + User)

# %%
def plot_hist_Features_kb(l_features_importances, l_features, title):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue', 'brown', 'green', 'Indigo', 'lightblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [14,14]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    #ax.bar(x, l_features_importances, color = colors)
    ax.bar(x, l_features_importances, width=0.5)

    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=18,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

   
    fig.tight_layout()
    #plt.legend()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Reputation (user)',
#  'Retweets',
#  'Political polarisation (user based)',
#  'Focusfuture',
#  'Moderacy polarisation (user based)',
#  'Text length',
#  'Number of URLs',
#  'Sexual',
#  'Informal',
#  'User sentiment average']

# %%
plot_hist_Features_kb(l_features_importances, l_features, 'Gb_tweetskb_content_user')

# %% [markdown]
# ***********************************************************************
# ***********************************************************************

# %% [markdown]
# ## Tweetskb
# ### Content only

# %%
features = df_tweetskb_user.columns
features

#features = features[2:83]
df_tweetskb_user = df_tweetskb_user[features.tolist()]
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Reputation (user)'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
gb_model = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
gb_model.fit(X_train, y_train)

f_importances = features_classifier_(X, gb_model)
f_importances
# Out:
#     index                               Feature  importance
# 0       0                              Retweets      0.2011
# 1       1                             Favorites      0.1799
# 2      55                           Focusfuture      0.1178
# 3       9                        Number of URLs      0.1118
# 4       8                           Text length      0.0766
# 5      35                                Sexual      0.0676
# 6      27                              Informal      0.0665
# 7      62                               Article      0.0564
# 8      21                                  Work      0.0348
# 9       6                    Number of hashtags      0.0299
# 10      7                    Number od mentions      0.0266
# 11     11                      Number of Emojis      0.0071
# 12      4                    Sentiment positive      0.0054
# 13     61                                 Ipron      0.0041
# 14     13  Political polarisation (tweet based)      0.0039
# 15     29                              Netspeak      0.0024
# 16     12                            Emoji_sent      0.0019
# 17     57                                    We      0.0018
# 18     33                                  Body      0.0011
# 19     56                                     I      0.0007
# 20      5                    Sentiment compound      0.0005
# 21     38                                Negemo      0.0005
# 22     51                                Reward      0.0003
# 23      3                     Sentiment neutral      0.0003
# 24     19                                Female      0.0003
# 25     49                                Achiev      0.0002
# 26     17                                Family      0.0001
# 27     37                                Posemo      0.0001
# 28     10                           Readability      0.0001
# 29     54                          Focuspresent      0.0000
# 30     58                                   You      0.0000
# 31     59                                 SheHe      0.0000
# 32     60                                  They      0.0000
# 33     53                             Focuspast      0.0000
# 34     69                                   Adj      0.0000
# 35     63                                  Prep      0.0000
# 36     64                               Auxverb      0.0000
# 37     65                                Adverb      0.0000
# 38     66                                  Conj      0.0000
# 39     67                                Negate      0.0000
# 40     68                                  Verb      0.0000
# 41     70                               compare      0.0000
# 42     71                              Interrog      0.0000
# 43     72                                Number      0.0000
# 44     73                                 Quant      0.0000
# 45     74                                   See      0.0000
# 46     75                                  Hear      0.0000
# 47     76                                  Feel      0.0000
# 48     77                                Motion      0.0000
# 49     78                                 Space      0.0000
# 50     52                                  Risk      0.0000
# 51     40                                 Anger      0.0000
# 52     50                                 Power      0.0000
# 53     48                           Affiliation      0.0000
# 54      2                    Sentiment negative      0.0000
# 55     14    Science polarisation (tweet based)      0.0000
# 56     15   Moderacy polarisation (tweet based)      0.0000
# 57     16                                Social      0.0000
# 58     18                                Friend      0.0000
# 59     20                                  Male      0.0000
# 60     22                               Leisure      0.0000
# 61     23                                  Home      0.0000
# 62     24                                 Money      0.0000
# 63     25                              Relegion      0.0000
# 64     26                                 Death      0.0000
# 65     28                                 Swear      0.0000
# 66     30                                Assent      0.0000
# 67     31                                Nonflu      0.0000
# 68     32                                Filler      0.0000
# 69     34                                Health      0.0000
# 70     36                                Ingest      0.0000
# 71     39                                   Anx      0.0000
# 72     41                                   Sad      0.0000
# 73     42                               Insight      0.0000
# 74     43                                 Cause      0.0000
# 75     44                               Discrep      0.0000
# 76     45                                Tentat      0.0000
# 77     46                               Certain      0.0000
# 78     47                                Differ      0.0000
# 79     79                                  Time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['Retweets' 'Favorites' 'URLs_num' 'focusfuture' 'Text_len' 'informal'
#  'sexual' 'work' 'article' 'Mentions_num' 'Hashtags_num' 'Emoji_num'
#  'tweet_politic_polarisation' 'vader_com' 'Vader_pos' 'ipron' 'netspeak'
#  'Emoji_sent' 'we' 'i' 'body' 'focuspast']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 22)
# (200000,)

# %%
# %%time
#200 000 tweets


clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.56 +/- 0.003
#  f1        : 0.63 +/- 0.004
#  recall    : 0.71 +/- 0.007
# Wall time: 23min 9s

# %%
# %%time
#200 000 tweets


clf_cv = GradientBoostingClassifier(n_estimators=200,learning_rate= 0.01, max_leaf_nodes=8)  
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.56 +/- 0.003
#  f1        : 0.63 +/- 0.004
#  recall    : 0.71 +/- 0.007
# Wall time: 1h 3min 18s

# %% [markdown]
# ***************************************************
# ***************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetskb (Content Only)

# %%
def plot_hist_Features_content_only_kb(l_features_importances, l_features, title):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    #colors = ['brown','khaki', 'lightsalmon', 'lightskyblue', 'maroon']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [14,14]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, width=0.5)
    ax.set_title('Gradient Boosting', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=20,  rotation='vertical')
    
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=13)

    fig.tight_layout()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Retweets',
#  'Favorites',
#  'Focusfuture',
#  'Number of URLs',
#  'Text length',
#  'Sexual',
#  'Informal',
#  'Article',
#  'Work',
#  'Number of hashtags']

# %%
plot_hist_Features_content_only_kb(l_features_importances, l_features, 'Gb_tweetskb_content_only')
