# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
csv.field_size_limit(100000000)
from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import KFold

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.float_format = '{:.4f}'.format

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # **Logostic Regression**
# ## *(1) TweetsCov19*
# #### (Content + User Features)

# %%
path = '../data/df_tweetscov19_sample_200000.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference' ])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1239921910114369537  e91f45964db23b2bec20d15fc6c501ae         0          0
# 1  1221651394068992001  7b8c3d61b23ef22900c7e8cac3ef655a         9         21
# 2  1247547192606437376  aeed110177e1f18d8e5721dc4257c2aa        12         25
# 3  1228281231713894401  bf8d92180630f872868ab15fafefa6da         0          0
# 4  1239619450455941123  f99928784e541662228f9c85519a0d75         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     1.0000     0.0000     0.0000             0             0
# 1    -0.0320     0.7210     0.2470     0.9431             0             0
# 2    -0.1340     0.5990     0.2680     0.7003             1             0
# 3    -0.0000     1.0000     0.0000     0.0000             0             0
# 4    -0.1620     0.8380     0.0000    -0.6808             0             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0        24         0      33.5750          0      0.0000
# 1       268         1      98.7810          0      0.0000
# 2        88         0      53.6550          2      0.4420
# 3       105         0      99.4920          0      0.0000
# 4       144         0      62.6250          2      0.3330
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male    work  \
# 0                       0.0000 25.0000  0.0000  0.0000  0.0000 0.0000 25.0000
# 1                       0.0000 10.1700  0.0000  0.0000  0.0000 5.0800  0.0000
# 2                       0.0000  7.1400  0.0000  0.0000  7.1400 0.0000  0.0000
# 3                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000  0.0000
# 4                       0.0000  4.1700  0.0000  0.0000  0.0000 0.0000  0.0000
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    4.1700 4.1700    0.0000  0.0000
#
#    nonflu  filler    body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  6.7800  0.0000 0.0000
# 2  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  7.1400 0.0000
# 3  0.0000  0.0000 10.5300  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4  0.0000  0.0000  4.1700  0.0000  0.0000  0.0000  0.0000  8.3300 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 0.0000   3.3900 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 4.1700 0.0000   4.1700 4.1700   0.0000  0.0000   0.0000  4.1700
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       3.3900  1.6900 0.0000  1.6900 0.0000     6.7800        5.0800
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 4       0.0000  0.0000 0.0000  4.1700 4.1700     4.1700        8.3300
#
#    focusfuture       i     we     you  shehe   they   ipron  article    prep  \
# 0       0.0000  0.0000 0.0000 25.0000 0.0000 0.0000  0.0000   0.0000  0.0000
# 1       0.0000  0.0000 0.0000  0.0000 5.0800 0.0000  8.4700  10.1700  8.4700
# 2       0.0000 14.2900 0.0000  0.0000 0.0000 0.0000  0.0000   0.0000 14.2900
# 3       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000  0.0000  10.5300 15.7900
# 4       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000 12.5000   4.1700  8.3300
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 1   5.0800  5.0800 6.7800  0.0000 10.1700 5.0800   5.0800    0.0000  0.0000
# 2   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 3   0.0000  0.0000 0.0000  0.0000  5.2600 0.0000   0.0000    0.0000  0.0000
# 4   4.1700  0.0000 0.0000  0.0000 12.5000 8.3300   8.3300    0.0000  4.1700
#
#    quant    see   hear   feel  motion   space   time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 1 0.0000 0.0000 1.6900 1.6900  1.6900  1.6900 0.0000
# 2 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000 15.7900 0.0000
# 4 4.1700 0.0000 0.0000 0.0000  8.3300  4.1700 8.3300
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       1
# 2                      0.0000                      79
# 3                      0.0000                       1
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.1250        True
# 1                        1               1.0000           0.3459        True
# 2                       79               1.0000           0.7898        True
# 3                        1               1.0000           0.0000        True
# 4                        1               1.0000           0.3372        True
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                      0.0000                          0.0000
# 1                      0.9431                          0.0000
# 2                      0.1608                          0.5395
# 3                      0.0000                          0.0000
# 4                     -0.6808                          0.0000
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1250524260529057795  f52316f7d523e78afebea89c89d1c289       132        497
# 1  1195371072163647489  cd7619a7df9b98d5f842ea12dc225d0d        35         91
# 4 0.0000 0.0000  12.5000 3.1200   3.1200  6.2500   3.1200  9.3800
#
#    affiliation  achiev   power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 13.1600  0.0000 2.6300     0.0000        5.2600
# 1       2.1300  0.0000  0.0000  2.1300 0.0000     2.1300       12.7700
# 2       0.0000  0.0000  0.0000  5.0000 0.0000     5.0000        5.0000
# 3       0.0000  0.0000 16.6700  0.0000 0.0000     0.0000        0.0000
# 4       0.0000  3.1200  0.0000  0.0000 0.0000     9.3800        3.1200
#
#    focusfuture      i     we    you  shehe   they   ipron  article    prep  \
# 0       5.2600 0.0000 0.0000 0.0000 0.0000 2.6300  2.6300   2.6300 10.5300
# 1       0.0000 0.0000 0.0000 0.0000 4.2600 0.0000 10.6400   0.0000 12.7700
# 2       0.0000 5.0000 0.0000 0.0000 0.0000 0.0000  5.0000  10.0000 15.0000
# 3       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000 16.6700
# 4       0.0000 0.0000 0.0000 3.1200 0.0000 0.0000  9.3800  12.5000  6.2500
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   5.2600  5.2600 5.2600  0.0000 10.5300 5.2600   5.2600    0.0000  0.0000
# 1  10.6400  8.5100 8.5100  2.1300 12.7700 4.2600   0.0000    4.2600  0.0000
# 2   0.0000 10.0000 5.0000  0.0000 10.0000 5.0000   0.0000    0.0000  0.0000
# 3   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 4   3.1200  3.1200 9.3800  3.1200 12.5000 0.0000   0.0000    3.1200  0.0000
#
#    quant    see   hear   feel  motion   space   time  \
# 0 0.0000 0.0000 0.0000 0.0000  2.6300  2.6300 5.2600
# 1 4.2600 2.1300 0.0000 0.0000  0.0000  6.3800 2.1300
# 2 0.0000 0.0000 0.0000 0.0000  5.0000 20.0000 0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 4 0.0000 0.0000 3.1200 0.0000  0.0000  0.0000 0.0000
#
#    user_political_polarisation  user_science_polarisation  \
# 0                      -1.0000                     0.0000
# 1                      -1.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                     -1.0000                      28
# 1                      1.0000                     352
# 2                      0.0000                       1
# 3                      0.0000                       1
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        0               0.0000           0.9957       False
# 1                        0               0.0000           0.9925       False
# 2                        0               0.0000           0.3043       False
# 3                        0               0.0000           0.6828       False
# 4                        1               1.0000           0.3847        True
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                     -0.2099                         -0.7070
# 1                     -0.2174                          1.0981
# 2                      0.0000                          0.0000
# 3                     -0.2960                          0.0000
# 4                     -0.4168                          0.0000
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   1.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                 -1.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetscov19_del = df_tweetscov19_user[df_tweetscov19_user['Is_deleted']==True]
df_tweetscov19_undel = df_tweetscov19_user[df_tweetscov19_user['Is_deleted']==False]

# %%
def plot_paiplot(df, hue, titel): 
   
    #plt.rcParams["figure.figsize"] = [6,4]
    #fig, ax = plt.subplots()
    sns.pairplot(df, hue = hue)

    #ax.set_ylabel('Dataframe')

    #ax.set_xlabel('Deletion ratio', fontsize=12)
    #plt.margins(0.02)
    #fig.tight_layout()
    #plt.show()

    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/log_reg/'+titel+'.jpg')

# %%
df = df_tweetscov19_user[['Is_deleted', 'Retweets', 'vader_com', 'Favorites']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetsocv19_Retweet_favoriet_sentiment')

# %%
df = df_tweetscov19_user[['Is_deleted', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetsocv19_politic_science_moderacy')

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_difference',
#        'tweet_political_polarisation_difference',
#        'tweet_science_polarisation_difference',
#        'tweet_moderacy_polarisation_difference'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)

# %%
df_tweetscov19_user.tail()
# Out:
#                    Tweet_Id                          Username  Retweets  \
# 199997           1                     -0.9376
# 199998           1                     -0.4096
# 199999           0                      0.3612
#
#         tweet_vadercompound_difference  \
# 199995                          0.0000
# 199996                          0.0000
# 199997                          0.0000
# 199998                         -0.4883
# 199999                          0.0000
#
#         tweet_political_polarisation_difference  \
# 199995                                   0.0000
# 199996                                   0.0000
# 199997                                   0.0000
# 199998                                   0.0000
# 199999                                   0.0000
#
#         tweet_science_polarisation_difference  \
# 199995                                 0.0000
# 199996                                 0.0000
# 199997                                 0.0000
# 199998                                 0.0000
# 199999                                 0.0000
#
#         tweet_moderacy_polarisation_difference
# 199995                                  0.0000
# 199996                                  0.0000
# 199997                                  0.0000
# 199998                                  0.0000
# 199999                                  0.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
def fit_log_reg(X,y):
    l_regression = LogisticRegression(random_state=20, solver = 'lbfgs')
    l_regression.fit(X,y)
    return l_regression

# %%
def test_log_reg(model, X_test, y_test):
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
l_regression = fit_log_reg(X_train, y_train)

# %%
test_log_reg(l_regression, X_test,y_test)
# Out:
# Accuracy : 0.564725

# %%
y_pred = l_regression.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59     19968
#            1       0.57      0.51      0.54     20032
#
#     accuracy                           0.56     40000
#    macro avg       0.57      0.56      0.56     40000
# weighted avg       0.57      0.56      0.56     40000

# %%
def plot_confusion_matrix(confu_matrix, classes, titel):
    sns.heatmap(confu_matrix, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
confusion_mx = confusion_matrix(y_test, y_pred)
confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
plot_confusion_matrix(confusion_mx, l_regression.classes_, 'Confusion Matrix')
print(confusion_mx)
# Out:
# [[0.61964143 0.38035857]
#  [0.49001597 0.50998403]]

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
clf_cv = LogisticRegression(random_state=20, solver = 'lbfgs')
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.006
#  f1        : 0.54 +/- 0.011
#  recall    : 0.50 +/- 0.019

# %% [markdown]
# ***

# %%
def features_classifier(X, y):

    decisionTC = DecisionTreeClassifier(random_state=15, criterion= 'entropy', max_depth = 10)
    decisionTC.fit(X,y)
    
    column_feature = {}

    for i, c in enumerate(X):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = decisionTC.feature_importances_[i]
        
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)
    
    return df_column_feature.reset_index()

# %%
f_importances = features_classifier( X, y)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.3179
# 1      81                user_science_polarisation      0.1193
# 2       9                                 URLs_num      0.1012
# 3      80              user_political_polarisation      0.0579
# 4      84               user_vadercompound_average      0.0572
# 5       6                             Hashtags_num      0.0369
# 6       8                                 Text_len      0.0348
# 7      82               user_moderacy_polarisation      0.0332
# 8      88   tweet_moderacy_polarisation_difference      0.0280
# 9       0                                 Retweets      0.0182
# 10     27                                 informal      0.0158
# 11     56                                        i      0.0152
# 12     63                                     prep      0.0137
# 13     10                              readability      0.0134
# 14     86  tweet_political_polarisation_difference      0.0086
# 15     87    tweet_science_polarisation_difference      0.0077
# 16     21                                     work      0.0076
# 17      7                             Mentions_num      0.0058
# 18     35                                   sexual      0.0055
# 19     12                               Emoji_sent      0.0052
# 20     65                                   adverb      0.0048
# 21     66                                     conj      0.0043
# 22      3                                Vader_neu      0.0042
# 23     78                                    space      0.0039
# 24      1                                Favorites      0.0039
# 25     85           tweet_vadercompound_difference      0.0036
# 26     57                                       we      0.0034
# 27     49                                   achiev      0.0031
# 28     20                                     male      0.0030
# 29     11                                Emoji_num      0.0030
# 30     61                                    ipron      0.0029
# 31     62                                  article      0.0026
# 32     16                                   social      0.0025
# 33     34                                   health      0.0025
# 34     44                                  discrep      0.0024
# 35     43                                    cause      0.0024
# 36     69                                      adj      0.0023
# 37     42                                  insight      0.0020
# 38     68                                     verb      0.0020
# 39     58                                      you      0.0019
# 40      4                                Vader_pos      0.0018
# 41     73                                    quant      0.0018
# 42      2                                Vader_neg      0.0018
# 43     29                                 netspeak      0.0018
# 44     45                                   tentat      0.0017
# 45      5                                vader_com      0.0017
# 46     79                                     time      0.0016
# 47     72                                   number      0.0015
# 48     40                                    anger      0.0014
# 49     64                                  auxverb      0.0014
# 50     67                                   negate      0.0014
# 51     74                                      see      0.0013
# 52     48                              affiliation      0.0013
# 53     60                                     they      0.0013
# 54     75                                     hear      0.0013
# 55     54                             focuspresent      0.0012
# 56     37                                   posemo      0.0012
# 57     55                              focusfuture      0.0011
# 58     22                                  leisure      0.0011
# 59     19                                   female      0.0011
# 60     28                                    swear      0.0010
# 61     77                                   motion      0.0008
# 62     47                                   differ      0.0008
# 63     53                                focuspast      0.0007
# 64     33                                     body      0.0006
# 65     26                                    death      0.0005
# 66     24                                    money      0.0004
# 67     71                                 interrog      0.0004
# 68     50                                    power      0.0004
# 69     70                                  compare      0.0004
# 70     51                                   reward      0.0003
# 71     36                                   ingest      0.0003
# 72     18                                   friend      0.0003
# 73     38                                   negemo      0.0002
# 74     17                                   family      0.0001
# 75     25                                 relegion      0.0000
# 76     13               tweet_politic_polarisation      0.0000
# 77     14               tweet_science_polarisation      0.0000
# 78     15              tweet_moderacy_polarisation      0.0000
# 79     39                                      anx      0.0000
# 80     30                                   assent      0.0000
# 81     46                                  certain      0.0000
# 82     52                                     risk      0.0000
# 83     76                                     feel      0.0000
# 84     23                                     home      0.0000
# 85     59                                    shehe      0.0000
# 86     41                                      sad      0.0000
# 87     32                                   filler      0.0000
# 88     31                                   nonflu      0.0000

# %%
f_importances = f_importances[f_importances['importance'] > 0.01]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'user_science_polarisation' 'URLs_num'
#  'user_political_polarisation' 'user_vadercompound_average' 'Hashtags_num'
#  'Text_len' 'user_moderacy_polarisation'
#  'tweet_moderacy_polarisation_difference' 'Retweets' 'informal' 'i' 'prep'
#  'readability']

# %%
len(f_importances)
# Out:
# 14

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 14)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X_new,y)
# Out:
# (160000, 14)
# (40000, 14)
# (160000,)
# (40000,)

# %%
l_regression = fit_log_reg(X_train, y_train)

# %%
test_log_reg(l_regression, X_test,y_test)
# Out:
# Accuracy : 0.582825

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59     19968
#            1       0.57      0.51      0.54     20032
#
#     accuracy                           0.56     40000
#    macro avg       0.57      0.56      0.56     40000
# weighted avg       0.57      0.56      0.56     40000

# %%
clf_cv = LogisticRegression(random_state=20, solver = 'lbfgs')
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.59 +/- 0.003
#  f1        : 0.59 +/- 0.018
#  recall    : 0.60 +/- 0.035

# %% [markdown]
# ***

# %%
decisionTC = DecisionTreeClassifier(random_state=20, criterion= 'entropy', max_depth = 10)
print_cross_val_score(decisionTC, X, y)
# Out:
#  percision : 0.58 +/- 0.006
#  f1        : 0.64 +/- 0.007
#  recall    : 0.71 +/- 0.015

# %%
print_cross_val_score(decisionTC, X_new, y)
# Out:
#  percision : 0.58 +/- 0.006
#  f1        : 0.63 +/- 0.007
#  recall    : 0.70 +/- 0.021

# %% [markdown]
# ***

# %%
y_prob_test = l_regression.predict_proba(X_test)

print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.6684865990420971

# %%
kf = KFold(n_splits=10, random_state=None, shuffle=False)

num_list = np.geomspace(1e-5, 1e5, num = 20)

# %%
num_list
# Out:
# array([1.00000000e-05, 3.35981829e-05, 1.12883789e-04, 3.79269019e-04,
#        1.27427499e-03, 4.28133240e-03, 1.43844989e-02, 4.83293024e-02,
#        1.62377674e-01, 5.45559478e-01, 1.83298071e+00, 6.15848211e+00,
#        2.06913808e+01, 6.95192796e+01, 2.33572147e+02, 7.84759970e+02,
#        2.63665090e+03, 8.85866790e+03, 2.97635144e+04, 1.00000000e+05])

# %%
l_regression3 = LogisticRegressionCV(cv=kf, random_state=15, Cs=num_list)
l_regression3.fit(X_train,y_train)
print('Accuracy : ',l_regression3.score(X_test, y_test))
# Out:
# Accuracy :  0.597575

# %%
y_prob_t3 = l_regression3.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_t3))
# Out:
# Logarithmic loss für Test data 0.6602983885631505

# %%
print('C Parameter :', l_regression3.C_)
# Out:
# C Parameter : [0.0483293]

# %%
l_regression_valid = LogisticRegression(random_state=20, solver = 'lbfgs', C=0.0483293)
print_cross_val_score(l_regression_valid, X_new, y)
# Out:
#  percision 0.59 +/- 0.004
#  f1        0.60 +/- 0.011
#  recall    0.61 +/- 0.021

# %%
param_grid = [{'penalty': ['l1', 'l2', 'elasticnet', 'none']},
             {'C' : np.logspace(-4,4,20)},
             {'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'ag', 'saga']},
             {'max_iter' : [100, 200, 500, 1000, 2500, 5000]}]

# %%
l_regression_GridS = LogisticRegression()

clf = GridSearchCV(l_regression_GridS, param_grid=param_grid, cv=10, verbose=True, n_jobs=-1)

# %%
# %%time
best_clf = clf.fit(X_new,y)
# Out:
# Fitting 10 folds for each of 35 candidates, totalling 350 fits
# Wall time: 4min 16s

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(solver='liblinear')

# %%
best_clf.score(X_new, y)
# Out:
# 0.59993

# %%
l_regression_best = LogisticRegression(solver='liblinear')

print_cross_val_score(l_regression_best, X_new, y)
# Out:
#  percision : 0.59 +/- 0.003
#  f1        : 0.62 +/- 0.003
#  recall    : 0.65 +/- 0.004

# %% [markdown]
# ****************************************************************************
# ****************************************************************************

# %% [markdown]
# ### Tweetscov19
# #### (Conten only)

# %%
features = df_tweetscov19_user.columns
features

features = features[2:83]
df_tweetscov19_user_2 = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user_2 = df_tweetscov19_user_2.drop(columns=[ 'Moderacy p.T.'])

df = df_tweetscov19_user_2.drop('Is_deleted', axis=1)
X = df_tweetscov19_user_2.drop('Is_deleted', axis=1).values
y = df_tweetscov19_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (4275002, 79)
# (4275002,)

# %%
features_cl = features_classifier(df , X, y)
features_cl
# Out:
#     index            Feature  importance
# 0       6            URLs n.      0.2129
# 1       0           Retweets      0.1409
# 2       5            Text l.      0.0756
# 3      20               Work      0.0623
# 4       3        Hashtags n.      0.0585
# 5      13       News(Shalla)      0.0566
# 6      11       Science p.T.      0.0506
# 7      10     Political p.T.      0.0473
# 8       7        Readability      0.0363
# 9      62        Preposition      0.0283
# 10      2          Sentiment      0.0251
# 11      4        Mentions n.      0.0250
# 12      8           Emoji n.      0.0224
# 13     14  Socialnet(Shalla)      0.0218
# 14     26           Informal      0.0217
# 15     55                  I      0.0200
# 16     12       Porn(Shalla)      0.0148
# 17     27              Swear      0.0130
# 18      1              Likes      0.0129
# 19     67               Verb      0.0082
# 20     34             Sexual      0.0075
# 21     15             Social      0.0038
# 22      9    Emoji sentiment      0.0028
# 23     23              Money      0.0027
# 24     74               Hear      0.0025
# 25     47        Affiliation      0.0024
# 26     60              Ipron      0.0022
# 27     22               Home      0.0019
# 28     28           Netspeak      0.0018
# 29     57                You      0.0016
# 30     18             Female      0.0014
# 31     78               Time      0.0014
# 32     76             Motion      0.0013
# 33     58              SheHe      0.0010
# 34     61            Article      0.0009
# 35     19               Male      0.0008
# 36     70      Interrogative      0.0008
# 37     32               Body      0.0008
# 38     65        Conjunctive      0.0006
# 39     53      Focus present      0.0005
# 40     50             Reward      0.0005
# 41     51               Risk      0.0005
# 42     68          Adjective      0.0004
# 43     77              Space      0.0004
# 44     39              Anger      0.0004
# 45     66             Negate      0.0003
# 46     48            Achieve      0.0003
# 47     52         Focus past      0.0003
# 48     69            Compare      0.0003
# 49     75               Feel      0.0002
# 50     37          Neg. emo.      0.0002
# 51     63            Auxverb      0.0002
# 52     54       Focus future      0.0002
# 53     25              Death      0.0002
# 54     44       Tentativness      0.0002
# 55     45          Certainty      0.0002
# 56     17             Friend      0.0002
# 57     38            Anxiety      0.0002
# 58     43            Discrep      0.0002
# 59     64             Adverb      0.0001
# 60     42              Cause      0.0001
# 61     30         Nonfluence      0.0001
# 62     29             Assent      0.0001
# 63     41            Insight      0.0001
# 64     56                 We      0.0001
# 65     59               They      0.0001
# 66     40            Sadness      0.0001
# 67     31             Filler      0.0001
# 68     46    Differentiation      0.0001
# 69     72       Quantitative      0.0001
# 70     73                See      0.0001
# 71     36          Pos. emo.      0.0001
# 72     35             Ingest      0.0001
# 73     49              Power      0.0001
# 74     21            Leisure      0.0000
# 75     33             Health      0.0000
# 76     16             Family      0.0000
# 77     71             Number      0.0000
# 78     24           Relegion      0.0000

# %%
features_cl = features_cl[features_cl['importance']>0]
features_cl = features_cl.Feature.values
print('Number of selected features: ', len(features_cl))
print()
print(features_cl)
# Out:
# Number of selected features:  78
#
# ['URLs n.' 'Retweets' 'Text l.' 'Work' 'Hashtags n.' 'News(Shalla)'
#  'Science p.T.' 'Political p.T.' 'Readability' 'Preposition' 'Sentiment'
#  'Mentions n.' 'Emoji n.' 'Socialnet(Shalla)' 'Informal' 'I'
#  'Porn(Shalla)' 'Swear' 'Likes' 'Verb' 'Sexual' 'Social' 'Emoji sentiment'
#  'Money' 'Hear' 'Affiliation' 'Ipron' 'Home' 'Netspeak' 'You' 'Female'
#  'Time' 'Motion' 'SheHe' 'Article' 'Male' 'Interrogative' 'Body'
#  'Conjunctive' 'Focus present' 'Reward' 'Risk' 'Adjective' 'Space' 'Anger'
#  'Negate' 'Achieve' 'Focus past' 'Compare' 'Feel' 'Neg. emo.' 'Auxverb'
#  'Focus future' 'Death' 'Tentativness' 'Certainty' 'Friend' 'Anxiety'
#  'Discrep' 'Adverb' 'Cause' 'Nonfluence' 'Assent' 'Insight' 'We' 'They'
#  'Sadness' 'Filler' 'Differentiation' 'Quantitative' 'See' 'Pos. emo.'
#  'Ingest' 'Power' 'Leisure' 'Health' 'Family' 'Number']

# %%
#X = df_tweetscov19_user_2[features_cl.tolist()].values
X.shape
# Out:
# (4275002, 79)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (3420001, 79)
# (855001, 79)
# (3420001,)
# (855001,)

# %%
sns.countplot(x = y_train)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
sns.countplot(x = y_test)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
l_regression = fit_log_reg(X_train,y_train)

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_LR_Inhalt_all_ohne_moderacy.sav'
pickle.dump(l_regression, open(pfad_modell, 'wb'))

# %%
y_prob = l_regression.predict_proba(X_test)

# %%
print('Accuracy without useres features is : ',l_regression.score(X_train, y_train))
# Out:
# Accuracy without useres features is :  0.5673463253373318

# %%
y_pred = l_regression.predict(X_train)
y_prob = l_regression.predict_proba(X_train)
y_prob_test = l_regression.predict_proba(X_test)

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.50      0.53   1709564
#            1       0.56      0.64      0.60   1710437
#
#     accuracy                           0.57   3420001
#    macro avg       0.57      0.57      0.57   3420001
# weighted avg       0.57      0.57      0.57   3420001

# %%
confusion_mx = confusion_matrix(y_train, y_pred)
confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
plot_confusion_matrix(confusion_mx, l_regression.classes_, 'Confusion Matrix')

# %%
print('Logarithmic loss für Training data', log_loss(y_train, y_prob))
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Training data 0.6801963020334549
# Logarithmic loss für Test data 0.6800949365967058

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_LR_Inhalt_all_ohne_moderacy.sav'
#l_regression = pickle.load(open(pfad_modell, 'rb'))

# %%
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='precision')
print(" percision %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='f1')
print(" f1        %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='recall')
print(" recall    %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
# Out:
#  percision 0.56 +/- 0.003
#  f1        0.60 +/- 0.005
#  recall    0.64 +/- 0.015

# %% [markdown]
# ****************************************************************
# ****************************************************************

# %% [markdown]
# ## *(2)Tweetskb*
# ### (Content + User feature)

# %%
#pfad_tsv = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/TweetsFormodel/tweetskb_sample_with_users_1_51.tsv'
pfad_tsv = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/TweetsKB_alle_geloeschten/TweetsKB_all_del_posted.tsv'

df_tweetskb_user = pd.read_csv(pfad_tsv, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Is_deleted', 'Retweets', 'Likes', 'Sentiment', 'Hashtags n.', 'Mentions n.', 'Text l.', 'URLs n.', 'Readability', 'Emoji n.', 'Emoji sentiment', 'Political p.T.', 'Science p.T.', 'Moderacy p.T.', 'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight', 'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation', 'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past', 'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive', 'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number', 'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Political p.u.', 'Science p.u.', 'Moderacy p.u.', 'Posted n.', 'Deleted n.', 'Deletion ratio', 'Reputation' ])
pd.options.display.max_columns = None
print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (5445154, 90)
#               Tweet_Id        Username  Is_deleted  Retweets  Likes  \
# 0  1234421176492912641    Jhenkyuttttt       False         3      7
# 1  1203032264038326273         EdS_888       False         0      0
# 2  1240505249724616705  Official_Lavan       False         0      0
# 3  1248234798390231045   chenfongthing       False        12     12
# 4  1221967294273851393      Joy_Anna15       False         0      0
#
#    Sentiment  Hashtags n.  Mentions n.  Text l.  URLs n.  Readability  \
# 0     0.3182            0            0       35        0      75.8750
# 1    -0.2396            0            1      208        0      81.2070
# 2     0.9356            1            0      115        0      95.9550
# 3     0.3182            0            0      107        0      87.3000
# 4     0.6260            1            0       54        0      77.3980
#
#    Emoji n.  Emoji sentiment  Political p.T.  Science p.T.  Moderacy p.T.  \
# 0         1           0.3530               0             0              0
# 1         0           0.0000               0             0              0
# 2         2           0.6650               0             0              0
# 3         1           0.6910               0             0              0
# 4         0           0.0000               0             0              0
#
#    Porn(Shalla)  News(Shalla)  Socialnet(Shalla)  Social  Family  Friend  \
# 0        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
# 1        0.0000        0.0000             0.0000 21.0500  0.0000  5.2600
# 2        0.0000        0.0000             0.0000 22.7300  0.0000  4.5500
# 3        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
#
#    Conjunctive  Negate    Verb  Adjective  Compare  Interrogative  Number  \
# 0       0.0000  0.0000  0.0000     0.0000   0.0000         0.0000  0.0000
# 1       7.8900  2.6300 21.0500    10.5300  10.5300         0.0000  0.0000
# 2       0.0000  0.0000 13.6400     0.0000   0.0000         4.5500  0.0000
# 3      13.6400  0.0000  9.0900     0.0000   0.0000         0.0000  0.0000
# 4       0.0000  0.0000  0.0000     0.0000   0.0000         0.0000  0.0000
#
#    Quantitative    See   Hear   Feel  Motion  Space   Time  Political p.u.  \
# 0        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000          0.0000
# 1        0.0000 0.0000 0.0000 0.0000  2.6300 0.0000 0.0000          0.0000
# 2        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 4.5500          0.0000
# 3        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 4.5500          0.0000
# 4        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000          0.0000
#
#    Science p.u.  Moderacy p.u.  Posted n.  Deleted n.  Deletion ratio  \
# 0        0.0000         0.0000          1           0          0.0000
# 1        0.0000         0.0000          2           0          0.0000
# 2        0.0000         0.0000          2           1          0.5000
# 3        0.0000         0.0000          6           0          0.0000
# 4        0.0000         0.0000          2           0          0.0000
#
#    Reputation
# 0      0.5025
# 1      0.5110
# 2      0.2500
# 3      0.4367
# 4      0.2551

# %%
df_tweetskb_user.head()
# Out:
#               Tweet_Id        Username  Is_deleted  Retweets  Likes  \
# 0  1234421176492912641    Jhenkyuttttt       False         3      7
# 1  1203032264038326273         EdS_888       False         0      0
# 2  1240505249724616705  Official_Lavan       False         0      0
# 3  1248234798390231045   chenfongthing       False        12     12
# 4  1221967294273851393      Joy_Anna15       False         0      0
#
#    Sentiment  Hashtags n.  Mentions n.  Text l.  URLs n.  Readability  \
# 0     0.3182            0            0       35        0      75.8750
# 1    -0.2396            0            1      208        0      81.2070
# 2     0.9356            1            0      115        0      95.9550
# 3     0.3182            0            0      107        0      87.3000
# 4     0.6260            1            0       54        0      77.3980
#
#    Emoji n.  Emoji sentiment  Political p.T.  Science p.T.  Moderacy p.T.  \
# 0         1           0.3530               0             0              0
# 1         0           0.0000               0             0              0
# 2         2           0.6650               0             0              0
# 3         1           0.6910               0             0              0
# 4         0           0.0000               0             0              0
#
#    Porn(Shalla)  News(Shalla)  Socialnet(Shalla)  Social  Family  Friend  \
# 0        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
# 1        0.0000        0.0000             0.0000 21.0500  0.0000  5.2600
# 2        0.0000        0.0000             0.0000 22.7300  0.0000  4.5500
# 3        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
# 4        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
#
#    Female   Male   Work  Leisure   Home  Money  Relegion  Death  Informal  \
# 0  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
# 1  0.0000 7.8900 2.6300   2.6300 0.0000 0.0000    0.0000 0.0000    5.2600
# 4       0.0000  0.0000  0.0000     0.0000   0.0000         0.0000  0.0000
#
#    Quantitative    See   Hear   Feel  Motion  Space   Time  Political p.u.  \
# 0        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000          0.0000
# 1        0.0000 0.0000 0.0000 0.0000  2.6300 0.0000 0.0000          0.0000
# 2        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 4.5500          0.0000
# 3        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 4.5500          0.0000
# 4        0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000          0.0000
#
#    Science p.u.  Moderacy p.u.  Posted n.  Deleted n.  Deletion ratio  \
# 0        0.0000         0.0000          1           0          0.0000
# 1        0.0000         0.0000          2           0          0.0000
# 2        0.0000         0.0000          2           1          0.5000
# 3        0.0000         0.0000          6           0          0.0000
# 4        0.0000         0.0000          2           0          0.0000
#
#    Reputation
# 0      0.5025
# 1      0.5110
# 2      0.2500
# 3      0.4367
# 4      0.2551

# %%
df_tweetskb_user.Username.unique().size
# Out:
# 3378025

# %%
df_tweetskb_del = df_tweetskb_user[df_tweetskb_user['Is_deleted']==True]
df_tweetskb_undel = df_tweetskb_user[df_tweetskb_user['Is_deleted']==False]

# %%
df = df_tweetskb_user[['Is_deleted', 'Retweets', 'Sentiment', 'Likes']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetskb_Retweet_favoriet_sentiment')

# %%
df = df_tweetskb_user[['Is_deleted', 'Political p.u.', 'Science p.u.', 'Moderacy p.u.']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetskb_politic_science_moderacy')

# %%
df = df_tweetskb_user[['Is_deleted', 'Political p.u.']]
plot_kdeplot(df, 'Is_deleted','Political p.u.', 'Political', 'TweetsKB','pairplot_tweetskb_politicd')

# %%
df = df_tweetskb_user[['Is_deleted', 'Science p.u.']]
plot_kdeplot(df, 'Is_deleted','Science p.u.','Science', 'TweetsKB' ,'pairplot_tweetskb_science')

# %%
df = df_tweetskb_user[['Is_deleted', 'Moderacy p.u.']]
plot_kdeplot(df, 'Is_deleted','Moderacy p.u.','Moderacy', 'TweetsKB' ,'pairplot_tweetskb_moderacy')

# %%
sns.countplot(x = 'Is_deleted', data = df)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
features = df_tweetskb_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Is_deleted', 'Retweets', 'Likes', 'Sentiment',
#        'Hashtags n.', 'Mentions n.', 'Text l.', 'URLs n.', 'Readability',
#        'Emoji n.', 'Emoji sentiment', 'Political p.T.', 'Science p.T.',
#        'Moderacy p.T.', 'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)',
#        'Social', 'Family', 'Friend', 'Female', 'Male', 'Work', 'Leisure',
#        'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak',
#        'Assent', 'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest',
#        'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight',
#        'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation',
#        'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past',
#        'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They',
#        'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive',
#        'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number',
#        'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Political p.u.', 'Science p.u.', 'Moderacy p.u.', 'Posted n.',
#        'Deleted n.', 'Deletion ratio', 'Reputation'],
#       dtype='object')

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 0, 1)
df_tweetskb_user.head()
# Out:
#               Tweet_Id        Username  Is_deleted  Retweets  Likes  \
# 0  1234421176492912641    Jhenkyuttttt           1         3      7
# 1  1203032264038326273         EdS_888           1         0      0
# 2  1240505249724616705  Official_Lavan           1         0      0
# 3  1248234798390231045   chenfongthing           1        12     12
# 4  1221967294273851393      Joy_Anna15           1         0      0
#
#    Sentiment  Hashtags n.  Mentions n.  Text l.  URLs n.  Readability  \
# 0     0.3182            0            0       35        0      75.8750
# 1    -0.2396            0            1      208        0      81.2070
# 2     0.9356            1            0      115        0      95.9550
# 3     0.3182            0            0      107        0      87.3000
# 4     0.6260            1            0       54        0      77.3980
#
#    Emoji n.  Emoji sentiment  Political p.T.  Science p.T.  Moderacy p.T.  \
# 0         1           0.3530               0             0              0
# 1         0           0.0000               0             0              0
# 2         2           0.6650               0             0              0
# 3         1           0.6910               0             0              0
# 4         0           0.0000               0             0              0
#
#    Porn(Shalla)  News(Shalla)  Socialnet(Shalla)  Social  Family  Friend  \
# 0        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
# 1        0.0000        0.0000             0.0000 21.0500  0.0000  5.2600
# 2        0.0000        0.0000             0.0000 22.7300  0.0000  4.5500
# 3        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
# 4        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
#
#    Female   Male   Work  Leisure   Home  Money  Relegion  Death  Informal  \
# 0  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
# 1  0.0000 7.8900 2.6300   2.6300 0.0000 0.0000    0.0000 0.0000    5.2600
# 2  0.0000 9.0900 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
# 3  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
# 4  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Swear  Netspeak  Assent  Nonfluence  Filler   Body  Health  Sexual  Ingest  \
# 0 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 1 0.0000    2.6300  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 2 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#    Science p.u.  Moderacy p.u.  Posted n.  Deleted n.  Deletion ratio  \
# 0        0.0000         0.0000          1           0          0.0000
# 1        0.0000         0.0000          2           0          0.0000
# 2        0.0000         0.0000          2           1          0.5000
# 3        0.0000         0.0000          6           0          0.0000
# 4        0.0000         0.0000          2           0          0.0000
#
#    Reputation
# 0      0.5025
# 1      0.5110
# 2      0.2500
# 3      0.4367
# 4      0.2551

# %%
features = features[2:90]

# %%
df_tweetskb_user_2 = df_tweetskb_user[features.tolist()]
df_tweetskb_user_2 = df_tweetskb_user_2.drop(columns=[  'Moderacy p.T.','Moderacy p.u.', 'Posted n.', 'Deleted n.', 'Deletion ratio'])
df = df_tweetskb_user_2.drop('Is_deleted', axis=1)
X = df_tweetskb_user_2.drop('Is_deleted', axis=1).values
y = df_tweetskb_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (5445154, 82)
# (5445154,)

# %%
features_cl = features_classifier(df , X, y)
features_cl
# Out:
#     index            Feature  importance
# 0      81         Reputation      0.2455
# 1       6            URLs n.      0.1102
# 2      62        Preposition      0.1000
# 3      55                  I      0.0977
# 4      79     Political p.u.      0.0871
# 5      26           Informal      0.0494
# 6       4        Mentions n.      0.0420
# 7      80       Science p.u.      0.0301
# 8       5            Text l.      0.0300
# 9       3        Hashtags n.      0.0277
# 10     34             Sexual      0.0231
# 11     12       Porn(Shalla)      0.0229
# 12      2          Sentiment      0.0166
# 13     13       News(Shalla)      0.0145
# 14     20               Work      0.0131
# 15      0           Retweets      0.0122
# 16      8           Emoji n.      0.0103
# 17     67               Verb      0.0092
# 18     14  Socialnet(Shalla)      0.0078
# 19     28           Netspeak      0.0070
# 20      1              Likes      0.0063
# 21     27              Swear      0.0050
# 22     15             Social      0.0026
# 23     57                You      0.0025
# 24     39              Anger      0.0024
# 25      9    Emoji sentiment      0.0020
# 26     60              Ipron      0.0018
# 27     29             Assent      0.0015
# 28     78               Time      0.0015
# 29     11       Science p.T.      0.0013
# 30     32               Body      0.0012
# 31     23              Money      0.0011
# 32     77              Space      0.0011
# 33      7        Readability      0.0011
# 34     47        Affiliation      0.0009
# 35     36          Pos. emo.      0.0009
# 36     71             Number      0.0009
# 37     52         Focus past      0.0008
# 38     53      Focus present      0.0006
# 39     68          Adjective      0.0004
# 40     64             Adverb      0.0004
# 41     44       Tentativness      0.0004
# 42     76             Motion      0.0004
# 43     66             Negate      0.0004
# 44     43            Discrep      0.0004
# 45     46    Differentiation      0.0003
# 46     49              Power      0.0003
# 47     65        Conjunctive      0.0003
# 48     70      Interrogative      0.0003
# 49     41            Insight      0.0003
# 50     48            Achieve      0.0003
# 51     61            Article      0.0003
# 52     75               Feel      0.0003
# 53     50             Reward      0.0003
# 54     37          Neg. emo.      0.0002
# 55     33             Health      0.0002
# 56     22               Home      0.0002
# 57     42              Cause      0.0002
# 58     72       Quantitative      0.0002
# 59     18             Female      0.0002
# 60     45          Certainty      0.0002
# 61     35             Ingest      0.0001
# 62     63            Auxverb      0.0001
# 63     73                See      0.0001
# 64     69            Compare      0.0001
# 65     16             Family      0.0001
# 66     19               Male      0.0001
# 67     54       Focus future      0.0001
# 68     24           Relegion      0.0001
# 69     74               Hear      0.0001
# 70     17             Friend      0.0001
# 71     21            Leisure      0.0001
# 72     40            Sadness      0.0001
# 73     51               Risk      0.0001
# 74     58              SheHe      0.0000
# 75     25              Death      0.0000
# 76     30         Nonfluence      0.0000
# 77     10     Political p.T.      0.0000
# 78     31             Filler      0.0000
# 79     59               They      0.0000
# 80     38            Anxiety      0.0000
# 81     56                 We      0.0000

# %%
features_cl = features_cl[features_cl['importance']>0]
features_cl = features_cl.Feature.values
print(features_cl)
# Out:
# ['Reputation' 'URLs n.' 'Preposition' 'I' 'Political p.u.' 'Informal'
#  'Mentions n.' 'Science p.u.' 'Text l.' 'Hashtags n.' 'Sexual'
#  'Porn(Shalla)' 'Sentiment' 'News(Shalla)' 'Work' 'Retweets' 'Emoji n.'
#  'Verb' 'Socialnet(Shalla)' 'Netspeak' 'Likes' 'Swear' 'Social' 'You'
#  'Anger' 'Emoji sentiment' 'Ipron' 'Assent' 'Time' 'Science p.T.' 'Body'
#  'Money' 'Space' 'Readability' 'Affiliation' 'Pos. emo.' 'Number'
#  'Focus past' 'Focus present' 'Adjective' 'Adverb' 'Tentativness' 'Motion'
#  'Negate' 'Discrep' 'Differentiation' 'Power' 'Conjunctive'
#  'Interrogative' 'Insight' 'Achieve' 'Article' 'Feel' 'Reward' 'Neg. emo.'
#  'Health' 'Home' 'Cause' 'Quantitative' 'Female' 'Certainty' 'Ingest'
#  'Auxverb' 'See' 'Compare' 'Family' 'Male' 'Focus future' 'Relegion'
#  'Hear' 'Friend' 'Leisure' 'Sadness' 'Risk' 'SheHe' 'Death' 'Nonfluence']

# %%
#X = df_tweetskb_user[features_cl.tolist()].values
X.shape
# Out:
# (5445154, 82)

# %%
X_train, X_test, y_train, y_test  = split_train_test_valid(X,y)
# Out:
# (4356123, 82)
# (1089031, 82)
# (4356123,)
# (1089031,)

# %%
sns.countplot(x = y_train)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
sns.countplot(x = y_test)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
l_regression = fit_log_reg(X_train, y_train)

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_LR_Benutzer_Inhalt_alle_ohne_moderacy.sav'
pickle.dump(l_regression, open(pfad_modell, 'wb'))

# %%
y_prob = l_regression.predict_proba(X_test)

# %%
print('Accuracy with useres featuresis : ',l_regression.score(X_train, y_train))
# Out:
# Accuracy with useres featuresis :  0.5535339566857961

# %%
y_pred = l_regression.predict(X_train)
y_prob = l_regression.predict_proba(X_train)
y_prob_test = l_regression.predict_proba(X_test)

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.52      0.54   2178121
#            1       0.55      0.59      0.57   2178002
#
#     accuracy                           0.55   4356123
#    macro avg       0.55      0.55      0.55   4356123
# weighted avg       0.55      0.55      0.55   4356123

# %%
confusion_mx = confusion_matrix(y_train, y_pred)
confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
plot_confusion_matrix(confusion_mx, l_regression.classes_, 'Confusion Matrix')

# %%
print('Logarithmic loss für Training data', log_loss(y_train, y_prob))
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Training data 0.6861140238813914
# Logarithmic loss für Test data 0.6862349289130182

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_LR_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#l_regression = pickle.load(open(pfad_modell, 'rb'))

# %%
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='precision')
print(" percision %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='f1')
print(" f1        %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='recall')
print(" recall    %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
# Out:
#  percision 0.55 +/- 0.001
#  f1        0.57 +/- 0.003
#  recall    0.59 +/- 0.007

# %% [markdown]
# **********************************************************************
# **********************************************************************

# %% [markdown]
# ### Tweetskb
# #### (Content only)

# %%
features = df_tweetskb_user.columns
features

features = features[2:83]
df_tweetskb_user_2 = df_tweetskb_user[features.tolist()]
df_tweetskb_user_2 = df_tweetskb_user_2.drop(columns=[ 'Moderacy p.T.'])

df = df_tweetskb_user_2.drop('Is_deleted', axis=1)
X = df_tweetskb_user_2.drop('Is_deleted', axis=1).values
y = df_tweetskb_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (5445154, 79)
# (5445154,)

# %%
features
# Out:
# Index(['Is_deleted', 'Retweets', 'Likes', 'Sentiment', 'Hashtags n.',
#        'Mentions n.', 'Text l.', 'URLs n.', 'Readability', 'Emoji n.',
#        'Emoji sentiment', 'Political p.T.', 'Science p.T.', 'Moderacy p.T.',
#        'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family',
#        'Friend', 'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money',
#        'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent',
#        'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest',
#        'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight',
#        'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation',
#        'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past',
#        'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They',
#        'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive',
#        'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number',
#        'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time'],
#       dtype='object')

# %%
features_cl = features_classifier(df , X, y)
features_cl
# Out:
#     index            Feature  importance
# 0       6            URLs n.      0.1432
# 1      62        Preposition      0.1189
# 2      55                  I      0.1181
# 3      26           Informal      0.0625
# 4       4        Mentions n.      0.0565
# 5       3        Hashtags n.      0.0537
# 6       0           Retweets      0.0501
# 7      34             Sexual      0.0487
# 8       5            Text l.      0.0416
# 9      20               Work      0.0391
# 10      2          Sentiment      0.0323
# 11      8           Emoji n.      0.0266
# 12     10     Political p.T.      0.0211
# 13      1              Likes      0.0190
# 14     14  Socialnet(Shalla)      0.0182
# 15     13       News(Shalla)      0.0172
# 16     12       Porn(Shalla)      0.0125
# 17     11       Science p.T.      0.0109
# 18     15             Social      0.0105
# 19     28           Netspeak      0.0103
# 20     27              Swear      0.0103
# 21     67               Verb      0.0071
# 22     23              Money      0.0059
# 23     39              Anger      0.0056
# 24      9    Emoji sentiment      0.0053
# 25     57                You      0.0052
# 26     60              Ipron      0.0043
# 27      7        Readability      0.0042
# 28     61            Article      0.0041
# 29     43            Discrep      0.0030
# 30     78               Time      0.0025
# 31     47        Affiliation      0.0025
# 32     29             Assent      0.0024
# 33     77              Space      0.0023
# 34     32               Body      0.0016
# 35     45          Certainty      0.0016
# 36     18             Female      0.0016
# 37     71             Number      0.0014
# 38     63            Auxverb      0.0013
# 39     36          Pos. emo.      0.0011
# 40     22               Home      0.0011
# 41     46    Differentiation      0.0011
# 42     33             Health      0.0010
# 43     21            Leisure      0.0009
# 44     50             Reward      0.0008
# 45     68          Adjective      0.0008
# 46     53      Focus present      0.0008
# 47     52         Focus past      0.0007
# 48     37          Neg. emo.      0.0007
# 49     49              Power      0.0006
# 50     66             Negate      0.0006
# 51     65        Conjunctive      0.0005
# 52     69            Compare      0.0005
# 53     73                See      0.0005
# 54     64             Adverb      0.0004
# 55     70      Interrogative      0.0004
# 56     16             Family      0.0004
# 57     41            Insight      0.0004
# 58     35             Ingest      0.0003
# 59     44       Tentativness      0.0003
# 60     58              SheHe      0.0003
# 61     19               Male      0.0003
# 62     74               Hear      0.0003
# 63     42              Cause      0.0003
# 64     59               They      0.0002
# 65     25              Death      0.0002
# 66     76             Motion      0.0002
# 67     56                 We      0.0002
# 68     75               Feel      0.0002
# 69     30         Nonfluence      0.0002
# 70     51               Risk      0.0001
# 71     72       Quantitative      0.0001
# 72     40            Sadness      0.0001
# 73     24           Relegion      0.0001
# 74     48            Achieve      0.0001
# 75     54       Focus future      0.0001
# 76     17             Friend      0.0000
# 77     38            Anxiety      0.0000
# 78     31             Filler      0.0000

# %%
features_cl = features_cl[features_cl['importance']>0]
features_cl = features_cl.Feature.values
print(features_cl)
# Out:
# ['URLs n.' 'Preposition' 'I' 'Informal' 'Mentions n.' 'Hashtags n.'
#  'Retweets' 'Sexual' 'Text l.' 'Work' 'Sentiment' 'Emoji n.'
#  'Political p.T.' 'Likes' 'Socialnet(Shalla)' 'News(Shalla)'
#  'Porn(Shalla)' 'Science p.T.' 'Social' 'Netspeak' 'Swear' 'Verb' 'Money'
#  'Anger' 'Emoji sentiment' 'You' 'Ipron' 'Readability' 'Article' 'Discrep'
#  'Time' 'Affiliation' 'Assent' 'Space' 'Body' 'Certainty' 'Female'
#  'Number' 'Auxverb' 'Pos. emo.' 'Home' 'Differentiation' 'Health'
#  'Leisure' 'Reward' 'Adjective' 'Focus present' 'Focus past' 'Neg. emo.'
#  'Power' 'Negate' 'Conjunctive' 'Compare' 'See' 'Adverb' 'Interrogative'
#  'Family' 'Insight' 'Ingest' 'Tentativness' 'SheHe' 'Male' 'Hear' 'Cause'
#  'They' 'Death' 'Motion' 'We' 'Feel' 'Nonfluence' 'Risk' 'Quantitative'
#  'Sadness' 'Relegion' 'Achieve' 'Focus future' 'Friend' 'Anxiety']

# %%
#X = df_tweetscov19_user_2[features_cl.tolist()].values
X.shape
# Out:
# (5445154, 79)

# %%
X_train, X_test, y_train, y_test  = split_train_test_valid(X,y)
# Out:
# (4356123, 79)
# (1089031, 79)
# (4356123,)
# (1089031,)

# %%
sns.countplot(x = y_train)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
sns.countplot(x = y_test)
# Out:
# <AxesSubplot:xlabel='Is_deleted', ylabel='count'>

# %%
l_regression = fit_log_reg(X_train, y_train)

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_LR_Inhalt_alle_ohne_moderacy.sav'
pickle.dump(l_regression, open(pfad_modell, 'wb'))

# %%
print('Accuracy without useres features is : ',l_regression.score(X_train, y_train))
# Out:
# Accuracy without useres features is :  0.5531324528715098

# %%
y_pred = l_regression.predict(X_train)
y_prob = l_regression.predict_proba(X_train)
y_prob_test = l_regression.predict_proba(X_test)

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.52      0.54   2178121
#            1       0.55      0.58      0.57   2178002
#
#     accuracy                           0.55   4356123
#    macro avg       0.55      0.55      0.55   4356123
# weighted avg       0.55      0.55      0.55   4356123

# %%
confusion_mx = confusion_matrix(y_train, y_pred)
confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
plot_confusion_matrix(confusion_mx, l_regression.classes_, 'Confusion Matrix')

# %%
print('Logarithmic loss für Training data', log_loss(y_train, y_prob))
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Training data 0.6859997270131609
# Logarithmic loss für Test data 0.6860934903177099

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_LR_Inhalt_alle_ohne_moderacy.sav'
#l_regression = pickle.load(open(pfad_modell, 'rb'))

# %%
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='precision')
print(" percision %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='f1')
print(" f1        %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
scores = cross_val_score(l_regression, X_test, y_test, cv=10, scoring='recall')
print(" recall    %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
# Out:
#  percision 0.55 +/- 0.001
#  f1        0.57 +/- 0.002
#  recall    0.59 +/- 0.005
