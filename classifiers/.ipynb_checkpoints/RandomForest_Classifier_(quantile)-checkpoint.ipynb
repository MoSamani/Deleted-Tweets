# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
from termcolor import colored
csv.field_size_limit(100000000)

from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import shap

from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.float_format = '{:.4f}'.format

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # RandomForestClassifier
# ## TweetsCov19
# ### (Tweet content + user features)

# %%
path = '../data/df_tweetscov19_sample_200000_23.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative', 'Sentiment neutral', 'Sentiment positive', 'Sentiment compound', 'Number of hashtags', 'Number od mentions', 'Text length', 'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent', 'Political polarisation (tweet based)', 'Science polarisation (tweet based)', 'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx', 'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain', 'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk', 'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj', 'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)', 'Reputation (user)', 'Is_deleted', 'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation'])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1254069159098322947  4e8e74c47b8950e4b3954c86732007f6         0          0
# 1  1249258619562070019  bd41ec450084d9a16582b6fccbddcc9f         0          0
# 2  1244312339756834817  4de0b1281cf756ea9707014c816679a1         0          0
# 3  1182296312932384768  a28f24f00de6b0aebb557d27f9c51500         0          0
# 4  1240046019548721156  a52194236f9679e4183863c3583c6178         0          0
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.2710             0.7290              0.0000
# 2             -0.2100             0.4330              0.3570
# 3             -0.0000             1.0000              0.0000
# 4             -0.1310             0.8690              0.0000
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   0                   0           17
# 1             -0.3818                   0                   0           72
# 2              0.3336                   1                   0           66
# 3              0.0000                   0                   0           93
# 4             -0.2755                   0                   1          111
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      35.6050                 0      0.0000
# 1               1      40.0900                 0      0.0000
# 2               0      75.5000                 1      0.0000
# 3               0      80.0980                 2     -0.1710
# 4               1      61.2400                 0      0.0000
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1                               0.0000  9.0900  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000  9.0900  0.0000  0.0000  0.0000 0.0000
# 3                               0.0000 10.0000  0.0000  0.0000  0.0000 0.0000
# 4                               0.0000 11.1100  0.0000  0.0000  0.0000 0.0000
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 9.0900   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 5.5600   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  9.0900
# 2  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  9.0900
# 3  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 4  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  5.5600  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 9.0900 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  9.0900
# 2 0.0000 0.0000 0.0000   0.0000 0.0000   9.0900  0.0000   0.0000  0.0000
# 3 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  5.5600
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  9.0900 9.0900  0.0000 0.0000     0.0000        0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        9.0900
# 3       0.0000  0.0000 0.0000  0.0000 0.0000    10.0000       20.0000
# 4       0.0000  0.0000 5.5600  0.0000 0.0000     0.0000        5.5600
#
#    Focusfuture      I     We    You  SheHe   They   Ipron  Article    Prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000  0.0000
# 1       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000  9.0900
# 2       0.0000 0.0000 0.0000 9.0900 0.0000 0.0000  0.0000   0.0000  0.0000
# 3       5.0000 0.0000 0.0000 5.0000 0.0000 0.0000 15.0000   0.0000 10.0000
# 4       0.0000 0.0000 0.0000 5.5600 0.0000 0.0000  0.0000   0.0000  0.0000
#
#    Auxverb  Adverb   Conj  Negate    Verb     Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000 0.0000  0.0000 33.3300  0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000 0.0000  9.0900  0.0000  0.0000   0.0000    0.0000  0.0000
# 2   0.0000  9.0900 9.0900  0.0000  9.0900  0.0000   0.0000    0.0000  0.0000
# 3  10.0000  0.0000 5.0000  0.0000 30.0000  5.0000   5.0000    5.0000  0.0000
# 4   0.0000  5.5600 5.5600  5.5600  5.5600 11.1100   0.0000    5.5600  0.0000
#
#    Quant    See   Hear   Feel  Motion  Space    Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 33.3300
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 2 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 3 0.0000 0.0000 5.0000 0.0000 10.0000 5.0000 10.0000
# 4 0.0000 0.0000 5.5600 0.0000  0.0000 5.5600 11.1100
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                               1.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                              -1.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         1
# 1                             -1.0000                        10
# 2                              0.0000                         1
# 3                              0.0000                         1
# 4                             -1.0000                         5
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          1                 1.0000             0.6264
# 1                         10                 1.0000             1.0000
# 2                          1                 1.0000             0.4861
# 3                          1                 1.0000             0.5193
# 4                          5                 1.0000             0.2887
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0        True                  0.0000                     0.0000
# 1        True                  0.4501                    -0.8319
# 2        True                  0.3336                     0.0000
# 3        True                  0.0000                     0.0000
# 4        True                 -0.4939                     0.2184
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                 -1.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  1.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                0.0000                                 1.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 1.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1249379289679704067  7f32ea2d61bcb33f859a07ca7f10f892         0          0
# 1  1247968669738688514  f42f354379c191ddac35ac706e61b98c         0          0
# 2  1257799162009182208  9895be6f76503e81ce1bce8be755b68e         0          0
# 3  1240859035068321792  5492077edfe943d636d0b7db922f574a         0          0
# 4  1249826935183560704  421bfc55a3d07eddb41d89af0453e96e         0          0
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.0000             0.8220              0.1780
# 2             -0.0000             0.6930              0.3070
# 3             -0.1050             0.8950              0.0000
# 4             -0.0680             0.5560              0.3760
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   1                   0          198
# 1              0.3804                   0                   4           96
# 2              0.8519                   0                   1          127
# 3             -0.5053                   0                   1          221
# 4              0.9644                   0                   1          121
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      62.3610                 0      0.0000
# 1               0      37.4550                 0      0.0000
# 2               0      64.8010                 1      0.6450
# 3               0      60.0760                 0      0.0000
# 4               0      88.9050                 4      1.5960
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000 21.0500  0.0000  0.0000  0.0000 5.2600
# 3                               0.0000 10.3400  0.0000  3.4500  0.0000 3.4500
# 4                               0.0000  4.1700  0.0000  0.0000  0.0000 4.1700
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   5.2600 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 3.4500   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 2  0.0000  0.0000  0.0000 5.2600  0.0000  0.0000  0.0000  5.2600  0.0000
# 3  0.0000  0.0000  0.0000 3.4500  3.4500  0.0000  0.0000  0.0000  3.4500
# 4  0.0000  0.0000  0.0000 0.0000  4.1700  0.0000  0.0000  0.0000  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 0.0000 0.0000   7.6900 0.0000   0.0000  0.0000   7.6900  0.0000
# 2 0.0000 0.0000 0.0000   5.2600 0.0000   0.0000  0.0000   5.2600  0.0000
# 3 0.0000 3.4500 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  0.0000 7.6900  0.0000 0.0000     0.0000        7.6900
# 2      15.7900  0.0000 5.2600  0.0000 0.0000     0.0000        5.2600
# 3       3.4500  0.0000 6.9000  0.0000 0.0000     0.0000        6.9000
# 4       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000       12.5000
#
#    Focusfuture      I      We    You  SheHe   They  Ipron  Article    Prep  \
# 0       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  6.6700
# 1       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000   7.6900  7.6900
# 2       0.0000 0.0000 10.5300 0.0000 5.2600 0.0000 5.2600   0.0000  5.2600
# 3       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000   3.4500  3.4500
# 4       0.0000 0.0000  0.0000 0.0000 4.1700 0.0000 0.0000   4.1700 16.6700
#
#    Auxverb  Adverb    Conj  Negate    Verb    Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000  3.3300  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000  0.0000  0.0000  7.6900 7.6900   7.6900    0.0000  0.0000
# 2   0.0000  0.0000 10.5300  0.0000  5.2600 0.0000   0.0000    0.0000  0.0000
# 3   6.9000  0.0000  0.0000  0.0000 10.3400 3.4500   0.0000    0.0000  0.0000
# 4   4.1700  0.0000  0.0000  0.0000 12.5000 4.1700   0.0000    0.0000  4.1700
#
#    Quant    See   Hear   Feel  Motion   Space    Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
# 1 7.6900 0.0000 0.0000 0.0000  0.0000 23.0800  0.0000
# 2 5.2600 0.0000 0.0000 0.0000  0.0000  5.2600 10.5300
# 3 0.0000 0.0000 0.0000 0.0000  0.0000  3.4500  3.4500
# 4 0.0000 8.3300 0.0000 0.0000  4.1700 12.5000  0.0000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                              -1.0000                            -1.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         1
# 1                             -1.0000                        14
# 2                              0.0000                         1
# 3                              0.0000                         1
# 4                              0.0000                         1
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          0                 0.0000             0.3051
# 1                         14                 1.0000             0.5005
# 2                          0                 0.0000             0.3663
# 3                          0                 0.0000             0.2596
# 4                          0                 0.0000             0.7871
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0       False                  0.0000                     0.0000
# 1        True                  0.0162                     0.3642
# 2       False                  0.8519                     0.0000
# 3       False                 -0.5053                     0.0000
# 4       False                  0.9644                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  1.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                1.0000                                 1.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative',
#        'Sentiment neutral', 'Sentiment positive', 'Sentiment compound',
#        'Number of hashtags', 'Number od mentions', 'Text length',
#        'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent',
#        'Political polarisation (tweet based)',
#        'Science polarisation (tweet based)',
#        'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend',
#        'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money', 'Relegion',
#        'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler',
#        'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx',
#        'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain',
#        'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk',
#        'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe',
#        'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj',
#        'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant',
#        'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Political polarisation (user based)',
#        'Science polarisation (user based)',
#        'Moderacy polarisation (user based)', 'Posted_tweets (per user)',
#        'Deleted_tweets (per user)', 'Deletion_ratio (user)',
#        'Reputation (user)', 'Is_deleted', 'User sentiment average',
#        'Tweet sentiment deviation', 'Tweet political polarisation deviation',
#        'Tweet science polarisation deviation',
#        'Tweet moderacy polarisation deviation'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)
df_tweetscov19_user.head()
# Out:
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1249379289679704067  7f32ea2d61bcb33f859a07ca7f10f892         0          0
# 1  1247968669738688514  f42f354379c191ddac35ac706e61b98c         0          0
# 2  1257799162009182208  9895be6f76503e81ce1bce8be755b68e         0          0
# 3  1240859035068321792  5492077edfe943d636d0b7db922f574a         0          0
# 4  1249826935183560704  421bfc55a3d07eddb41d89af0453e96e         0          0
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.0000             0.8220              0.1780
# 2             -0.0000             0.6930              0.3070
# 3             -0.1050             0.8950              0.0000
# 4             -0.0680             0.5560              0.3760
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   1                   0          198
# 1              0.3804                   0                   4           96
# 2              0.8519                   0                   1          127
# 3             -0.5053                   0                   1          221
# 4              0.9644                   0                   1          121
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      62.3610                 0      0.0000
# 1               0      37.4550                 0      0.0000
# 2               0      64.8010                 1      0.6450
# 3               0      60.0760                 0      0.0000
# 4               0      88.9050                 4      1.5960
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000 21.0500  0.0000  0.0000  0.0000 5.2600
# 3                               0.0000 10.3400  0.0000  3.4500  0.0000 3.4500
# 4                               0.0000  4.1700  0.0000  0.0000  0.0000 4.1700
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   5.2600 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 3.4500   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 2  0.0000  0.0000  0.0000 5.2600  0.0000  0.0000  0.0000  5.2600  0.0000
# 3  0.0000  0.0000  0.0000 3.4500  3.4500  0.0000  0.0000  0.0000  3.4500
# 4  0.0000  0.0000  0.0000 0.0000  4.1700  0.0000  0.0000  0.0000  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 0.0000 0.0000   7.6900 0.0000   0.0000  0.0000   7.6900  0.0000
# 2 0.0000 0.0000 0.0000   5.2600 0.0000   0.0000  0.0000   5.2600  0.0000
# 3 0.0000 3.4500 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  0.0000 7.6900  0.0000 0.0000     0.0000        7.6900
# 2      15.7900  0.0000 5.2600  0.0000 0.0000     0.0000        5.2600
# 3       3.4500  0.0000 6.9000  0.0000 0.0000     0.0000        6.9000
# 4       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000       12.5000
#
#    Focusfuture      I      We    You  SheHe   They  Ipron  Article    Prep  \
# 0       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  6.6700
# 1       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000   7.6900  7.6900
# 2       0.0000 0.0000 10.5300 0.0000 5.2600 0.0000 5.2600   0.0000  5.2600
# 3       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000   3.4500  3.4500
# 4       0.0000 0.0000  0.0000 0.0000 4.1700 0.0000 0.0000   4.1700 16.6700
#
#    Auxverb  Adverb    Conj  Negate    Verb    Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000  3.3300  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000  0.0000  0.0000  7.6900 7.6900   7.6900    0.0000  0.0000
# 2   0.0000  0.0000 10.5300  0.0000  5.2600 0.0000   0.0000    0.0000  0.0000
# 3   6.9000  0.0000  0.0000  0.0000 10.3400 3.4500   0.0000    0.0000  0.0000
# 4   4.1700  0.0000  0.0000  0.0000 12.5000 4.1700   0.0000    0.0000  4.1700
#
#    Quant    See   Hear   Feel  Motion   Space    Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
# 1 7.6900 0.0000 0.0000 0.0000  0.0000 23.0800  0.0000
# 2 5.2600 0.0000 0.0000 0.0000  0.0000  5.2600 10.5300
# 3 0.0000 0.0000 0.0000 0.0000  0.0000  3.4500  3.4500
# 4 0.0000 8.3300 0.0000 0.0000  4.1700 12.5000  0.0000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                              -1.0000                            -1.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         1
# 1                             -1.0000                        14
# 2                              0.0000                         1
# 3                              0.0000                         1
# 4                              0.0000                         1
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          0                 0.0000             0.3051
# 1                         14                 1.0000             0.5005
# 2                          0                 0.0000             0.3663
# 3                          0                 0.0000             0.2596
# 4                          0                 0.0000             0.7871
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0           0                  0.0000                     0.0000
# 1           1                  0.0162                     0.3642
# 2           0                  0.8519                     0.0000
# 3           0                 -0.5053                     0.0000
# 4           0                  0.9644                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  1.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                1.0000                                 1.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username',  'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
def fit_random_forest_clf(X,y):

    clf = RandomForestClassifier( n_jobs=-1)
    clf.fit(X,y)
    return clf

# %%
def test_random_forest_clf(model, X_test, y_test):
    
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
rf_model = fit_random_forest_clf(X_train, y_train)

# %%
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.63915

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.54      0.60     19935
#            1       0.62      0.74      0.67     20065
#
#     accuracy                           0.64     40000
#    macro avg       0.64      0.64      0.64     40000
# weighted avg       0.64      0.64      0.64     40000

# %%
def plot_confusion_matrix(y_test, y_pred, classes, titel):
    
    confusion_mx = confusion_matrix(y_test, y_pred)
    confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
    
    sns.heatmap(confusion_mx, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %% [markdown]
# ***

# %%
def features_classifier_(df, model):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = model.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)

    df_column_feature = df_column_feature.reset_index()
    df_column_feature
    return df_column_feature

# %%
rf_model = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)

rf_model.fit(X_train, y_train)

f_importances = features_classifier_(X_train, rf_model)
f_importances
# Out:
#     index                                 Feature  importance
# 0      83                       Reputation (user)      0.1550
# 1      82      Moderacy polarisation (user based)      0.0885
# 2      80     Political polarisation (user based)      0.0858
# 3       9                          Number of URLs      0.0737
# 4       1                               Favorites      0.0670
# 5       0                                Retweets      0.0668
# 6      88   Tweet moderacy polarisation deviation      0.0460
# 7      86  Tweet political polarisation deviation      0.0391
# 8       8                             Text length      0.0351
# 9       6                      Number of hashtags      0.0233
# 10     56                                       I      0.0231
# 11     84                  User sentiment average      0.0220
# 12     27                                Informal      0.0146
# 13     21                                    Work      0.0125
# 14     15     Moderacy polarisation (tweet based)      0.0124
# 15     68                                    Verb      0.0120
# 16     13    Political polarisation (tweet based)      0.0113
# 17     63                                    Prep      0.0105
# 18     10                             Readability      0.0093
# 19     61                                   Ipron      0.0080
# 20     81       Science polarisation (user based)      0.0076
# 21      5                      Sentiment compound      0.0064
# 22     87    Tweet science polarisation deviation      0.0064
# 23     29                                Netspeak      0.0064
# 24     28                                   Swear      0.0058
# 25      2                      Sentiment negative      0.0057
# 26      7                      Number od mentions      0.0056
# 27     16                                  Social      0.0053
# 28     78                                   Space      0.0051
# 29     85               Tweet sentiment deviation      0.0051
# 30     54                            Focuspresent      0.0048
# 31      3                       Sentiment neutral      0.0046
# 32     65                                  Adverb      0.0045
# 33     12                              Emoji_sent      0.0040
# 34     64                                 Auxverb      0.0039
# 35     62                                 Article      0.0038
# 36     11                        Number of Emojis      0.0037
# 37     66                                    Conj      0.0036
# 38     53                               Focuspast      0.0034
# 39      4                      Sentiment positive      0.0032
# 40     35                                  Sexual      0.0031
# 41     38                                  Negemo      0.0030
# 42     79                                    Time      0.0029
# 43     58                                     You      0.0029
# 44     71                                Interrog      0.0027
# 45     40                                   Anger      0.0027
# 46     50                                   Power      0.0026
# 47     47                                  Differ      0.0025
# 48     69                                     Adj      0.0025
# 49     37                                  Posemo      0.0025
# 50     48                             Affiliation      0.0024
# 51     49                                  Achiev      0.0023
# 52     45                                  Tentat      0.0022
# 53     67                                  Negate      0.0022
# 54     33                                    Body      0.0022
# 55     44                                 Discrep      0.0020
# 56     46                                 Certain      0.0020
# 57     42                                 Insight      0.0020
# 58     77                                  Motion      0.0020
# 59     43                                   Cause      0.0020
# 60     70                                 compare      0.0019
# 61     51                                  Reward      0.0019
# 62     59                                   SheHe      0.0019
# 63     19                                  Female      0.0018
# 64     73                                   Quant      0.0017
# 65     20                                    Male      0.0017
# 66     55                             Focusfuture      0.0016
# 67     74                                     See      0.0016
# 68     22                                 Leisure      0.0016
# 69     57                                      We      0.0016
# 70     34                                  Health      0.0015
# 71     24                                   Money      0.0015
# 72     75                                    Hear      0.0014
# 73     60                                    They      0.0014
# 74     52                                    Risk      0.0013
# 75     76                                    Feel      0.0013
# 76     72                                  Number      0.0012
# 77     26                                   Death      0.0011
# 78     23                                    Home      0.0011
# 79     36                                  Ingest      0.0009
# 80     41                                     Sad      0.0009
# 81     39                                     Anx      0.0009
# 82     14      Science polarisation (tweet based)      0.0008
# 83     18                                  Friend      0.0008
# 84     25                                Relegion      0.0007
# 85     17                                  Family      0.0006
# 86     30                                  Assent      0.0006
# 87     31                                  Nonflu      0.0005
# 88     32                                  Filler      0.0001

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'user_political_polarisation'
#  'user_moderacy_polarisation' 'URLs_num' 'Favorites' 'Retweets'
#  'tweet_moderacy_polarisation_abweichung'
#  'tweet_political_polarisation_abweichung' 'Text_len'
#  'user_vadercompound_average' 'Hashtags_num' 'i' 'informal'
#  'tweet_politic_polarisation' 'work' 'prep' 'tweet_moderacy_polarisation'
#  'verb' 'readability']

# %%
len(f_importances)
# Out:
# 19

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 19)
# (200000,)

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.61 +/- 0.009
#  f1        : 0.69 +/- 0.010
#  recall    : 0.79 +/- 0.020
# Wall time: 44.7 s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.61 +/- 0.009
#  f1        : 0.69 +/- 0.010
#  recall    : 0.78 +/- 0.016
# Wall time: 50.6 s

# %% [markdown]
# ******

# %% [markdown]
# ***

# %% [markdown]
# ****

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]
max_features = ['sqrt', 'log2', 'auto']
max_depth =  [2,4,6,8,10]
min_samples_split = [2,4,8]
min_samples_leaf = [1,2,4]
bootstrap = [True, False]

# %%
param_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf,
              'bootstrap' : bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 1000], 'max_features': ['sqrt', 'log2', 'auto'], 'max_depth': [2, 4, 6, 8, 10], 'min_samples_split': [2, 4, 8], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_model = RandomForestClassifier()

# %%
# %%time
clf_grid = GridSearchCV(rf_model, param_grid = param_grid, cv = 3, verbose = 2, n_jobs = -1)
clf_grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1620 candidates, totalling 4860 fits
# Wall time: 1h 8min 34s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [100, 200, 300, 400, 500, 1000]},
#              verbose=2)

# %%
clf_grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 8,
#  'n_estimators': 300}

# %%
clf_grid.score(X_test,y_test)
# Out:
# 0.641

# %%
# %%time
#20 000 Tweets

clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.61 +/- 0.009
#  f1        : 0.69 +/- 0.012
#  recall    : 0.79 +/- 0.019
# Wall time: 45.4 s

# %%
# %%time
#200 000 Tweets

clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.61 +/- 0.002
#  f1        : 0.69 +/- 0.002
#  recall    : 0.80 +/- 0.005
# Wall time: 6min 43s

# %% [markdown]
# ***

# %%
def plot_hist_Features(l_features_importances, l_features, title):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue', 'peru', 'black', 'mediumslateblue', 'lightblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, width = 0.5)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
    #plt.legend()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Reputation (user)',
#  'Moderacy polarisation (user based)',
#  'Political polarisation (user based)',
#  'Number of URLs',
#  'Favorites',
#  'Retweets',
#  'Tweet moderacy polarisation deviation',
#  'Tweet political polarisation deviation',
#  'Text length',
#  'Number of hashtags']

# %%
plot_hist_Features(l_features_importances, l_features, 'Rf_tweetscov19_content_User')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ## TweetsCov19
# ### (Content only)

# %%
features = df_tweetscov19_user.columns
features

#features = features[2:83]
df_tweetscov19_user = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation' ])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[  'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Reputation (user)'])

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test= split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                               Feature  importance
# 0       0                              Retweets      0.1461
# 1       1                             Favorites      0.1330
# 2       9                        Number of URLs      0.1147
# 3       8                           Text length      0.0571
# 4      56                                     I      0.0379
# 5      13  Political polarisation (tweet based)      0.0352
# 6       6                    Number of hashtags      0.0321
# 7      21                                  Work      0.0279
# 8      27                              Informal      0.0269
# 9      15   Moderacy polarisation (tweet based)      0.0252
# 10     68                                  Verb      0.0223
# 11     63                                  Prep      0.0212
# 12     10                           Readability      0.0163
# 13     61                                 Ipron      0.0158
# 14     29                              Netspeak      0.0131
# 15     78                                 Space      0.0116
# 16     28                                 Swear      0.0114
# 17      5                    Sentiment compound      0.0107
# 18      7                    Number od mentions      0.0099
# 19     16                                Social      0.0098
# 20      2                    Sentiment negative      0.0090
# 21     65                                Adverb      0.0087
# 22     54                          Focuspresent      0.0078
# 23      3                     Sentiment neutral      0.0078
# 24     11                      Number of Emojis      0.0069
# 25     66                                  Conj      0.0069
# 26     64                               Auxverb      0.0066
# 27     62                               Article      0.0065
# 28     12                            Emoji_sent      0.0065
# 29     58                                   You      0.0064
# 30     35                                Sexual      0.0060
# 31     53                             Focuspast      0.0060
# 32      4                    Sentiment positive      0.0058
# 33     79                                  Time      0.0053
# 34     69                                   Adj      0.0049
# 35     38                                Negemo      0.0047
# 36     71                              Interrog      0.0046
# 37     40                                 Anger      0.0045
# 38     50                                 Power      0.0043
# 39     47                                Differ      0.0040
# 40     33                                  Body      0.0040
# 41     49                                Achiev      0.0039
# 42     37                                Posemo      0.0039
# 43     45                                Tentat      0.0035
# 44     46                               Certain      0.0035
# 45     67                                Negate      0.0035
# 46     48                           Affiliation      0.0035
# 47     19                                Female      0.0034
# 48     70                               compare      0.0033
# 49     44                               Discrep      0.0033
# 50     77                                Motion      0.0032
# 51     59                                 SheHe      0.0032
# 52     51                                Reward      0.0032
# 53     43                                 Cause      0.0031
# 54     34                                Health      0.0030
# 55     20                                  Male      0.0029
# 56     42                               Insight      0.0028
# 57     73                                 Quant      0.0028
# 58     74                                   See      0.0027
# 59     55                           Focusfuture      0.0026
# 60     60                                  They      0.0026
# 61     24                                 Money      0.0026
# 62     57                                    We      0.0026
# 63     22                               Leisure      0.0025
# 64     52                                  Risk      0.0023
# 65     75                                  Hear      0.0022
# 66     23                                  Home      0.0018
# 67     72                                Number      0.0018
# 68     76                                  Feel      0.0017
# 69     14    Science polarisation (tweet based)      0.0016
# 70     36                                Ingest      0.0016
# 71     41                                   Sad      0.0015
# 72     39                                   Anx      0.0015
# 73     18                                Friend      0.0015
# 74     26                                 Death      0.0013
# 75     25                              Relegion      0.0012
# 76     17                                Family      0.0012
# 77     30                                Assent      0.0010
# 78     31                                Nonflu      0.0009
# 79     32                                Filler      0.0002

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['Retweets' 'Favorites' 'URLs_num' 'Text_len' 'i' 'Hashtags_num'
#  'tweet_politic_polarisation' 'informal' 'tweet_moderacy_polarisation'
#  'work' 'prep' 'verb' 'readability' 'swear' 'netspeak' 'ipron' 'space'
#  'vader_com' 'Mentions_num' 'social' 'Vader_neg' 'adverb' 'focuspresent'
#  'Vader_neu']

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 24)
# (200000,)

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(rf_model, X_new, y)
# Out:
#  percision : 0.61 +/- 0.011
#  f1        : 0.65 +/- 0.011
#  recall    : 0.71 +/- 0.019
# Wall time: 44.7 s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(rf_model, X, y)
# Out:
#  percision : 0.61 +/- 0.012
#  f1        : 0.65 +/- 0.013
#  recall    : 0.70 +/- 0.020
# Wall time: 47.1 s

# %% [markdown]
# ********************************************************
# ********************************************************

# %%
# %%time
#200 000 Tweets

clf_cv = RandomForestClassifier(n_estimators = 300, max_features = 'sqrt',max_depth = 10, min_samples_split = 8, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.66 +/- 0.003
#  recall    : 0.72 +/- 0.004
# Wall time: 7min 46s

# %% [markdown]
# ***

# %% [markdown]
# ## Plot feature Imortances
# ### TweetCov19 (Content Only)

# %%
def plot_hist_Features_content_only(l_features_importances, l_features, title):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['peru', 'black', 'mediumslateblue', 'lightblue', 'lightgreen']
    
    x = np.arange(len(l_features))

    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, width = 0.5)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=18)
    ax.set_ylabel('Feature Importance', fontsize=20)
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
    fig.tight_layout()
    

    #plt.legend()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Retweets',
#  'Favorites',
#  'Number of URLs',
#  'Text length',
#  'I',
#  'Political polarisation (tweet based)',
#  'Number of hashtags',
#  'Work',
#  'Informal',
#  'Moderacy polarisation (tweet based)']

# %%
plot_hist_Features_content_only(l_features_importances, l_features, 'Rf_tweetscov19_content_only')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# # Tweetskb
# ### (Content + User Features)

# %%
path = '../data/df_tweetskb_sample_200000_9.tsv'

df_tweetskb_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative', 'Sentiment neutral', 'Sentiment positive', 'Sentiment compound', 'Number of hashtags', 'Number od mentions', 'Text length', 'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent', 'Political polarisation (tweet based)', 'Science polarisation (tweet based)', 'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx', 'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain', 'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk', 'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj', 'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)', 'Reputation (user)', 'Is_deleted', 'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation'])

print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id        Username  Retweets  Favorites  \
# 0  1234468305332654080        cacamshx         1          1
# 1  1232807636535394304  GrammieJustice         0          0
# 2  1241798055826874368        gguksera         0          0
# 3  1185748472579780608         WTFMeqs         0          0
# 4  1247192242084884488         wavikee         1          4
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.0000             1.0000              0.0000
# 1             -0.3550             0.6450              0.0000
# 2             -0.0000             1.0000              0.0000
# 3             -0.0000             1.0000              0.0000
# 4             -0.0000             0.8330              0.1670
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0              0.0000                   0                   0           34
# 1             -0.5106                   0                   1           71
# 2              0.0000                   0                   0           35
# 3              0.0000                   0                   0           22
# 4              0.4588                   0                   1           68
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0     103.5400                 1      0.0000
# 1               1       6.3590                 0      0.0000
# 2               0      62.7900                 0      0.0000
# 3               0     100.2400                 0      0.0000
# 4               0      66.1000                 4      0.3565
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female   Male  \
# 0                               0.0000 42.8600  0.0000  0.0000 14.2900 0.0000
# 1                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 3                               0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4                               0.0000  9.0900  0.0000  0.0000  0.0000 0.0000
#
#     Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 0 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 1 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 2 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 3 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 4 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  Negemo  \
# 0  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 2  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 3  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 4  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#      Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  Differ  \
# 0 0.0000 0.0000 0.0000   0.0000 0.0000  14.2900  0.0000   0.0000  0.0000
# 1 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
#
#    Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0      14.2900  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000    16.6700        0.0000
# 4       0.0000  0.0000 0.0000  0.0000 0.0000    18.1800        0.0000
#
#    Focusfuture       I     We     You  SheHe   They   Ipron  Article    Prep  \
# 0       0.0000 14.2900 0.0000 14.2900 0.0000 0.0000  0.0000   0.0000 14.2900
# 1       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000  0.0000  10.0000  0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000 16.6700   0.0000  0.0000
# 3       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000  0.0000   0.0000 16.6700
# 4       9.0900  0.0000 0.0000  0.0000 0.0000 9.0900  0.0000   9.0900  0.0000
#
#    Auxverb  Adverb   Conj  Negate   Verb    Adj  compare  Interrog  Number  \
# 0   0.0000  0.0000 0.0000 14.2900 0.0000 0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000   0.0000    0.0000  0.0000
# 2   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000   0.0000    0.0000  0.0000
# 3   0.0000  0.0000 0.0000 16.6700 0.0000 0.0000   0.0000    0.0000  0.0000
# 4   0.0000  0.0000 0.0000 18.1800 0.0000 0.0000   0.0000    0.0000  0.0000
#
#    Quant    See   Hear   Feel  Motion  Space   Time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# 1 0.0000 0.0000 0.0000 0.0000 10.0000 0.0000 0.0000
# 2 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 0.0000
# 4 0.0000 0.0000 0.0000 9.0900  0.0000 0.0000 0.0000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                               0.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         2
# 1                              0.0000                         3
# 2                              0.0000                         3
# 3                              0.0000                         1
# 4                              0.0000                         1
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          2                 1.0000             0.5363
# 1                          3                 1.0000             0.3613
# 2                          3                 1.0000             0.5345
# 3                          1                 1.0000             0.1919
# 4                          1                 1.0000             0.1336
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0        True                  0.2107                     0.0000
# 1        True                 -0.0605                    -0.4501
# 2        True                  0.1027                     0.0000
# 3        True                  0.0000                     0.0000
# 4        True                  0.4588                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                0.0000                                 0.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
features = df_tweetskb_user.columns
#features

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 1, 0)
df_tweetskb_user.tail()
# Out:
#                    Tweet_Id       Username  Retweets  Favorites  \
# 199995  1247284461307400200  virtualscones         0          0
# 199996  1204137626728452096       maxi_why         0          0
# 199997  1257710175651323916  _AdeAugustine         0          0
# 199998  1215872861476397056      jodystans         0          0
# 199999  1242155490236403714     DerekRRose         0          0
#
#         Sentiment negative  Sentiment neutral  Sentiment positive  \
# 199995             -0.0000             0.5520              0.4480
# 199996             -0.2050             0.7950              0.0000
# 199997             -0.4420             0.5580              0.0000
# 199998             -0.2710             0.7290              0.0000
# 199999             -0.0000             0.4880              0.5120
#
#         Sentiment compound  Number of hashtags  Number od mentions  \
# 199995              0.7430                   0                   0
# 199996             -0.2023                   0                   0
# 199997             -0.5789                   0                   0
# 199998             -0.3818                   0                   1
# 199999              0.6369                   0                   1
#
#         Text length  Number of URLs  Readability  Number of Emojis  \
# 199995           60               0      95.9550                 0
# 199996           41               0      82.3900                 0
# 199997           38               0      82.3900                 0
# 199998           77               0      29.5150                 0
# 199999           28               0      66.4000                 0
#
#         Emoji_sent  Political polarisation (tweet based)  \
# 199995      0.0000                                0.0000
# 199996      0.0000                                0.0000
# 199997      0.0000                                0.0000
# 199998      0.0000                                0.0000
# 199999      0.0000                                0.0000
#
#         Science polarisation (tweet based)  \
# 199995                              0.0000
# 199996                              0.0000
# 199997                              0.0000
# 199998                              0.0000
# 199999                              0.0000
#
#         Moderacy polarisation (tweet based)  Social  Family  Friend  Female  \
# 199995                               0.0000  0.0000  0.0000  0.0000  0.0000
# 199996                               0.0000 12.5000  0.0000  0.0000  0.0000
# 199997                               0.0000 12.5000  0.0000  0.0000 12.5000
# 199998                               0.0000  9.0900  0.0000  0.0000  0.0000
# 199999                               0.0000 20.0000  0.0000  0.0000  0.0000
#
#          Male   Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  \
# 199995 0.0000 8.3300   8.3300 0.0000 0.0000    8.3300 0.0000    0.0000 0.0000
# 199996 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199997 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199998 9.0900 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199999 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#         Netspeak  Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  \
# 199995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199996    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199997    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  9.0900
# 199999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#         Posemo  Negemo    Anx   Anger    Sad  Insight  Cause  Discrep  Tentat  \
# 199995  0.0000  0.0000 0.0000  0.0000 0.0000   0.0000 0.0000   8.3300  0.0000
# 199996  0.0000 12.5000 0.0000 12.5000 0.0000   0.0000 0.0000   0.0000 12.5000
# 199997  0.0000 12.5000 0.0000  0.0000 0.0000  12.5000 0.0000  12.5000  0.0000
# 199998  0.0000  9.0900 9.0900  9.0900 0.0000   0.0000 0.0000   0.0000  0.0000
# 199999 20.0000  0.0000 0.0000  0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
#
#         Certain  Differ  Affiliation  Achiev  Power  Reward    Risk  \
# 199995   0.0000  0.0000       0.0000  0.0000 8.3300  0.0000  0.0000
# 199996   0.0000 12.5000      12.5000  0.0000 0.0000  0.0000  0.0000
# 199997   0.0000 12.5000       0.0000  0.0000 0.0000  0.0000 12.5000
# 199998   0.0000  0.0000       0.0000  0.0000 9.0900  0.0000  9.0900
# 199999   0.0000  0.0000      20.0000  0.0000 0.0000  0.0000  0.0000
#
#         Focuspast  Focuspresent  Focusfuture      I     We    You  SheHe  \
# 199995     0.0000        8.3300       8.3300 0.0000 0.0000 0.0000 0.0000
# 199996    12.5000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199997    25.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199998     0.0000        0.0000       0.0000 0.0000 0.0000 9.0900 0.0000
# 199999     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
#
#           They   Ipron  Article    Prep  Auxverb  Adverb   Conj  Negate  \
# 199995  8.3300  0.0000   8.3300 16.6700   0.0000  0.0000 0.0000 25.0000
# 199996 12.5000  0.0000  12.5000 12.5000   0.0000 12.5000 0.0000 12.5000
# 199997  0.0000 12.5000   0.0000 12.5000   0.0000 12.5000 0.0000 25.0000
# 199998  0.0000  0.0000   9.0900  0.0000   0.0000  0.0000 0.0000  0.0000
# 199999  0.0000  0.0000   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000
#
#           Verb    Adj  compare  Interrog  Number  Quant    See   Hear   Feel  \
# 199995  0.0000 8.3300   0.0000    0.0000  0.0000 0.0000 8.3300 0.0000 0.0000
# 199996 12.5000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199997  0.0000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199998  0.0000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199999  0.0000 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
#
#         Motion  Space   Time  Political polarisation (user based)  \
# 199995  0.0000 0.0000 0.0000                               0.0000
# 199996  0.0000 0.0000 0.0000                               0.0000
# 199997  0.0000 0.0000 0.0000                               0.0000
# 199998  0.0000 0.0000 0.0000                               0.0000
# 199999  0.0000 0.0000 0.0000                               0.0000
#
#         Science polarisation (user based)  Moderacy polarisation (user based)  \
# 199995                             0.0000                              0.0000
# 199996                             0.0000                              0.0000
# 199997                             0.0000                              0.0000
# 199998                             0.0000                              0.0000
# 199999                             0.0000                              0.0000
#
#         Posted_tweets (per user)  Deleted_tweets (per user)  \
# 199995                         1                          0
# 199996                         1                          0
# 199997                         4                          0
# 199998                         5                          0
# 199999                         3                          0
#
#         Deletion_ratio (user)  Reputation (user)  Is_deleted  \
# 199995                 0.0000             0.3476           0
# 199996                 0.0000             0.3703           0
# 199997                 0.0000             0.3828           0
# 199998                 0.0000             0.5587           0
# 199999                 0.0000             0.5087           0
#
#         User sentiment average  Tweet sentiment deviation  \
# 199995                  0.7430                     0.0000
# 199996                 -0.2023                     0.0000
# 199997                  0.2487                    -0.8276
# 199998                 -0.2929                    -0.0889
# 199999                  0.0569                     0.5800
#
#         Tweet political polarisation deviation  \
# 199995                                  0.0000
# 199996                                  0.0000
# 199997                                  0.0000
# 199998                                  0.0000
# 199999                                  0.0000
#
#         Tweet science polarisation deviation  \
# 199995                                0.0000
# 199996                                0.0000
# 199997                                0.0000
# 199998                                0.0000
# 199999                                0.0000
#
#         Tweet moderacy polarisation deviation
# 199995                                 0.0000
# 199996                                 0.0000
# 199997                                 0.0000
# 199998                                 0.0000
# 199999                                 0.0000

# %%
df_tweetskb_user = df_tweetskb_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id        Username  Retweets  Favorites  \
# 0  1247160733550305282  cruelefnsummer         0          0
# 1  1251296329202049024        diorkenn         1          1
# 2  1183864680248303616      MyloveYamu         2          0
# 3  1192224763181064193   kreckerjaztyn         0          0
# 4  1266508562978619392    Mayles_World         0          0
#
#    Sentiment negative  Sentiment neutral  Sentiment positive  \
# 0             -0.1830             0.8170              0.0000
# 1             -0.0000             0.7550              0.2450
# 2             -0.1020             0.5900              0.3070
# 3             -0.0000             1.0000              0.0000
# 4             -0.2380             0.6380              0.1240
#
#    Sentiment compound  Number of hashtags  Number od mentions  Text length  \
# 0             -0.7574                   0                   4          173
# 1              0.0772                   0                   0           23
# 2              0.6808                   1                   1          163
# 3              0.0000                   0                   2           35
# 4             -0.4333                   0                   2          109
#
#    Number of URLs  Readability  Number of Emojis  Emoji_sent  \
# 0               0      45.8660                 2     -0.0930
# 1               0     100.2400                 0      0.0000
# 2               0      58.1230                 0      0.0000
# 3               0    -134.6100                 0      0.0000
# 4               0      78.2450                 0      0.0000
#
#    Political polarisation (tweet based)  Science polarisation (tweet based)  \
# 0                                0.0000                              0.0000
# 1                                0.0000                              0.0000
# 2                                0.0000                              0.0000
# 3                                0.0000                              0.0000
# 4                                0.0000                              0.0000
#
#    Moderacy polarisation (tweet based)  Social  Family  Friend  Female  \
# 0                               0.0000 16.0000  8.0000  0.0000  0.0000
# 1                               0.0000 40.0000  0.0000 20.0000  0.0000
# 2                               0.0000  8.7000  0.0000  0.0000  0.0000
# 3                               0.0000  0.0000  0.0000  0.0000  0.0000
# 4                               0.0000 11.1100  0.0000  0.0000  0.0000
#
#      Male   Work  Leisure   Home  Money  Relegion  Death  Informal  Swear  \
# 0  0.0000 0.0000   4.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 1 20.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 2  0.0000 4.3500   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 3  0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 4  0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#    Netspeak  Assent  Nonflu  Filler   Body  Health  Sexual  Ingest  Posemo  \
# 0    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  4.0000  0.0000
# 1    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000
# 2    0.0000  0.0000  0.0000  0.0000 0.0000  4.3500  0.0000  0.0000 13.0400
# 3    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000
# 4    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  5.5600
#
#    Negemo    Anx  Anger    Sad  Insight  Cause  Discrep  Tentat  Certain  \
# 0  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   4.0000  0.0000   0.0000
# 1  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000  20.0000  0.0000   0.0000
# 2  4.3500 0.0000 0.0000 0.0000   8.7000 0.0000   0.0000  0.0000   4.3500
# 3  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000
# 4  0.0000 0.0000 0.0000 0.0000   5.5600 5.5600   0.0000  0.0000   5.5600
#
#    Differ  Affiliation  Achiev  Power  Reward   Risk  Focuspast  Focuspresent  \
# 0  0.0000       8.0000  0.0000 8.0000  0.0000 0.0000     8.0000        4.0000
# 1  0.0000      20.0000  0.0000 0.0000  0.0000 0.0000    20.0000        0.0000
# 2  0.0000       0.0000  8.7000 4.3500  4.3500 0.0000    21.7400        4.3500
# 3  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 4  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000    16.6700        0.0000
#
#    Focusfuture      I      We    You  SheHe   They   Ipron  Article    Prep  \
# 0       0.0000 0.0000  4.0000 0.0000 0.0000 0.0000 12.0000   8.0000  8.0000
# 1       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 20.0000   0.0000  0.0000
# 2       0.0000 0.0000  8.7000 0.0000 0.0000 0.0000  4.3500   4.3500  8.7000
# 3       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000  0.0000   0.0000 33.3300
# 4       0.0000 0.0000 11.1100 0.0000 0.0000 5.5600  5.5600   0.0000 11.1100
#
#    Auxverb  Adverb   Conj  Negate    Verb    Adj  compare  Interrog  Number  \
# 0   4.0000  8.0000 0.0000 12.0000 12.0000 8.0000   0.0000    0.0000  4.0000
# 1   0.0000  0.0000 0.0000 20.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 2   4.3500  0.0000 0.0000 17.3900  0.0000 0.0000   0.0000    0.0000  4.3500
# 3   0.0000  0.0000 0.0000 33.3300  0.0000 0.0000   0.0000    0.0000  0.0000
# 4  11.1100  0.0000 0.0000 16.6700  0.0000 0.0000   5.5600    0.0000  0.0000
#
#    Quant    See    Hear   Feel  Motion  Space   Time  \
# 0 0.0000 4.0000  0.0000 0.0000  8.0000 0.0000 0.0000
# 1 0.0000 0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 2 0.0000 0.0000 13.0400 4.3500  0.0000 8.7000 0.0000
# 3 0.0000 0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 4 0.0000 5.5600  0.0000 0.0000  0.0000 0.0000 0.0000
#
#    Political polarisation (user based)  Science polarisation (user based)  \
# 0                               0.0000                             0.0000
# 1                               0.0000                             0.0000
# 2                               0.0000                             0.0000
# 3                               0.0000                             0.0000
# 4                               0.0000                             0.0000
#
#    Moderacy polarisation (user based)  Posted_tweets (per user)  \
# 0                              0.0000                         2
# 1                              0.0000                        14
# 2                              0.0000                        11
# 3                              0.0000                         1
# 4                              0.0000                         1
#
#    Deleted_tweets (per user)  Deletion_ratio (user)  Reputation (user)  \
# 0                          2                 1.0000             0.5258
# 1                          7                 0.5000             0.6988
# 2                          0                 0.0000             0.4723
# 3                          1                 1.0000             0.1867
# 4                          1                 1.0000             0.0591
#
#    Is_deleted  User sentiment average  Tweet sentiment deviation  \
# 0           1                  0.0869                    -0.8443
# 1           1                  0.0992                    -0.0220
# 2           0                  0.4612                     0.2196
# 3           1                  0.0000                     0.0000
# 4           1                 -0.4333                     0.0000
#
#    Tweet political polarisation deviation  \
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000
#
#    Tweet science polarisation deviation  Tweet moderacy polarisation deviation
# 0                                0.0000                                 0.0000
# 1                                0.0000                                 0.0000
# 2                                0.0000                                 0.0000
# 3                                0.0000                                 0.0000
# 4                                0.0000                                 0.0000

# %%
print(len(features))
features
# Out:
# 95
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Sentiment negative',
#        'Sentiment neutral', 'Sentiment positive', 'Sentiment compound',
#        'Number of hashtags', 'Number od mentions', 'Text length',
#        'Number of URLs', 'Readability', 'Number of Emojis', 'Emoji_sent',
#        'Political polarisation (tweet based)',
#        'Science polarisation (tweet based)',
#        'Moderacy polarisation (tweet based)', 'Social', 'Family', 'Friend',
#        'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money', 'Relegion',
#        'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonflu', 'Filler',
#        'Body', 'Health', 'Sexual', 'Ingest', 'Posemo', 'Negemo', 'Anx',
#        'Anger', 'Sad', 'Insight', 'Cause', 'Discrep', 'Tentat', 'Certain',
#        'Differ', 'Affiliation', 'Achiev', 'Power', 'Reward', 'Risk',
#        'Focuspast', 'Focuspresent', 'Focusfuture', 'I', 'We', 'You', 'SheHe',
#        'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj',
#        'Negate', 'Verb', 'Adj', 'compare', 'Interrog', 'Number', 'Quant',
#        'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Political polarisation (user based)',
#        'Science polarisation (user based)',
#        'Moderacy polarisation (user based)', 'Posted_tweets (per user)',
#        'Deleted_tweets (per user)', 'Deletion_ratio (user)',
#        'Reputation (user)', 'Is_deleted', 'User sentiment average',
#        'Tweet sentiment deviation', 'Tweet political polarisation deviation',
#        'Tweet science polarisation deviation',
#        'Tweet moderacy polarisation deviation'],
#       dtype='object')

# %%
#df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Tweet_Id', 'Username', 'Posted_tweets (per user)', 'Deleted_tweets (per user)', 'Deletion_ratio (user)'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.58285

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.56      0.57     19976
#            1       0.58      0.61      0.59     20024
#
#     accuracy                           0.58     40000
#    macro avg       0.58      0.58      0.58     40000
# weighted avg       0.58      0.58      0.58     40000

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)

clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                                 Feature  importance
# 0      83                       Reputation (user)      0.1515
# 1       0                                Retweets      0.0745
# 2       1                               Favorites      0.0745
# 3      80     Political polarisation (user based)      0.0587
# 4      55                             Focusfuture      0.0545
# 5      82      Moderacy polarisation (user based)      0.0425
# 6       8                             Text length      0.0423
# 7       9                          Number of URLs      0.0382
# 8      84                  User sentiment average      0.0346
# 9      88   Tweet moderacy polarisation deviation      0.0314
# 10     27                                Informal      0.0293
# 11     86  Tweet political polarisation deviation      0.0276
# 12     35                                  Sexual      0.0250
# 13      6                      Number of hashtags      0.0232
# 14     62                                 Article      0.0204
# 15     21                                    Work      0.0160
# 16     85               Tweet sentiment deviation      0.0141
# 17     29                                Netspeak      0.0140
# 18      7                      Number od mentions      0.0115
# 19     10                             Readability      0.0106
# 20     77                                  Motion      0.0106
# 21      5                      Sentiment compound      0.0103
# 22     61                                   Ipron      0.0095
# 23     28                                   Swear      0.0088
# 24      4                      Sentiment positive      0.0069
# 25      2                      Sentiment negative      0.0068
# 26     12                              Emoji_sent      0.0067
# 27     11                        Number of Emojis      0.0063
# 28      3                       Sentiment neutral      0.0062
# 29     67                                  Negate      0.0061
# 30     16                                  Social      0.0058
# 31     63                                    Prep      0.0054
# 32     78                                   Space      0.0051
# 33     53                               Focuspast      0.0043
# 34     13    Political polarisation (tweet based)      0.0042
# 35     33                                    Body      0.0042
# 36     57                                      We      0.0039
# 37     38                                  Negemo      0.0039
# 38     37                                  Posemo      0.0039
# 39     65                                  Adverb      0.0035
# 40     40                                   Anger      0.0033
# 41     48                             Affiliation      0.0031
# 42     60                                    They      0.0030
# 43     68                                    Verb      0.0030
# 44     49                                  Achiev      0.0029
# 45     64                                 Auxverb      0.0027
# 46     22                                 Leisure      0.0027
# 47     50                                   Power      0.0026
# 48     15     Moderacy polarisation (tweet based)      0.0025
# 49     47                                  Differ      0.0025
# 50     42                                 Insight      0.0024
# 51     44                                 Discrep      0.0024
# 52     56                                       I      0.0024
# 53     51                                  Reward      0.0024
# 54     72                                  Number      0.0024
# 55     69                                     Adj      0.0023
# 56     45                                  Tentat      0.0023
# 57     76                                    Feel      0.0022
# 58     70                                 compare      0.0022
# 59     46                                 Certain      0.0020
# 60     43                                   Cause      0.0020
# 61     73                                   Quant      0.0020
# 62     24                                   Money      0.0018
# 63     66                                    Conj      0.0017
# 64     30                                  Assent      0.0017
# 65     54                            Focuspresent      0.0017
# 66     19                                  Female      0.0016
# 67     74                                     See      0.0015
# 68     20                                    Male      0.0015
# 69     58                                     You      0.0013
# 70     52                                    Risk      0.0012
# 71     17                                  Family      0.0012
# 72     18                                  Friend      0.0012
# 73     34                                  Health      0.0011
# 74     75                                    Hear      0.0011
# 75     41                                     Sad      0.0011
# 76     71                                Interrog      0.0010
# 77     59                                   SheHe      0.0010
# 78     25                                Relegion      0.0008
# 79     39                                     Anx      0.0007
# 80     23                                    Home      0.0007
# 81     81       Science polarisation (user based)      0.0007
# 82     36                                  Ingest      0.0007
# 83     31                                  Nonflu      0.0007
# 84     26                                   Death      0.0006
# 85     14      Science polarisation (tweet based)      0.0004
# 86     87    Tweet science polarisation deviation      0.0004
# 87     32                                  Filler      0.0002
# 88     79                                    Time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'Favorites' 'Retweets' 'focusfuture'
#  'user_moderacy_polarisation' 'user_political_polarisation' 'Text_len'
#  'URLs_num' 'user_vadercompound_average' 'informal'
#  'tweet_moderacy_polarisation_abweichung'
#  'tweet_political_polarisation_abweichung' 'sexual' 'Hashtags_num'
#  'article' 'work' 'netspeak' 'Mentions_num' 'motion'
#  'tweet_vadercompound_abweichung' 'swear' 'readability' 'vader_com'
#  'ipron']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 24)
# (200000,)

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.61 +/- 0.012
#  f1        : 0.54 +/- 0.009
#  recall    : 0.48 +/- 0.014
# Wall time: 55.8 s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.61 +/- 0.012
#  f1        : 0.53 +/- 0.016
#  recall    : 0.47 +/- 0.020
# Wall time: 57.2 s

# %% [markdown]
# ***

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]
max_features = ['sqrt', 'log2', 'auto']
max_depth =  [2,4,6,8,10]
min_samples_split = [2,4,8]
min_samples_leaf = [1,2,4]
bootstrap = [True, False]

# %%
param_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf,
              'bootstrap' : bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 1000], 'max_features': ['sqrt', 'log2', 'auto'], 'max_depth': [2, 4, 6, 8, 10], 'min_samples_split': [2, 4, 8], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_model = RandomForestClassifier()

# %%
# %%time
clf_grid = GridSearchCV(rf_model, param_grid = param_grid, cv = 3, verbose = 10, n_jobs = -1)
clf_grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1620 candidates, totalling 4860 fits
# Wall time: 57min 54s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [100, 200, 300, 400, 500, 1000]},
#              verbose=10)

# %%
clf_grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 8,
#  'n_estimators': 300}

# %%
# %%time
#20000 Tweets
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)

print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.61 +/- 0.012
#  f1        : 0.54 +/- 0.012
#  recall    : 0.48 +/- 0.018
# Wall time: 54.3 s

# %%
# %%time
#200 000 Tweets
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)

print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.57 +/- 0.003
#  f1        : 0.64 +/- 0.003
#  recall    : 0.72 +/- 0.003
# Wall time: 8min 46s

# %% [markdown]
# *****************************************************
# *****************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content + User)

# %%
def plot_hist_Features_kb(l_features_importances, l_features, title):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue','Black', 'peru', 'mediumslateblue', 'lightgreen']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, width = 0.5)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
   #plt.legend()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Reputation (user)',
#  'Retweets',
#  'Favorites',
#  'Political polarisation (user based)',
#  'Focusfuture',
#  'Moderacy polarisation (user based)',
#  'Text length',
#  'Number of URLs',
#  'User sentiment average',
#  'Tweet moderacy polarisation deviation']

# %%
plot_hist_Features_kb(l_features_importances, l_features, 'Rf_tweetskb_content_user')

# %% [markdown]
# ***********************************************************************
# ***********************************************************************

# %% [markdown]
# ## Tweetskb
# ### Content only

# %%
features = df_tweetskb_user.columns
features

#features = features[2:83]
df_tweetskb_user = df_tweetskb_user[features.tolist()]
df_tweetskb_user = df_tweetskb_user.drop(columns=[  'User sentiment average', 'Tweet sentiment deviation', 'Tweet political polarisation deviation', 'Tweet science polarisation deviation', 'Tweet moderacy polarisation deviation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[  'Political polarisation (user based)', 'Science polarisation (user based)', 'Moderacy polarisation (user based)',  'Reputation (user)'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)
clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                               Feature  importance
# 0       1                             Favorites      0.1341
# 1       0                              Retweets      0.1049
# 2      55                           Focusfuture      0.0712
# 3       9                        Number of URLs      0.0644
# 4       8                           Text length      0.0590
# 5      27                              Informal      0.0414
# 6      62                               Article      0.0342
# 7      35                                Sexual      0.0325
# 8       6                    Number of hashtags      0.0319
# 9      21                                  Work      0.0289
# 10     29                              Netspeak      0.0194
# 11     10                           Readability      0.0180
# 12     61                                 Ipron      0.0162
# 13      5                    Sentiment compound      0.0161
# 14     28                                 Swear      0.0150
# 15     77                                Motion      0.0145
# 16      7                    Number od mentions      0.0136
# 17     13  Political polarisation (tweet based)      0.0130
# 18     12                            Emoji_sent      0.0110
# 19     16                                Social      0.0107
# 20     11                      Number of Emojis      0.0107
# 21     67                                Negate      0.0104
# 22      2                    Sentiment negative      0.0104
# 23      4                    Sentiment positive      0.0102
# 24      3                     Sentiment neutral      0.0098
# 25     78                                 Space      0.0089
# 26     63                                  Prep      0.0087
# 27     53                             Focuspast      0.0086
# 28     57                                    We      0.0073
# 29     38                                Negemo      0.0068
# 30     33                                  Body      0.0062
# 31     65                                Adverb      0.0060
# 32     15   Moderacy polarisation (tweet based)      0.0059
# 33     37                                Posemo      0.0058
# 34     49                                Achiev      0.0058
# 35     60                                  They      0.0054
# 36     48                           Affiliation      0.0052
# 37     40                                 Anger      0.0051
# 38     64                               Auxverb      0.0051
# 39     68                                  Verb      0.0050
# 40     50                                 Power      0.0049
# 41     22                               Leisure      0.0043
# 42     69                                   Adj      0.0042
# 43     47                                Differ      0.0040
# 44     56                                     I      0.0040
# 45     46                               Certain      0.0039
# 46     72                                Number      0.0039
# 47     51                                Reward      0.0037
# 48     76                                  Feel      0.0037
# 49     44                               Discrep      0.0037
# 50     70                               compare      0.0036
# 51     45                                Tentat      0.0035
# 52     42                               Insight      0.0034
# 53     43                                 Cause      0.0034
# 54     19                                Female      0.0032
# 55     66                                  Conj      0.0031
# 56     73                                 Quant      0.0029
# 57     24                                 Money      0.0029
# 58     54                          Focuspresent      0.0029
# 59     30                                Assent      0.0025
# 60     74                                   See      0.0025
# 61     20                                  Male      0.0024
# 62     58                                   You      0.0023
# 63     18                                Friend      0.0021
# 64     17                                Family      0.0021
# 65     75                                  Hear      0.0020
# 66     52                                  Risk      0.0020
# 67     41                                   Sad      0.0019
# 68     34                                Health      0.0019
# 69     71                              Interrog      0.0019
# 70     59                                 SheHe      0.0017
# 71     25                              Relegion      0.0015
# 72     36                                Ingest      0.0013
# 73     23                                  Home      0.0012
# 74     39                                   Anx      0.0012
# 75     26                                 Death      0.0011
# 76     31                                Nonflu      0.0010
# 77     14    Science polarisation (tweet based)      0.0006
# 78     32                                Filler      0.0005
# 79     79                                  Time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['Favorites' 'Retweets' 'Focusfuture' 'Text length' 'Number of URLs'
#  'Informal' 'Sexual' 'Article' 'Number of hashtags' 'Work' 'Netspeak'
#  'Readability' 'Motion' 'Ipron' 'Sentiment compound' 'Swear'
#  'Number od mentions' 'Emoji_sent' 'Sentiment negative'
#  'Political polarisation (tweet based)' 'Sentiment positive' 'Social'
#  'Number of Emojis' 'Negate' 'Sentiment neutral' 'Prep' 'Space'
#  'Focuspast']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 27)
# (200000,)

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.59 +/- 0.015
#  f1        : 0.54 +/- 0.013
#  recall    : 0.49 +/- 0.018
# Wall time: 49 s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.011
#  f1        : 0.53 +/- 0.013
#  recall    : 0.49 +/- 0.020
# Wall time: 50 s

# %% [markdown]
# ***************************************************
# ***************************************************

# %%
# %%time
#200 000 Tweets
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 8, min_samples_leaf= 2, max_features= 'auto', max_depth = 10, bootstrap= False, n_jobs=-1)

print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.57 +/- 0.003
#  f1        : 0.62 +/- 0.002
#  recall    : 0.68 +/- 0.004
# Wall time: 9min 45s

# %% [markdown]
# ***

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content Only )

# %%
def plot_hist_Features_content_only_kb(l_features_importances, l_features, title):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['black', 'peru', 'mediumslateblue', 'lightblue', 'lightgreen']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, width = 0.5)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
 
    #plt.legend()
    plt.savefig('../plots/'+title+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:10]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:10]
l_features
# Out:
# ['Favorites',
#  'Retweets',
#  'Focusfuture',
#  'Number of URLs',
#  'Text length',
#  'Informal',
#  'Article',
#  'Sexual',
#  'Number of hashtags',
#  'Work']

# %%
plot_hist_Features_content_only_kb(l_features_importances, l_features, 'Rf_tweetskb_content_only')
