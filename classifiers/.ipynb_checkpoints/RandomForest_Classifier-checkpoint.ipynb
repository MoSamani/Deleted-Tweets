# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
from termcolor import colored
csv.field_size_limit(100000000)

from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import shap

from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.float_format = '{:.4f}'.format

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # RandomForestClassifier
# ## TweetsCov19
# ### (Tweet content + user features)

# %%
path = '../data/df_tweetscov19_sample_20000.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (20000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1251202109036429320  2ca4c3e3e83d7367f9c597f4c2c54cb8         0          0
# 1  1192983638587125760  c63e520dcea34ef2fae6c8ef915a2171         0          0
# 2  1228024984901181446  985490c568350f131ddd952cc1b0b50d         0          0
# 3  1239590954375544833  00261dbeeec78ae2c87bb3fef7fc26ee         0          0
# 4  1189026874824937472  e1be434c92e5dc76f98a2c06a3693528         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     0.9210     0.0790     0.2023             0             3
# 1    -0.0000     0.5710     0.4290     0.8402             0             2
# 2    -0.0530     0.8600     0.0870     0.3063             0             3
# 3    -0.0000     1.0000     0.0000     0.0000             1             0
# 4    -0.0000     1.0000     0.0000     0.0000             0             1
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0       144         0      57.6050          0      0.0000
# 1        95         0      96.5770          0      0.0000
# 2       250         0      37.9000          0      0.0000
# 3        74         0      59.7450          0      0.0000
# 4        80         0      85.0740          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female    male   work  \
# 0                       0.0000  8.7000  0.0000  0.0000  0.0000  0.0000 8.7000
# 1                       0.0000  6.6700  0.0000  0.0000  0.0000  0.0000 0.0000
# 2                       0.0000  2.7800  0.0000  0.0000  0.0000  0.0000 0.0000
# 3                       0.0000 18.1800  0.0000  0.0000  0.0000  0.0000 9.0900
# 4                       0.0000 16.6700  0.0000  5.5600  0.0000 11.1100 0.0000
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 2.7800    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  4.3500  0.0000 0.0000
# 1  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000 13.3300  0.0000 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  2.7800 0.0000
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4  0.0000  0.0000 0.0000  5.5600  0.0000  0.0000  0.0000  0.0000 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 4.3500   4.3500  0.0000   4.3500  0.0000
# 1 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   6.6700  0.0000
# 2 2.7800 0.0000   0.0000 0.0000   0.0000  0.0000   5.5600  0.0000
# 3 0.0000 0.0000   0.0000 0.0000   9.0900  0.0000   0.0000  0.0000
# 4 0.0000 0.0000   5.5600 0.0000   0.0000  5.5600   0.0000  0.0000
#
#    affiliation  achiev   power  reward   risk  focuspast  focuspresent  \
# 0       4.3500  0.0000 13.0400  4.3500 0.0000     0.0000       13.0400
# 1       0.0000  0.0000  0.0000  0.0000 0.0000     0.0000       13.3300
# 2       0.0000  0.0000  5.5600  5.5600 2.7800     5.5600        2.7800
# 3      18.1800  9.0900  0.0000  0.0000 0.0000     0.0000       18.1800
# 4       0.0000  0.0000  0.0000  0.0000 0.0000     0.0000       16.6700
#
#    focusfuture      i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000 0.0000 4.3500 0.0000 0.0000 0.0000 4.3500   8.7000  8.7000
# 1       0.0000 0.0000 0.0000 6.6700 0.0000 0.0000 0.0000   6.6700 13.3300
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 2.7800   5.5600  8.3300
# 3       0.0000 0.0000 9.0900 0.0000 0.0000 0.0000 0.0000   9.0900  9.0900
# 4       5.5600 0.0000 0.0000 0.0000 5.5600 0.0000 5.5600  11.1100  5.5600
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   8.7000  4.3500 4.3500  0.0000 17.3900 0.0000   0.0000    4.3500  0.0000
# 1   0.0000  0.0000 0.0000  0.0000  6.6700 0.0000   0.0000    0.0000  0.0000
# 2   2.7800  5.5600 2.7800  0.0000 11.1100 5.5600   5.5600    0.0000  0.0000
# 3   9.0900  0.0000 0.0000  0.0000 27.2700 0.0000   0.0000    0.0000  0.0000
# 4  11.1100  0.0000 5.5600  0.0000 22.2200 5.5600   0.0000    5.5600  0.0000
#
#    quant     see   hear   feel  motion  space    time  \
# 0 0.0000  0.0000 4.3500 0.0000  0.0000 0.0000  0.0000
# 1 6.6700 13.3300 0.0000 0.0000  0.0000 6.6700  0.0000
# 2 5.5600  0.0000 0.0000 0.0000  2.7800 2.7800 11.1100
# 3 0.0000  0.0000 0.0000 0.0000  9.0900 9.0900  0.0000
# 4 0.0000  5.5600 0.0000 0.0000  0.0000 5.5600  0.0000
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       1
# 2                      0.0000                       1
# 3                      0.0000                       2
# 4                      0.0000                       3
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.3447        True
# 1                        1               1.0000           0.3484        True
# 2                        1               1.0000           0.1215        True
# 3                        2               1.0000           0.5126        True
# 4                        3               1.0000           0.4708        True
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.2023                          0.0000
# 1                      0.8402                          0.0000
# 2                      0.3063                          0.0000
# 3                      0.0000                          0.0000
# 4                      0.1099                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (20000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1231564552854265856  37477d36aa1c259333aa8409ae277695        90         96
# 1  1250128371390054402  2b2fbb9cb21e7bcbf46fa4bcd2b4bb0b         0          0
# 2  1259918906237517826  f5e3487c2d5b652a560978e9b5033bdc         6          8
# 3  1187374698247708673  988f34a270c6bc0ac7825a70296c4fc3         3          4
# 4  1241219929774440448  fa1b7f1e1ef0159eb1bf96c9f304269f         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     0.6120     0.3880     0.9382             2             0
# 1    -0.0000     0.8930     0.1070     0.4118             0             1
# 2    -0.0700     0.9300     0.0000    -0.4023             3             0
# 3    -0.0740     0.9260     0.0000    -0.5093             1             0
# 4    -0.4300     0.5700     0.0000    -0.8516             0             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0       168         0      55.1250          3      1.0460
# 1       128         0      69.6750          0      0.0000
# 2       280         1      33.8300          0      0.0000
# 3       280         1      66.0730          0      0.0000
# 4        79         0      78.8730          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                     -1.0000
# 3                     -1.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  9.0900  0.0000  0.0000  0.0000 0.0000 0.0000
# 1                       0.0000  8.3300  0.0000  0.0000  0.0000 8.3300 0.0000
# 2                       0.0000  5.0000  0.0000  0.0000  0.0000 0.0000 5.0000
# 3                      -1.0000 10.8700  0.0000  0.0000  0.0000 4.3500 4.3500
# 4                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   4.1700 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 2.1700    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    6.6700 6.6700    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  9.0900  0.0000 0.0000
# 1  0.0000  0.0000 4.1700  4.1700  0.0000  0.0000  4.1700  0.0000 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  2.5000  0.0000 0.0000
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  2.1700 0.0000
# 4  0.0000  0.0000 6.6700  0.0000  0.0000  0.0000  0.0000 13.3300 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   3.0300  9.0900   0.0000  3.0300
# 1 0.0000 0.0000   8.3300 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 0.0000   0.0000 0.0000   0.0000  2.5000   0.0000  5.0000
# 3 2.1700 0.0000   2.1700 2.1700   0.0000  0.0000   0.0000  4.3500
# 4 6.6700 0.0000   6.6700 0.0000   0.0000  6.6700   0.0000  0.0000
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       6.0600  3.0300 3.0300  3.0300 0.0000     3.0300        3.0300
# 1       0.0000  0.0000 4.1700  0.0000 0.0000     4.1700       16.6700
# 2       0.0000  0.0000 2.5000  0.0000 2.5000     2.5000        5.0000
# 3       0.0000  0.0000 4.3500  0.0000 0.0000     2.1700        6.5200
# 4       0.0000  0.0000 0.0000  0.0000 6.6700     0.0000        6.6700
#
#    focusfuture      i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000 0.0000 3.0300 3.0300 0.0000 0.0000 0.0000   3.0300 12.1200
# 1       0.0000 0.0000 0.0000 0.0000 8.3300 0.0000 8.3300   4.1700 25.0000
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 2.5000 0.0000   7.5000  7.5000
# 3       0.0000 0.0000 0.0000 0.0000 4.3500 2.1700 2.1700   6.5200 10.8700
# 4       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  6.6700
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   6.0600  0.0000 6.0600  0.0000 12.1200 3.0300   0.0000    0.0000  0.0000
# 1   8.3300 12.5000 8.3300  0.0000 16.6700 0.0000   0.0000    4.1700  0.0000
# 2   5.0000  2.5000 5.0000  2.5000 12.5000 0.0000   0.0000    0.0000  0.0000
# 3   4.3500  0.0000 2.1700  2.1700  8.7000 2.1700   2.1700    2.1700  0.0000
# 4   0.0000 13.3300 6.6700  0.0000  6.6700 0.0000   0.0000    0.0000  0.0000
#
#    quant    see   hear   feel  motion   space    time  \
# 0 3.0300 0.0000 0.0000 0.0000  0.0000  6.0600  3.0300
# 1 0.0000 0.0000 0.0000 0.0000  4.1700 12.5000  0.0000
# 2 5.0000 0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000  4.3500  6.5200
# 4 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 13.3300
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                      -0.3333                    -0.5556
# 3                      -1.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                      11
# 1                      0.0000                       1
# 2                      0.3333                      24
# 3                     -1.0000                       4
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        0               0.0000           0.8285       False
# 1                        0               0.0000           0.2355       False
# 2                       23               0.9583           0.2018        True
# 3                        0               0.0000           0.9779       False
# 4                        1               1.0000           0.6302        True
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.5538                          0.3844
# 1                      0.4118                          0.0000
# 2                     -0.2280                         -0.1743
# 3                     -0.2884                         -0.2209
# 4                     -0.8516                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.3333
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                -0.4444
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                 -0.3333
# 3                                  0.0000
# 4                                  0.0000

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_abweichung',
#        'tweet_political_polarisation_abweichung',
#        'tweet_science_polarisation_abweichung',
#        'tweet_moderacy_polarisation_abweichung'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)
df_tweetscov19_user.head()
# Out:
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1231564552854265856  37477d36aa1c259333aa8409ae277695        90         96
# 1  1250128371390054402  2b2fbb9cb21e7bcbf46fa4bcd2b4bb0b         0          0
# 2  1259918906237517826  f5e3487c2d5b652a560978e9b5033bdc         6          8
# 3  1187374698247708673  988f34a270c6bc0ac7825a70296c4fc3         3          4
# 4  1241219929774440448  fa1b7f1e1ef0159eb1bf96c9f304269f         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     0.6120     0.3880     0.9382             2             0
# 1    -0.0000     0.8930     0.1070     0.4118             0             1
# 2    -0.0700     0.9300     0.0000    -0.4023             3             0
# 3    -0.0740     0.9260     0.0000    -0.5093             1             0
# 4    -0.4300     0.5700     0.0000    -0.8516             0             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0       168         0      55.1250          3      1.0460
# 1       128         0      69.6750          0      0.0000
# 2       280         1      33.8300          0      0.0000
# 3       280         1      66.0730          0      0.0000
# 4        79         0      78.8730          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                     -1.0000
# 3                     -1.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  9.0900  0.0000  0.0000  0.0000 0.0000 0.0000
# 1                       0.0000  8.3300  0.0000  0.0000  0.0000 8.3300 0.0000
# 2                       0.0000  5.0000  0.0000  0.0000  0.0000 0.0000 5.0000
# 3                      -1.0000 10.8700  0.0000  0.0000  0.0000 4.3500 4.3500
# 4                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   4.1700 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 2.1700    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    6.6700 6.6700    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  9.0900  0.0000 0.0000
# 1  0.0000  0.0000 4.1700  4.1700  0.0000  0.0000  4.1700  0.0000 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  2.5000  0.0000 0.0000
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  2.1700 0.0000
# 4  0.0000  0.0000 6.6700  0.0000  0.0000  0.0000  0.0000 13.3300 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   3.0300  9.0900   0.0000  3.0300
# 1 0.0000 0.0000   8.3300 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 0.0000 0.0000   0.0000 0.0000   0.0000  2.5000   0.0000  5.0000
# 3 2.1700 0.0000   2.1700 2.1700   0.0000  0.0000   0.0000  4.3500
# 4 6.6700 0.0000   6.6700 0.0000   0.0000  6.6700   0.0000  0.0000
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       6.0600  3.0300 3.0300  3.0300 0.0000     3.0300        3.0300
# 1       0.0000  0.0000 4.1700  0.0000 0.0000     4.1700       16.6700
# 2       0.0000  0.0000 2.5000  0.0000 2.5000     2.5000        5.0000
# 3       0.0000  0.0000 4.3500  0.0000 0.0000     2.1700        6.5200
# 4       0.0000  0.0000 0.0000  0.0000 6.6700     0.0000        6.6700
#
#    focusfuture      i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000 0.0000 3.0300 3.0300 0.0000 0.0000 0.0000   3.0300 12.1200
# 1       0.0000 0.0000 0.0000 0.0000 8.3300 0.0000 8.3300   4.1700 25.0000
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 2.5000 0.0000   7.5000  7.5000
# 3       0.0000 0.0000 0.0000 0.0000 4.3500 2.1700 2.1700   6.5200 10.8700
# 4       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  6.6700
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   6.0600  0.0000 6.0600  0.0000 12.1200 3.0300   0.0000    0.0000  0.0000
# 1   8.3300 12.5000 8.3300  0.0000 16.6700 0.0000   0.0000    4.1700  0.0000
# 2   5.0000  2.5000 5.0000  2.5000 12.5000 0.0000   0.0000    0.0000  0.0000
# 3   4.3500  0.0000 2.1700  2.1700  8.7000 2.1700   2.1700    2.1700  0.0000
# 4   0.0000 13.3300 6.6700  0.0000  6.6700 0.0000   0.0000    0.0000  0.0000
#
#    quant    see   hear   feel  motion   space    time  \
# 0 3.0300 0.0000 0.0000 0.0000  0.0000  6.0600  3.0300
# 1 0.0000 0.0000 0.0000 0.0000  4.1700 12.5000  0.0000
# 2 5.0000 0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000  4.3500  6.5200
# 4 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 13.3300
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                      -0.3333                    -0.5556
# 3                      -1.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                      11
# 1                      0.0000                       1
# 2                      0.3333                      24
# 3                     -1.0000                       4
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        0               0.0000           0.8285           0
# 1                        0               0.0000           0.2355           0
# 2                       23               0.9583           0.2018           1
# 3                        0               0.0000           0.9779           0
# 4                        1               1.0000           0.6302           1
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.5538                          0.3844
# 1                      0.4118                          0.0000
# 2                     -0.2280                         -0.1743
# 3                     -0.2884                         -0.2209
# 4                     -0.8516                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.3333
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                -0.4444
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                 -0.3333
# 3                                  0.0000
# 4                                  0.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (20000, 89)
# (20000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 89)
# (4000, 89)
# (16000,)
# (4000,)

# %%
def fit_random_forest_clf(X,y):

    clf = RandomForestClassifier( n_jobs=-1)
    clf.fit(X,y)
    return clf

# %%
def test_random_forest_clf(model, X_test, y_test):
    
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
rf_model = fit_random_forest_clf(X_train, y_train)

# %%
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.61025

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.58      0.60      2033
#            1       0.60      0.64      0.62      1967
#
#     accuracy                           0.61      4000
#    macro avg       0.61      0.61      0.61      4000
# weighted avg       0.61      0.61      0.61      4000

# %%
def plot_confusion_matrix(y_test, y_pred, classes, titel):
    
    confusion_mx = confusion_matrix(y_test, y_pred)
    confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
    
    sns.heatmap(confusion_mx, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %% [markdown]
# ***

# %%
def features_classifier_(df, model):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = model.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)

    df_column_feature = df_column_feature.reset_index()
    df_column_feature
    return df_column_feature

# %%
rf_model = RandomForestClassifier(n_estimators = 1000 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 2, min_samples_leaf=1, bootstrap = True, n_jobs=-1)

rf_model.fit(X_train, y_train)

f_importances = features_classifier_(X_train, rf_model)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.1093
# 1      84               user_vadercompound_average      0.0336
# 2       9                                 URLs_num      0.0304
# 3      80              user_political_polarisation      0.0300
# 4       8                                 Text_len      0.0294
# 5      81                user_science_polarisation      0.0294
# 6      82               user_moderacy_polarisation      0.0290
# 7      10                              readability      0.0259
# 8       0                                 Retweets      0.0236
# 9      68                                     verb      0.0212
# 10      1                                Favorites      0.0207
# 11     87    tweet_science_polarisation_abweichung      0.0195
# 12      5                                vader_com      0.0194
# 13     63                                     prep      0.0178
# 14     86  tweet_political_polarisation_abweichung      0.0163
# 15      6                             Hashtags_num      0.0155
# 16     85           tweet_vadercompound_abweichung      0.0154
# 17      3                                Vader_neu      0.0152
# 18     27                                 informal      0.0148
# 19     88   tweet_moderacy_polarisation_abweichung      0.0144
# 20      2                                Vader_neg      0.0139
# 21     61                                    ipron      0.0138
# 22     54                             focuspresent      0.0134
# 23     16                                   social      0.0128
# 24     64                                  auxverb      0.0127
# 25     66                                     conj      0.0124
# 26      4                                Vader_pos      0.0122
# 27     78                                    space      0.0121
# 28     62                                  article      0.0116
# 29     21                                     work      0.0115
# 30     79                                     time      0.0115
# 31     28                                    swear      0.0105
# 32     65                                   adverb      0.0105
# 33     56                                        i      0.0103
# 34     53                                focuspast      0.0102
# 35     69                                      adj      0.0099
# 36     38                                   negemo      0.0090
# 37     37                                   posemo      0.0084
# 38     50                                    power      0.0084
# 39     47                                   differ      0.0082
# 40     45                                   tentat      0.0080
# 41     43                                    cause      0.0076
# 42     70                                  compare      0.0076
# 43     49                                   achiev      0.0075
# 44     29                                 netspeak      0.0073
# 45     42                                  insight      0.0073
# 46     48                              affiliation      0.0069
# 47     77                                   motion      0.0069
# 48     46                                  certain      0.0068
# 49     73                                    quant      0.0068
# 50     58                                      you      0.0068
# 51     40                                    anger      0.0067
# 52     13               tweet_politic_polarisation      0.0066
# 53     22                                  leisure      0.0066
# 54     44                                  discrep      0.0064
# 55     34                                   health      0.0064
# 56     55                              focusfuture      0.0063
# 57     71                                 interrog      0.0062
# 58     12                               Emoji_sent      0.0061
# 59     51                                   reward      0.0061
# 60      7                             Mentions_num      0.0060
# 61     15              tweet_moderacy_polarisation      0.0060
# 62     67                                   negate      0.0056
# 63     74                                      see      0.0056
# 64     59                                    shehe      0.0055
# 65     20                                     male      0.0051
# 66     52                                     risk      0.0050
# 67     11                                Emoji_num      0.0049
# 68     33                                     body      0.0048
# 69     60                                     they      0.0047
# 70     24                                    money      0.0047
# 71     75                                     hear      0.0046
# 72     72                                   number      0.0045
# 73     35                                   sexual      0.0040
# 74     57                                       we      0.0038
# 75     41                                      sad      0.0035
# 76     26                                    death      0.0034
# 77     14               tweet_science_polarisation      0.0031
# 78     76                                     feel      0.0030
# 79     19                                   female      0.0030
# 80     36                                   ingest      0.0030
# 81     23                                     home      0.0029
# 82     39                                      anx      0.0029
# 83     18                                   friend      0.0023
# 84     25                                 relegion      0.0022
# 85     17                                   family      0.0022
# 86     31                                   nonflu      0.0015
# 87     30                                   assent      0.0014
# 88     32                                   filler      0.0004

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'user_vadercompound_average' 'URLs_num'
#  'user_political_polarisation' 'Text_len' 'user_science_polarisation'
#  'user_moderacy_polarisation' 'readability' 'Retweets' 'verb' 'Favorites'
#  'tweet_science_polarisation_abweichung' 'vader_com' 'prep'
#  'tweet_political_polarisation_abweichung' 'Hashtags_num'
#  'tweet_vadercompound_abweichung' 'Vader_neu' 'informal'
#  'tweet_moderacy_polarisation_abweichung' 'Vader_neg' 'ipron'
#  'focuspresent' 'social' 'auxverb' 'conj' 'Vader_pos' 'space' 'article'
#  'work' 'time' 'swear' 'adverb' 'i' 'focuspast' 'adj' 'negemo' 'posemo'
#  'power' 'differ' 'tentat']

# %%
len(f_importances)
# Out:
# 41

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (20000, 41)
# (20000,)

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
# %%time
rf_model = RandomForestClassifier(n_estimators = 1000 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 2, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.006
#  f1        : 0.66 +/- 0.006
#  recall    : 0.73 +/- 0.014
# Wall time: 2min 37s

# %%
# %%time
rf_model = RandomForestClassifier(n_estimators = 1000 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 2, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.005
#  f1        : 0.66 +/- 0.006
#  recall    : 0.73 +/- 0.015
# Wall time: 2min 46s

# %% [markdown]
# ******

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]
max_features = ['sqrt', 'log2', 'auto']
max_depth =  [2,4,6,8,10]
min_samples_split = [2,4,8]
min_samples_leaf = [1,2,4]
bootstrap = [True, False]

# %%
param_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf,
              'bootstrap' : bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 1000], 'max_features': ['sqrt', 'log2', 'auto'], 'max_depth': [2, 4, 6, 8, 10], 'min_samples_split': [2, 4, 8], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
rf_model = RandomForestClassifier()

# %%
clf_grid = GridSearchCV(rf_model, param_grid = param_grid, cv = 3, verbose = 2, n_jobs = -1)
clf_grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1620 candidates, totalling 4860 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [100, 200, 300, 400, 500, 1000]},
#              verbose=2)

# %%
clf_grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1000}

# %%
clf_grid.score(X_test,y_test)
# Out:
# 0.616

# %%
# %%time
#20000 Tweets

clf_cv = RandomForestClassifier(n_estimators = 1000 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 2, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.005
#  f1        : 0.66 +/- 0.006
#  recall    : 0.73 +/- 0.015
# Wall time: 2min 40s

# %%
# %%time
#200000 Tweets

clf_cv = RandomForestClassifier(n_estimators = 1000 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 2, min_samples_leaf=1, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.002
#  f1        : 0.67 +/- 0.003
#  recall    : 0.77 +/- 0.005
# Wall time: 8min 1s

# %% [markdown]
# ***

# %%
def plot_hist_Features(l_features_importances, l_features, titel):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue', 'peru', 'black', 'mediumslateblue', 'lightblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Reputation', 'Likes', 'Retweets', 'Political p.u.', 'Moderacy p.u.']

# %%
plot_hist_Features(l_features_importances, l_features, 'Rf_TweetsCov19_content_User(reputation)_o_moderacy_all_del')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ## TweetsCov19
# ### (Content only)

# %%
features = df_tweetscov19_user.columns
features

#features = features[2:83]
df_tweetscov19_user = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test= split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
# %%time
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.602725
# Wall time: 12.7 s

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Inhalt_all_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 5, min_samples_leaf=2, bootstrap = True, n_jobs=-1)
clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                      Feature  importance
# 0       1                    Favorites      0.1014
# 1       9                     URLs_num      0.0995
# 2       0                     Retweets      0.0984
# 3       8                     Text_len      0.0490
# 4      13   tweet_politic_polarisation      0.0442
# 5       6                 Hashtags_num      0.0364
# 6      21                         work      0.0359
# 7      15  tweet_moderacy_polarisation      0.0354
# 8      56                            i      0.0321
# 9      27                     informal      0.0308
# 10     63                         prep      0.0266
# 11     68                         verb      0.0265
# 12     10                  readability      0.0196
# 13     29                     netspeak      0.0181
# 14     61                        ipron      0.0139
# 15      5                    vader_com      0.0138
# 16     28                        swear      0.0130
# 17      2                    Vader_neg      0.0123
# 18     11                    Emoji_num      0.0118
# 19     78                        space      0.0111
# 20      7                 Mentions_num      0.0106
# 21      3                    Vader_neu      0.0104
# 22     54                 focuspresent      0.0103
# 23     16                       social      0.0096
# 24     65                       adverb      0.0096
# 25     12                   Emoji_sent      0.0089
# 26     35                       sexual      0.0088
# 27     64                      auxverb      0.0081
# 28     40                        anger      0.0079
# 29     66                         conj      0.0079
# 30     62                      article      0.0077
# 31     79                         time      0.0072
# 32     53                    focuspast      0.0066
# 33     69                          adj      0.0065
# 34      4                    Vader_pos      0.0062
# 35     38                       negemo      0.0060
# 36     50                        power      0.0058
# 37     58                          you      0.0054
# 38     14   tweet_science_polarisation      0.0050
# 39     49                       achiev      0.0048
# 40     37                       posemo      0.0047
# 41     67                       negate      0.0045
# 42     77                       motion      0.0045
# 43     47                       differ      0.0042
# 44     48                  affiliation      0.0042
# 45     70                      compare      0.0042
# 46     45                       tentat      0.0041
# 47     59                        shehe      0.0041
# 48     71                     interrog      0.0040
# 49     33                         body      0.0040
# 50     19                       female      0.0038
# 51     44                      discrep      0.0038
# 52     73                        quant      0.0037
# 53     46                      certain      0.0036
# 54     34                       health      0.0035
# 55     43                        cause      0.0034
# 56     42                      insight      0.0034
# 57     20                         male      0.0034
# 58     52                         risk      0.0034
# 59     60                         they      0.0034
# 60     55                  focusfuture      0.0033
# 61     22                      leisure      0.0032
# 62     51                       reward      0.0031
# 63     74                          see      0.0028
# 64     24                        money      0.0028
# 65     57                           we      0.0027
# 66     75                         hear      0.0026
# 67     23                         home      0.0022
# 68     72                       number      0.0021
# 69     36                       ingest      0.0019
# 70     41                          sad      0.0017
# 71     26                        death      0.0016
# 72     76                         feel      0.0016
# 73     39                          anx      0.0015
# 74     18                       friend      0.0015
# 75     17                       family      0.0013
# 76     25                     relegion      0.0012
# 77     30                       assent      0.0011
# 78     31                       nonflu      0.0009
# 79     32                       filler      0.0002

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['Favorites' 'URLs_num' 'Retweets' 'Text_len' 'tweet_politic_polarisation'
#  'Hashtags_num' 'work' 'tweet_moderacy_polarisation' 'i' 'informal' 'prep'
#  'verb' 'readability' 'netspeak' 'ipron' 'vader_com' 'swear' 'Vader_neg'
#  'Emoji_num' 'space' 'Mentions_num' 'Vader_neu' 'focuspresent' 'social'
#  'adverb' 'Emoji_sent' 'sexual' 'auxverb']

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 28)
# (200000,)

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 5, min_samples_leaf=2, bootstrap = True, n_jobs=-1)
print_cross_val_score(rf_model, X_new, y)
# Out:
#  percision : 0.59 +/- 0.003
#  f1        : 0.62 +/- 0.004
#  recall    : 0.64 +/- 0.005
# Wall time: 5min 50s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 5, min_samples_leaf=2, bootstrap = True, n_jobs=-1)
print_cross_val_score(rf_model, X, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.62 +/- 0.004
#  recall    : 0.65 +/- 0.006
# Wall time: 8min 47s

# %% [markdown]
# ********************************************************
# ********************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### TweetCov19 (Content Only)

# %%
def plot_hist_Features_content_only(l_features_importances, l_features, titel):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['peru', 'black', 'mediumslateblue', 'lightblue', 'lightgreen']
    
    x = np.arange(len(l_features))

    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=18)
    ax.set_ylabel('Feature Importance', fontsize=20)
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
    fig.tight_layout()
    

    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Retweets', 'Text l.', 'Readability', 'Sentiment']

# %%
plot_hist_Features_content_only(l_features_importances, l_features, 'Rf_TweetsCov19_content_only_o_moderacy_all_del')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# # Tweetskb
# ### (Content + User Features)

# %%
path = '../data/df_tweetskb_sample_200000.tsv'

df_tweetskb_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])

print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id         Username  Retweets  Favorites  Vader_neg  \
# 0  1258692963997110274         enchufIa         0          0    -0.0000
# 1  1242346821785174016         yoonybin         0          0    -0.0000
# 2  1258318338654167043  ishehnaaz_GillF       664        349    -0.0000
# 3  1192978601236484096  Tiffany19Curtis         0          0    -0.0000
# 4  1263943368612220938     leftareloons         0          0    -0.0000
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     0.7580     0.2420     0.4939             0             1        58
# 1     1.0000     0.0000     0.0000             0             0        31
# 2     0.8420     0.1580     0.7579             1             2       189
# 3     1.0000     0.0000     0.0000             0             0        44
# 4     1.0000     0.0000     0.0000             0             1        35
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0      87.9970          0      0.0000                      0.0000
# 1         0      87.9450          0      0.0000                      0.0000
# 2         0      75.5070          8      0.6760                      0.0000
# 3         0     113.1000          0      0.0000                      0.0000
# 4         0      87.9450          1      0.0000                      0.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000 18.1800  0.0000
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000  7.4100  0.0000
# 3                      0.0000                       0.0000  0.0000  0.0000
# 4                      0.0000                       0.0000  0.0000  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  9.0900  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  3.7000  0.0000 3.7000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    9.0900 0.0000    9.0900  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    3.7000 0.0000    3.7000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000  18.1800 0.0000   0.0000
# 1  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 2  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 3.7000   0.0000
# 3  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000      18.1800  0.0000 0.0000  0.0000 0.0000
# 1  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 2  0.0000   0.0000  0.0000       0.0000  0.0000 3.7000  0.0000 0.0000
# 3 10.0000   0.0000 10.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000 20.0000 0.0000
#
#    focuspast  focuspresent  focusfuture      i     we    you  shehe    they  \
# 0     0.0000        0.0000       9.0900 9.0900 9.0900 0.0000 0.0000  0.0000
# 1    42.8600        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000  0.0000
# 2     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000  0.0000
# 3    20.0000        0.0000      10.0000 0.0000 0.0000 0.0000 0.0000 10.0000
# 4     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000  0.0000
#
#    ipron  article    prep  auxverb  adverb   conj  negate    verb    adj  \
# 0 9.0900   9.0900  0.0000   0.0000  0.0000 0.0000 18.1800  0.0000 0.0000
# 1 0.0000   0.0000 14.2900  14.2900  0.0000 0.0000 14.2900  0.0000 0.0000
# 2 3.7000   3.7000  0.0000   3.7000  7.4100 0.0000  0.0000  3.7000 0.0000
# 3 0.0000  10.0000 10.0000   0.0000 10.0000 0.0000 30.0000 10.0000 0.0000
# 4 0.0000   0.0000  0.0000  20.0000 20.0000 0.0000 20.0000  0.0000 0.0000
#
#    compare  interrog  number  quant    see   hear    feel  motion   space  \
# 0   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000  0.0000  0.0000  9.0900
# 1   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 28.5700
# 2   3.7000    0.0000  0.0000 0.0000 0.0000 0.0000  3.7000  3.7000  3.7000
# 3   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 10.0000 20.0000  0.0000
# 4   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000  0.0000 20.0000  0.0000
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       1
# 2                      0.0000                      21
# 3                      0.0000                       1
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.4419        True
# 1                        1               1.0000           0.0000        True
# 2                       21               1.0000           0.9899        True
# 3                        1               1.0000           0.3628        True
# 4                        1               1.0000           0.4486        True
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.4939                          0.0000
# 1                      0.0000                          0.0000
# 2                      0.5562                          0.2017
# 3                      0.0000                          0.0000
# 4                      0.0000                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
features = df_tweetskb_user.columns
#features

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 0, 1)
df_tweetskb_user.tail()
# Out:
#                    Tweet_Id      Username  Retweets  Favorites  Vader_neg  \
# 199995  1242956543575961600  peripointsss         0          0    -0.0000
# 199996  1201762746200711168  itsmeshe4jex         3          1    -0.0000
# 199997  1207319448379674624  thefilmcrowd        11         15    -0.1390
# 199998  1234353149453983744    SSTHAKUR20         0          0    -0.0000
# 199999  1179861539446296576    benoobrown        82       1217    -0.0000
#
#         Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 199995     0.9090     0.0910     0.3612             0             0       131
# 199996     1.0000     0.0000     0.0000             1             0        34
# 199997     0.7010     0.1600     0.2577             0             0       299
# 199998     0.4000     0.6000     0.4588             0             1        27
# 199999     1.0000     0.0000     0.0000             0             0        71
#
#         URLs_num  readability  Emoji_num  Emoji_sent  \
# 199995         0      69.8140          0      0.0000
# 199996         0      33.5750          0      0.0000
# 199997         2      65.2490          0      0.0000
# 199998         0    -133.5950          1      0.5870
# 199999         1      66.1000          0      0.0000
#
#         tweet_politic_polarisation  tweet_science_polarisation  \
# 199995                      0.0000                      0.0000
# 199996                      0.0000                      0.0000
# 199997                      0.0000                      0.0000
# 199998                      0.0000                      0.0000
# 199999                      0.0000                      0.0000
#
#         tweet_moderacy_polarisation  social  family  friend  female   male  \
# 199995                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 199996                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 199997                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 199998                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 199999                       0.0000 16.6700  0.0000  0.0000  8.3300 0.0000
#
#          work  leisure   home  money  relegion  death  informal  swear  \
# 199995 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199996 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199997 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199998 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199999 0.0000   0.0000 0.0000 0.0000    8.3300 0.0000    0.0000 0.0000
#
#         netspeak  assent  nonflu  filler   body  health  sexual  ingest  \
# 199995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199996    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199997    0.0000  0.0000  0.0000  0.0000 2.0000  0.0000  2.0000  0.0000
# 199998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#         posemo  negemo    anx  anger    sad  insight  cause  discrep  tentat  \
# 199995  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 199996  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 199997  0.0000  2.0000 2.0000 0.0000 0.0000   0.0000 0.0000   0.0000  4.0000
# 199998  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 199999  0.0000  0.0000 0.0000 0.0000 0.0000   8.3300 0.0000   0.0000  0.0000
#
#         certain  differ  affiliation  achiev   power  reward   risk  \
# 199995   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000
# 199996   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000
# 199997   0.0000  0.0000       0.0000  0.0000  2.0000  0.0000 0.0000
# 199998   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000
# 199999   0.0000  0.0000       0.0000  0.0000 16.6700  0.0000 0.0000
#
#         focuspast  focuspresent  focusfuture      i     we    you  shehe  \
# 199995     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199996     0.0000        0.0000      20.0000 0.0000 0.0000 0.0000 0.0000
# 199997     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199998     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000
# 199999     0.0000        0.0000       0.0000 0.0000 8.3300 0.0000 0.0000
#
#          they  ipron  article   prep  auxverb  adverb   conj  negate   verb  \
# 199995 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000 0.0000  0.0000 0.0000
# 199996 0.0000 0.0000   0.0000 0.0000  20.0000  0.0000 0.0000  0.0000 0.0000
# 199997 0.0000 0.0000  16.0000 0.0000   0.0000  2.0000 0.0000  0.0000 2.0000
# 199998 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000 0.0000  0.0000 0.0000
# 199999 0.0000 0.0000  16.6700 8.3300   8.3300  0.0000 0.0000  8.3300 0.0000
#
#           adj  compare  interrog  number  quant    see   hear   feel  motion  \
# 199995 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000
# 199996 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 20.0000
# 199997 2.0000   0.0000    0.0000  2.0000 0.0000 0.0000 0.0000 0.0000  8.0000
# 199998 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000
# 199999 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  8.3300
#
#          space   time  user_political_polarisation  user_science_polarisation  \
# 199995  0.0000 0.0000                       0.0000                     0.0000
# 199996 20.0000 0.0000                       0.0000                     0.0000
# 199997  0.0000 0.0000                       0.0000                     0.0000
# 199998  0.0000 0.0000                       0.0000                     0.0000
# 199999  8.3300 0.0000                       0.0000                     0.0000
#
#         user_moderacy_polarisation  user_num_posted_tweets  \
# 199995                      0.0000                       3
# 199996                      0.0000                       1
# 199997                      0.0000                       5
# 199998                      0.0000                       1
# 199999                      0.0000                      21
#
#         user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  \
# 199995                        0               0.0000           0.4921
# 199996                        0               0.0000           0.3636
# 199997                        0               0.0000           0.4939
# 199998                        0               0.0000           0.5382
# 199999                        0               0.0000           0.6040
#
#         Is_deleted  user_vadercompound_average  \
# 199995           1                      0.4095
# 199996           1                      0.0000
# 199997           1                     -0.0183
# 199998           1                      0.4588
# 199999           1                     -0.0026
#
#         tweet_vadercompound_abweichung  \
# 199995                         -0.0483
# 199996                          0.0000
# 199997                          0.2760
# 199998                          0.0000
# 199999                          0.0000
#
#         tweet_political_polarisation_abweichung  \
# 199995                                   0.0000
# 199996                                   0.0000
# 199997                                   0.0000
# 199998                                   0.0000
# 199999                                   0.0000
#
#         tweet_science_polarisation_abweichung  \
# 199995                                 0.0000
# 199996                                 0.0000
# 199997                                 0.0000
# 199998                                 0.0000
# 199999                                 0.0000
#
#         tweet_moderacy_polarisation_abweichung
# 199995                                  0.0000
# 199996                                  0.0000
# 199997                                  0.0000
# 199998                                  0.0000
# 199999                                  0.0000

# %%
df_tweetskb_user = df_tweetskb_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id       Username  Retweets  Favorites  Vader_neg  \
# 0  1238510820398477313      jhxmgxmez         0          0    -0.0000
# 1  1197712766670389253     issalucyyy         0          0    -0.2070
# 2  1228072892237152257   imbatangsexy         0          0    -0.0000
# 3  1249831272093908992  cheron_dearle         0          0    -0.0000
# 4  1193956691940925441      SteveyAsp         0          0    -0.1910
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     0.6580     0.3420     0.3818             0             0        33
# 1     0.7270     0.0660    -0.7184             0             0       230
# 2     0.2840     0.7160     0.8779             0             1        38
# 3     0.4710     0.5290     0.6696             0             0        19
# 4     0.5350     0.2740     0.4588             0             1        61
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0      87.9450          0      0.0000                      0.0000
# 1         0      70.8460          0      0.0000                      0.0000
# 2         0      49.4800          2      0.7460                      0.0000
# 3         0     117.1600          0      0.0000                      0.0000
# 4         0      89.5170          1      0.2210                      0.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000 16.6700  0.0000
# 1                      0.0000                       0.0000  7.5000  5.0000
# 2                      0.0000                       0.0000  0.0000  0.0000
# 3                      0.0000                       0.0000 20.0000  0.0000
# 4                      0.0000                       0.0000  7.6900  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 1  0.0000  2.5000 2.5000 0.0000   2.5000 0.0000 5.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    5.0000 5.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4    7.6900 7.6900    0.0000  0.0000  0.0000  0.0000 7.6900  0.0000  0.0000
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 1  0.0000  0.0000  5.0000 0.0000 5.0000 0.0000   2.5000 0.0000   0.0000
# 2  0.0000 25.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 3  0.0000 20.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  0.0000  0.0000  7.6900 0.0000 7.6900 0.0000   0.0000 7.6900   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 1  2.5000   2.5000  5.0000       0.0000  0.0000 0.0000  2.5000 0.0000
# 2 25.0000   0.0000  0.0000       0.0000  0.0000 0.0000 25.0000 0.0000
# 3  0.0000   0.0000  0.0000      20.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  7.6900       0.0000  0.0000 0.0000  0.0000 0.0000
#
#    focuspast  focuspresent  focusfuture      i     we    you   shehe   they  \
# 0     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000 16.6700 0.0000
# 1     7.5000        0.0000       2.5000 0.0000 0.0000 0.0000  0.0000 5.0000
# 2     0.0000        0.0000       0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 3     0.0000        0.0000      20.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 4     7.6900        0.0000       0.0000 0.0000 0.0000 0.0000  0.0000 7.6900
#
#     ipron  article   prep  auxverb  adverb   conj  negate   verb    adj  \
# 0 16.6700  16.6700 0.0000  16.6700  0.0000 0.0000  0.0000 0.0000 0.0000
# 1  5.0000   2.5000 7.5000   7.5000  7.5000 5.0000 12.5000 2.5000 2.5000
# 2  0.0000   0.0000 0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 3  0.0000   0.0000 0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 4  7.6900   0.0000 7.6900   0.0000  7.6900 0.0000 15.3800 0.0000 0.0000
#
#    compare  interrog  number   quant    see   hear   feel  motion  space  \
# 0   0.0000    0.0000  0.0000 33.3300 0.0000 0.0000 0.0000  0.0000 0.0000
# 1   0.0000    0.0000  2.5000  0.0000 0.0000 0.0000 0.0000  0.0000 2.5000
# 2   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 3   0.0000   20.0000  0.0000  0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 4   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       2
# 2                      0.0000                       1
# 3                      0.0000                       1
# 4                      0.0000                       5
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.3886           0
# 1                        0               0.0000           0.4468           1
# 2                        0               0.0000           0.1344           1
# 3                        1               1.0000           0.4845           0
# 4                        0               0.0000           0.3582           1
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.3818                          0.0000
# 1                     -0.7686                          0.0502
# 2                      0.8779                          0.0000
# 3                      0.6696                          0.0000
# 4                      0.4331                          0.0257
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
print(len(features))
features
# Out:
# 95
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_abweichung',
#        'tweet_political_polarisation_abweichung',
#        'tweet_science_polarisation_abweichung',
#        'tweet_moderacy_polarisation_abweichung'],
#       dtype='object')

# %%
#df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.57685

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.63      0.60     19915
#            1       0.59      0.53      0.56     20085
#
#     accuracy                           0.58     40000
#    macro avg       0.58      0.58      0.58     40000
# weighted avg       0.58      0.58      0.58     40000

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth = 10, bootstrap= False, n_jobs=-1)
#clf_cv = RandomForestClassifier(n_estimators = 1000, random_state=20, max_depth = 4, n_jobs=-1)

clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.1243
# 1       9                                 URLs_num      0.0558
# 2      55                              focusfuture      0.0493
# 3       8                                 Text_len      0.0483
# 4      80              user_political_polarisation      0.0455
# 5      27                                 informal      0.0376
# 6      82               user_moderacy_polarisation      0.0340
# 7      62                                  article      0.0331
# 8      84               user_vadercompound_average      0.0319
# 9       6                             Hashtags_num      0.0283
# 10     35                                   sexual      0.0274
# 11     21                                     work      0.0268
# 12      0                                 Retweets      0.0206
# 13     77                                   motion      0.0205
# 14      1                                Favorites      0.0187
# 15     28                                    swear      0.0181
# 16     86  tweet_political_polarisation_abweichung      0.0173
# 17     29                                 netspeak      0.0169
# 18     61                                    ipron      0.0158
# 19     88   tweet_moderacy_polarisation_abweichung      0.0151
# 20      5                                vader_com      0.0150
# 21     10                              readability      0.0144
# 22      7                             Mentions_num      0.0142
# 23      4                                Vader_pos      0.0101
# 24      3                                Vader_neu      0.0098
# 25     81                user_science_polarisation      0.0097
# 26     85           tweet_vadercompound_abweichung      0.0097
# 27      2                                Vader_neg      0.0097
# 28     11                                Emoji_num      0.0091
# 29     16                                   social      0.0087
# 30     67                                   negate      0.0085
# 31     12                               Emoji_sent      0.0084
# 32     78                                    space      0.0080
# 33     49                                   achiev      0.0077
# 34     33                                     body      0.0075
# 35     13               tweet_politic_polarisation      0.0063
# 36     53                                focuspast      0.0063
# 37     63                                     prep      0.0058
# 38     15              tweet_moderacy_polarisation      0.0056
# 39     64                                  auxverb      0.0054
# 40     68                                     verb      0.0054
# 41     60                                     they      0.0052
# 42     38                                   negemo      0.0051
# 43     37                                   posemo      0.0050
# 44     50                                    power      0.0048
# 45     22                                  leisure      0.0048
# 46     65                                   adverb      0.0048
# 47     48                              affiliation      0.0047
# 48     40                                    anger      0.0045
# 49     57                                       we      0.0042
# 50     87    tweet_science_polarisation_abweichung      0.0038
# 51     76                                     feel      0.0037
# 52     51                                   reward      0.0034
# 53     42                                  insight      0.0034
# 54     70                                  compare      0.0033
# 55     46                                  certain      0.0033
# 56     47                                   differ      0.0033
# 57     69                                      adj      0.0032
# 58     44                                  discrep      0.0031
# 59     56                                        i      0.0030
# 60     72                                   number      0.0030
# 61     43                                    cause      0.0030
# 62     20                                     male      0.0029
# 63     19                                   female      0.0028
# 64     58                                      you      0.0028
# 65     45                                   tentat      0.0027
# 66     24                                    money      0.0026
# 67     66                                     conj      0.0025
# 68     54                             focuspresent      0.0025
# 69     73                                    quant      0.0024
# 70     59                                    shehe      0.0020
# 71     71                                 interrog      0.0019
# 72     74                                      see      0.0019
# 73     14               tweet_science_polarisation      0.0019
# 74     18                                   friend      0.0017
# 75     34                                   health      0.0017
# 76     30                                   assent      0.0017
# 77     52                                     risk      0.0017
# 78     75                                     hear      0.0014
# 79     41                                      sad      0.0013
# 80     23                                     home      0.0013
# 81     17                                   family      0.0013
# 82     36                                   ingest      0.0013
# 83     25                                 relegion      0.0012
# 84     31                                   nonflu      0.0011
# 85     39                                      anx      0.0009
# 86     26                                    death      0.0009
# 87     32                                   filler      0.0003
# 88     79                                     time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'URLs_num' 'focusfuture' 'Text_len'
#  'user_political_polarisation' 'informal' 'user_moderacy_polarisation'
#  'article' 'user_vadercompound_average' 'Hashtags_num' 'sexual' 'work'
#  'Retweets' 'motion' 'Favorites' 'swear'
#  'tweet_political_polarisation_abweichung' 'netspeak' 'ipron'
#  'tweet_moderacy_polarisation_abweichung' 'vader_com' 'readability'
#  'Mentions_num' 'Vader_pos' 'Vader_neu' 'user_science_polarisation'
#  'tweet_vadercompound_abweichung' 'Vader_neg' 'Emoji_num' 'social'
#  'negate' 'Emoji_sent' 'space']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 33)
# (200000,)

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth = 10, bootstrap= False, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.60 +/- 0.005
#  f1        : 0.53 +/- 0.005
#  recall    : 0.48 +/- 0.007
# Wall time: 10min 32s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth = 10, bootstrap= False, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.53 +/- 0.004
#  recall    : 0.48 +/- 0.006
# Wall time: 12min 44s

# %% [markdown]
# ***

# %%
n_estimators = [100, 200, 300, 400, 500, 1000]
max_features = ['sqrt', 'log2', 'auto']
max_depth =  [2,4,6,8,10]
min_samples_split = [2,4,8]
min_samples_leaf = [1,2,4]
bootstrap = [True, False]

# %%
param_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf,
              'bootstrap' : bootstrap}
print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 1000], 'max_features': ['sqrt', 'log2'], 'max_depth': [2, 4, 6, 8, 10], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
rf_model = RandomForestClassifier()

# %%
# %%time
clf_grid = GridSearchCV(rf_model, param_grid = param_grid, cv = 3, verbose = 10, n_jobs = -1)
clf_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# Wall time: 32min 41s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200, 300, 400, 500, 1000]},
#              verbose=10)

# %%
clf_grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth = 10, bootstrap= False, n_jobs=-1)

print_cross_val_score(clf_cv, X_new, y)

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth = 10, bootstrap= False, n_jobs=-1)

print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.014
#  f1        : 0.52 +/- 0.019
#  recall    : 0.47 +/- 0.022
# Wall time: 57.2 s

# %% [markdown]
# *****************************************************
# *****************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content + User)

# %%
def plot_hist_Features_kb(l_features_importances, l_features, titel):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue','Black', 'peru', 'mediumslateblue', 'lightgreen']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
   #plt.legend()
    plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Reputation', 'Text l.', 'Readability', 'Sentiment', 'Verb']

# %%
plot_hist_Features_kb(l_features_importances, l_features, 'Rf_Tweetskb_content_User(reputation)_2_o_moderacy_all_del')

# %% [markdown]
# ***********************************************************************
# ***********************************************************************

# %% [markdown]
# ## Tweetskb
# ### Content only

# %%
features = df_tweetskb_user.columns
features

#features = features[2:83]
df_tweetskb_user = df_tweetskb_user[features.tolist()]
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
clf_cv = RandomForestClassifier(n_estimators = 300, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth = 10, bootstrap= False, n_jobs=-1)
clf_cv.fit(X_train, y_train)

f_importances = features_classifier_(X, clf_cv)
f_importances
# Out:
#     index                      Feature  importance
# 0       9                     URLs_num      0.0792
# 1      55                  focusfuture      0.0649
# 2       8                     Text_len      0.0641
# 3      27                     informal      0.0486
# 4      62                      article      0.0483
# 5       1                    Favorites      0.0350
# 6      21                         work      0.0344
# 7       6                 Hashtags_num      0.0342
# 8      35                       sexual      0.0335
# 9      77                       motion      0.0335
# 10      0                     Retweets      0.0334
# 11     29                     netspeak      0.0228
# 12     28                        swear      0.0223
# 13      5                    vader_com      0.0212
# 14     10                  readability      0.0203
# 15     61                        ipron      0.0176
# 16      7                 Mentions_num      0.0158
# 17     13   tweet_politic_polarisation      0.0155
# 18      3                    Vader_neu      0.0145
# 19     11                    Emoji_num      0.0138
# 20      4                    Vader_pos      0.0136
# 21     12                   Emoji_sent      0.0135
# 22     16                       social      0.0131
# 23     78                        space      0.0129
# 24     15  tweet_moderacy_polarisation      0.0127
# 25      2                    Vader_neg      0.0126
# 26     67                       negate      0.0117
# 27     49                       achiev      0.0109
# 28     53                    focuspast      0.0098
# 29     33                         body      0.0088
# 30     64                      auxverb      0.0087
# 31     22                      leisure      0.0081
# 32     63                         prep      0.0079
# 33     37                       posemo      0.0073
# 34     38                       negemo      0.0073
# 35     65                       adverb      0.0072
# 36     68                         verb      0.0071
# 37     48                  affiliation      0.0069
# 38     40                        anger      0.0069
# 39     60                         they      0.0069
# 40     50                        power      0.0064
# 41     57                           we      0.0064
# 42     42                      insight      0.0050
# 43     44                      discrep      0.0049
# 44     70                      compare      0.0048
# 45     56                            i      0.0048
# 46     46                      certain      0.0047
# 47     51                       reward      0.0045
# 48     76                         feel      0.0045
# 49     43                        cause      0.0045
# 50     47                       differ      0.0044
# 51     19                       female      0.0043
# 52     69                          adj      0.0041
# 53     72                       number      0.0041
# 54     14   tweet_science_polarisation      0.0040
# 55     45                       tentat      0.0040
# 56     66                         conj      0.0037
# 57     24                        money      0.0037
# 58     20                         male      0.0036
# 59     73                        quant      0.0036
# 60     58                          you      0.0035
# 61     54                 focuspresent      0.0035
# 62     18                       friend      0.0031
# 63     74                          see      0.0029
# 64     71                     interrog      0.0029
# 65     30                       assent      0.0028
# 66     75                         hear      0.0025
# 67     34                       health      0.0025
# 68     59                        shehe      0.0025
# 69     52                         risk      0.0024
# 70     23                         home      0.0024
# 71     17                       family      0.0021
# 72     41                          sad      0.0021
# 73     25                     relegion      0.0017
# 74     36                       ingest      0.0016
# 75     39                          anx      0.0014
# 76     26                        death      0.0013
# 77     31                       nonflu      0.0012
# 78     32                       filler      0.0006
# 79     79                         time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] > 0.008]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['URLs_num' 'focusfuture' 'Text_len' 'informal' 'article' 'Favorites'
#  'work' 'Hashtags_num' 'sexual' 'motion' 'Retweets' 'netspeak' 'swear'
#  'vader_com' 'readability' 'ipron' 'Mentions_num'
#  'tweet_politic_polarisation' 'Vader_neu' 'Emoji_num' 'Vader_pos'
#  'Emoji_sent' 'social' 'space' 'tweet_moderacy_polarisation' 'Vader_neg'
#  'negate' 'achiev' 'focuspast' 'body' 'auxverb' 'leisure']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7b83cdf6b17> in <module>
# ----> 1 X_new,y = get_X_y(df_tweetskb_user, f_importances)
#
# NameError: name 'get_X_y' is not defined

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 5, min_samples_leaf=2, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X_new, y)
# Out:
#  percision : 0.58 +/- 0.002
#  f1        : 0.54 +/- 0.004
#  recall    : 0.51 +/- 0.007
# Wall time: 4min 46s

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=20, max_features = 'sqrt',max_depth = 10, min_samples_split = 5, min_samples_leaf=2, bootstrap = True, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.58 +/- 0.002
#  f1        : 0.54 +/- 0.003
#  recall    : 0.50 +/- 0.005
# Wall time: 6min 3s

# %% [markdown]
# ***************************************************
# ***************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content Only )

# %%
def plot_hist_Features_content_only_kb(l_features_importances, l_features, titel):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['black', 'peru', 'mediumslateblue', 'lightblue', 'lightgreen']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
 
    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Readability', 'Text l.', 'Retweets', 'Sentiment']

# %%
plot_hist_Features_content_only_kb(l_features_importances, l_features, 'Rf_Tweetskb_content_only_ohne_moderacy_alle_del')
