# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
from termcolor import colored
csv.field_size_limit(100000000)

from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import shap

from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingClassifier

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.float_format = '{:.4f}'.format

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # RandomForestClassifier
# ## TweetsCov19
# ### (Tweet content + user features)

# %%
path = '../data/df_tweetscov19_sample_20000.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference' ])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (20000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1236495952258707456  d98b72ff8b36385f50e1bd44bf3d09b9         0          0
# 1  1265887546409713664  c751771e7a305d4679d628f7c1a330e3         7          8
# 2  1265363442501853184  09f7798af45e96fba119819297777bfa         0          0
# 3  1251336179951128577  d979f1b0ca230cfb22300313318e3dc7         0          0
# 4  1209276556448800772  1210c19b21e622ce71e65c6a6cced1be        26        512
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     1.0000     0.0000     0.0000             0             0
# 1    -0.1020     0.8980     0.0000    -0.3818             3             0
# 2    -0.0000     0.7860     0.2140     0.4588             0             1
# 3    -0.0570     0.9430     0.0000    -0.4215             0             0
# 4    -0.2360     0.7070     0.0570    -0.8779             0             2
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0       278         1      79.7930          0      0.0000
# 1       205         0      14.7960          0      0.0000
# 2        73         0      53.6550          0      0.0000
# 3       272         0      43.2380          0      0.0000
# 4       258         0      83.5760          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  2.0400  0.0000  0.0000  0.0000 0.0000 4.0800
# 1                       0.0000  3.7000  0.0000  0.0000  0.0000 0.0000 7.4100
# 2                       0.0000  8.3300  0.0000  0.0000  0.0000 8.3300 0.0000
# 3                       0.0000  4.2600  0.0000  0.0000  0.0000 0.0000 0.0000
# 4                       0.0000  4.5500  0.0000  0.0000  0.0000 2.2700 2.2700
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    2.0400 0.0000    0.0000  0.0000
# 1   0.0000 3.7000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   8.3300 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 2.1300    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 2.2700    0.0000 0.0000    2.2700 0.0000    0.0000  2.2700
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  2.0400  0.0000 0.0000  0.0000  0.0000  0.0000  2.0400  0.0000 0.0000
# 1  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  8.3300  8.3300  0.0000 0.0000
# 3  0.0000  0.0000 0.0000  2.1300  0.0000  0.0000  0.0000  2.1300 0.0000
# 4  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  2.2700  4.5500 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   2.0400  0.0000   4.0800  4.0800
# 1 0.0000 0.0000   0.0000 3.7000   3.7000  3.7000   3.7000  0.0000
# 2 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 2.1300 0.0000   0.0000 2.1300   0.0000  0.0000   4.2600 10.6400
# 4 0.0000 0.0000   9.0900 2.2700   2.2700  2.2700   0.0000  4.5500
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 2.0400  0.0000 0.0000     2.0400        0.0000
# 1       3.7000  3.7000 3.7000  0.0000 0.0000     0.0000        3.7000
# 2       0.0000  0.0000 0.0000  8.3300 0.0000     0.0000        0.0000
# 3       0.0000  2.1300 0.0000  0.0000 0.0000     2.1300        6.3800
# 4       0.0000  0.0000 2.2700  2.2700 2.2700     9.0900        6.8200
#
#    focusfuture      i     we    you  shehe   they   ipron  article    prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  4.0800   4.0800  8.1600
# 1       0.0000 0.0000 3.7000 0.0000 0.0000 0.0000  0.0000   3.7000  7.4100
# 2       0.0000 0.0000 0.0000 0.0000 8.3300 0.0000  0.0000  16.6700  8.3300
# 3       0.0000 0.0000 0.0000 0.0000 0.0000 2.1300  8.5100   2.1300 10.6400
# 4       0.0000 0.0000 0.0000 0.0000 2.2700 0.0000 11.3600   2.2700  6.8200
#
#    auxverb  adverb   conj  negate    verb    adj  compare  interrog  number  \
# 0   4.0800  4.0800 2.0400  2.0400  4.0800 6.1200   0.0000    0.0000  0.0000
# 1   3.7000  7.4100 3.7000  0.0000  3.7000 0.0000   0.0000    3.7000  0.0000
# 2   0.0000  8.3300 0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 3   4.2600  6.3800 4.2600  2.1300  6.3800 4.2600   4.2600    2.1300  2.1300
# 4   9.0900  6.8200 9.0900  2.2700 22.7300 4.5500   2.2700    2.2700  2.2700
#
#    quant    see   hear   feel  motion   space   time  \
# 0 2.0400 0.0000 0.0000 0.0000  0.0000  6.1200 0.0000
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 11.1100 3.7000
# 2 0.0000 0.0000 8.3300 0.0000  0.0000  0.0000 0.0000
# 3 6.3800 0.0000 0.0000 0.0000  0.0000  4.2600 6.3800
# 4 0.0000 0.0000 0.0000 0.0000  0.0000  2.2700 2.2700
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                      -1.0000                     1.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       2
# 1                      0.0000                      10
# 2                      0.0000                       1
# 3                      0.0000                       3
# 4                     -1.0000                     106
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               0.5000           0.6171        True
# 1                        1               0.1000           0.8864        True
# 2                        1               1.0000           0.2731        True
# 3                        3               1.0000           0.8745        True
# 4                      104               0.9811           0.9888        True
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                     -0.2009                          0.0000
# 1                      0.1799                         -0.5617
# 2                      0.4588                          0.0000
# 3                     -0.1517                         -0.2698
# 4                     -0.0995                         -0.7784
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   1.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                -1.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  1.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (20000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1249964165952704512  12da27fd1234a94c50950d61ea13a86d         1          5
# 1  1262136062689804294  bf52051ba1f1641c7b38f4380c996e69       353        457
# 2  1243994412373467137  cb2008845a5a2b8d67cec7a71811bfad         1          4
# 3  1188914365749174272  8b260b7c2185c275592e67976b769dd7        57        103
# 4  1267086324152049665  0540adacef58316ad860a6507df15fd6         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     0.5440     0.4560     0.7065             1             0
# 1    -0.2710     0.6630     0.0660    -0.9087             0             0
# 2    -0.2820     0.6550     0.0630    -0.8271             0             0
# 3    -0.2100     0.7440     0.0460    -0.8055             0             0
# 4    -0.0380     0.8080     0.1530     0.7609             0             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0        75         0      47.3000          0      0.0000
# 1       282         1      53.5120          0      0.0000
# 2       193         0      55.7640          0      0.0000
# 3       200         0      90.9350          0      0.0000
# 4       235         0      41.3340          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      1.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 1                       1.0000  2.1300  0.0000  0.0000  0.0000 0.0000 2.1300
# 2                       0.0000 12.1200  0.0000  0.0000  0.0000 0.0000 0.0000
# 3                       0.0000 10.8100  0.0000  0.0000  0.0000 0.0000 2.7000
# 4                       0.0000  4.6500  0.0000  0.0000  0.0000 0.0000 0.0000
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 2.1300    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 2.7000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1  0.0000  0.0000 0.0000  2.1300  0.0000  0.0000  2.1300  4.2600 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000 12.1200 3.0300
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  5.4100 0.0000
# 4  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  4.6500  2.3300 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 9.0900 0.0000   0.0000 0.0000   0.0000  0.0000   3.0300  0.0000
# 3 0.0000 2.7000   5.4100 2.7000   2.7000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000   0.0000 4.6500   4.6500  0.0000   4.6500  4.6500
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  2.1300 0.0000  2.1300 2.1300     2.1300        4.2600
# 2       3.0300  0.0000 0.0000  0.0000 3.0300     0.0000        3.0300
# 3       2.7000  0.0000 5.4100  0.0000 0.0000     0.0000       10.8100
# 4       2.3300  0.0000 4.6500  2.3300 2.3300     0.0000       13.9500
#
#    focusfuture      i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  0.0000
# 1       0.0000 0.0000 0.0000 0.0000 0.0000 2.1300 0.0000   2.1300 10.6400
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   9.0900 18.1800
# 3       5.4100 0.0000 2.7000 0.0000 0.0000 0.0000 8.1100   5.4100 13.5100
# 4       4.6500 0.0000 2.3300 0.0000 0.0000 0.0000 6.9800   6.9800 16.2800
#
#    auxverb  adverb    conj  negate    verb    adj  compare  interrog  number  \
# 0   0.0000  0.0000  0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 1   4.2600  4.2600  4.2600  0.0000  4.2600 2.1300   0.0000    0.0000  0.0000
# 2   3.0300  3.0300  3.0300  0.0000  3.0300 0.0000   3.0300    0.0000  0.0000
# 3   8.1100  2.7000 10.8100  2.7000 16.2200 8.1100   2.7000    0.0000  0.0000
# 4   9.3000 11.6300  6.9800  0.0000 16.2800 2.3300   2.3300    0.0000  0.0000
#
#    quant    see   hear   feel  motion  space    time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 4.2600  8.5100
# 2 3.0300 0.0000 0.0000 0.0000  0.0000 6.0600  0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000 2.7000  2.7000
# 4 2.3300 2.3300 0.0000 0.0000  6.9800 4.6500 11.6300
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.2381                    -1.0000
# 2                      -1.0000                     0.0000
# 3                      -1.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       6
# 1                      0.3333                      85
# 2                     -1.0000                       9
# 3                     -1.0000                     106
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               0.1667           0.7214        True
# 1                       85               1.0000           0.5023        True
# 2                        9               1.0000           0.4551        True
# 3                       29               0.2736           0.5791       False
# 4                        0               0.0000           0.6755       False
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                      0.1895                          0.5170
# 1                     -0.0271                         -0.8816
# 2                     -0.0526                         -0.7745
# 3                     -0.1531                         -0.6524
# 4                      0.7609                          0.0000
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.7619
# 2                                   1.0000
# 3                                   1.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 1.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.6667
# 2                                  1.0000
# 3                                  1.0000
# 4                                  0.0000

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_difference',
#        'tweet_political_polarisation_difference',
#        'tweet_science_polarisation_difference',
#        'tweet_moderacy_polarisation_difference'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)
df_tweetscov19_user.head()
# Out:
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1249964165952704512  12da27fd1234a94c50950d61ea13a86d         1          5
# 1  1262136062689804294  bf52051ba1f1641c7b38f4380c996e69       353        457
# 2  1243994412373467137  cb2008845a5a2b8d67cec7a71811bfad         1          4
# 3  1188914365749174272  8b260b7c2185c275592e67976b769dd7        57        103
# 4  1267086324152049665  0540adacef58316ad860a6507df15fd6         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     0.5440     0.4560     0.7065             1             0
# 1    -0.2710     0.6630     0.0660    -0.9087             0             0
# 2    -0.2820     0.6550     0.0630    -0.8271             0             0
# 3    -0.2100     0.7440     0.0460    -0.8055             0             0
# 4    -0.0380     0.8080     0.1530     0.7609             0             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0        75         0      47.3000          0      0.0000
# 1       282         1      53.5120          0      0.0000
# 2       193         0      55.7640          0      0.0000
# 3       200         0      90.9350          0      0.0000
# 4       235         0      41.3340          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      1.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 1                       1.0000  2.1300  0.0000  0.0000  0.0000 0.0000 2.1300
# 2                       0.0000 12.1200  0.0000  0.0000  0.0000 0.0000 0.0000
# 3                       0.0000 10.8100  0.0000  0.0000  0.0000 0.0000 2.7000
# 4                       0.0000  4.6500  0.0000  0.0000  0.0000 0.0000 0.0000
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 2.1300    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 2.7000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1  0.0000  0.0000 0.0000  2.1300  0.0000  0.0000  2.1300  4.2600 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000 12.1200 3.0300
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  5.4100 0.0000
# 4  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  4.6500  2.3300 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 2 9.0900 0.0000   0.0000 0.0000   0.0000  0.0000   3.0300  0.0000
# 3 0.0000 2.7000   5.4100 2.7000   2.7000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000   0.0000 4.6500   4.6500  0.0000   4.6500  4.6500
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  2.1300 0.0000  2.1300 2.1300     2.1300        4.2600
# 2       3.0300  0.0000 0.0000  0.0000 3.0300     0.0000        3.0300
# 3       2.7000  0.0000 5.4100  0.0000 0.0000     0.0000       10.8100
# 4       2.3300  0.0000 4.6500  2.3300 2.3300     0.0000       13.9500
#
#    focusfuture      i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  0.0000
# 1       0.0000 0.0000 0.0000 0.0000 0.0000 2.1300 0.0000   2.1300 10.6400
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   9.0900 18.1800
# 3       5.4100 0.0000 2.7000 0.0000 0.0000 0.0000 8.1100   5.4100 13.5100
# 4       4.6500 0.0000 2.3300 0.0000 0.0000 0.0000 6.9800   6.9800 16.2800
#
#    auxverb  adverb    conj  negate    verb    adj  compare  interrog  number  \
# 0   0.0000  0.0000  0.0000  0.0000  0.0000 0.0000   0.0000    0.0000  0.0000
# 1   4.2600  4.2600  4.2600  0.0000  4.2600 2.1300   0.0000    0.0000  0.0000
# 2   3.0300  3.0300  3.0300  0.0000  3.0300 0.0000   3.0300    0.0000  0.0000
# 3   8.1100  2.7000 10.8100  2.7000 16.2200 8.1100   2.7000    0.0000  0.0000
# 4   9.3000 11.6300  6.9800  0.0000 16.2800 2.3300   2.3300    0.0000  0.0000
#
#    quant    see   hear   feel  motion  space    time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 4.2600  8.5100
# 2 3.0300 0.0000 0.0000 0.0000  0.0000 6.0600  0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000 2.7000  2.7000
# 4 2.3300 2.3300 0.0000 0.0000  6.9800 4.6500 11.6300
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.2381                    -1.0000
# 2                      -1.0000                     0.0000
# 3                      -1.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       6
# 1                      0.3333                      85
# 2                     -1.0000                       9
# 3                     -1.0000                     106
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               0.1667           0.7214           1
# 1                       85               1.0000           0.5023           1
# 2                        9               1.0000           0.4551           1
# 3                       29               0.2736           0.5791           0
# 4                        0               0.0000           0.6755           0
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                      0.1895                          0.5170
# 1                     -0.0271                         -0.8816
# 2                     -0.0526                         -0.7745
# 3                     -0.1531                         -0.6524
# 4                      0.7609                          0.0000
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.7619
# 2                                   1.0000
# 3                                   1.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 1.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.6667
# 2                                  1.0000
# 3                                  1.0000
# 4                                  0.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (20000, 89)
# (20000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 89)
# (4000, 89)
# (16000,)
# (4000,)

# %%
def fit_random_forest_clf(X,y):
    
    clf = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
    clf.fit(X,y)
    return clf

# %%
def test_random_forest_clf(model, X_test, y_test):
    
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
rf_model = fit_random_forest_clf(X_train, y_train)

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Benutzer_Inhalt_alle_ohne_moderacy_2.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.612

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.56      0.60      2031
#            1       0.60      0.66      0.63      1969
#
#     accuracy                           0.61      4000
#    macro avg       0.61      0.61      0.61      4000
# weighted avg       0.61      0.61      0.61      4000

# %%
def plot_confusion_matrix(y_test, y_pred, classes, titel):
    
    confusion_mx = confusion_matrix(y_test, y_pred)
    confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
    
    sns.heatmap(confusion_mx, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
clf_cv = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.010
#  f1        : 0.62 +/- 0.012
#  recall    : 0.65 +/- 0.016

# %% [markdown]
# ***

# %%
def features_classifier_(df, model):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = model.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)

    df_column_feature = df_column_feature.reset_index()
    df_column_feature
    return df_column_feature

# %%
f_importances = features_classifier_(X, rf_model)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.0620
# 1      10                              readability      0.0385
# 2       8                                 Text_len      0.0381
# 3      84               user_vadercompound_average      0.0372
# 4      63                                     prep      0.0261
# 5       5                                vader_com      0.0243
# 6       3                                Vader_neu      0.0241
# 7      68                                     verb      0.0238
# 8      54                             focuspresent      0.0212
# 9      78                                    space      0.0204
# 10     85           tweet_vadercompound_difference      0.0204
# 11     16                                   social      0.0194
# 12     62                                  article      0.0189
# 13      4                                Vader_pos      0.0187
# 14     64                                  auxverb      0.0187
# 15     79                                     time      0.0179
# 16      2                                Vader_neg      0.0176
# 17     61                                    ipron      0.0172
# 18     66                                     conj      0.0166
# 19      0                                 Retweets      0.0162
# 20     65                                   adverb      0.0160
# 21      1                                Favorites      0.0153
# 22     69                                      adj      0.0148
# 23     53                                focuspast      0.0136
# 24     50                                    power      0.0127
# 25     21                                     work      0.0124
# 26     37                                   posemo      0.0118
# 27      7                             Mentions_num      0.0117
# 28     47                                   differ      0.0111
# 29     77                                   motion      0.0109
# 30     80              user_political_polarisation      0.0107
# 31     45                                   tentat      0.0106
# 32     73                                    quant      0.0105
# 33     70                                  compare      0.0104
# 34      6                             Hashtags_num      0.0104
# 35     42                                  insight      0.0103
# 36     48                              affiliation      0.0102
# 37     38                                   negemo      0.0100
# 38     43                                    cause      0.0100
# 39     46                                  certain      0.0097
# 40     56                                        i      0.0092
# 41     71                                 interrog      0.0091
# 42     82               user_moderacy_polarisation      0.0088
# 43     58                                      you      0.0088
# 44     51                                   reward      0.0086
# 45      9                                 URLs_num      0.0086
# 46     49                                   achiev      0.0086
# 47     44                                  discrep      0.0085
# 48     81                user_science_polarisation      0.0084
# 49     12                               Emoji_sent      0.0083
# 50     74                                      see      0.0082
# 51     55                              focusfuture      0.0082
# 52     27                                 informal      0.0081
# 53     22                                  leisure      0.0075
# 54     67                                   negate      0.0074
# 55     34                                   health      0.0073
# 56     11                                Emoji_num      0.0068
# 57     24                                    money      0.0066
# 58     52                                     risk      0.0063
# 59     86  tweet_political_polarisation_difference      0.0062
# 60     60                                     they      0.0060
# 61     20                                     male      0.0060
# 62     33                                     body      0.0059
# 63     72                                   number      0.0058
# 64     75                                     hear      0.0058
# 65     87    tweet_science_polarisation_difference      0.0056
# 66     57                                       we      0.0056
# 67     88   tweet_moderacy_polarisation_difference      0.0056
# 68     40                                    anger      0.0055
# 69     59                                    shehe      0.0054
# 70     29                                 netspeak      0.0044
# 71     23                                     home      0.0042
# 72     76                                     feel      0.0040
# 73     36                                   ingest      0.0037
# 74     41                                      sad      0.0037
# 75     26                                    death      0.0037
# 76     19                                   female      0.0037
# 77     39                                      anx      0.0033
# 78     28                                    swear      0.0033
# 79     18                                   friend      0.0030
# 80     13               tweet_politic_polarisation      0.0030
# 81     17                                   family      0.0027
# 82     25                                 relegion      0.0025
# 83     35                                   sexual      0.0023
# 84     15              tweet_moderacy_polarisation      0.0017
# 85     30                                   assent      0.0015
# 86     14               tweet_science_polarisation      0.0013
# 87     31                                   nonflu      0.0012
# 88     32                                   filler      0.0003

# %%
f_importances = f_importances[f_importances['importance'] > 0.01]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'readability' 'Text_len' 'user_vadercompound_average'
#  'prep' 'verb' 'vader_com' 'Vader_neu' 'focuspresent'
#  'tweet_vadercompound_difference' 'social' 'space' 'Vader_pos' 'auxverb'
#  'article' 'time' 'conj' 'ipron' 'Vader_neg' 'Retweets' 'adverb'
#  'Favorites' 'adj' 'focuspast' 'Mentions_num' 'power' 'work'
#  'user_political_polarisation' 'posemo' 'differ' 'Hashtags_num' 'compare'
#  'affiliation' 'tentat' 'quant' 'motion' 'negemo' 'cause' 'insight']

# %%
len(f_importances)
# Out:
# 39

# %%
X,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (20000, 39)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 39)
# (4000, 39)
# (16000,)
# (4000,)

# %%
rf_model = fit_random_forest_clf(X_train, y_train)

# %%
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.58875

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.54      0.57      2013
#            1       0.58      0.64      0.61      1987
#
#     accuracy                           0.59      4000
#    macro avg       0.59      0.59      0.59      4000
# weighted avg       0.59      0.59      0.59      4000

# %%
clf_cv = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.59 +/- 0.008
#  f1        : 0.61 +/- 0.012
#  recall    : 0.63 +/- 0.019

# %% [markdown]
# ****

# %%
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (20000, 89)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 89)
# (4000, 89)
# (16000,)
# (4000,)

# %%
clf_cv = RandomForestClassifier(n_estimators=100,criterion = 'entropy' ,random_state=0, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.007
#  f1        : 0.62 +/- 0.009
#  recall    : 0.64 +/- 0.014

# %%
clf_cv = RandomForestClassifier(n_estimators=100, criterion = 'log_loss' ,random_state=0, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : nan +/- nan
#  f1        : nan +/- nan
#  recall    : nan +/- nan

# %% [markdown]
# ***

# %%
clf_cv = RandomForestClassifier(n_estimators = 100, criterion = 'entropy' ,random_state = 0, max_features = 'log2', n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.010
#  f1        : 0.61 +/- 0.007
#  recall    : 0.63 +/- 0.009

# %%
clf_cv = RandomForestClassifier(n_estimators = 100, criterion = 'gini' ,random_state = 0, max_features = 'log2', n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.015
#  f1        : 0.61 +/- 0.011
#  recall    : 0.63 +/- 0.013

# %%
clf_cv = RandomForestClassifier(n_estimators = 100, criterion = 'gini', oob_score = bool , random_state=5, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.60 +/- 0.011
#  f1        : 0.62 +/- 0.009
#  recall    : 0.64 +/- 0.012

# %% [markdown]
# ***

# %%
for i in range(5):
    r_s = 0    
    r_s = r_s + (i * 5)
    clf_cv = RandomForestClassifier(n_estimators = 100, criterion = 'entropy' ,random_state = r_s, n_jobs=-1)
    
    print('random_state = ', r_s)
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# random_state =  0
#  percision : 0.60 +/- 0.012
#  f1        : 0.61 +/- 0.013
#  recall    : 0.63 +/- 0.017
# ---------------------------
# random_state =  5
#  percision : 0.60 +/- 0.013
#  f1        : 0.62 +/- 0.014
#  recall    : 0.64 +/- 0.018
# ---------------------------
# random_state =  10
#  percision : 0.60 +/- 0.013
#  f1        : 0.62 +/- 0.010
#  recall    : 0.63 +/- 0.008
# ---------------------------
# random_state =  15
#  percision : 0.60 +/- 0.016
#  f1        : 0.62 +/- 0.014
#  recall    : 0.64 +/- 0.014
# ---------------------------
# random_state =  20
#  percision : 0.60 +/- 0.010
#  f1        : 0.62 +/- 0.008
#  recall    : 0.64 +/- 0.011
# ---------------------------

# %% [markdown]
# ***

# %%
for i in range(5):
    r_s = 0    
    r_s = r_s + (i * 5)
    clf_cv = RandomForestClassifier(n_estimators = 100, criterion = 'gini' ,random_state = r_s, n_jobs=-1)
    
    print('random_state = ', r_s)
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# random_state =  0
#  percision : 0.60 +/- 0.013
#  f1        : 0.62 +/- 0.011
#  recall    : 0.64 +/- 0.014
# ---------------------------
# random_state =  5
#  percision : 0.60 +/- 0.011
#  f1        : 0.62 +/- 0.009
#  recall    : 0.64 +/- 0.012
# ---------------------------
# random_state =  10
#  percision : 0.60 +/- 0.013
#  f1        : 0.62 +/- 0.013
#  recall    : 0.64 +/- 0.015
# ---------------------------
# random_state =  15
#  percision : 0.60 +/- 0.012
#  f1        : 0.62 +/- 0.011
#  recall    : 0.64 +/- 0.013
# ---------------------------
# random_state =  20
#  percision : 0.60 +/- 0.012
#  f1        : 0.62 +/- 0.012
#  recall    : 0.64 +/- 0.015
# ---------------------------

# %% [markdown]
# ***

# %%
for i in range(7):
    n_es = 80    
    n_es = n_es + (i * 20)
    clf_cv = RandomForestClassifier(n_estimators = n_es , random_state=5, n_jobs=-1)
    
    print('n_estimators = ', n_es)
    print_cross_val_score(clf_cv, X, y)
    print('---------------------------')
# Out:
# n_estimators =  80
#  percision : 0.60 +/- 0.006
#  f1        : 0.61 +/- 0.009
#  recall    : 0.63 +/- 0.016
# ---------------------------
# n_estimators =  100
#  percision : 0.60 +/- 0.008
#  f1        : 0.62 +/- 0.011
#  recall    : 0.65 +/- 0.019
# ---------------------------
# n_estimators =  120
#  percision : 0.60 +/- 0.005
#  f1        : 0.62 +/- 0.010
#  recall    : 0.65 +/- 0.017
# ---------------------------
# n_estimators =  140
#  percision : 0.60 +/- 0.006
#  f1        : 0.62 +/- 0.010
#  recall    : 0.65 +/- 0.017
# ---------------------------
# n_estimators =  160
#  percision : 0.60 +/- 0.007
#  f1        : 0.63 +/- 0.011
#  recall    : 0.66 +/- 0.019
# ---------------------------
# n_estimators =  180
#  percision : 0.60 +/- 0.008
#  f1        : 0.63 +/- 0.011
#  recall    : 0.66 +/- 0.018
# ---------------------------
# n_estimators =  200
#  percision : 0.60 +/- 0.007
#  f1        : 0.63 +/- 0.009
#  recall    : 0.66 +/- 0.016
# ---------------------------

# %% [markdown]
# ***

# %%
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=5, n_jobs=-1)
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.62 +/- 0.003
#  f1        : 0.66 +/- 0.003
#  recall    : 0.70 +/- 0.005

# %% [markdown]
# ***

# %%
def plot_hist_Features(l_features_importances, l_features, titel):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue', 'peru', 'black', 'mediumslateblue', 'lightblue']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Reputation', 'Likes', 'Retweets', 'Political p.u.', 'Moderacy p.u.']

# %%
plot_hist_Features(l_features_importances, l_features, 'Rf_TweetsCov19_content_User(reputation)_o_moderacy_all_del')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ## TweetsCov19
# ### (Content only)

# %%
features = df_tweetscov19_user.columns
features

#features = features[2:83]
df_tweetscov19_user = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])
# Out:
# (20000, 81)
# (20000,)

# %%
X_train, X_test, y_train, y_test= split_train_test_valid(X,y)
# Out:
# (16000, 81)
# (4000, 81)
# (16000,)
# (4000,)

# %%
# %%time
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.57825
# Wall time: 888 ms

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Inhalt_all_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
f_importances = features_classifier_(df, rf_model)
f_importances
# Out:
#     index                         Feature  importance
# 0      10                     readability      0.0455
# 1       8                        Text_len      0.0445
# 2      63                            prep      0.0314
# 3       5                       vader_com      0.0297
# 4      68                            verb      0.0296
# 5       3                       Vader_neu      0.0285
# 6      80  tweet_vadercompound_difference      0.0245
# 7      54                    focuspresent      0.0245
# 8      78                           space      0.0238
# 9       4                       Vader_pos      0.0227
# 10     16                          social      0.0220
# 11     64                         auxverb      0.0219
# 12     62                         article      0.0216
# 13      2                       Vader_neg      0.0207
# 14     79                            time      0.0205
# 15      0                        Retweets      0.0201
# 16     61                           ipron      0.0200
# 17     66                            conj      0.0197
# 18      1                       Favorites      0.0190
# 19     65                          adverb      0.0177
# 20     69                             adj      0.0170
# 21     53                       focuspast      0.0153
# 22     50                           power      0.0153
# 23     21                            work      0.0143
# 24     37                          posemo      0.0137
# 25      7                    Mentions_num      0.0136
# 26     47                          differ      0.0127
# 27      6                    Hashtags_num      0.0126
# 28     77                          motion      0.0124
# 29     73                           quant      0.0124
# 30     70                         compare      0.0123
# 31     38                          negemo      0.0120
# 32     45                          tentat      0.0118
# 33     43                           cause      0.0117
# 34     48                     affiliation      0.0116
# 35     42                         insight      0.0116
# 36     71                        interrog      0.0104
# 37     46                         certain      0.0103
# 38     49                          achiev      0.0102
# 39     56                               i      0.0101
# 40     58                             you      0.0100
# 41     55                     focusfuture      0.0097
# 42     51                          reward      0.0096
# 43     44                         discrep      0.0094
# 44     12                      Emoji_sent      0.0092
# 45     27                        informal      0.0087
# 46     74                             see      0.0087
# 47      9                        URLs_num      0.0087
# 48     67                          negate      0.0086
# 49     22                         leisure      0.0084
# 50     34                          health      0.0082
# 51     11                       Emoji_num      0.0078
# 52     52                            risk      0.0075
# 53     24                           money      0.0073
# 54     60                            they      0.0072
# 55     75                            hear      0.0066
# 56     40                           anger      0.0066
# 57     20                            male      0.0065
# 58     57                              we      0.0065
# 59     59                           shehe      0.0064
# 60     72                          number      0.0064
# 61     33                            body      0.0064
# 62     13      tweet_politic_polarisation      0.0056
# 63     23                            home      0.0052
# 64     29                        netspeak      0.0052
# 65     26                           death      0.0046
# 66     41                             sad      0.0044
# 67     39                             anx      0.0042
# 68     76                            feel      0.0040
# 69     14      tweet_science_polarisation      0.0040
# 70     36                          ingest      0.0038
# 71     19                          female      0.0037
# 72     28                           swear      0.0037
# 73     18                          friend      0.0036
# 74     17                          family      0.0031
# 75     15     tweet_moderacy_polarisation      0.0027
# 76     25                        relegion      0.0026
# 77     35                          sexual      0.0025
# 78     30                          assent      0.0016
# 79     31                          nonflu      0.0012
# 80     32                          filler      0.0004

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57      2014
#            1       0.57      0.59      0.58      1986
#
#     accuracy                           0.58      4000
#    macro avg       0.58      0.58      0.58      4000
# weighted avg       0.58      0.58      0.58      4000

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Inhalt_all_ohne_moderacy.sav'
#rf_model = pickle.load(open(pfad_modell, 'rb'))

# %%
# %%time
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=5, n_jobs=-1)
print_cross_val_score(rf_model, X_test, y_test)
# Out:
#  percision : 0.56 +/- 0.025
#  f1        : 0.56 +/- 0.020
#  recall    : 0.55 +/- 0.024
# Wall time: 10.9 s

# %% [markdown]
# ********************************************************
# ********************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### TweetCov19 (Content Only)

# %%
def plot_hist_Features_content_only(l_features_importances, l_features, titel):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['peru', 'black', 'mediumslateblue', 'lightblue', 'lightgreen']
    
    x = np.arange(len(l_features))

    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=18)
    ax.set_ylabel('Feature Importance', fontsize=20)
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
    fig.tight_layout()
    

    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Retweets', 'Text l.', 'Readability', 'Sentiment']

# %%
plot_hist_Features_content_only(l_features_importances, l_features, 'Rf_TweetsCov19_content_only_o_moderacy_all_del')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# # Tweetskb
# ### (Content + User Features)

# %%
path = '../data/df_tweetskb_sample_20000.tsv'

df_tweetskb_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference'])

print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (20000, 95)
#               Tweet_Id       Username  Retweets  Favorites  Vader_neg  \
# 0  1225591042872954881  MarylandTwang         0          0    -0.0000
# 1  1228234997900824578  yv04_official         0          0    -0.0000
# 2  1219729452713644032   TupacAlbania         0          0    -0.0000
# 3  1211057745979461632       BigZuri_         0          0    -0.6020
# 4  1247337657698525184  trinamoriarty         0          0    -0.0690
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     0.6490     0.3510     0.9448             0             0       182
# 1     0.9310     0.0690     0.4137             1             0       253
# 2     1.0000     0.0000     0.0000             0             0        80
# 3     0.3980     0.0000    -0.7930             0             0        27
# 4     0.5900     0.3410     0.8625             0             1       137
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0      95.8030          0      0.0000                      0.0000
# 1         0      55.8270          0      0.0000                      0.0000
# 2         0      65.1680          0      0.0000                      0.0000
# 3         0      83.3200          0      0.0000                      0.0000
# 4         0      56.7990          2      0.4840                      0.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000  6.0600  3.0300
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000  5.8800  0.0000
# 3                      0.0000                       0.0000 16.6700  0.0000
# 4                      0.0000                       0.0000 11.5400  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  0.0000  3.0300 3.0300 0.0000   3.0300 0.0000 3.0300    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    3.0300 0.0000    0.0000  3.0300  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4   15.3800 3.8500    3.8500  7.6900  3.8500  0.0000 0.0000  3.8500  3.8500
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  6.0600  0.0000 0.0000 0.0000 0.0000   0.0000 6.0600   0.0000
# 1  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   2.4400 2.4400   2.4400
# 2  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000  11.7600 0.0000   0.0000
# 3  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  3.8500  3.8500  3.8500 0.0000 3.8500 0.0000   0.0000 0.0000   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000       6.0600  0.0000 0.0000  3.0300 0.0000
# 1  4.8800   0.0000  4.8800       0.0000  0.0000 0.0000  0.0000 2.4400
# 2  0.0000   0.0000  0.0000       0.0000  0.0000 5.8800  0.0000 0.0000
# 3  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  3.8500 0.0000
#
#    focuspast  focuspresent  focusfuture      i     we    you  shehe    they  \
# 0    21.2100        0.0000       0.0000 0.0000 0.0000 3.0300 0.0000  6.0600
# 1     9.7600        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000  4.8800
# 2    17.6500        0.0000      23.5300 0.0000 0.0000 0.0000 0.0000  5.8800
# 3    16.6700        0.0000       0.0000 0.0000 0.0000 0.0000 0.0000 16.6700
# 4     3.8500        3.8500       7.6900 0.0000 3.8500 0.0000 0.0000  0.0000
#
#    ipron  article    prep  auxverb  adverb   conj  negate   verb    adj  \
# 0 3.0300   6.0600  6.0600   6.0600  9.0900 0.0000 21.2100 6.0600 0.0000
# 1 9.7600  12.2000  9.7600   4.8800  2.4400 4.8800 14.6300 2.4400 2.4400
# 2 5.8800   5.8800  5.8800   5.8800 11.7600 0.0000 17.6500 5.8800 0.0000
# 3 0.0000  16.6700  0.0000   0.0000  0.0000 0.0000 16.6700 0.0000 0.0000
# 4 0.0000  15.3800 11.5400   7.6900  7.6900 0.0000 19.2300 3.8500 7.6900
#
#    compare  interrog  number  quant     see   hear   feel  motion   space  \
# 0   0.0000    0.0000  3.0300 0.0000  0.0000 0.0000 3.0300  3.0300  6.0600
# 1   2.4400    2.4400  2.4400 0.0000  0.0000 0.0000 2.4400 12.2000  0.0000
# 2   5.8800    5.8800  0.0000 0.0000  5.8800 0.0000 0.0000 11.7600  5.8800
# 3   0.0000    0.0000  0.0000 0.0000 16.6700 0.0000 0.0000  0.0000  0.0000
# 4   3.8500    0.0000  0.0000 0.0000  3.8500 0.0000 0.0000  0.0000 11.5400
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       1
# 2                      0.0000                       1
# 3                      0.0000                       8
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.8684        True
# 1                        1               1.0000           0.0187        True
# 2                        1               1.0000           0.2329        True
# 3                        8               1.0000           0.6473        True
# 4                        1               1.0000           0.1885        True
#
#    user_vadercompound_average  tweet_vadercompound_difference  \
# 0                      0.9448                          0.0000
# 1                      0.4137                          0.0000
# 2                      0.0000                          0.0000
# 3                     -0.0037                         -0.7893
# 4                      0.8625                          0.0000
#
#    tweet_political_polarisation_difference  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_difference  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_difference
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
features = df_tweetskb_user.columns
#features

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 0, 1)
df_tweetskb_user.tail()
# Out:
#                   Tweet_Id         Username  Retweets  Favorites  Vader_neg  \
# 19995  1202377071797899266    derekhalfdead         0          0    -0.0000
# 19996  1182914318452441088   littledolanhoe         0          0    -0.0000
# 19997  1240556004686864384         Here4Kat         2          8    -0.0000
# 19998  1250120446533447681  ramonsalinasart         7         20    -0.0000
# 19999  1220777813881393152      Swordsfall1        79        250    -0.1560
#
#        Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 19995     0.5220     0.4780     0.6705             1             0        67
# 19996     1.0000     0.0000     0.0000             0             1        49
# 19997     0.7770     0.2230     0.9118             0             1       288
# 19998     0.8640     0.1360     0.7482             1             0       298
# 19999     0.6070     0.2360     0.6908             0             1       199
#
#        URLs_num  readability  Emoji_num  Emoji_sent  \
# 19995         0      18.4440          1      0.7670
# 19996         0      61.2400          0      0.0000
# 19997         1      55.9310          0      0.0000
# 19998         5      57.1190          6      0.3690
# 19999         0      90.0320          0      0.0000
#
#        tweet_politic_polarisation  tweet_science_polarisation  \
# 19995                      0.0000                      0.0000
# 19996                      0.0000                      0.0000
# 19997                      0.0000                      0.0000
# 19998                      0.0000                      0.0000
# 19999                      0.0000                      0.0000
#
#        tweet_moderacy_polarisation  social  family  friend  female   male  \
# 19995                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 19996                       0.0000 37.5000  0.0000  0.0000  0.0000 0.0000
# 19997                       0.0000 11.1100  0.0000  0.0000  3.7000 0.0000
# 19998                       0.0000  6.3800  0.0000  0.0000  0.0000 0.0000
# 19999                       0.0000  8.5700  0.0000  2.8600  0.0000 0.0000
#
#         work  leisure   home  money  relegion  death  informal  swear  \
# 19995 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19996 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000   12.5000 0.0000
# 19997 0.0000   3.7000 0.0000 1.8500    0.0000 0.0000    0.0000 0.0000
# 19998 2.1300   4.2600 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 19999 2.8600   2.8600 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#        netspeak  assent  nonflu  filler   body  health  sexual  ingest  \
# 19995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19996   12.5000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19997    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  1.8500
# 19998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 19999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#        posemo  negemo    anx  anger    sad  insight  cause  discrep  tentat  \
# 19995  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19996 12.5000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19997  5.5600  0.0000 0.0000 0.0000 0.0000   0.0000 1.8500   3.7000  0.0000
# 19998  2.1300  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 19999  5.7100  5.7100 0.0000 5.7100 0.0000   2.8600 2.8600   0.0000  0.0000
#
#        certain  differ  affiliation  achiev  power  reward   risk  focuspast  \
# 19995   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000
# 19996   0.0000  0.0000      12.5000  0.0000 0.0000  0.0000 0.0000    12.5000
# 19997   5.5600  0.0000       0.0000  1.8500 7.4100  3.7000 0.0000    11.1100
# 19998   0.0000  0.0000       2.1300  2.1300 0.0000  0.0000 0.0000     4.2600
# 19999   2.8600  0.0000       5.7100  0.0000 0.0000  8.5700 0.0000     8.5700
#
#        focuspresent  focusfuture      i      we    you  shehe   they  ipron  \
# 19995        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 19996        0.0000      12.5000 0.0000 12.5000 0.0000 0.0000 0.0000 0.0000
# 19997        0.0000       0.0000 0.0000  5.5600 3.7000 0.0000 0.0000 5.5600
# 19998        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000 0.0000 2.1300
# 19999        0.0000       0.0000 0.0000  0.0000 0.0000 2.8600 5.7100 5.7100
#
#        article    prep  auxverb  adverb   conj  negate   verb    adj  compare  \
# 19995   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000   0.0000
# 19996  12.5000 12.5000  12.5000  0.0000 0.0000 12.5000 0.0000 0.0000   0.0000
# 19997  11.1100  9.2600   9.2600  3.7000 0.0000 14.8100 7.4100 1.8500   1.8500
# 19998   4.2600  0.0000   0.0000  2.1300 0.0000  2.1300 0.0000 0.0000   0.0000
# 19999  17.1400  5.7100   2.8600  0.0000 0.0000 11.4300 5.7100 0.0000   0.0000
#
#        interrog  number  quant    see   hear   feel  motion   space   time  \
# 19995    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 19996    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 12.5000 12.5000 0.0000
# 19997    0.0000  1.8500 5.5600 0.0000 0.0000 1.8500  7.4100  1.8500 0.0000
# 19998    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 19999    0.0000  0.0000 0.0000 0.0000 0.0000 2.8600  5.7100  0.0000 0.0000
#
#        user_political_polarisation  user_science_polarisation  \
# 19995                       0.0000                     0.0000
# 19996                       0.0000                     0.0000
# 19997                       0.0000                     0.0000
# 19998                       0.0000                     0.0000
# 19999                       0.0000                     0.0000
#
#        user_moderacy_polarisation  user_num_posted_tweets  \
# 19995                      0.0000                       1
# 19996                      0.0000                       4
# 19997                      0.0000                       1
# 19998                      0.0000                       4
# 19999                      0.0000                      24
#
#        user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  \
# 19995                        0               0.0000           0.8610
# 19996                        0               0.0000           0.8656
# 19997                        0               0.0000           0.9865
# 19998                        0               0.0000           0.3747
# 19999                        0               0.0000           0.9064
#
#        Is_deleted  user_vadercompound_average  tweet_vadercompound_difference  \
# 19995           1                      0.6705                          0.0000
# 19996           1                     -0.1415                          0.0000
# 19997           1                      0.9118                          0.0000
# 19998           1                      0.7764                         -0.0282
# 19999           1                      0.0961                          0.5947
#
#        tweet_political_polarisation_difference  \
# 19995                                   0.0000
# 19996                                   0.0000
# 19997                                   0.0000
# 19998                                   0.0000
# 19999                                   0.0000
#
#        tweet_science_polarisation_difference  \
# 19995                                 0.0000
# 19996                                 0.0000
# 19997                                 0.0000
# 19998                                 0.0000
# 19999                                 0.0000
#
#        tweet_moderacy_polarisation_difference
# 19995                                  0.0000
# 19996                                  0.0000
# 19997                                  0.0000
# 19998                                  0.0000
# 19999                                  0.0000

# %%
#features = features[2:94]
print(len(features))
features
# Out:
# 95
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_difference',
#        'tweet_political_polarisation_difference',
#        'tweet_science_polarisation_difference',
#        'tweet_moderacy_polarisation_difference'],
#       dtype='object')

# %%
#df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (20000, 89)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 89)
# (4000, 89)
# (16000,)
# (4000,)

# %%
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.612

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.56      0.60      2031
#            1       0.60      0.66      0.63      1969
#
#     accuracy                           0.61      4000
#    macro avg       0.61      0.61      0.61      4000
# weighted avg       0.61      0.61      0.61      4000

# %%
f_importances = features_classifier_(X, rf_model)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.0578
# 1      10                              readability      0.0369
# 2       8                                 Text_len      0.0350
# 3      84               user_vadercompound_average      0.0324
# 4      63                                     prep      0.0268
# 5       5                                vader_com      0.0249
# 6      68                                     verb      0.0246
# 7       3                                Vader_neu      0.0241
# 8      54                             focuspresent      0.0209
# 9      85           tweet_vadercompound_difference      0.0208
# 10     78                                    space      0.0206
# 11     16                                   social      0.0197
# 12      4                                Vader_pos      0.0188
# 13     64                                  auxverb      0.0187
# 14     62                                  article      0.0187
# 15     79                                     time      0.0179
# 16     61                                    ipron      0.0174
# 17     66                                     conj      0.0171
# 18      2                                Vader_neg      0.0168
# 19      0                                 Retweets      0.0161
# 20     65                                   adverb      0.0156
# 21     69                                      adj      0.0154
# 22      1                                Favorites      0.0153
# 23     53                                focuspast      0.0135
# 24     50                                    power      0.0133
# 25     21                                     work      0.0126
# 26      7                             Mentions_num      0.0119
# 27     37                                   posemo      0.0118
# 28     80              user_political_polarisation      0.0115
# 29     47                                   differ      0.0113
# 30     45                                   tentat      0.0112
# 31     73                                    quant      0.0112
# 32     70                                  compare      0.0110
# 33     77                                   motion      0.0109
# 34     42                                  insight      0.0107
# 35      6                             Hashtags_num      0.0105
# 36     48                              affiliation      0.0105
# 37     38                                   negemo      0.0103
# 38     43                                    cause      0.0101
# 39     46                                  certain      0.0097
# 40     51                                   reward      0.0091
# 41     71                                 interrog      0.0090
# 42     56                                        i      0.0090
# 43     49                                   achiev      0.0090
# 44     58                                      you      0.0088
# 45      9                                 URLs_num      0.0086
# 46     27                                 informal      0.0084
# 47     44                                  discrep      0.0084
# 48     82               user_moderacy_polarisation      0.0084
# 49     74                                      see      0.0082
# 50     12                               Emoji_sent      0.0082
# 51     55                              focusfuture      0.0082
# 52     81                user_science_polarisation      0.0076
# 53     67                                   negate      0.0074
# 54     22                                  leisure      0.0074
# 55     86  tweet_political_polarisation_difference      0.0074
# 56     34                                   health      0.0071
# 57     52                                     risk      0.0070
# 58     11                                Emoji_num      0.0066
# 59     40                                    anger      0.0065
# 60     60                                     they      0.0065
# 61     24                                    money      0.0064
# 62     57                                       we      0.0061
# 63     33                                     body      0.0060
# 64     20                                     male      0.0060
# 65     59                                    shehe      0.0057
# 66     88   tweet_moderacy_polarisation_difference      0.0056
# 67     87    tweet_science_polarisation_difference      0.0056
# 68     75                                     hear      0.0055
# 69     29                                 netspeak      0.0054
# 70     72                                   number      0.0053
# 71     23                                     home      0.0045
# 72     41                                      sad      0.0039
# 73     28                                    swear      0.0037
# 74     39                                      anx      0.0037
# 75     76                                     feel      0.0037
# 76     26                                    death      0.0037
# 77     19                                   female      0.0036
# 78     13               tweet_politic_polarisation      0.0035
# 79     36                                   ingest      0.0035
# 80     18                                   friend      0.0033
# 81     17                                   family      0.0028
# 82     35                                   sexual      0.0026
# 83     25                                 relegion      0.0024
# 84     15              tweet_moderacy_polarisation      0.0017
# 85     30                                   assent      0.0016
# 86     14               tweet_science_polarisation      0.0013
# 87     31                                   nonflu      0.0013
# 88     32                                   filler      0.0004

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
#pfad_model = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#rf_modell = pickle.load(open(pfad_modell, 'rb'))

# %%
clf_cv = RandomForestClassifier(n_estimators = 200 , random_state=5, n_jobs=-1)
print_cross_val_score(clf_cv, X_test, y_test)
# Out:
#  percision : 0.57 +/- 0.018
#  f1        : 0.58 +/- 0.023
#  recall    : 0.60 +/- 0.039

# %% [markdown]
# *****************************************************
# *****************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content + User)

# %%
def plot_hist_Features_kb(l_features_importances, l_features, titel):
    
    #colors = ['mediumorchid', 'gold', 'green', 'peru', 'red', 'mediumslateblue', 'deepskyblue', 'darkkhaki', 'brown']
    colors = ['steelblue','Black', 'peru', 'mediumslateblue', 'lightgreen']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
   #plt.legend()
    plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Reputation', 'Text l.', 'Readability', 'Sentiment', 'Verb']

# %%
plot_hist_Features_kb(l_features_importances, l_features, 'Rf_Tweetskb_content_User(reputation)_2_o_moderacy_all_del')

# %% [markdown]
# ***********************************************************************
# ***********************************************************************

# %% [markdown]
# ## Tweetskb
# ### Content only

# %%
features = df_tweetskb_user.columns
features

#features = features[2:83]
df_tweetskb_user = df_tweetskb_user[features.tolist()]
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_difference', 'tweet_political_polarisation_difference', 'tweet_science_polarisation_difference', 'tweet_moderacy_polarisation_difference'])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (20000, 80)
# (20000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 80)
# (4000, 80)
# (16000,)
# (4000,)

# %%
# %%time
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.5635
# Wall time: 728 ms

# %%
#pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Inhalt_alle_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
f_importances = features_classifier_(X, rf_model)
f_importances
# Out:
#     index                      Feature  importance
# 0       8                     Text_len      0.0720
# 1      10                  readability      0.0686
# 2       5                    vader_com      0.0396
# 3       3                    Vader_neu      0.0376
# 4       4                    Vader_pos      0.0299
# 5      62                      article      0.0283
# 6      67                       negate      0.0265
# 7       0                     Retweets      0.0237
# 8      16                       social      0.0237
# 9      53                    focuspast      0.0233
# 10      2                    Vader_neg      0.0225
# 11      1                    Favorites      0.0221
# 12     77                       motion      0.0205
# 13     63                         prep      0.0204
# 14     78                        space      0.0191
# 15     61                        ipron      0.0191
# 16     60                         they      0.0186
# 17     64                      auxverb      0.0179
# 18      7                 Mentions_num      0.0178
# 19     12                   Emoji_sent      0.0170
# 20     65                       adverb      0.0167
# 21     68                         verb      0.0165
# 22     37                       posemo      0.0157
# 23     11                    Emoji_num      0.0139
# 24     55                  focusfuture      0.0136
# 25     57                           we      0.0124
# 26     50                        power      0.0121
# 27     27                     informal      0.0120
# 28     48                  affiliation      0.0115
# 29     47                       differ      0.0114
# 30      6                 Hashtags_num      0.0106
# 31     42                      insight      0.0106
# 32     72                       number      0.0105
# 33     76                         feel      0.0105
# 34     21                         work      0.0103
# 35     38                       negemo      0.0103
# 36     45                       tentat      0.0101
# 37     51                       reward      0.0099
# 38     46                      certain      0.0097
# 39     69                          adj      0.0095
# 40     22                      leisure      0.0090
# 41     73                        quant      0.0089
# 42     43                        cause      0.0086
# 43     54                 focuspresent      0.0085
# 44     44                      discrep      0.0083
# 45     49                       achiev      0.0082
# 46     70                      compare      0.0079
# 47     29                     netspeak      0.0077
# 48     66                         conj      0.0075
# 49     33                         body      0.0071
# 50     20                         male      0.0068
# 51      9                     URLs_num      0.0067
# 52     74                          see      0.0061
# 53     71                     interrog      0.0060
# 54     24                        money      0.0059
# 55     58                          you      0.0058
# 56     40                        anger      0.0054
# 57     19                       female      0.0050
# 58     59                        shehe      0.0049
# 59     34                       health      0.0047
# 60     56                            i      0.0047
# 61     28                        swear      0.0046
# 62     75                         hear      0.0044
# 63     36                       ingest      0.0042
# 64     52                         risk      0.0042
# 65     17                       family      0.0039
# 66     18                       friend      0.0038
# 67     35                       sexual      0.0037
# 68     41                          sad      0.0036
# 69     23                         home      0.0032
# 70     25                     relegion      0.0028
# 71     26                        death      0.0025
# 72     30                       assent      0.0024
# 73     39                          anx      0.0023
# 74     31                       nonflu      0.0015
# 75     13   tweet_politic_polarisation      0.0012
# 76     15  tweet_moderacy_polarisation      0.0011
# 77     14   tweet_science_polarisation      0.0008
# 78     32                       filler      0.0004
# 79     79                         time      0.0000

# %%
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.59      0.58      2003
#            1       0.57      0.54      0.55      1997
#
#     accuracy                           0.56      4000
#    macro avg       0.56      0.56      0.56      4000
# weighted avg       0.56      0.56      0.56      4000

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
y_prob_test = rf_model.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.6967986912195782

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Inhalt_alle_ohne_moderacy.sav'
#rf_regression = pickle.load(open(pfad_modell, 'rb'))

# %%
# %%time
clf_cv
print_cross_val_score(clf_cv, X_test, y_test)
# Out:
#  percision : 0.57 +/- 0.015
#  f1        : 0.55 +/- 0.010
#  recall    : 0.54 +/- 0.015
# Wall time: 16.4 s

# %% [markdown]
# ***************************************************
# ***************************************************

# %% [markdown]
# ## Plot feature Imortances
# ### Tweetkb (Content Only )

# %%
def plot_hist_Features_content_only_kb(l_features_importances, l_features, titel):
    
    #colors = ['red', 'blue', 'peru', 'orange', 'yellow', 'mediumslateblue', 'deepskyblue', 'steelblue']
    colors = ['black', 'peru', 'mediumslateblue', 'lightblue', 'lightgreen']
    
    x = np.arange(len(l_features))
    #figure(figsize=(12, 8), dpi=80)
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    #ax.hist(df1, df2 = bins,  color = 'mediumslateblue', label = 'nicht gelöscht')
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    #ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    #ax.tick_params(axis='x', which='major', labelsize=14)
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
 
    #plt.legend()
    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Readability', 'Text l.', 'Retweets', 'Sentiment']

# %%
plot_hist_Features_content_only_kb(l_features_importances, l_features, 'Rf_Tweetskb_content_only_ohne_moderacy_alle_del')
