# %%
import csv
import pandas as pd
import numpy as np
import json
import jsonlines
import re
csv.field_size_limit(100000000)
from datetime import datetime
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, classification_report, log_loss
from sklearn.model_selection import cross_val_score

from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import KFold

try:
    from urllib.parse import urlparse
except ImportError:
     from urlparse import urlparse
# %matplotlib inline 

import matplotlib.dates as mdates
import matplotlib.ticker as tick

import warnings
warnings.filterwarnings("ignore")

pd.options.display.float_format = '{:.4f}'.format

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # **Logostic Regression**
# ## *(1) TweetsCov19*
# #### (Content + User Features)

# %%
path = '../data/df_tweetscov19_sample_200000_23.tsv'

df_tweetscov19_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung'])

print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1254069159098322947  4e8e74c47b8950e4b3954c86732007f6         0          0
# 1  1249258619562070019  bd41ec450084d9a16582b6fccbddcc9f         0          0
# 2  1244312339756834817  4de0b1281cf756ea9707014c816679a1         0          0
# 3  1182296312932384768  a28f24f00de6b0aebb557d27f9c51500         0          0
# 4  1240046019548721156  a52194236f9679e4183863c3583c6178         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     1.0000     0.0000     0.0000             0             0
# 1    -0.2710     0.7290     0.0000    -0.3818             0             0
# 2    -0.2100     0.4330     0.3570     0.3336             1             0
# 3    -0.0000     1.0000     0.0000     0.0000             0             0
# 4    -0.1310     0.8690     0.0000    -0.2755             0             1
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0        17         0      35.6050          0      0.0000
# 1        72         1      40.0900          0      0.0000
# 2        66         0      75.5000          1      0.0000
# 3        93         0      80.0980          2     -0.1710
# 4       111         1      61.2400          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 1                       0.0000  9.0900  0.0000  0.0000  0.0000 0.0000 9.0900
# 2                       0.0000  9.0900  0.0000  0.0000  0.0000 0.0000 0.0000
# 3                       0.0000 10.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 4                       0.0000 11.1100  0.0000  0.0000  0.0000 0.0000 5.5600
#
#    leisure   home  money  relegion  death  informal  swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
#
#    nonflu  filler   body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  9.0900 0.0000
# 2  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  9.0900 0.0000
# 3  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 4  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000  5.5600  0.0000 0.0000
#
#    anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1 9.0900 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  9.0900
# 2 0.0000 0.0000   0.0000 0.0000   9.0900  0.0000   0.0000  0.0000
# 3 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 4 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  5.5600
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 1       0.0000  9.0900 9.0900  0.0000 0.0000     0.0000        0.0000
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        9.0900
# 3       0.0000  0.0000 0.0000  0.0000 0.0000    10.0000       20.0000
# 4       0.0000  0.0000 5.5600  0.0000 0.0000     0.0000        5.5600
#
#    focusfuture      i     we    you  shehe   they   ipron  article    prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000  0.0000
# 1       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000  0.0000   0.0000  9.0900
# 2       0.0000 0.0000 0.0000 9.0900 0.0000 0.0000  0.0000   0.0000  0.0000
# 3       5.0000 0.0000 0.0000 5.0000 0.0000 0.0000 15.0000   0.0000 10.0000
# 4       0.0000 0.0000 0.0000 5.5600 0.0000 0.0000  0.0000   0.0000  0.0000
#
#    auxverb  adverb   conj  negate    verb     adj  compare  interrog  number  \
# 0   0.0000  0.0000 0.0000  0.0000 33.3300  0.0000   0.0000    0.0000  0.0000
# 1   0.0000  0.0000 0.0000  9.0900  0.0000  0.0000   0.0000    0.0000  0.0000
# 2   0.0000  9.0900 9.0900  0.0000  9.0900  0.0000   0.0000    0.0000  0.0000
# 3  10.0000  0.0000 5.0000  0.0000 30.0000  5.0000   5.0000    5.0000  0.0000
# 4   0.0000  5.5600 5.5600  5.5600  5.5600 11.1100   0.0000    5.5600  0.0000
#
#    quant    see   hear   feel  motion  space    time  \
# 0 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000 33.3300
# 1 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 2 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000  0.0000
# 3 0.0000 0.0000 5.0000 0.0000 10.0000 5.0000 10.0000
# 4 0.0000 0.0000 5.5600 0.0000  0.0000 5.5600 11.1100
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       1.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                      -1.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                     -1.0000                      10
# 2                      0.0000                       1
# 3                      0.0000                       1
# 4                     -1.0000                       5
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.6264        True
# 1                       10               1.0000           1.0000        True
# 2                        1               1.0000           0.4861        True
# 3                        1               1.0000           0.5193        True
# 4                        5               1.0000           0.2887        True
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.0000                          0.0000
# 1                      0.4501                         -0.8319
# 2                      0.3336                          0.0000
# 3                      0.0000                          0.0000
# 4                     -0.4939                          0.2184
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                  -1.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   1.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  1.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  1.0000

# %%
df_tweetscov19_user = df_tweetscov19_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id                          Username  Retweets  Favorites  \
# 0  1246504580831043584  977b0a25760290b01fc6f1bfab286b62         0          0
# 1  1220328877484101636  64d70257d2612ff0579001406159174e         0          0
# 2  1246819522729988099  312364856103d350ce5daa2e062d592d         0          0
# 3  1242733746354130944  25e3e3c547a1a0f82839a7e077db90ea         0          0
# 4  1240998453725052931  f6ed002fb4d115ba62126d16e4c4babc         0          0
#
#    Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  \
# 0    -0.0000     1.0000     0.0000     0.0000             0             0
# 1    -0.0000     0.8190     0.1810     0.7052             0             1
# 2    -0.0000     0.8760     0.1240     0.3400             2             0
# 3    -0.3260     0.4980     0.1760    -0.6486             0             1
# 4    -0.2220     0.5820     0.1960    -0.5707             0             0
#
#    Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 0        91         0      47.8330          0      0.0000
# 1       203         1      89.9810          0      0.0000
# 2       158         1      43.3810          1      0.2140
# 3        92         0      71.8150          0      0.0000
# 4       302         0      46.7630          0      0.0000
#
#    tweet_politic_polarisation  tweet_science_polarisation  \
# 0                      0.0000                      0.0000
# 1                      0.0000                      0.0000
# 2                      0.0000                      0.0000
# 3                      0.0000                      0.0000
# 4                      0.0000                      0.0000
#
#    tweet_moderacy_polarisation  social  family  friend  female   male   work  \
# 0                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 6.2500
# 1                       0.0000 10.5300  0.0000  2.6300  0.0000 2.6300 0.0000
# 2                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 3                       0.0000  6.2500  0.0000  0.0000  0.0000 0.0000 0.0000
# 4                       0.0000  3.7000  0.0000  0.0000  0.0000 0.0000 0.0000
#
#    leisure   home  money  relegion  death  informal   swear  netspeak  assent  \
# 0   0.0000 0.0000 0.0000    0.0000 6.2500    0.0000  0.0000    0.0000  0.0000
# 1   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000  0.0000    0.0000  0.0000
# 2   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000  0.0000    0.0000  0.0000
# 3   0.0000 0.0000 0.0000    0.0000 0.0000   12.5000 12.5000    0.0000  0.0000
# 4   0.0000 0.0000 0.0000    1.8500 0.0000    0.0000  0.0000    0.0000  0.0000
#
#    nonflu  filler    body  health  sexual  ingest  posemo  negemo    anx  \
# 0  0.0000  0.0000  6.2500  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 1  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 2  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 3  0.0000  0.0000 12.5000  6.2500  0.0000  0.0000  0.0000 25.0000 0.0000
# 4  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  1.8500  1.8500 1.8500
#
#     anger    sad  insight  cause  discrep  tentat  certain  differ  \
# 0  0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 1  0.0000 0.0000   2.6300 2.6300   5.2600  0.0000   2.6300  0.0000
# 2  0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  0.0000
# 3 12.5000 6.2500   0.0000 0.0000   0.0000  6.2500   0.0000  6.2500
# 4  0.0000 0.0000   0.0000 0.0000   0.0000  0.0000   0.0000  3.7000
#
#    affiliation  achiev  power  reward   risk  focuspast  focuspresent  \
# 0       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000       12.5000
# 1       2.6300  0.0000 0.0000  0.0000 0.0000     2.6300       13.1600
# 2       0.0000  0.0000 0.0000  0.0000 0.0000     0.0000        0.0000
# 3       0.0000  0.0000 0.0000  0.0000 6.2500     0.0000        6.2500
# 4       3.7000  0.0000 1.8500  0.0000 0.0000     1.8500        0.0000
#
#    focusfuture      i     we    you  shehe   they  ipron  article    prep  \
# 0       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 6.2500  12.5000 18.7500
# 1       2.6300 2.6300 0.0000 2.6300 2.6300 0.0000 2.6300   5.2600  7.8900
# 2       0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000  8.7000
# 3       0.0000 6.2500 0.0000 0.0000 0.0000 0.0000 6.2500   0.0000  0.0000
# 4       0.0000 0.0000 1.8500 0.0000 0.0000 0.0000 0.0000   3.7000  9.2600
#
#    auxverb  adverb   conj  negate    verb     adj  compare  interrog  number  \
# 0   6.2500  0.0000 0.0000  0.0000 12.5000  6.2500   0.0000    6.2500  6.2500
# 1   5.2600  5.2600 0.0000  0.0000 18.4200  5.2600   5.2600    0.0000  0.0000
# 2   0.0000  4.3500 0.0000  0.0000  0.0000  0.0000   0.0000    0.0000  0.0000
# 3   0.0000  6.2500 6.2500  6.2500  6.2500 12.5000   0.0000    0.0000  0.0000
# 4   0.0000  0.0000 5.5600  1.8500  1.8500  0.0000   0.0000    0.0000  0.0000
#
#    quant    see   hear   feel  motion   space   time  \
# 0 0.0000 0.0000 0.0000 0.0000  6.2500 12.5000 6.2500
# 1 2.6300 7.8900 2.6300 0.0000  0.0000  0.0000 5.2600
# 2 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 3 0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000
# 4 0.0000 0.0000 1.8500 0.0000  0.0000  0.0000 0.0000
#
#    user_political_polarisation  user_science_polarisation  \
# 0                       0.0000                     0.0000
# 1                       0.0000                     0.0000
# 2                       0.0000                     0.0000
# 3                       0.0000                     0.0000
# 4                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       2
# 2                      0.0000                       6
# 3                      0.0000                       1
# 4                      0.0000                       8
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.2083        True
# 1                        0               0.0000           0.3925       False
# 2                        0               0.0000           1.0000       False
# 3                        0               0.0000           0.5318       False
# 4                        8               1.0000           0.4971        True
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.0000                          0.0000
# 1                      0.3140                          0.3912
# 2                      0.4463                         -0.1063
# 3                     -0.6486                          0.0000
# 4                      0.0702                         -0.6409
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetscov19_del = df_tweetscov19_user[df_tweetscov19_user['Is_deleted']==True]
df_tweetscov19_undel = df_tweetscov19_user[df_tweetscov19_user['Is_deleted']==False]

# %%
def plot_paiplot(df, hue, titel): 
   
    #plt.rcParams["figure.figsize"] = [6,4]
    #fig, ax = plt.subplots()
    sns.pairplot(df, hue = hue)

    #ax.set_ylabel('Dataframe')

    #ax.set_xlabel('Deletion ratio', fontsize=12)
    #plt.margins(0.02)
    #fig.tight_layout()
    #plt.show()

    #plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/log_reg/'+titel+'.jpg')

# %%
df = df_tweetscov19_user[['Is_deleted', 'Retweets', 'vader_com', 'Favorites']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetsocv19_Retweet_favoriet_sentiment')

# %%
df = df_tweetscov19_user[['Is_deleted', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetsocv19_politic_science_moderacy')

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_abweichung',
#        'tweet_political_polarisation_abweichung',
#        'tweet_science_polarisation_abweichung',
#        'tweet_moderacy_polarisation_abweichung'],
#       dtype='object')

# %%
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 1, 0)

# %%
df_tweetscov19_user.tail()
# Out:
#                    Tweet_Id                          Username  Retweets  \
# 199995  1231892011579363329  99aee3a052c672c1680a9b59ff8f4500         0
# 199996  1263502454961864705  eaba92b6aefb7f85703e0c387586bf7c         0
# 199997  1202522559977328643  5cdb6dd75e22fac5618bfbdbde990333        32
# 199998  1229257133012783105  0a3b23a34f6c835857f9844982e0bbbc         0
# 199999  1261846157866737664  f3eb566126fe86e83761f2e8813fab4c         0
#
#         Favorites  Vader_neg  Vader_neu  Vader_pos  vader_com  Hashtags_num  \
# 199995          0    -0.0000     1.0000     0.0000     0.0000             1
# 199996          0    -0.1430     0.7140     0.1430     0.0000             0
# 199997        308    -0.1980     0.6650     0.1380    -0.3071             0
# 199998          0    -0.0740     0.6610     0.2650     0.7096             0
# 199999          0    -0.2990     0.7010     0.0000    -0.9442             0
#
#         Mentions_num  Text_len  URLs_num  readability  Emoji_num  Emoji_sent  \
# 199995             0        54         1      31.5450          0      0.0000
# 199996             0        71         0      95.4200          0      0.0000
# 199997             0       233         0      76.5850          0      0.0000
# 199998             1        75         0      84.8450          1      0.2210
# 199999             0       272         1      77.1050          0      0.0000
#
#         tweet_politic_polarisation  tweet_science_polarisation  \
# 199995                     -1.0000                      0.0000
# 199996                      0.0000                      0.0000
# 199997                      0.0000                      0.0000
# 199998                      0.0000                      0.0000
# 199999                      0.0000                      0.0000
#
#         tweet_moderacy_polarisation  social  family  friend  female   male  \
# 199995                      -1.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 199996                       0.0000 11.7600  0.0000  0.0000  0.0000 5.8800
# 199997                       0.0000  7.1400  0.0000  0.0000  0.0000 0.0000
# 199998                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
# 199999                       0.0000  0.0000  0.0000  0.0000  0.0000 0.0000
#
#          work  leisure   home  money  relegion  death  informal  swear  \
# 199995 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199996 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    5.8800 0.0000
# 199997 7.1400   2.3800 2.3800 0.0000    0.0000 0.0000    0.0000 0.0000
# 199998 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
# 199999 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000
#
#         netspeak  assent  nonflu  filler   body  health  sexual  ingest  \
# 199995    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199996    0.0000  5.8800  0.0000  0.0000 5.8800  0.0000  0.0000  0.0000
# 199997    0.0000  0.0000  0.0000  0.0000 0.0000  2.3800  0.0000  0.0000
# 199998    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 199999    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#         posemo  negemo    anx  anger    sad  insight  cause  discrep  tentat  \
# 199995  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 199996  5.8800  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000  0.0000
# 199997  4.7600  2.3800 0.0000 0.0000 2.3800   2.3800 4.7600   0.0000  2.3800
# 199998  6.6700  0.0000 0.0000 0.0000 0.0000   6.6700 0.0000   0.0000  0.0000
# 199999  0.0000  2.2700 0.0000 2.2700 0.0000   2.2700 2.2700   0.0000  2.2700
#
#         certain  differ  affiliation  achiev   power  reward   risk  \
# 199995   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000
# 199996   0.0000 11.7600       0.0000  0.0000  0.0000  0.0000 0.0000
# 199997   0.0000  2.3800       0.0000  7.1400 14.2900  7.1400 2.3800
# 199998   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000
# 199999   0.0000  0.0000       0.0000  0.0000  0.0000  0.0000 0.0000
#
#         focuspast  focuspresent  focusfuture      i     we    you  shehe  \
# 199995     0.0000       11.1100       0.0000 0.0000 0.0000 0.0000 0.0000
# 199996     5.8800       11.7600       0.0000 0.0000 0.0000 0.0000 5.8800
# 199997     4.7600        9.5200       0.0000 4.7600 0.0000 4.7600 0.0000
# 199998     0.0000        6.6700       0.0000 6.6700 0.0000 0.0000 0.0000
# 199999     0.0000        6.8200       0.0000 0.0000 0.0000 0.0000 0.0000
#
#          they   ipron  article    prep  auxverb  adverb    conj  negate  \
# 199995 0.0000  0.0000   0.0000  0.0000   0.0000  0.0000  0.0000  0.0000
# 199996 0.0000 11.7600   5.8800  5.8800   0.0000  5.8800 11.7600  5.8800
# 199997 0.0000  4.7600   2.3800  9.5200   4.7600  2.3800  7.1400  2.3800
# 199998 0.0000  6.6700   6.6700 20.0000   0.0000  0.0000  0.0000  0.0000
# 199999 0.0000  2.2700   6.8200  4.5500   2.2700  2.2700  2.2700  0.0000
#
#           verb    adj  compare  interrog  number  quant    see   hear   feel  \
# 199995 11.1100 0.0000   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000
# 199996 17.6500 5.8800   0.0000    0.0000  0.0000 0.0000 0.0000 5.8800 0.0000
# 199997 16.6700 7.1400   4.7600    0.0000  2.3800 0.0000 4.7600 0.0000 0.0000
# 199998  6.6700 6.6700   0.0000    0.0000  6.6700 0.0000 0.0000 0.0000 6.6700
# 199999  4.5500 4.5500   4.5500    0.0000  0.0000 2.2700 0.0000 0.0000 0.0000
#
#         motion   space   time  user_political_polarisation  \
# 199995  0.0000  0.0000 0.0000                      -1.0000
# 199996  5.8800  5.8800 5.8800                       0.0000
# 199997  0.0000 11.9000 4.7600                       0.0000
# 199998  0.0000  6.6700 6.6700                       0.0000
# 199999  0.0000  2.2700 2.2700                       0.0000
#
#         user_science_polarisation  user_moderacy_polarisation  \
# 199995                     0.0000                     -1.0000
# 199996                     0.0000                      0.0000
# 199997                     0.0000                      0.0000
# 199998                     0.0000                      0.0000
# 199999                     0.0000                      0.0000
#
#         user_num_posted_tweets  user_num_deleted_tweets  user_Deletion_ratio  \
# 199995                       1                        1               1.0000
# 199996                       3                        3               1.0000
# 199997                      52                        0               0.0000
# 199998                       2                        0               0.0000
# 199999                       3                        0               0.0000
#
#         user_Reputation  Is_deleted  user_vadercompound_average  \
# 199995           0.3463           1                      0.0000
# 199996           0.1265           1                      0.0963
# 199997           0.9701           0                      0.1511
# 199998           0.8567           0                      0.3548
# 199999           0.9864           0                     -0.0003
#
#         tweet_vadercompound_abweichung  \
# 199995                          0.0000
# 199996                          0.0000
# 199997                         -0.4582
# 199998                          0.3548
# 199999                         -0.9439
#
#         tweet_political_polarisation_abweichung  \
# 199995                                   0.0000
# 199996                                   0.0000
# 199997                                   0.0000
# 199998                                   0.0000
# 199999                                   0.0000
#
#         tweet_science_polarisation_abweichung  \
# 199995                                 0.0000
# 199996                                 0.0000
# 199997                                 0.0000
# 199998                                 0.0000
# 199999                                 0.0000
#
#         tweet_moderacy_polarisation_abweichung
# 199995                                  0.0000
# 199996                                  0.0000
# 199997                                  0.0000
# 199998                                  0.0000
# 199999                                  0.0000

# %%
#df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation','user_science_polarisation.','user_moderacy_polarisation'])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
def get_X_y(df, features):
    
    if 'Is_deleted' not in features:
        features = np.append(features, 'Is_deleted')
        
    df = df[features.tolist()]
    X = df.drop('Is_deleted', axis=1)
    y = df['Is_deleted']

    y = y.astype(int)
    print(X.shape)
    print(y.shape)
    
    return X,y

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %%
def fit_log_reg(X,y):
    l_regression = LogisticRegression(random_state=20, solver = 'lbfgs')
    l_regression.fit(X,y)
    return l_regression

# %%
def test_log_reg(model, X_test, y_test):
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
l_regression = fit_log_reg(X_train, y_train)

# %%
test_log_reg(l_regression, X_test,y_test)
# Out:
# Accuracy : 0.5963

# %%
y_pred = l_regression.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.63      0.61     19916
#            1       0.61      0.56      0.58     20084
#
#     accuracy                           0.60     40000
#    macro avg       0.60      0.60      0.60     40000
# weighted avg       0.60      0.60      0.60     40000

# %%
def plot_confusion_matrix(confu_matrix, classes, titel):
    sns.heatmap(confu_matrix, xticklabels = classes, yticklabels = classes, annot=True)
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
confusion_mx = confusion_matrix(y_test, y_pred)
confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
plot_confusion_matrix(confusion_mx, l_regression.classes_, 'Confusion Matrix')
print(confusion_mx)
# Out:
# [[0.62989556 0.37010444]
#  [0.43701454 0.56298546]]

# %%
def print_cross_val_score(model, X, y):
    scores = cross_val_score(model, X, y, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X, y, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
clf_cv = LogisticRegression(random_state=20, solver = 'lbfgs')
print_cross_val_score(clf_cv, X, y)
# Out:
#  percision : 0.61 +/- 0.004
#  f1        : 0.56 +/- 0.006
#  recall    : 0.53 +/- 0.009

# %% [markdown]
# ***

# %%
#Finding best DecisionTreeClassifier for detecting feature importances
param_grid = {'criterion':['gini','entropy'],
              'max_depth': range(1,10),
              'random_state' : [5, 10, 15],
              'min_samples_split' : range(1,10),
              'min_samples_leaf' : range(1,10)}

# %%
model = DecisionTreeClassifier()

DecisionTreeClassifier_clf = GridSearchCV(model, param_grid=param_grid, cv=5, verbose=True, n_jobs=-1)

# %%
# %%time
best_clf = DecisionTreeClassifier_clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 4374 candidates, totalling 21870 fits
# Wall time: 9min 24s

# %%
best_clf.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'random_state': 5}

# %% [markdown]
# ****

# %%
def features_classifier_tweetscov19(X, y):

    decisionTC = DecisionTreeClassifier(random_state=5, criterion= 'entropy', max_depth = 8, min_samples_leaf= 3, min_samples_split= 2 )
    decisionTC.fit(X,y)
    
    column_feature = {}

    for i, c in enumerate(X):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = decisionTC.feature_importances_[i]
        
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)
    
    return df_column_feature.reset_index()

# %%
f_importances = features_classifier_tweetscov19( X, y)
f_importances
# Out:
#     index                                  Feature  importance
# 0      82               user_moderacy_polarisation      0.3411
# 1      83                          user_Reputation      0.3101
# 2       9                                 URLs_num      0.0836
# 3       0                                 Retweets      0.0639
# 4       8                                 Text_len      0.0316
# 5      56                                        i      0.0281
# 6       6                             Hashtags_num      0.0212
# 7      80              user_political_polarisation      0.0173
# 8      84               user_vadercompound_average      0.0080
# 9      88   tweet_moderacy_polarisation_abweichung      0.0078
# 10     12                               Emoji_sent      0.0072
# 11     21                                     work      0.0072
# 12     27                                 informal      0.0065
# 13     81                user_science_polarisation      0.0058
# 14     35                                   sexual      0.0050
# 15     53                                focuspast      0.0045
# 16     28                                    swear      0.0035
# 17     63                                     prep      0.0027
# 18      2                                Vader_neg      0.0027
# 19     87    tweet_science_polarisation_abweichung      0.0022
# 20     85           tweet_vadercompound_abweichung      0.0022
# 21     11                                Emoji_num      0.0022
# 22      7                             Mentions_num      0.0020
# 23     61                                    ipron      0.0020
# 24     67                                   negate      0.0019
# 25     86  tweet_political_polarisation_abweichung      0.0018
# 26     10                              readability      0.0017
# 27     62                                  article      0.0016
# 28     68                                     verb      0.0016
# 29      1                                Favorites      0.0016
# 30     42                                  insight      0.0014
# 31     26                                    death      0.0012
# 32      5                                vader_com      0.0012
# 33     33                                     body      0.0012
# 34     78                                    space      0.0012
# 35      4                                Vader_pos      0.0011
# 36     69                                      adj      0.0011
# 37     66                                     conj      0.0009
# 38     58                                      you      0.0009
# 39     46                                  certain      0.0008
# 40     65                                   adverb      0.0008
# 41     76                                     feel      0.0008
# 42     50                                    power      0.0007
# 43     48                              affiliation      0.0007
# 44     29                                 netspeak      0.0006
# 45     43                                    cause      0.0006
# 46     79                                     time      0.0006
# 47     34                                   health      0.0006
# 48      3                                Vader_neu      0.0005
# 49     45                                   tentat      0.0005
# 50     19                                   female      0.0005
# 51     70                                  compare      0.0005
# 52     36                                   ingest      0.0005
# 53     72                                   number      0.0005
# 54     20                                     male      0.0004
# 55     60                                     they      0.0004
# 56     37                                   posemo      0.0004
# 57     64                                  auxverb      0.0003
# 58     49                                   achiev      0.0003
# 59     54                             focuspresent      0.0003
# 60     40                                    anger      0.0002
# 61     59                                    shehe      0.0000
# 62     75                                     hear      0.0000
# 63     13               tweet_politic_polarisation      0.0000
# 64     14               tweet_science_polarisation      0.0000
# 65     15              tweet_moderacy_polarisation      0.0000
# 66     16                                   social      0.0000
# 67     17                                   family      0.0000
# 68     18                                   friend      0.0000
# 69     22                                  leisure      0.0000
# 70     23                                     home      0.0000
# 71     24                                    money      0.0000
# 72     25                                 relegion      0.0000
# 73     77                                   motion      0.0000
# 74     30                                   assent      0.0000
# 75     74                                      see      0.0000
# 76     57                                       we      0.0000
# 77     73                                    quant      0.0000
# 78     31                                   nonflu      0.0000
# 79     71                                 interrog      0.0000
# 80     32                                   filler      0.0000
# 81     38                                   negemo      0.0000
# 82     39                                      anx      0.0000
# 83     41                                      sad      0.0000
# 84     47                                   differ      0.0000
# 85     51                                   reward      0.0000
# 86     52                                     risk      0.0000
# 87     55                              focusfuture      0.0000
# 88     44                                  discrep      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0.0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_moderacy_polarisation' 'user_Reputation' 'URLs_num' 'Retweets'
#  'Text_len' 'i' 'Hashtags_num' 'user_political_polarisation'
#  'user_vadercompound_average' 'tweet_moderacy_polarisation_abweichung'
#  'Emoji_sent' 'work' 'informal' 'user_science_polarisation' 'sexual'
#  'focuspast' 'swear' 'prep' 'Vader_neg'
#  'tweet_science_polarisation_abweichung' 'tweet_vadercompound_abweichung'
#  'Emoji_num' 'Mentions_num' 'ipron' 'negate'
#  'tweet_political_polarisation_abweichung' 'readability' 'article' 'verb'
#  'Favorites' 'insight' 'death' 'vader_com' 'body' 'space' 'Vader_pos'
#  'adj' 'conj' 'you' 'certain' 'adverb' 'feel' 'power' 'affiliation'
#  'netspeak' 'cause' 'time' 'health' 'Vader_neu' 'tentat' 'female'
#  'compare' 'ingest' 'number' 'male' 'they' 'posemo' 'auxverb' 'achiev'
#  'focuspresent' 'anger']

# %%
len(f_importances)
# Out:
# 61

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 61)
# (200000,)

# %% [markdown]
# ***

# %%
param_grid = [{'penalty': ['l1', 'l2', 'elasticnet', 'none']},
             {'C' : np.logspace(-4,4,20)},
             {'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'ag', 'saga']},
             {'max_iter' : [100, 200, 500, 1000, 2500, 5000]}]

# %%
l_regression_GridS = LogisticRegression()

clf = GridSearchCV(l_regression_GridS, param_grid=param_grid, cv=5, verbose=True, n_jobs=-1)

# %%
# %%time
best_clf = clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# Wall time: 1min 8s

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(solver='newton-cg')

# %%
best_clf.best_params_
# Out:
# {'solver': 'newton-cg'}

# %%
l_regression_best = LogisticRegression(solver='newton-cg')

print_cross_val_score(l_regression_best, X_new, y)
# Out:
#  percision : 0.61 +/- 0.003
#  f1        : 0.64 +/- 0.003
#  recall    : 0.68 +/- 0.004

# %%
l_regression_best = LogisticRegression(solver='newton-cg')

print_cross_val_score(l_regression_best, X, y)
# Out:
#  percision : 0.61 +/- 0.003
#  f1        : 0.64 +/- 0.003
#  recall    : 0.68 +/- 0.003

# %% [markdown]
# ****************************************************************************
# ****************************************************************************

# %% [markdown]
# ### Tweetscov19
# #### (Conten only)

# %%
features = df_tweetscov19_user.columns
features

#features = features[2:83]
df_tweetscov19_user = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])
df_tweetscov19_user = df_tweetscov19_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetscov19_user.columns
X,y = get_X_y(df_tweetscov19_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
f_importances = features_classifier_tweetscov19( X, y)
f_importances
# Out:
#     index                      Feature  importance
# 0       0                     Retweets      0.3411
# 1       9                     URLs_num      0.2241
# 2       8                     Text_len      0.0783
# 3      56                            i      0.0517
# 4       1                    Favorites      0.0464
# 5      27                     informal      0.0324
# 6      21                         work      0.0286
# 7      13   tweet_politic_polarisation      0.0275
# 8       6                 Hashtags_num      0.0242
# 9      63                         prep      0.0171
# 10      7                 Mentions_num      0.0160
# 11     14   tweet_science_polarisation      0.0101
# 12     10                  readability      0.0090
# 13     28                        swear      0.0081
# 14     35                       sexual      0.0072
# 15     11                    Emoji_num      0.0052
# 16     16                       social      0.0050
# 17     68                         verb      0.0049
# 18     29                     netspeak      0.0047
# 19      5                    vader_com      0.0044
# 20     12                   Emoji_sent      0.0032
# 21     71                     interrog      0.0032
# 22     58                          you      0.0027
# 23     61                        ipron      0.0026
# 24     15  tweet_moderacy_polarisation      0.0024
# 25      2                    Vader_neg      0.0024
# 26     75                         hear      0.0024
# 27     49                       achiev      0.0020
# 28     33                         body      0.0019
# 29     48                  affiliation      0.0018
# 30     62                      article      0.0016
# 31     78                        space      0.0016
# 32      3                    Vader_neu      0.0015
# 33     46                      certain      0.0013
# 34     31                       nonflu      0.0013
# 35     67                       negate      0.0012
# 36     43                        cause      0.0012
# 37     44                      discrep      0.0012
# 38     74                          see      0.0011
# 39     52                         risk      0.0011
# 40     72                       number      0.0010
# 41     54                 focuspresent      0.0009
# 42     51                       reward      0.0009
# 43     34                       health      0.0009
# 44     73                        quant      0.0009
# 45      4                    Vader_pos      0.0008
# 46     79                         time      0.0008
# 47     64                      auxverb      0.0007
# 48     59                        shehe      0.0007
# 49     53                    focuspast      0.0007
# 50     40                        anger      0.0007
# 51     20                         male      0.0006
# 52     45                       tentat      0.0006
# 53     19                       female      0.0006
# 54     55                  focusfuture      0.0006
# 55     37                       posemo      0.0006
# 56     50                        power      0.0005
# 57     60                         they      0.0005
# 58     69                          adj      0.0005
# 59     23                         home      0.0005
# 60     26                        death      0.0005
# 61     36                       ingest      0.0004
# 62     39                          anx      0.0004
# 63     77                       motion      0.0004
# 64     66                         conj      0.0004
# 65     47                       differ      0.0002
# 66     38                       negemo      0.0001
# 67     41                          sad      0.0000
# 68     17                       family      0.0000
# 69     76                         feel      0.0000
# 70     18                       friend      0.0000
# 71     42                      insight      0.0000
# 72     32                       filler      0.0000
# 73     22                      leisure      0.0000
# 74     30                       assent      0.0000
# 75     24                        money      0.0000
# 76     25                     relegion      0.0000
# 77     65                       adverb      0.0000
# 78     57                           we      0.0000
# 79     70                      compare      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0.0]
f_importances = f_importances.Feature.values

print(len(f_importances))
print(f_importances)
# Out:
# 67
# ['Retweets' 'URLs_num' 'Text_len' 'i' 'Favorites' 'informal' 'work'
#  'tweet_politic_polarisation' 'Hashtags_num' 'prep' 'Mentions_num'
#  'tweet_science_polarisation' 'readability' 'swear' 'sexual' 'Emoji_num'
#  'social' 'verb' 'netspeak' 'vader_com' 'Emoji_sent' 'interrog' 'you'
#  'ipron' 'tweet_moderacy_polarisation' 'Vader_neg' 'hear' 'achiev' 'body'
#  'affiliation' 'article' 'space' 'Vader_neu' 'certain' 'nonflu' 'negate'
#  'cause' 'discrep' 'see' 'risk' 'number' 'focuspresent' 'reward' 'health'
#  'quant' 'Vader_pos' 'time' 'auxverb' 'shehe' 'focuspast' 'anger' 'male'
#  'tentat' 'female' 'focusfuture' 'posemo' 'power' 'they' 'adj' 'home'
#  'death' 'ingest' 'anx' 'motion' 'conj' 'differ' 'negemo']

# %%
X_new,y = get_X_y(df_tweetscov19_user, f_importances)
# Out:
# (200000, 67)
# (200000,)

# %%
l_regression_best = LogisticRegression(solver='newton-cg')

print_cross_val_score(l_regression_best, X_new, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.62 +/- 0.003
#  recall    : 0.64 +/- 0.004

# %%
l_regression_best = LogisticRegression(solver='newton-cg')

print_cross_val_score(l_regression_best, X, y)
# Out:
#  percision : 0.60 +/- 0.003
#  f1        : 0.61 +/- 0.004
#  recall    : 0.63 +/- 0.005

# %% [markdown]
# ****************************************************************
# ****************************************************************

# %% [markdown]
# ## *(2)Tweetskb*
# ### (Content + User feature)

# %%
path = '../data/df_tweetskb_sample_200000_9.tsv'

df_tweetskb_user = pd.read_csv(path, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg', 'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num', 'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent', 'tweet_politic_polarisation', 'tweet_science_polarisation', 'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female', 'male' , 'work', 'leisure', 'home', 'money', 'relegion', 'death', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body', 'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ', 'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast', 'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear', 'feel', 'motion', 'space', 'time', 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio', 'user_Reputation', 'Is_deleted', 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])

print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (200000, 95)
#               Tweet_Id        Username  Retweets  Favorites  Vader_neg  \
# 0  1234468305332654080        cacamshx         1          1    -0.0000
# 1  1232807636535394304  GrammieJustice         0          0    -0.3550
# 2  1241798055826874368        gguksera         0          0    -0.0000
# 3  1185748472579780608         WTFMeqs         0          0    -0.0000
# 4  1247192242084884488         wavikee         1          4    -0.0000
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     1.0000     0.0000     0.0000             0             0        34
# 1     0.6450     0.0000    -0.5106             0             1        71
# 2     1.0000     0.0000     0.0000             0             0        35
# 3     1.0000     0.0000     0.0000             0             0        22
# 4     0.8330     0.1670     0.4588             0             1        68
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0     103.5400          1      0.0000                      0.0000
# 1         1       6.3590          0      0.0000                      0.0000
# 2         0      62.7900          0      0.0000                      0.0000
# 3         0     100.2400          0      0.0000                      0.0000
# 4         0      66.1000          4      0.3565                      0.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000 42.8600  0.0000
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000  0.0000  0.0000
# 3                      0.0000                       0.0000  0.0000  0.0000
# 4                      0.0000                       0.0000  9.0900  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  0.0000 14.2900 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000  14.2900
# 1  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 2  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 3  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000      14.2900  0.0000 0.0000  0.0000 0.0000
# 1  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 2  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 3  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
#
#    focuspast  focuspresent  focusfuture       i     we     you  shehe   they  \
# 0     0.0000        0.0000       0.0000 14.2900 0.0000 14.2900 0.0000 0.0000
# 1     0.0000        0.0000       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 2     0.0000        0.0000       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 3    16.6700        0.0000       0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 4    18.1800        0.0000       9.0900  0.0000 0.0000  0.0000 0.0000 9.0900
#
#     ipron  article    prep  auxverb  adverb   conj  negate   verb    adj  \
# 0  0.0000   0.0000 14.2900   0.0000  0.0000 0.0000 14.2900 0.0000 0.0000
# 1  0.0000  10.0000  0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 2 16.6700   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000 0.0000 0.0000
# 3  0.0000   0.0000 16.6700   0.0000  0.0000 0.0000 16.6700 0.0000 0.0000
# 4  0.0000   9.0900  0.0000   0.0000  0.0000 0.0000 18.1800 0.0000 0.0000
#
#    compare  interrog  number  quant    see   hear   feel  motion  space  \
# 0   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 1   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000 10.0000 0.0000
# 2   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 3   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 0.0000  0.0000 0.0000
# 4   0.0000    0.0000  0.0000 0.0000 0.0000 0.0000 9.0900  0.0000 0.0000
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                       0.0000                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       2
# 1                      0.0000                       3
# 2                      0.0000                       3
# 3                      0.0000                       1
# 4                      0.0000                       1
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        2               1.0000           0.5363        True
# 1                        3               1.0000           0.3613        True
# 2                        3               1.0000           0.5345        True
# 3                        1               1.0000           0.1919        True
# 4                        1               1.0000           0.1336        True
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.2107                          0.0000
# 1                     -0.0605                         -0.4501
# 2                      0.1027                          0.0000
# 3                      0.0000                          0.0000
# 4                      0.4588                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetskb_user = df_tweetskb_user.sample(frac=1).reset_index(drop=True)

print('Shape: ', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape:  (200000, 95)
#               Tweet_Id         Username  Retweets  Favorites  Vader_neg  \
# 0  1248860609476587521        MinaDawnn         0          0    -0.0000
# 1  1248082251511771136      artz_potato         0          0    -0.1640
# 2  1195732795169157126      KarlBroberg         0          0    -0.0800
# 3  1200747783151480832  Jeffrey_Addison         2          0    -0.0000
# 4  1226956561601515528          Ianbins        40        137    -0.0000
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     0.6190     0.3810     0.5106             0             2        59
# 1     0.8360     0.0000    -0.2411             0             1        60
# 2     0.7450     0.1760     0.4215             0             2       106
# 3     0.7890     0.2110     0.7579             4             0       215
# 4     1.0000     0.0000     0.0000             0             0       128
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0      75.5000          0      0.0000                      0.0000
# 1         0      87.9970          0      0.0000                      0.0000
# 2         0      42.5450          0      0.0000                      0.0000
# 3         0      58.8660          0      0.0000                      0.0000
# 4         1      59.1610          1      0.0180                      1.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000 25.0000  0.0000
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000 12.5000  0.0000
# 3                      0.0000                       0.0000  0.0000  0.0000
# 4                      0.0000                      -1.0000  0.0000  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 6.4500    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000  12.5000
# 1  0.0000  8.3300  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   8.3300
# 2  0.0000  6.2500  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   6.2500
# 3  0.0000  6.4500  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 1  8.3300   8.3300 16.6700       0.0000  0.0000 0.0000  0.0000 0.0000
# 2  6.2500   0.0000  0.0000       6.2500  0.0000 0.0000  0.0000 0.0000
# 3  0.0000   6.4500  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
#
#    focuspast  focuspresent  focusfuture      i      we    you  shehe    they  \
# 0    25.0000        0.0000      12.5000 0.0000 12.5000 0.0000 0.0000  0.0000
# 1     8.3300        0.0000       8.3300 0.0000  0.0000 0.0000 0.0000  8.3300
# 2    12.5000        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000 12.5000
# 3     0.0000        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000  0.0000
# 4     0.0000        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000  0.0000
#
#     ipron  article    prep  auxverb  adverb   conj  negate    verb    adj  \
# 0 12.5000   0.0000  0.0000   0.0000  0.0000 0.0000 25.0000  0.0000 0.0000
# 1  0.0000   8.3300  8.3300   8.3300  8.3300 8.3300  8.3300  0.0000 0.0000
# 2  0.0000  18.7500 12.5000   0.0000  0.0000 0.0000 18.7500 12.5000 0.0000
# 3  6.4500   9.6800  0.0000   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000
#
#    compare  interrog  number   quant    see   hear    feel  motion   space  \
# 0   0.0000    0.0000  0.0000 12.5000 0.0000 0.0000 12.5000  0.0000  0.0000
# 1   0.0000    8.3300  0.0000  0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
# 2   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000  6.2500  6.2500 12.5000
# 3   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000  3.2300  6.4500  0.0000
# 4   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                      -0.3333                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       3
# 2                      0.0000                       1
# 3                      0.0000                       3
# 4                     -1.0000                      23
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.4207        True
# 1                        3               1.0000           0.4000        True
# 2                        0               0.0000           0.8749       False
# 3                        0               0.0000           0.5827       False
# 4                        1               0.0435           0.8417       False
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.5106                          0.0000
# 1                      0.2467                         -0.4878
# 2                      0.4215                          0.0000
# 3                      0.4173                          0.3406
# 4                      0.0106                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   1.3333
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetskb_user.Username.unique().size
# Out:
# 191899

# %%
df_tweetskb_del = df_tweetskb_user[df_tweetskb_user['Is_deleted']==True]
df_tweetskb_undel = df_tweetskb_user[df_tweetskb_user['Is_deleted']==False]

# %%
df = df_tweetskb_user[['Is_deleted', 'Retweets', 'vader_com', 'Favorites']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetskb_Retweet_favoriet_sentiment')

# %%
df = df_tweetskb_user[['Is_deleted',  'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation']]
plot_paiplot(df, 'Is_deleted', 'pairplot_tweetskb_politic_science_moderacy')

# %%
features = df_tweetskb_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Retweets', 'Favorites', 'Vader_neg',
#        'Vader_neu', 'Vader_pos', 'vader_com', 'Hashtags_num', 'Mentions_num',
#        'Text_len', 'URLs_num', 'readability', 'Emoji_num', 'Emoji_sent',
#        'tweet_politic_polarisation', 'tweet_science_polarisation',
#        'tweet_moderacy_polarisation', 'social', 'family', 'friend', 'female',
#        'male', 'work', 'leisure', 'home', 'money', 'relegion', 'death',
#        'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'body',
#        'health', 'sexual', 'ingest', 'posemo', 'negemo', 'anx', 'anger', 'sad',
#        'insight', 'cause', 'discrep', 'tentat', 'certain', 'differ',
#        'affiliation', 'achiev', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'i', 'we', 'you', 'shehe', 'they',
#        'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate',
#        'verb', 'adj', 'compare', 'interrog', 'number', 'quant', 'see', 'hear',
#        'feel', 'motion', 'space', 'time', 'user_political_polarisation',
#        'user_science_polarisation', 'user_moderacy_polarisation',
#        'user_num_posted_tweets', 'user_num_deleted_tweets',
#        'user_Deletion_ratio', 'user_Reputation', 'Is_deleted',
#        'user_vadercompound_average', 'tweet_vadercompound_abweichung',
#        'tweet_political_polarisation_abweichung',
#        'tweet_science_polarisation_abweichung',
#        'tweet_moderacy_polarisation_abweichung'],
#       dtype='object')

# %%
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 1, 0)
df_tweetskb_user.head()
# Out:
#               Tweet_Id         Username  Retweets  Favorites  Vader_neg  \
# 0  1248860609476587521        MinaDawnn         0          0    -0.0000
# 1  1248082251511771136      artz_potato         0          0    -0.1640
# 2  1195732795169157126      KarlBroberg         0          0    -0.0800
# 3  1200747783151480832  Jeffrey_Addison         2          0    -0.0000
# 4  1226956561601515528          Ianbins        40        137    -0.0000
#
#    Vader_neu  Vader_pos  vader_com  Hashtags_num  Mentions_num  Text_len  \
# 0     0.6190     0.3810     0.5106             0             2        59
# 1     0.8360     0.0000    -0.2411             0             1        60
# 2     0.7450     0.1760     0.4215             0             2       106
# 3     0.7890     0.2110     0.7579             4             0       215
# 4     1.0000     0.0000     0.0000             0             0       128
#
#    URLs_num  readability  Emoji_num  Emoji_sent  tweet_politic_polarisation  \
# 0         0      75.5000          0      0.0000                      0.0000
# 1         0      87.9970          0      0.0000                      0.0000
# 2         0      42.5450          0      0.0000                      0.0000
# 3         0      58.8660          0      0.0000                      0.0000
# 4         1      59.1610          1      0.0180                      1.0000
#
#    tweet_science_polarisation  tweet_moderacy_polarisation  social  family  \
# 0                      0.0000                       0.0000 25.0000  0.0000
# 1                      0.0000                       0.0000  0.0000  0.0000
# 2                      0.0000                       0.0000 12.5000  0.0000
# 3                      0.0000                       0.0000  0.0000  0.0000
# 4                      0.0000                      -1.0000  0.0000  0.0000
#
#    friend  female   male   work  leisure   home  money  relegion  death  \
# 0  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 1  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 2  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
# 3  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 6.4500    0.0000 0.0000
# 4  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000
#
#    informal  swear  netspeak  assent  nonflu  filler   body  health  sexual  \
# 0    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 1    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 2    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 3    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
# 4    0.0000 0.0000    0.0000  0.0000  0.0000  0.0000 0.0000  0.0000  0.0000
#
#    ingest  posemo  negemo    anx  anger    sad  insight  cause  discrep  \
# 0  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000  12.5000
# 1  0.0000  8.3300  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   8.3300
# 2  0.0000  6.2500  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   6.2500
# 3  0.0000  6.4500  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
# 4  0.0000  0.0000  0.0000 0.0000 0.0000 0.0000   0.0000 0.0000   0.0000
#
#    tentat  certain  differ  affiliation  achiev  power  reward   risk  \
# 0  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 1  8.3300   8.3300 16.6700       0.0000  0.0000 0.0000  0.0000 0.0000
# 2  6.2500   0.0000  0.0000       6.2500  0.0000 0.0000  0.0000 0.0000
# 3  0.0000   6.4500  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000       0.0000  0.0000 0.0000  0.0000 0.0000
#
#    focuspast  focuspresent  focusfuture      i      we    you  shehe    they  \
# 0    25.0000        0.0000      12.5000 0.0000 12.5000 0.0000 0.0000  0.0000
# 1     8.3300        0.0000       8.3300 0.0000  0.0000 0.0000 0.0000  8.3300
# 2    12.5000        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000 12.5000
# 3     0.0000        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000  0.0000
# 4     0.0000        0.0000       0.0000 0.0000  0.0000 0.0000 0.0000  0.0000
#
#     ipron  article    prep  auxverb  adverb   conj  negate    verb    adj  \
# 0 12.5000   0.0000  0.0000   0.0000  0.0000 0.0000 25.0000  0.0000 0.0000
# 1  0.0000   8.3300  8.3300   8.3300  8.3300 8.3300  8.3300  0.0000 0.0000
# 2  0.0000  18.7500 12.5000   0.0000  0.0000 0.0000 18.7500 12.5000 0.0000
# 3  6.4500   9.6800  0.0000   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000
# 4  0.0000   0.0000  0.0000   0.0000  0.0000 0.0000  0.0000  0.0000 0.0000
#
#    compare  interrog  number   quant    see   hear    feel  motion   space  \
# 0   0.0000    0.0000  0.0000 12.5000 0.0000 0.0000 12.5000  0.0000  0.0000
# 1   0.0000    8.3300  0.0000  0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
# 2   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000  6.2500  6.2500 12.5000
# 3   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000  3.2300  6.4500  0.0000
# 4   0.0000    0.0000  0.0000  0.0000 0.0000 0.0000  0.0000  0.0000  0.0000
#
#     time  user_political_polarisation  user_science_polarisation  \
# 0 0.0000                       0.0000                     0.0000
# 1 0.0000                       0.0000                     0.0000
# 2 0.0000                       0.0000                     0.0000
# 3 0.0000                       0.0000                     0.0000
# 4 0.0000                      -0.3333                     0.0000
#
#    user_moderacy_polarisation  user_num_posted_tweets  \
# 0                      0.0000                       1
# 1                      0.0000                       3
# 2                      0.0000                       1
# 3                      0.0000                       3
# 4                     -1.0000                      23
#
#    user_num_deleted_tweets  user_Deletion_ratio  user_Reputation  Is_deleted  \
# 0                        1               1.0000           0.4207           1
# 1                        3               1.0000           0.4000           1
# 2                        0               0.0000           0.8749           0
# 3                        0               0.0000           0.5827           0
# 4                        1               0.0435           0.8417           0
#
#    user_vadercompound_average  tweet_vadercompound_abweichung  \
# 0                      0.5106                          0.0000
# 1                      0.2467                         -0.4878
# 2                      0.4215                          0.0000
# 3                      0.4173                          0.3406
# 4                      0.0106                          0.0000
#
#    tweet_political_polarisation_abweichung  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   1.3333
#
#    tweet_science_polarisation_abweichung  \
# 0                                 0.0000
# 1                                 0.0000
# 2                                 0.0000
# 3                                 0.0000
# 4                                 0.0000
#
#    tweet_moderacy_polarisation_abweichung
# 0                                  0.0000
# 1                                  0.0000
# 2                                  0.0000
# 3                                  0.0000
# 4                                  0.0000

# %%
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'Tweet_Id', 'Username', 'user_num_posted_tweets', 'user_num_deleted_tweets', 'user_Deletion_ratio'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 89)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 89)
# (40000, 89)
# (160000,)
# (40000,)

# %% [markdown]
# ***

# %%
#Finding best DecisionTreeClassifier for detecting the feature importances
param_grid = {'criterion':['gini','entropy'],
              'max_depth': range(1,10),
              'random_state' : [5, 10, 15],
              'min_samples_split' : range(1,10),
              'min_samples_leaf' : range(1,10)}

# %%
model = DecisionTreeClassifier()

DecisionTreeClassifier_clf = GridSearchCV(model, param_grid=param_grid, cv=5, verbose=True, n_jobs=-1)

# %%
# %%time
best_clf = DecisionTreeClassifier_clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 4374 candidates, totalling 21870 fits
# Wall time: 7min 31s

# %%
best_clf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 3,
#  'min_samples_split': 7,
#  'random_state': 10}

# %%
def features_classifier_tweetskb(X, y):

    decisionTC = DecisionTreeClassifier(random_state=10, criterion= 'gini', max_depth = 6, min_samples_leaf=3, min_samples_split=7)
    decisionTC.fit(X,y)
    
    column_feature = {}

    for i, c in enumerate(X):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = decisionTC.feature_importances_[i]
        
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)
    
    return df_column_feature.reset_index()

# %%
f_importances = features_classifier_tweetskb( X, y)
f_importances
# Out:
#     index                                  Feature  importance
# 0      83                          user_Reputation      0.4467
# 1      80              user_political_polarisation      0.1821
# 2      55                              focusfuture      0.1065
# 3       8                                 Text_len      0.0988
# 4      84               user_vadercompound_average      0.0501
# 5       9                                 URLs_num      0.0356
# 6      35                                   sexual      0.0198
# 7       7                             Mentions_num      0.0141
# 8       0                                 Retweets      0.0109
# 9       1                                Favorites      0.0099
# 10     27                                 informal      0.0068
# 11     29                                 netspeak      0.0056
# 12     61                                    ipron      0.0027
# 13     85           tweet_vadercompound_abweichung      0.0018
# 14     63                                     prep      0.0017
# 15      5                                vader_com      0.0012
# 16     52                                     risk      0.0012
# 17     43                                    cause      0.0010
# 18     65                                   adverb      0.0008
# 19     82               user_moderacy_polarisation      0.0007
# 20      6                             Hashtags_num      0.0006
# 21      2                                Vader_neg      0.0005
# 22     86  tweet_political_polarisation_abweichung      0.0004
# 23     41                                      sad      0.0002
# 24     10                              readability      0.0001
# 25      3                                Vader_neu      0.0001
# 26     59                                    shehe      0.0000
# 27     57                                       we      0.0000
# 28     60                                     they      0.0000
# 29     56                                        i      0.0000
# 30     54                             focuspresent      0.0000
# 31     62                                  article      0.0000
# 32     64                                  auxverb      0.0000
# 33     58                                      you      0.0000
# 34     72                                   number      0.0000
# 35     66                                     conj      0.0000
# 36     67                                   negate      0.0000
# 37     68                                     verb      0.0000
# 38     69                                      adj      0.0000
# 39     70                                  compare      0.0000
# 40     71                                 interrog      0.0000
# 41     73                                    quant      0.0000
# 42     74                                      see      0.0000
# 43     75                                     hear      0.0000
# 44     76                                     feel      0.0000
# 45     77                                   motion      0.0000
# 46     78                                    space      0.0000
# 47     79                                     time      0.0000
# 48     81                user_science_polarisation      0.0000
# 49     87    tweet_science_polarisation_abweichung      0.0000
# 50     53                                focuspast      0.0000
# 51     44                                  discrep      0.0000
# 52     51                                   reward      0.0000
# 53     26                                    death      0.0000
# 54     24                                    money      0.0000
# 55     23                                     home      0.0000
# 56     22                                  leisure      0.0000
# 57     21                                     work      0.0000
# 58     20                                     male      0.0000
# 59     19                                   female      0.0000
# 60     18                                   friend      0.0000
# 61     17                                   family      0.0000
# 62     16                                   social      0.0000
# 63     15              tweet_moderacy_polarisation      0.0000
# 64     14               tweet_science_polarisation      0.0000
# 65     13               tweet_politic_polarisation      0.0000
# 66     12                               Emoji_sent      0.0000
# 67     11                                Emoji_num      0.0000
# 68      4                                Vader_pos      0.0000
# 69     25                                 relegion      0.0000
# 70     28                                    swear      0.0000
# 71     50                                    power      0.0000
# 72     30                                   assent      0.0000
# 73     49                                   achiev      0.0000
# 74     48                              affiliation      0.0000
# 75     47                                   differ      0.0000
# 76     46                                  certain      0.0000
# 77     45                                   tentat      0.0000
# 78     42                                  insight      0.0000
# 79     40                                    anger      0.0000
# 80     39                                      anx      0.0000
# 81     38                                   negemo      0.0000
# 82     37                                   posemo      0.0000
# 83     36                                   ingest      0.0000
# 84     34                                   health      0.0000
# 85     33                                     body      0.0000
# 86     32                                   filler      0.0000
# 87     31                                   nonflu      0.0000
# 88     88   tweet_moderacy_polarisation_abweichung      0.0000

# %%
f_importances = f_importances[f_importances['importance']!=0.0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['user_Reputation' 'user_political_polarisation' 'focusfuture' 'Text_len'
#  'user_vadercompound_average' 'URLs_num' 'sexual' 'Mentions_num'
#  'Retweets' 'Favorites' 'informal' 'netspeak' 'ipron'
#  'tweet_vadercompound_abweichung' 'prep' 'vader_com' 'risk' 'cause'
#  'adverb' 'user_moderacy_polarisation' 'Hashtags_num' 'Vader_neg'
#  'tweet_political_polarisation_abweichung' 'sad' 'readability' 'Vader_neu']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 26)
# (200000,)

# %%
param_grid = [{'penalty': ['l1', 'l2', 'elasticnet', 'none']},
             {'C' : np.logspace(-4,4,20)},
             {'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'ag', 'saga']},
             {'max_iter' : [100, 200, 500, 1000, 2500, 5000]}]

# %%
l_regression_GridS = LogisticRegression()

best_clf = GridSearchCV(l_regression_GridS, param_grid=param_grid, cv=5, verbose=10, n_jobs=-1)

# %%
# %%time
best_clf = best_clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# Wall time: 59.5 s

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(max_iter=500)

# %%
l_regression_best = LogisticRegression(max_iter= 500)

print_cross_val_score(l_regression_best, X_new, y)
# Out:
#  percision : 0.57 +/- 0.004
#  f1        : 0.56 +/- 0.015
#  recall    : 0.56 +/- 0.030

# %%
l_regression_best = LogisticRegression(max_iter= 500)

print_cross_val_score(l_regression_best, X, y)
# Out:
#  percision : 0.57 +/- 0.003
#  f1        : 0.55 +/- 0.003
#  recall    : 0.53 +/- 0.004

# %% [markdown]
# **********************************************************************
# **********************************************************************

# %% [markdown]
# ### Tweetskb
# #### (Content only)

# %%
features = df_tweetskb_user.columns
features

#features = features[2:83]
df_tweetskb_user = df_tweetskb_user[features.tolist()]
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_vadercompound_average', 'tweet_vadercompound_abweichung', 'tweet_political_polarisation_abweichung', 'tweet_science_polarisation_abweichung', 'tweet_moderacy_polarisation_abweichung' ])
df_tweetskb_user = df_tweetskb_user.drop(columns=[ 'user_political_polarisation', 'user_science_polarisation', 'user_moderacy_polarisation', 'user_Reputation'])

# %%
features = df_tweetskb_user.columns
X,y = get_X_y(df_tweetskb_user, features)
# Out:
# (200000, 80)
# (200000,)

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (160000, 80)
# (40000, 80)
# (160000,)
# (40000,)

# %%
f_importances = features_classifier_tweetskb( X, y)
f_importances
# Out:
#     index                      Feature  importance
# 0       0                     Retweets      0.3301
# 1       9                     URLs_num      0.1068
# 2      55                  focusfuture      0.1044
# 3       8                     Text_len      0.0877
# 4      27                     informal      0.0681
# 5      35                       sexual      0.0635
# 6       1                    Favorites      0.0533
# 7       7                 Mentions_num      0.0419
# 8      62                      article      0.0360
# 9       5                    vader_com      0.0229
# 10     11                    Emoji_num      0.0221
# 11      6                 Hashtags_num      0.0193
# 12     29                     netspeak      0.0096
# 13     21                         work      0.0068
# 14     33                         body      0.0054
# 15     13   tweet_politic_polarisation      0.0044
# 16     45                       tentat      0.0029
# 17     12                   Emoji_sent      0.0026
# 18     10                  readability      0.0025
# 19     37                       posemo      0.0019
# 20     53                    focuspast      0.0017
# 21     65                       adverb      0.0014
# 22     56                            i      0.0012
# 23     72                       number      0.0011
# 24     58                          you      0.0011
# 25     42                      insight      0.0008
# 26     17                       family      0.0006
# 27     54                 focuspresent      0.0000
# 28     57                           we      0.0000
# 29     59                        shehe      0.0000
# 30     52                         risk      0.0000
# 31     60                         they      0.0000
# 32     67                       negate      0.0000
# 33     61                        ipron      0.0000
# 34     63                         prep      0.0000
# 35     64                      auxverb      0.0000
# 36     66                         conj      0.0000
# 37     50                        power      0.0000
# 38     68                         verb      0.0000
# 39     69                          adj      0.0000
# 40     70                      compare      0.0000
# 41     71                     interrog      0.0000
# 42     73                        quant      0.0000
# 43     74                          see      0.0000
# 44     75                         hear      0.0000
# 45     76                         feel      0.0000
# 46     77                       motion      0.0000
# 47     78                        space      0.0000
# 48     51                       reward      0.0000
# 49     40                        anger      0.0000
# 50     49                       achiev      0.0000
# 51     48                  affiliation      0.0000
# 52      2                    Vader_neg      0.0000
# 53      3                    Vader_neu      0.0000
# 54      4                    Vader_pos      0.0000
# 55     14   tweet_science_polarisation      0.0000
# 56     15  tweet_moderacy_polarisation      0.0000
# 57     16                       social      0.0000
# 58     18                       friend      0.0000
# 59     19                       female      0.0000
# 60     20                         male      0.0000
# 61     22                      leisure      0.0000
# 62     23                         home      0.0000
# 63     24                        money      0.0000
# 64     25                     relegion      0.0000
# 65     26                        death      0.0000
# 66     28                        swear      0.0000
# 67     30                       assent      0.0000
# 68     31                       nonflu      0.0000
# 69     32                       filler      0.0000
# 70     34                       health      0.0000
# 71     36                       ingest      0.0000
# 72     38                       negemo      0.0000
# 73     39                          anx      0.0000
# 74     41                          sad      0.0000
# 75     43                        cause      0.0000
# 76     44                      discrep      0.0000
# 77     46                      certain      0.0000
# 78     47                       differ      0.0000
# 79     79                         time      0.0000

# %%
f_importances = f_importances[f_importances['importance'] != 0.0]
f_importances = f_importances.Feature.values
print(f_importances)
# Out:
# ['Retweets' 'URLs_num' 'focusfuture' 'Text_len' 'informal' 'sexual'
#  'Favorites' 'Mentions_num' 'article' 'vader_com' 'Emoji_num'
#  'Hashtags_num' 'netspeak' 'work' 'body' 'tweet_politic_polarisation'
#  'tentat' 'Emoji_sent' 'readability' 'posemo' 'focuspast' 'adverb' 'i'
#  'number' 'you' 'insight' 'family']

# %%
X_new,y = get_X_y(df_tweetskb_user, f_importances)
# Out:
# (200000, 27)
# (200000,)

# %%
l_regression_best = LogisticRegression(max_iter= 500)

print_cross_val_score(l_regression_best, X_new, y)
# Out:
#  percision : 0.56 +/- 0.004
#  f1        : 0.56 +/- 0.003
#  recall    : 0.55 +/- 0.005

# %%
l_regression_best = LogisticRegression(max_iter= 500)

print_cross_val_score(l_regression_best, X, y)
# Out:
#  percision : 0.57 +/- 0.003
#  f1        : 0.55 +/- 0.003
#  recall    : 0.54 +/- 0.004
